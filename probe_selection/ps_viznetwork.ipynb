# %%
library(targets)

# %%
tar_visnetwork()
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6      ✔ dplyr   1.0.10
# ✔ tibble  3.1.8      ✔ stringr 1.4.1
# ✔ readr   2.1.2      ✔ forcats 0.5.2
# ✔ purrr   0.3.4
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Loading required package: SummarizedExperiment
# Loading required package: MatrixGenerics
# Loading required package: matrixStats
#
# Attaching package: ‘matrixStats’
#
# The following object is masked from ‘package:dplyr’:
#
#     count
#
#
# Attaching package: ‘MatrixGenerics’
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
# ...

# %%
sct_var_feats = qs::qread('_targets/objects/sct_var_feats_10k')
sct_var_feats
# Out:
#     [1] "Gpc5"           "Slc4a4"         "St18"           "Il1rapl2"
#     [5] "Col25a1"        "Trpm3"          "Col23a1"        "Adarb2"
#     [9] "Slc1a2"         "Sox6"           "Zfp804b"        "Nhsl1"
#    [13] "Pdzrn3"         "Unc13c"         "Slit2"          "Galntl6"
#    [17] "Npas3"          "Slc1a3"         "Hs3st4"         "Qk"
#    [21] "Nfia"           "Nxph1"          "Cntn5"          "Slc7a11"
#    [25] "Prex2"          "Chl1"           "Zeb2"           "Ebf1"
#    [29] "Tafa1"          "Bcas1"          "Tll1"           "Grik1"
#    [33] "Lhfp"           "Foxp2"          "Npsr1"          "Cdh20"
#    [37] "Slc39a12"       "Nrg1"           "Htr2c"          "Plp1"
#    [41] "Cntn4"          "Etnppl"         "Kcnip4"         "Plce1"
#    [45] "Erbb4"          "Plcl1"          "Mobp"           "P3h2"
#    [49] "Tafa4"          "Rgs6"           "Sprr2a2"        "Atp13a4"
#    [53] "Scn7a"          "Fgf13"          "Cdc14a"         "Pitpnc1"
# ...

# %%
length(sct_var_feats)
# Out:
# [1] 10000
