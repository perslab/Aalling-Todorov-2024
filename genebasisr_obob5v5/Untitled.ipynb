# %%
library(targets)
library(visNetwork)
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6      ✔ purrr   0.3.4
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.2      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
options(jupyter.plot_scale=1)

# %%
source('../genebasisr/genebasisr.R')
# Out:
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘matrixStats’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     count
#
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
# ...

# %%
options(repr.plot.width=5, repr.plot.height=5)
plotof_name = 'all_n1xo_nosct__select_batch.cell_class___eval.all_n1xo_nosct__predict.cell_class__eval_batch.cell_class'
plot_path = paste0('_targets/objects/plotof_ctm_100_batched_', plotof_name)
p = qs::qread(plot_path)
p
# Out:
# plot without title

# %%
options(repr.plot.width=10, repr.plot.height=10)
plotof_name = 'all_n1xo_nosct__select_batch.cell_class___eval.all_n1xo_nosct__predict.labels__eval_batch.cell_class'
plot_path = paste0('_targets/objects/plotof_ctm_100_batched_', plotof_name)
p = qs::qread(plot_path)
p
# Out:
# plot without title

# %%
options(repr.plot.width=10, repr.plot.height=10)
plotof_name = 'all_n1xo_nosct__select_batch.cell_class___eval.other__predict.labels__eval_batch.none'
plot_path = paste0('_targets/objects/plotof_ctm_100_batched_', plotof_name)
p = qs::qread(plot_path)
p
# Out:
# Error in qs::qread(plot_path): Failed to open _targets/objects/plotof_ctm_100_batched_all_n1xo_nosct__select_batch.cell_class___eval.other__predict.labels__eval_batch.none. Check file path.
# Traceback:
#
# 1. qs::qread(plot_path)

# %%
options(repr.plot.width=10, repr.plot.height=10)
plotof_name = 'all_n1xo_nosct__select_batch.cell_class___eval.all_n1xo_nosct__predict.labels__eval_batch.cell_class'
plot_path = paste0('_targets/objects/plotof_ctm_100_batched_', plotof_name)
p = qs::qread(plot_path)
p
# Out:
# plot without title

# %%
options(repr.plot.width=10, repr.plot.height=10)
plotof_name = 'all_n1xo_nosct__select_batch.cell_class___eval.all_n1xo_nosct__predict.labels__eval_batch.none'
plot_path = paste0('_targets/objects/plotof_ctm_100_batched_', plotof_name)
p = qs::qread(plot_path)
p
# Out:
# plot without title

# %%
options(repr.plot.width=10, repr.plot.height=10)
plotof_name = 'all_n1xo_nosct__select_batch.none___eval.all_n1xo_nosct__predict.labels__eval_batch.cell_class'
plot_path = paste0('_targets/objects/plotof_ctm_100_batched_', plotof_name)
p = qs::qread(plot_path)
p
# Out:
# plot without title

# %%
options(repr.plot.width=10, repr.plot.height=10)
plotof_name = 'all_n1xo_nosct__select_batch.none___eval.all_n1xo_nosct__predict.labels__eval_batch.none'
plot_path = paste0('_targets/objects/plotof_ctm_100_batched_', plotof_name)
p = qs::qread(plot_path)
p
# Out:
# plot without title

# %%
options(repr.plot.width=10, repr.plot.height=10)
plotof_name = 'all_n1xo_nosct__select_batch.cell_class___eval.other__predict.labels__eval_batch.none'
plot_path = paste0('_targets/objects/plotof_ctm_100_batched_', plotof_name)
p = qs::qread(plot_path)
p
# Out:
# plot without title

# %%
options(repr.plot.width=10, repr.plot.height=10)
plotof_name = 'all_n1xo_nosct__select_batch.cell_class___eval.other__predict.polar_label__eval_batch.none'
plot_path = paste0('_targets/objects/plotof_ctm_100_batched_', plotof_name)
p = qs::qread(plot_path)
p
# Out:
# plot without title

# %%
options(repr.plot.width=10, repr.plot.height=10)
plotof_name = 'all_n1xo_nosct__select_batch.none___eval.other__predict.polar_label__eval_batch.none'
plot_path = paste0('_targets/objects/plotof_ctm_100_batched_', plotof_name)
p = qs::qread(plot_path)
p
# Out:
# plot without title

# %%
options(repr.plot.width=10, repr.plot.height=10)
# plotof_name = 'all_n1xo_nosct__select_batch.cell_class___eval.other__predict.polar_label__eval_batch.none'
plotof_name = 'litgenes_all_n1xo_nosct__select_batch.cell_class___eval.other__predict.polar_label__eval_batch.none'
plot_path = paste0('_targets/objects/plotof_ctm_100_batched_', plotof_name)
p = qs::qread(plot_path)
p
# Out:
# plot without title

# %%
options(repr.plot.width=10, repr.plot.height=10)
plotof_name = 'litgenes_all_n1xo_nosct__select_batch.none___eval.other__predict.polar_label__eval_batch.none'
plot_path = paste0('_targets/objects/plotof_ctm_100_batched_', plotof_name)
p = qs::qread(plot_path)
p
# Out:
# plot without title

# %%
options(repr.plot.width=10, repr.plot.height=10)
plot_path = '_targets/objects/plotof_ctm_100_gs85_gs85_litgenes_other__select_batch.none___eval.other__predict.polar_label__eval_batch.none'
# plotof_name = 'litgenes_all_n1xo_nosct__select_batch.none___eval.other__predict.polar_label__eval_batch.none'
# plot_path = paste0('_targets/objects/plotof_ctm_100_batched_', plotof_name)
p = qs::qread(plot_path)
p
# Out:
# plot without title

# %%
options(repr.plot.width=10, repr.plot.height=10)
plot_path = '_targets/objects/plotof_ctm_100_batched_all_n1xo__select_batch.none___eval.all_n1xo__predict.polar_label__eval_batch.none'
# plotof_name = 'litgenes_all_n1xo_nosct__select_batch.none___eval.other__predict.polar_label__eval_batch.none'
# plot_path = paste0('_targets/objects/plotof_ctm_100_batched_', plotof_name)
p = qs::qread(plot_path)
p
# Out:
# plot without title

# %%
options(repr.plot.width=10, repr.plot.height=10)
plot_path = '_targets/objects/plotof_ctm_100_gs85_gs85_litgenes_other__select_batch.none___eval.all_n1xo__predict.polar_label__eval_batch.none'
# plotof_name = 'litgenes_all_n1xo_nosct__select_batch.none___eval.other__predict.polar_label__eval_batch.none'
# plot_path = paste0('_targets/objects/plotof_ctm_100_batched_', plotof_name)
p = qs::qread(plot_path)
p
# Out:
# plot without title

# %%
sce_name = "sce_00_other"
sce_path = paste0('_targets/objects/', sce_name)
sce = qs::qread(sce_path)
sce
# Out:
# class: SingleCellExperiment
# dim: 22618 13594
# metadata(0):
# assays(2): counts logcounts
# rownames(22618): Lypla1 Tcea1 ... ENSMUSG00000095041 ENSMUSG00000100896
# rowData names(0):
# colnames(13594): GTCCTCAAGCGAGGAG_1_1 CTTCGGTTCAGCTGAT_1_1 ...
#   TTAATCCGTGATAGTA_5_3 TCACTCGAGGATACCG_5_3
# colData names(37): orig.ident nCount_RNA ... polar_label ident
# reducedDimNames(2): PCA UMAP
# mainExpName: SCT
# altExpNames(2): RNA integrated

# %%
meta = colData(sce) %>% data.frame

# %%
lib_stat_name = 'litgenes_all_n1xo_nosct__select_batch.none___eval.other__predict.polar_label__eval_batch.none'
# lib_stat_path = paste0('_targets/objects/lib_stat_batched_litgenes_all_n1xo_nosct__select_batch.none___eval.other__predict.polar_label__eval_batch.none')
lib_stat_path = paste0('_targets/objects/lib_stat_batched_', lib_stat_name)
lib_stat = qs::qread(lib_stat_path)

# %%
n_genes_total=100
cell_score_stat = lib_stat$cell_score_stat[lib_stat$cell_score_stat$n_genes == n_genes_total , ] 
cell_score_stat = merge(cell_score_stat, meta) 

p = ggplot(cell_score_stat , aes(x = celltype , y = cell_score, fill = celltype)) + 
  geom_boxplot() + 
  scale_fill_manual(values = celltype_colors) + 
  theme_classic() + 
  labs(y = "Cell neighborhood preservation score" , x = "# genes") + 
  theme(legend.position = "none") + 
  theme(axis.text.x = element_text(angle = 90, hjust = 1, vjust = 0.5)) 
p

# %%
22
