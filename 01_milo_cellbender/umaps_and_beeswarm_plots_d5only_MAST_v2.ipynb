# %%
library(Seurat)
library(tidyverse)
library(ggplot2)
library(ggrepel)
library(ggbeeswarm)
library(patchwork)
library(miloR)
options(ggrepel.max.overlaps = Inf)

# %%
source('milo_cellbender.R')

# %%
obj_neuron = qs::qread('_targets_MAST_v2/objects/exp_labelled_neuron') %>%
             set_labels_to_lvl1 %>%
             #set_batch_to_lane %>% # do not set batch to lane for cluster splits
             prep_obj_for_milo_cb_v01 
obj_neuron
# Out:
# An object of class Seurat
# 29128 features across 104587 samples within 2 assays
# Active assay: integrated (2000 features, 2000 variable features)
#  2 layers present: data, scale.data
#  1 other assay present: RNA
#  2 dimensional reductions calculated: pca, umap

# %%
DimPlot(obj_neuron)
# Out:
# Rasterizing points since number of points exceeds 100,000.
# To disable this behavior set `raster=FALSE`
# plot without title

# %%
obj_other = qs::qread('_targets_MAST_v2/objects/exp_labelled_other') %>%
             set_labels_to_lvl1 %>%
             #set_batch_to_lane %>% # do not set batch to lane for cluster splits
             prep_obj_for_milo_cb_v01 
obj_other
# Out:
# An object of class Seurat
# 25033 features across 29782 samples within 2 assays
# Active assay: integrated (2000 features, 2000 variable features)
#  2 layers present: data, scale.data
#  1 other assay present: RNA
#  2 dimensional reductions calculated: pca, umap

# %%
DimPlot(obj_other)
# Out:
# plot without title

# %%
labels_classes_tib = (obj_other@meta.data %>% select(labels) %>% mutate(class = 'other') %>% tibble %>% distinct(labels, class)) %>%
bind_rows(obj_neuron@meta.data %>% select(labels) %>% mutate(class = 'neuron') %>% tibble %>% distinct(labels, class)) %>%
mutate(labels = str_replace(labels, fixed('-'), '__'))

# %%
umap_coords_neuron = obj_neuron %>%
`@`('reductions') %>%
`$`('umap') %>%
`@`('cell.embeddings') %>%
as.data.frame %>%
rownames_to_column('cell_barcode')

umap_coords_neuron %>% head
# Out:
#   cell_barcode               umap_1    umap_2
# 1 SI-TT-A11_AAACCCAAGGTGGTTG  1.060039  -9.89935829
# 2 SI-TT-A11_AAACCCACATACAGCT  4.324369   1.16208909
# 3 SI-TT-A11_AAACCCACATGAGGGT  4.696438  -3.14927985
# 4 SI-TT-A11_AAACCCAGTACGTTCA  1.344125 -13.86531212
# 5 SI-TT-A11_AAACCCATCCAAGCAT -5.445605  12.35118530
# 6 SI-TT-A11_AAACCCATCCCATAAG -9.186716   0.09222025

# %%
umap_coords_other = obj_other %>%
`@`('reductions') %>%
`$`('umap') %>%
`@`('cell.embeddings') %>%
as.data.frame %>%
rownames_to_column('cell_barcode')

umap_coords_other %>% head
# Out:
#   cell_barcode               umap_1    umap_2
# 1 SI-TT-A11_AAACCCAGTATCGGTT -3.457507  10.322045
# 2 SI-TT-A11_AAACGAAAGGTTCTTG  5.005185 -13.727981
# 3 SI-TT-A11_AAACGAACAAGGAGTC -3.099344  -3.947226
# 4 SI-TT-A11_AAACGAACAGCCTTCT -2.956816  -3.160569
# 5 SI-TT-A11_AAACGCTAGTGCTAGG -2.045796   7.196627
# 6 SI-TT-A11_AAAGGATTCAACCCGG  2.649539  10.880517

# %%
ambiguous_cells = intersect(umap_coords_neuron %>% pull(cell_barcode), umap_coords_other %>% pull(cell_barcode))
ambiguous_cells %>% length
# Out:
# [1] 0

# %%
umap_coords_neuron = umap_coords_neuron %>% filter(!(cell_barcode %in% ambiguous_cells))
umap_coords_other = umap_coords_other %>% filter(!(cell_barcode %in% ambiguous_cells))
umap_coords = bind_rows(umap_coords_neuron, umap_coords_other)
umap_coords %>% dim
# Out:
# [1] 134369      3

# %%
# da_results_restored = qs::qread('_targets_MAST_v2/objects/combined_da_results_nhg_all.obob5v5__v__all.obobBL6')
da_results_restored = qs::qread('_targets_MAST_v2/objects/combined_da_results_nhg_Day5.obob5v5__v__Day5.obobBL6d5')
# column_to_rownames('hash.mcl.ID')

dim(da_results_restored)
da_results_restored %>% head
# Out:
# [1] 13135    18
#   logFC    logCPM   F        PValue       FDR         Nhood SpatialFDR
# 1 3.786202 13.32846 28.65605 1.203665e-05 0.002250854 127   0.002451558
# 2 2.942268 13.13703 22.75446 5.730611e-05 0.003109848  18   0.003257913
# 3 3.762935 13.18959 23.36177 4.837156e-05 0.003109848  19   0.003257913
# 4 3.207390 13.03162 21.31327 8.646514e-05 0.003109848  41   0.003257913
# 5 2.281578 12.96570 21.49272 8.208911e-05 0.003109848  90   0.003257913
# 6 4.542154 13.16189 22.97615 9.978122e-05 0.003109848 144   0.003257913
#   polarity labels labels_fraction comparison                      restored
# 1 pos      Agrp   1               Day5.obob5v5__v__Day5.obobBL6d5  TRUE
# 2 pos      Agrp   1               Day5.obob5v5__v__Day5.obobBL6d5  TRUE
# 3 pos      Agrp   1               Day5.obob5v5__v__Day5.obobBL6d5  TRUE
# 4 pos      Agrp   1               Day5.obob5v5__v__Day5.obobBL6d5  TRUE
# 5 pos      Agrp   1               Day5.obob5v5__v__Day5.obobBL6d5 FALSE
# 6 pos      Agrp   1               Day5.obob5v5__v__Day5.obobBL6d5  TRUE
#   exact_grouping restored_grouping fgf1_grouping bl6_grouping
# 1 pos_restored   pos_restored      pos           neg
# 2 pos_restored   pos_restored      pos           neg
# 3 pos_restored   pos_restored      pos           neg
# 4 pos_restored   pos_restored      pos           neg
# 5 pos_FGF1       pos_FGF1          pos           none
# 6 pos_restored   pos_restored      pos           neg
#   hash.mcl.ID                n_cells
# 1 SI-TT-E10_GCAGGCTGTGGACAGT 89
# 2 SI-TT-C11_GTGTAACTCTTCCCGA 85
# 3 SI-TT-H10_ACATCGACAAGACTGG 80
# 4 SI-TT-C12_GTTGAACAGTAGTCTC 79
# 5 SI-TT-E11_TTGTGTTGTTACGATC 80
# 6 SI-TT-A11_TTCTAGTGTGGAAATT 76

# %%
# da_results_bl6 = qs::qread('_targets_MAST_v2/objects/combined_da_results_idx_all.obobBL6') %>%
da_results_bl6 = qs::qread('_targets_MAST_v2/objects/combined_da_results_idx_Day5.obobBL6d5') %>%
rename(n_cells = n_cells.x) %>%
select(-n_cells.y) %>%
mutate(polarity = case_when(polarity == 'none' ~ 'none',
                            polarity == 'pos' ~ 'neg',
                            polarity == 'neg' ~ 'pos')) %>%
mutate(logFC = -logFC)


dim(da_results_bl6)
da_results_bl6 %>% head
# Out:
# [1] 13135    12
#   logFC    logCPM   F        PValue       FDR          Nhood SpatialFDR
# 1 8.664499 13.47266 366.3092 2.235582e-12 4.180538e-10  32   2.446212e-10
# 2 8.004429 12.98563 159.7132 1.608347e-11 9.960091e-10  30   7.224227e-10
# 3 8.548313 13.37556 285.4091 1.480124e-11 9.960091e-10 103   7.224227e-10
# 4 7.256882 13.18602 155.1263 2.130501e-11 9.960091e-10  57   8.031479e-10
# 5 7.109636 13.02557 139.3101 5.962089e-11 1.164549e-09  55   9.548138e-10
# 6 7.104301 13.02050 137.2741 6.856719e-11 1.164549e-09  83   9.548138e-10
#   polarity labels labels_fraction n_cells hash.mcl.ID
# 1 pos      Agrp   1               92      SI-TT-A12_TGATGCAGTGCTGATT
# 2 pos      Agrp   1               63      SI-TT-A11_CATCGTCCAAGTGATA
# 3 pos      Agrp   1               86      SI-TT-G10_GGCACGTAGCCTGACC
# 4 pos      Agrp   1               75      SI-TT-H10_GTAATCGTCTCGACCT
# 5 pos      Agrp   1               66      SI-TT-E11_GCTACCTCATCCGATA
# 6 pos      Agrp   1               66      SI-TT-C11_CCTCATGAGGTCGTGA

# %%
da_results_fgf1 = qs::qread('_targets_MAST_v2/objects/combined_da_results_idx_Day5.obob5v5') %>%
rename(n_cells = n_cells.x) %>%
select(-n_cells.y)


dim(da_results_fgf1)
da_results_fgf1 %>% head
# Out:
# [1] 13135    12
#   logFC    logCPM   F        PValue       FDR         Nhood SpatialFDR
# 1 3.786202 13.32846 28.65605 1.203665e-05 0.002250854 127   0.002451558
# 2 2.942268 13.13703 22.75446 5.730611e-05 0.003109848  18   0.003257913
# 3 3.762935 13.18959 23.36177 4.837156e-05 0.003109848  19   0.003257913
# 4 3.207390 13.03162 21.31327 8.646514e-05 0.003109848  41   0.003257913
# 5 2.281578 12.96570 21.49272 8.208911e-05 0.003109848  90   0.003257913
# 6 4.542154 13.16189 22.97615 9.978122e-05 0.003109848 144   0.003257913
#   polarity labels labels_fraction n_cells hash.mcl.ID
# 1 pos      Agrp   1               89      SI-TT-E10_GCAGGCTGTGGACAGT
# 2 pos      Agrp   1               85      SI-TT-C11_GTGTAACTCTTCCCGA
# 3 pos      Agrp   1               80      SI-TT-H10_ACATCGACAAGACTGG
# 4 pos      Agrp   1               79      SI-TT-C12_GTTGAACAGTAGTCTC
# 5 pos      Agrp   1               80      SI-TT-E11_TTGTGTTGTTACGATC
# 6 pos      Agrp   1               76      SI-TT-A11_TTCTAGTGTGGAAATT

# %%
da_results_2 = full_join(da_results_fgf1, da_results_bl6, by=c('Nhood', 'labels'), suffix = c('_fgf1', '_bl6'))
da_results_2 %>% head
# Out:
#   logFC_fgf1 logCPM_fgf1 F_fgf1   PValue_fgf1  FDR_fgf1    Nhood
# 1 3.786202   13.32846    28.65605 1.203665e-05 0.002250854 127
# 2 2.942268   13.13703    22.75446 5.730611e-05 0.003109848  18
# 3 3.762935   13.18959    23.36177 4.837156e-05 0.003109848  19
# 4 3.207390   13.03162    21.31327 8.646514e-05 0.003109848  41
# 5 2.281578   12.96570    21.49272 8.208911e-05 0.003109848  90
# 6 4.542154   13.16189    22.97615 9.978122e-05 0.003109848 144
#   SpatialFDR_fgf1 polarity_fgf1 labels labels_fraction_fgf1 ⋯ logFC_bl6
# 1 0.002451558     pos           Agrp   1                    ⋯  6.716506
# 2 0.003257913     pos           Agrp   1                    ⋯  3.192094
# 3 0.003257913     pos           Agrp   1                    ⋯  6.461479
# 4 0.003257913     pos           Agrp   1                    ⋯  3.153802
# 5 0.003257913     pos           Agrp   1                    ⋯ -1.020584
# 6 0.003257913     pos           Agrp   1                    ⋯  8.146953
#   logCPM_bl6 F_bl6      PValue_bl6   FDR_bl6      SpatialFDR_bl6 polarity_bl6
# 1 13.32846   98.9882688 1.691103e-10 1.756868e-09 1.521349e-09   pos
# 2 13.13703   18.4248083 2.056099e-04 5.340146e-04 4.726740e-04   pos
# 3 13.18959   74.0789103 3.367667e-09 1.880265e-08 1.715807e-08   pos
# 4 13.03162   12.4463870 1.529748e-03 2.466059e-03 2.251006e-03   pos
# 5 12.96570    0.9013692 3.508883e-01 3.645340e-01 3.606322e-01   none
# 6 13.16189   97.0751771 2.718156e-09 1.588422e-08 1.451895e-08   pos
#   labels_fraction_bl6 n_cells_bl6 hash.mcl.ID_bl6
# 1 1                   89          SI-TT-E10_GCAGGCTGTGGACAGT
# 2 1                   85          SI-TT-C11_GTGTAACTCTTCCCGA
# 3 1                   80          SI-TT-H10_ACATCGACAAGACTGG
# 4 1                   79          SI-TT-C12_GTTGAACAGTAGTCTC
# 5 1                   80          SI-TT-E11_TTGTGTTGTTACGATC
# 6 1                   76          SI-TT-A11_TTCTAGTGTGGAAATT

# %%
da_results = da_results_restored %>% full_join(da_results_2, by=c('Nhood', 'labels')) %>%
mutate(exact_grouping = case_when(is.na(exact_grouping) & (polarity_bl6 != 'none') ~ paste0(polarity_bl6, '_BL6'),
                                  is.na(exact_grouping) & (polarity_bl6 == 'none') ~ paste0(polarity_bl6),
                                  TRUE ~ exact_grouping)) %>%
mutate(n_cells = n_cells_fgf1) %>%
left_join(labels_classes_tib, by='labels') %>%
mutate(cell_barcode = hash.mcl.ID_fgf1) %>%
relocate(cell_barcode, .after='hash.mcl.ID') %>%
select(-all_of(c("hash.mcl.ID", "hash.mcl.ID_fgf1", "hash.mcl.ID_bl6"))) %>%
left_join(umap_coords, by='cell_barcode') %>%
mutate(polarity_bl6 = case_when(logFC_bl6 > 0 & SpatialFDR_bl6 < 0.1 ~ 'pos',
                                logFC_bl6 < 0 & SpatialFDR_bl6 < 0.1 ~ 'neg',
                                TRUE ~ 'none')) %>%
mutate(polarity_fgf1 = case_when(logFC_fgf1 > 0 & SpatialFDR_fgf1 < 0.1 ~ 'pos',
                                logFC_fgf1 < 0 & SpatialFDR_fgf1 < 0.1 ~ 'neg',
                                TRUE ~ 'none'))

da_results %>% dim
da_results %>% head
# Out:
# [1] 13135    39
#   logFC    logCPM   F        PValue       FDR         Nhood SpatialFDR
# 1 3.786202 13.32846 28.65605 1.203665e-05 0.002250854 127   0.002451558
# 2 2.942268 13.13703 22.75446 5.730611e-05 0.003109848  18   0.003257913
# 3 3.762935 13.18959 23.36177 4.837156e-05 0.003109848  19   0.003257913
# 4 3.207390 13.03162 21.31327 8.646514e-05 0.003109848  41   0.003257913
# 5 2.281578 12.96570 21.49272 8.208911e-05 0.003109848  90   0.003257913
# 6 4.542154 13.16189 22.97615 9.978122e-05 0.003109848 144   0.003257913
#   polarity labels labels_fraction ⋯ F_bl6      PValue_bl6   FDR_bl6
# 1 pos      Agrp   1               ⋯ 98.9882688 1.691103e-10 1.756868e-09
# 2 pos      Agrp   1               ⋯ 18.4248083 2.056099e-04 5.340146e-04
# 3 pos      Agrp   1               ⋯ 74.0789103 3.367667e-09 1.880265e-08
# 4 pos      Agrp   1               ⋯ 12.4463870 1.529748e-03 2.466059e-03
# 5 pos      Agrp   1               ⋯  0.9013692 3.508883e-01 3.645340e-01
# 6 pos      Agrp   1               ⋯ 97.0751771 2.718156e-09 1.588422e-08
#   SpatialFDR_bl6 polarity_bl6 labels_fraction_bl6 n_cells_bl6 class  umap_1
# 1 1.521349e-09   pos          1                   89          neuron 3.216700
# 2 4.726740e-04   pos          1                   85          neuron 3.556380
# 3 1.715807e-08   pos          1                   80          neuron 3.986626
# 4 2.251006e-03   pos          1                   79          neuron 3.500047
# 5 3.606322e-01   none         1                   80          neuron 3.647344
# 6 1.451895e-08   pos          1                   76          neuron 2.933367
#   umap_2
# 1 -13.25480
# 2 -13.47460
# 3 -12.99642
# 4 -14.23880
# 5 -14.31736
# 6 -13.35223

# %%
da_results_restored
# Out:
#       logFC        logCPM   F            PValue       FDR         Nhood
# 1      3.786202    13.32846 28.656051    1.203665e-05 0.002250854 127
# 2      2.942268    13.13703 22.754456    5.730611e-05 0.003109848  18
# 3      3.762935    13.18959 23.361771    4.837156e-05 0.003109848  19
# 4      3.207390    13.03162 21.313274    8.646514e-05 0.003109848  41
# 5      2.281578    12.96570 21.492719    8.208911e-05 0.003109848  90
# 6      4.542154    13.16189 22.976154    9.978122e-05 0.003109848 144
# 7      3.281324    13.11102 20.154829    1.215300e-04 0.003246587  94
# 8      2.190297    12.91682 19.004608    1.607876e-04 0.003758410  43
# 9      2.232338    12.92793 17.986971    2.357006e-04 0.004530297  10
# 10    -2.113340    12.75363 18.333261    2.422619e-04 0.004530297  61
# 11     2.229784    13.13098 16.742127    3.311167e-04 0.005628984  17
# 12     4.608721    13.06989 16.328077    5.972579e-04 0.009307269  92
# 13     1.728437    13.07687 14.655234    6.692558e-04 0.009626988 174
# 14    -2.979977    12.71060 14.970263    7.401313e-04 0.009886040  53
# 15     1.965402    13.01143 12.681030    1.404795e-03 0.017513112  25
# 16     1.598634    12.70144 12.051867    1.705923e-03 0.019937973 152
# 17     1.445080    13.30772 11.951188    1.834784e-03 0.020182627 182
# 18     3.860889    13.05132 12.515298    1.969199e-03 0.020457785 147
# 19     3.758573    12.92182 11.842584    2.469880e-03 0.024308815  99
# 20    -2.332134    12.61238 11.100489    2.805219e-03 0.026228799   8
# 21     1.309210    12.90580 10.046794    3.690703e-03 0.031370972  31
# 22    -2.512402    12.73542 10.440799    3.581868e-03 0.031370972  38
# 23     1.322083    12.81318  9.606675    4.769657e-03 0.034304841  34
# 24     1.264606    13.37804  9.474273    4.761359e-03 0.034304841 122
# 25    -1.580696    12.86395  9.786481    4.590552e-03 0.034304841 157
# 26     1.439531    13.05218  9.549683    4.504083e-03 0.034304841 177
# 27    -1.557372    12.91548  9.315095    5.509455e-03 0.036197967  89
# 28    -1.310016    12.85751  9.312370    5.354558e-03 0.036197967  91
# 29    -1.590968    12.75765  9.193083    5.613589e-03 0.036197967 181
# 30    -1.376960    12.97234  8.769009    6.200849e-03 0.038539866  35
# ⋮     ⋮            ⋮        ⋮            ⋮            ⋮           ⋮
# 13106 -0.266796407 14.21091 3.285984e-01 0.5711257    0.7890552    94
# 13107  0.343447443 13.93837 4.533797e-01 0.6193344    0.8287473    24
# 13108 -0.243754715 14.23521 2.636230e-01 0.6117267    0.8287473    28
# 13109  0.254614158 14.14599 2.464242e-01 0.6235337    0.8287473    69
# 13110  0.255872484 14.10864 2.294279e-01 0.6357204    0.8335186     4
# 13111 -0.239890197 13.81614 2.196317e-01 0.6430001    0.8335186    82
# 13112 -0.206316530 13.92653 1.660573e-01 0.6867824    0.8420828    32
# 13113  0.275005183 14.29257 3.452411e-01 0.6902265    0.8420828    62
# 13114 -0.231784578 14.13666 2.014832e-01 0.6570299    0.8413187    64
# 13115 -0.193001336 14.02059 1.741218e-01 0.7018408    0.8420828    66
# 13116 -0.178034446 14.16026 1.455496e-01 0.7057456    0.8420828    75
# 13117 -0.215624510 14.25112 1.663790e-01 0.6864962    0.8420828    76
# 13118 -0.222157932 13.82275 1.829614e-01 0.6721586    0.8420828    88
# 13119 -0.165812123 14.31244 1.074855e-01 0.7454985    0.8795207    11
# 13120  0.173580004 13.80408 8.924251e-02 0.7673794    0.8878510     8
# 13121  0.195174253 13.99344 1.617343e-01 0.7694709    0.8878510    60
# 13122 -0.141415249 14.08513 7.381976e-02 0.7878757    0.8992060   104
# 13123  0.174211636 14.02025 1.150898e-01 0.8062356    0.9005824    15
# 13124 -0.132713245 13.90026 6.439159e-02 0.8015651    0.9005824    27
# 13125  0.111500983 14.27988 4.863936e-02 0.8270708    0.9141309    20
# 13126 -0.095274951 14.29266 4.310928e-02 0.8370436    0.9155164    43
# 13127  0.202374176 13.97158 1.506149e-01 0.8494504    0.9195082     2
# 13128  0.135448087 13.74217 5.374614e-02 0.8887273    0.9522078    99
# 13129 -0.070327921 13.92983 1.275340e-02 0.9109025    0.9661087    68
# 13130  0.086214248 13.80653 7.555285e-03 0.9315555    0.9766985    90
# 13131  0.041033508 14.04715 5.868181e-03 0.9394910    0.9766985    93
# 13132  0.016893507 14.06106 9.366549e-04 0.9758049    0.9902161    21
# 13133  0.014533618 13.94737 5.906525e-04 0.9807855    0.9902161    34
# 13134  0.175507151 13.94642 1.140997e-01 0.9784412    0.9902161    78
# 13135 -0.001452656 14.17135 6.724219e-07 0.9993516    0.9993516    59
#       SpatialFDR  polarity labels    labels_fraction
# 1     0.002451558 pos      Agrp      1
# 2     0.003257913 pos      Agrp      1
# 3     0.003257913 pos      Agrp      1
# 4     0.003257913 pos      Agrp      1
# 5     0.003257913 pos      Agrp      1
# 6     0.003257913 pos      Agrp      1
# 7     0.003378598 pos      Agrp      1
# 8     0.003867592 pos      Agrp      1
# 9     0.004761925 pos      Agrp      1
# 10    0.004761925 neg      Agrp      1
# 11    0.005909762 pos      Agrp      1
# 12    0.009851248 pos      Agrp      1
# 13    0.010205708 pos      Agrp      1
# 14    0.010663375 neg      Agrp      1
# 15    0.018847324 pos      Agrp      1
# 16    0.022297335 pos      Agrp      1
# 17    0.022644377 pos      Agrp      1
# 18    0.023014594 pos      Agrp      1
# 19    0.027596663 pos      Agrp      1
# 20    0.029974941 neg      Agrp      1
# 21    0.036013713 pos      Agrp      1
# 22    0.036013713 neg      Agrp      1
# 23    0.039231792 pos      Agrp      1
# 24    0.039231792 pos      Agrp      1
# 25    0.039231792 neg      Agrp      1
# 26    0.039231792 pos      Agrp      1
# 27    0.040239546 neg      Agrp      1
# 28    0.040239546 neg      Agrp      1
# 29    0.040239546 neg      Agrp      1
# 30    0.042468333 neg      Agrp      1
# ⋮     ⋮           ⋮        ⋮         ⋮
# 13106 0.7974299   none     Trh__Lef1 1
# 13107 0.8364371   none     Trh__Lef1 1
# 13108 0.8364371   none     Trh__Lef1 1
# 13109 0.8364371   none     Trh__Lef1 1
# 13110 0.8416962   none     Trh__Lef1 1
# 13111 0.8418791   none     Trh__Lef1 1
# 13112 0.8445063   none     Trh__Lef1 1
# 13113 0.8445063   none     Trh__Lef1 1
# 13114 0.8445063   none     Trh__Lef1 1
# 13115 0.8445063   none     Trh__Lef1 1
# 13116 0.8445063   none     Trh__Lef1 1
# 13117 0.8445063   none     Trh__Lef1 1
# 13118 0.8445063   none     Trh__Lef1 1
# 13119 0.8818268   none     Trh__Lef1 1
# 13120 0.8920277   none     Trh__Lef1 1
# 13121 0.8920277   none     Trh__Lef1 1
# 13122 0.9026038   none     Trh__Lef1 1
# 13123 0.9035050   none     Trh__Lef1 1
# 13124 0.9035050   none     Trh__Lef1 1
# 13125 0.9150076   none     Trh__Lef1 1
# 13126 0.9150076   none     Trh__Lef1 1
# 13127 0.9195864   none     Trh__Lef1 1
# 13128 0.9525701   none     Trh__Lef1 1
# 13129 0.9673155   none     Trh__Lef1 1
# 13130 0.9775033   none     Trh__Lef1 1
# 13131 0.9775033   none     Trh__Lef1 1
# 13132 0.9908880   none     Trh__Lef1 1
# 13133 0.9908880   none     Trh__Lef1 1
# 13134 0.9908880   none     Trh__Lef1 1
# 13135 0.9993516   none     Trh__Lef1 1
#       comparison                      restored exact_grouping restored_grouping
# 1     Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 2     Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 3     Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 4     Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 5     Day5.obob5v5__v__Day5.obobBL6d5 FALSE    pos_FGF1       pos_FGF1
# 6     Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 7     Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 8     Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 9     Day5.obob5v5__v__Day5.obobBL6d5 FALSE    pos_FGF1       pos_FGF1
# 10    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    neg_restored   neg_restored
# 11    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 12    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 13    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 14    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    neg_restored   neg_restored
# 15    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 16    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 17    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 18    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 19    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 20    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    neg_restored   neg_restored
# 21    Day5.obob5v5__v__Day5.obobBL6d5 FALSE    pos_away       pos_away
# 22    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    neg_restored   neg_restored
# 23    Day5.obob5v5__v__Day5.obobBL6d5 FALSE    pos_away       pos_away
# 24    Day5.obob5v5__v__Day5.obobBL6d5 FALSE    pos_FGF1       pos_FGF1
# 25    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    neg_restored   neg_restored
# 26    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 27    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    neg_restored   neg_restored
# 28    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    neg_restored   neg_restored
# 29    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    neg_restored   neg_restored
# 30    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    neg_restored   neg_restored
# ⋮     ⋮                               ⋮        ⋮              ⋮
# 13106 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13107 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13108 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13109 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13110 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13111 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13112 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13113 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13114 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13115 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13116 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13117 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13118 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13119 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13120 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13121 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13122 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13123 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13124 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13125 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13126 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13127 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13128 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13129 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13130 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13131 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13132 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13133 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13134 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 13135 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
#       fgf1_grouping bl6_grouping hash.mcl.ID                n_cells
# 1     pos           neg          SI-TT-E10_GCAGGCTGTGGACAGT  89
# 2     pos           neg          SI-TT-C11_GTGTAACTCTTCCCGA  85
# 3     pos           neg          SI-TT-H10_ACATCGACAAGACTGG  80
# 4     pos           neg          SI-TT-C12_GTTGAACAGTAGTCTC  79
# 5     pos           none         SI-TT-E11_TTGTGTTGTTACGATC  80
# 6     pos           neg          SI-TT-A11_TTCTAGTGTGGAAATT  76
# 7     pos           neg          SI-TT-E11_GTGATGTTCCACGTGG  83
# 8     pos           neg          SI-TT-H10_TGTCCCAGTTACAGCT  73
# 9     pos           none         SI-TT-A12_GAGAGGTTCCTCAGGG  75
# 10    neg           pos          SI-TT-G10_TGCGATATCTGAGAAA  75
# 11    pos           neg          SI-TT-H10_TGTTGGAGTAGCTTTG  83
# 12    pos           neg          SI-TT-E11_CATTCTACAAGCAATA  71
# 13    pos           neg          SI-TT-A12_CCTTCAGGTGAATTAG  86
# 14    neg           pos          SI-TT-B12_CCTGTTGCATATCTGG  63
# 15    pos           neg          SI-TT-E11_TTTACCACACTGGATT  82
# 16    pos           neg          SI-TT-A11_TTCCAATCACTATCCC  60
# 17    pos           neg          SI-TT-C11_CAGATTGAGACGGAAA 108
# 18    pos           neg          SI-TT-C11_TGCATCCGTTAAACCC  68
# 19    pos           neg          SI-TT-G10_TACGGTATCAAAGGAT  62
# 20    neg           pos          SI-TT-C12_AAGTTCGCAGGCAATG  61
# 21    pos           pos          SI-TT-G10_TACCCACGTCGTGATT  80
# 22    neg           pos          SI-TT-B12_GCGATCGCAGTACTAC  66
# 23    pos           pos          SI-TT-H10_TGGGTTAGTTCTCGTC  72
# 24    pos           none         SI-TT-G10_AGTGTTGGTCTAGGTT 119
# 25    neg           pos          SI-TT-H10_ACAAAGATCCATATGG  82
# 26    pos           neg          SI-TT-E10_TCGACGGGTTCGATTG  81
# 27    neg           pos          SI-TT-C11_TGATGGTAGTTCCGTA  89
# 28    neg           pos          SI-TT-A11_GCCATGGCAACCGACC  85
# 29    neg           pos          SI-TT-C11_TCAATTCTCCCACAGG  77
# 30    neg           pos          SI-TT-E11_CTGCATCAGGAACTCG  91
# ⋮     ⋮             ⋮            ⋮                          ⋮
# 13106 none          none         SI-TT-C11_GTCACTCAGCATATGA  99
# 13107 none          none         SI-TT-E11_TGTAACGAGATGAAGG  72
# 13108 none          none         SI-TT-A11_GCCGATGGTACCTTCC  99
# 13109 none          none         SI-TT-G11_TCAAGTGTCCGTGACG  87
# 13110 none          none         SI-TT-C11_GTATTGGGTGAATAAC  91
# 13111 none          none         SI-TT-C11_AGTGCCGGTATGATCC  67
# 13112 none          none         SI-TT-C11_GCCAGCAGTAGGTGCA  74
# 13113 none          none         SI-TT-F11_CATGCCTGTGCATGTT 102
# 13114 none          none         SI-TT-C11_AACCAACAGATTGCGG  88
# 13115 none          none         SI-TT-G11_TCGCTTGTCAAATGCC  78
# 13116 none          none         SI-TT-G11_TCTATACAGGTTAAAC  94
# 13117 none          none         SI-TT-F11_GTAACCACAGACCATT  94
# 13118 none          none         SI-TT-D11_AGCCAGCCACTTACAG  65
# 13119 none          none         SI-TT-D11_ACTTCCGGTAACATGA 107
# 13120 none          none         SI-TT-E10_CCTCATGGTGAGCCAA  64
# 13121 none          none         SI-TT-C11_GCTGGGTAGTCTTCGA  83
# 13122 none          none         SI-TT-E11_CCTCCTCTCGTACACA  85
# 13123 none          none         SI-TT-C11_GCTGAATAGGCATTTC  78
# 13124 none          none         SI-TT-C11_CCGCAAGAGTGCGCTC  72
# 13125 none          none         SI-TT-G10_AGTCACACACTAAACC  98
# 13126 none          none         SI-TT-D11_TCGGATATCTTTCAGT 108
# 13127 none          none         SI-TT-F10_CTTCCGACAGTGTGCC  80
# 13128 none          none         SI-TT-E11_GGGTCACCACTAACGT  60
# 13129 none          none         SI-TT-D11_CTCGAGGTCAGAGTGG  68
# 13130 none          none         SI-TT-H10_TCCAGAACAAGTGACG  69
# 13131 none          none         SI-TT-F11_CAGCAGCTCGTTGTGA  81
# 13132 none          none         SI-TT-B12_CTCACTGGTACCAATC  87
# 13133 none          none         SI-TT-H10_CTACCCAGTTCGTACA  75
# 13134 none          none         SI-TT-E11_GGGCCATCATGTTTGG  75
# 13135 none          none         SI-TT-E11_TTGTTTGTCCATAGGT  86

# %%
options(repr.plot.width=3.5, repr.plot.height=3.5)
umap_bl6_other = da_results %>%
filter(class == 'other') %>%
mutate(polarity_bl6 = factor(polarity_bl6, levels = c("none", "neg", "pos"))) %>%
arrange(polarity_bl6) %>%
ggplot(aes(x = umap_1, y = umap_2, color=polarity_bl6, alpha=polarity_bl6)) + 
geom_point(size=0.5, shape = 16) + 
scale_color_manual(values = c('none' =  "#a1a1a1",
                              'neg' = "#1b7837",
                              'pos' = "#762a83")) +
scale_alpha_manual(values = c("none" = 0.25, "neg" = 0.5, "pos"=0.5)) +
theme_minimal() + theme(legend.position=c(0.9,0.125)) + theme(
  axis.ticks = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank()
) + theme(
  axis.text = element_blank(),
  axis.title.x = element_blank(),
  axis.text.x = element_blank(),
  axis.text.y = element_blank(),
  axis.title.y = element_blank()
) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))

umap_bl6_other
# Out:
# plot without title

# %%
options(repr.plot.width=3.5, repr.plot.height=3.5)
label_data <- da_results %>%
  filter(class == 'other') %>%
  mutate(labels = str_replace(labels, fixed('__'), '\n')) %>%
  group_by(labels) %>%
  summarise(umap_1 = mean(umap_1, na.rm = TRUE),
            umap_2 = mean(umap_2, na.rm =TRUE),
            label = first(labels))

umap_fgf1_other = da_results %>%
filter(class == 'other') %>%
mutate(polarity_fgf1 = factor(polarity_fgf1, levels = c("none", "neg", "pos"))) %>%
arrange(polarity_fgf1) %>%
ggplot(aes(x = umap_1, y = umap_2, color=polarity_fgf1, alpha=polarity_fgf1)) + 
geom_point(size=0.5, shape = 16) + 
scale_color_manual(values = c('none' =  "#a1a1a1",
                              'neg' = "#d73027",
                              'pos' = "#4575b4")) +
scale_alpha_manual(values = c("none" = 0.25, "neg" = 0.5, "pos"=0.5)) +
geom_text_repel(data = label_data, aes(x = umap_1, y = umap_2, label = label), 
              size = 2, 
              box.padding = unit(1, "lines"), 
              point.padding = unit(2, "lines"),
              segment.color = 'grey50',
              inherit.aes = FALSE) +
theme_minimal() + theme(legend.position=c(0.9,0.125)) + theme(
  axis.ticks = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank()
) + theme(
  axis.text = element_blank(),
  axis.title.x = element_blank(),
  axis.text.x = element_blank(),
  axis.text.y = element_blank(),
  axis.title.y = element_blank()
) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))


umap_fgf1_other
# Out:
# plot without title

# %%
options(repr.plot.width=3.5, repr.plot.height=3.5)
umap_restored_other = da_results %>%
filter(class == 'other') %>%
mutate(polarity = case_when(exact_grouping == 'pos_restored' ~ "pos",
                             exact_grouping == 'neg_restored' ~ "neg",
                             TRUE ~ 'other')) %>%
mutate(polarity = factor(polarity, levels = c("other", "neg", "pos"))) %>%
arrange(polarity) %>%
ggplot(aes(x = umap_1, y = umap_2, color=polarity, alpha=polarity)) + 
geom_point(size=0.5, shape = 16) + 
scale_color_manual(values = c('other' =  "#a1a1a1",
                              'neg' = "#a50026",
                              'pos' = "#313695")) +
scale_alpha_manual(values = c("other" = 0.25, "neg" = 0.5, "pos"=0.5)) +
theme_minimal() + theme(legend.position=c(0.9,0.125)) + theme(
  axis.ticks = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank()
) + theme(
  axis.text = element_blank(),
  axis.title.x = element_blank(),
  axis.text.x = element_blank(),
  axis.text.y = element_blank(),
  axis.title.y = element_blank()
) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))

umap_restored_other
# Out:
# plot without title

# %%
all_restored_summary = qs::qread('_targets_MAST_v2/objects/all_restored_summary') %>%
filter(comparison == 'Day5.obob5v5__v__Day5.obobBL6d5') %>%
mutate(prop_fgf1 = n_fgf1/n_total) %>%
mutate(prop_BL6 = n_BL6/n_total) %>%
mutate(prop_sum = prop_fgf1 + prop_BL6) %>%
mutate(n_sum = n_fgf1 + n_BL6) %>%
arrange(desc(n_fgf1))

all_restored_summary %>% head

label_order = all_restored_summary %>% pull(labels)
label_order
# Out:
#   labels     n_total n_fgf1 n_fgf1.pos n_fgf1.neg prop_fgf1.pos n_BL6
# 1 other      855     325    139        186        0.4276923       4
# 2 Astrocytes 447     192     73        119        0.3802083     123
# 3 g2         424     182     75        107        0.4120879      94
# 4 n1         384      96     29         67        0.3020833     206
# 5 Htr3b      142      77     42         35        0.5454545       3
# 6 OPC         98      51     27         24        0.5294118       0
#   n_restored n_restored.pos n_restored.neg prop_restored_BL6 prop_restored_FGF1
# 1  4          4              0             1.0000000         0.01230769
# 2 35          2             33             0.2845528         0.18229167
# 3 24          1             23             0.2553191         0.13186813
# 4 76         15             61             0.3689320         0.79166667
# 5  3          3              0             1.0000000         0.03896104
# 6  0          0              0                   NaN         0.00000000
#   comparison                      prop_fgf1 prop_BL6    prop_sum  n_sum
# 1 Day5.obob5v5__v__Day5.obobBL6d5 0.3801170 0.004678363 0.3847953 329
# 2 Day5.obob5v5__v__Day5.obobBL6d5 0.4295302 0.275167785 0.7046980 315
# 3 Day5.obob5v5__v__Day5.obobBL6d5 0.4292453 0.221698113 0.6509434 276
# 4 Day5.obob5v5__v__Day5.obobBL6d5 0.2500000 0.536458333 0.7864583 302
# 5 Day5.obob5v5__v__Day5.obobBL6d5 0.5422535 0.021126761 0.5633803  80
# 6 Day5.obob5v5__v__Day5.obobBL6d5 0.5204082 0.000000000 0.5204082  51
#  [1] "other"               "Astrocytes"          "g2"
#  [4] "n1"                  "Htr3b"               "OPC"
#  [7] "g3"                  "Agrp"                "Trh__Lef1"
# [10] "Tanycytes"           "n0"                  "Oligodendrocytes"
# [13] "g1"                  "Ghrh"                "Ppp1r17__Tafa4"
# [16] "Ependymal_cells"     "Sst__Unc13c"         "Tbx19__Pirt"
# [19] "Irx5__Lmx1a"         "Kiss1__Tac2"         "Pomc__Glipr1"
# [22] "Pou6f2__Prkcq__Whrn" "Sst__Pthlh"          "n8"
# [25] "Th__Slc6a3"          "neuron"              "Arx__Nr5a2"
# [28] "Dlk1"                "Endothelial_cells"   "Esr1"
# [31] "Fez1"                "Gpr50__Tac2"         "Hdc"
# [34] "Lepr15"              "Lepr67"              "Lepr89"
# [37] "Lpar1_oligo"         "Met__Pappa2"         "Met__Prlh"
# [40] "Microglia"           "Nfib_1"              "Nfib_2"
# [43] "Nfib_3"              "Nfix__Nfib"          "Nfix__Nfib__Hgf"
# [46] "Nfix__Nfib__Lhx6"    "Npsr1__Epha3"        "Pomc__Anxa2"
# [49] "Pomc__Ttr"           "Ppp1r17"             "Ppp1r17__Ltbp1"
# [52] "Reln__Lef1"          "Sim1"                "Slc17a6__Trhr"
# [55] "Sst__Nts"            "Th__Nfib"            "Tmem215__Dach2"
# [58] "Tmem215__Greb1"      "Trh__Cxcl12"         "g4"
# [61] "g_drop"              "n2"                  "n3"
# [64] "n4"                  "n5"                  "n6"
# [67] "n_drop"

# %%
all_restored_summary %>% filter(prop_sum > 0) %>%
left_join(labels_classes_tib, by='labels') %>%
group_by(class) %>% summarise(n=n())
# Out:
#   class  n
# 1 neuron 24
# 2 other   5
# 3 NA     11

# %%
all_restored_summary %>%
left_join(labels_classes_tib, by='labels') %>%
filter(class=='neuron') %>%
arrange(desc(n_sum)) %>%
head(20)
# Out:
#    labels              n_total n_fgf1 n_fgf1.pos n_fgf1.neg prop_fgf1.pos n_BL6
# 1  Agrp                187     40     27         13         0.6750000     168
# 2  Htr3b               142     77     42         35         0.5454545       3
# 3  Trh__Cxcl12         137      0     NA         NA                NA      76
# 4  Pomc__Glipr1         80      4      1          3         0.2500000      47
# 5  Kiss1__Tac2          92      4     NA          4                NA      45
# 6  Ghrh                 70      7      3          4         0.4285714      35
# 7  Trh__Lef1           105     37     20         17         0.5405405       0
# 8  Sst__Unc13c         117      5      5         NA         1.0000000      30
# 9  Tmem215__Greb1       88      0     NA         NA                NA      34
# 10 Pou6f2__Prkcq__Whrn  73      4      4         NA         1.0000000       9
# 11 Tbx19__Pirt          80      5      2          3         0.4000000       4
# 12 Th__Slc6a3           34      1      1         NA         1.0000000       8
# 13 Th__Nfib             26      0     NA         NA                NA       9
# 14 Irx5__Lmx1a         190      4      4         NA         1.0000000       4
# 15 Pomc__Anxa2          22      0     NA         NA                NA       8
# 16 Pomc__Ttr            50      0     NA         NA                NA       8
# 17 Ppp1r17__Tafa4      166      6      1          5         0.1666667       0
# 18 Sst__Pthlh           49      3      3         NA         1.0000000       0
# 19 Nfix__Nfib__Lhx6    124      0     NA         NA                NA       3
# 20 Lpar1_oligo          32      0     NA         NA                NA       2
#    n_restored n_restored.pos n_restored.neg prop_restored_BL6
# 1  33         20             13             0.19642857
# 2   3          3              0             1.00000000
# 3   0          0              0             0.00000000
# 4   4          1              3             0.08510638
# 5   4          0              4             0.08888889
# 6   7          3              4             0.20000000
# 7   0          0              0                    NaN
# 8   5          5              0             0.16666667
# 9   0          0              0             0.00000000
# 10  3          3              0             0.33333333
# 11  0          0              0             0.00000000
# 12  1          1              0             0.12500000
# 13  0          0              0             0.00000000
# 14  4          4              0             1.00000000
# 15  0          0              0             0.00000000
# 16  0          0              0             0.00000000
# 17  0          0              0                    NaN
# 18  0          0              0                    NaN
# 19  0          0              0             0.00000000
# 20  0          0              0             0.00000000
#    prop_restored_FGF1 comparison                      prop_fgf1  prop_BL6
# 1  0.82500000         Day5.obob5v5__v__Day5.obobBL6d5 0.21390374 0.89839572
# 2  0.03896104         Day5.obob5v5__v__Day5.obobBL6d5 0.54225352 0.02112676
# 3         NaN         Day5.obob5v5__v__Day5.obobBL6d5 0.00000000 0.55474453
# 4  1.00000000         Day5.obob5v5__v__Day5.obobBL6d5 0.05000000 0.58750000
# 5  1.00000000         Day5.obob5v5__v__Day5.obobBL6d5 0.04347826 0.48913043
# 6  1.00000000         Day5.obob5v5__v__Day5.obobBL6d5 0.10000000 0.50000000
# 7  0.00000000         Day5.obob5v5__v__Day5.obobBL6d5 0.35238095 0.00000000
# 8  1.00000000         Day5.obob5v5__v__Day5.obobBL6d5 0.04273504 0.25641026
# 9         NaN         Day5.obob5v5__v__Day5.obobBL6d5 0.00000000 0.38636364
# 10 0.75000000         Day5.obob5v5__v__Day5.obobBL6d5 0.05479452 0.12328767
# 11 0.00000000         Day5.obob5v5__v__Day5.obobBL6d5 0.06250000 0.05000000
# 12 1.00000000         Day5.obob5v5__v__Day5.obobBL6d5 0.02941176 0.23529412
# 13        NaN         Day5.obob5v5__v__Day5.obobBL6d5 0.00000000 0.34615385
# 14 1.00000000         Day5.obob5v5__v__Day5.obobBL6d5 0.02105263 0.02105263
# 15        NaN         Day5.obob5v5__v__Day5.obobBL6d5 0.00000000 0.36363636
# 16        NaN         Day5.obob5v5__v__Day5.obobBL6d5 0.00000000 0.16000000
# 17 0.00000000         Day5.obob5v5__v__Day5.obobBL6d5 0.03614458 0.00000000
# 18 0.00000000         Day5.obob5v5__v__Day5.obobBL6d5 0.06122449 0.00000000
# 19        NaN         Day5.obob5v5__v__Day5.obobBL6d5 0.00000000 0.02419355
# 20        NaN         Day5.obob5v5__v__Day5.obobBL6d5 0.00000000 0.06250000
#    prop_sum   n_sum class
# 1  1.11229947 208   neuron
# 2  0.56338028  80   neuron
# 3  0.55474453  76   neuron
# 4  0.63750000  51   neuron
# 5  0.53260870  49   neuron
# 6  0.60000000  42   neuron
# 7  0.35238095  37   neuron
# 8  0.29914530  35   neuron
# 9  0.38636364  34   neuron
# 10 0.17808219  13   neuron
# 11 0.11250000   9   neuron
# 12 0.26470588   9   neuron
# 13 0.34615385   9   neuron
# 14 0.04210526   8   neuron
# 15 0.36363636   8   neuron
# 16 0.16000000   8   neuron
# 17 0.03614458   6   neuron
# 18 0.06122449   3   neuron
# 19 0.02419355   3   neuron
# 20 0.06250000   2   neuron

# %%
unchanged_labels = all_restored_summary %>%
filter(!(prop_sum > 0)) %>%
pull(labels)
unchanged_labels
# Out:
#  [1] "Dlk1"              "Endothelial_cells" "Esr1"
#  [4] "Fez1"              "Gpr50__Tac2"       "Hdc"
#  [7] "Lepr15"            "Lepr67"            "Lepr89"
# [10] "Met__Pappa2"       "Microglia"         "Nfib_1"
# [13] "Nfib_2"            "Nfib_3"            "Nfix__Nfib"
# [16] "Npsr1__Epha3"      "Ppp1r17"           "Ppp1r17__Ltbp1"
# [19] "Reln__Lef1"        "Sim1"              "Slc17a6__Trhr"
# [22] "Sst__Nts"          "g4"                "g_drop"
# [25] "n4"                "n6"                "n_drop"

# %%
all_restored_summary %>%
filter(str_detect(labels, 'Ghrh'))
# Out:
#   labels n_total n_fgf1 n_fgf1.pos n_fgf1.neg prop_fgf1.pos n_BL6 n_restored
# 1 Ghrh   70      7      3          4          0.4285714     35    7
#   n_restored.pos n_restored.neg prop_restored_BL6 prop_restored_FGF1
# 1 3              4              0.2               1
#   comparison                      prop_fgf1 prop_BL6 prop_sum n_sum
# 1 Day5.obob5v5__v__Day5.obobBL6d5 0.1       0.5      0.6      42

# %%
beeswarm_tibble = da_results %>%
select(Nhood, labels, class, n_cells, polarity_fgf1, SpatialFDR_fgf1, logFC_fgf1, polarity_bl6, SpatialFDR_bl6, logFC_bl6, exact_grouping) %>%
mutate(restored = case_when(exact_grouping == 'pos_restored' ~ 'yes',
                             exact_grouping == 'neg_restored' ~ 'yes',
                             TRUE ~ 'no')) %>%
mutate(restored = factor(restored, levels=c('no', 'yes')))

# Separate data frames for each type of measurement
polarity_df <- beeswarm_tibble %>%
  select(Nhood, labels, class, n_cells, starts_with("polarity"), exact_grouping, restored) %>%
  pivot_longer(cols = starts_with("polarity"),
               names_to = "comparison",
               values_to = "polarity") %>%
  mutate(comparison = ifelse(str_detect(comparison, "bl6"), "BL6", "FGF1"))

spatial_df <- beeswarm_tibble %>%
  select(Nhood, labels, class, n_cells, starts_with("SpatialFDR"), exact_grouping, restored) %>%
  pivot_longer(cols = starts_with("SpatialFDR"),
               names_to = "comparison",
               values_to = "SpatialFDR") %>%
  mutate(comparison = ifelse(str_detect(comparison, "bl6"), "BL6", "FGF1"))

logfc_df <- beeswarm_tibble %>%
  select(Nhood, labels, class, n_cells, starts_with("logFC"), exact_grouping, restored) %>%
  pivot_longer(cols = starts_with("logFC"),
               names_to = "comparison",
               values_to = "logFC") %>%
  mutate(comparison = ifelse(str_detect(comparison, "bl6"), "BL6", "FGF1"))

# Join all dataframes
beeswarm_tibble <- polarity_df %>%
  inner_join(spatial_df, by = c("Nhood", "labels", "class", "n_cells", "comparison", "exact_grouping", "restored")) %>%
  inner_join(logfc_df, by = c("Nhood", "labels", "class", "n_cells", "comparison", "exact_grouping", "restored"))


beeswarm_tibble = beeswarm_tibble %>%
mutate(labels = factor(labels, levels=rev(label_order))) %>%
rowwise %>%
mutate(label.group = paste0(labels, '.', comparison)) %>% 
ungroup %>%
mutate(polarity = paste0(polarity, '.', comparison)) %>%
mutate(polarity = case_when(str_detect(polarity, 'none') ~ 'none',
                            TRUE ~ polarity)) %>%
mutate(polarity = factor(polarity, levels=rev(c('none', 'neg.BL6', 'pos.BL6', 'neg.FGF1', 'pos.FGF1')))) %>%
arrange(desc(labels))

beeswarm_tibble
# Out:
#       Nhood labels class n_cells exact_grouping restored comparison polarity
# 1     386   other  NA     80     pos_FGF1       no       FGF1       pos.FGF1
# 2     386   other  NA     80     pos_FGF1       no       BL6        none
# 3     822   other  NA     70     pos_FGF1       no       FGF1       pos.FGF1
# 4     822   other  NA     70     pos_FGF1       no       BL6        none
# 5     464   other  NA     72     pos_FGF1       no       FGF1       pos.FGF1
# 6     464   other  NA     72     pos_FGF1       no       BL6        none
# 7     263   other  NA     70     pos_FGF1       no       FGF1       pos.FGF1
# 8     263   other  NA     70     pos_FGF1       no       BL6        none
# 9     199   other  NA     65     pos_FGF1       no       FGF1       pos.FGF1
# 10    199   other  NA     65     pos_FGF1       no       BL6        none
# 11    397   other  NA     72     pos_FGF1       no       FGF1       pos.FGF1
# 12    397   other  NA     72     pos_FGF1       no       BL6        none
# 13     35   other  NA     60     pos_FGF1       no       FGF1       pos.FGF1
# 14     35   other  NA     60     pos_FGF1       no       BL6        none
# 15    718   other  NA     51     pos_FGF1       no       FGF1       pos.FGF1
# 16    718   other  NA     51     pos_FGF1       no       BL6        none
# 17    582   other  NA     84     pos_FGF1       no       FGF1       pos.FGF1
# 18    582   other  NA     84     pos_FGF1       no       BL6        none
# 19    707   other  NA    257     neg_FGF1       no       FGF1       neg.FGF1
# 20    707   other  NA    257     neg_FGF1       no       BL6        none
# 21    135   other  NA     64     pos_FGF1       no       FGF1       pos.FGF1
# 22    135   other  NA     64     pos_FGF1       no       BL6        none
# 23     99   other  NA    218     neg_FGF1       no       FGF1       neg.FGF1
# 24     99   other  NA    218     neg_FGF1       no       BL6        none
# 25    662   other  NA    189     neg_FGF1       no       FGF1       neg.FGF1
# 26    662   other  NA    189     neg_FGF1       no       BL6        none
# 27    290   other  NA     57     pos_FGF1       no       FGF1       pos.FGF1
# 28    290   other  NA     57     pos_FGF1       no       BL6        none
# 29    574   other  NA    137     pos_FGF1       no       FGF1       pos.FGF1
# 30    574   other  NA    137     pos_FGF1       no       BL6        none
# ⋮     ⋮     ⋮      ⋮     ⋮       ⋮              ⋮        ⋮          ⋮
# 26241  72   n_drop NA    75      none           no       FGF1       none
# 26242  72   n_drop NA    75      none           no       BL6        none
# 26243 159   n_drop NA    70      none           no       FGF1       none
# 26244 159   n_drop NA    70      none           no       BL6        none
# 26245 171   n_drop NA    58      none           no       FGF1       none
# 26246 171   n_drop NA    58      none           no       BL6        none
# 26247 215   n_drop NA    62      none           no       FGF1       none
# 26248 215   n_drop NA    62      none           no       BL6        none
# 26249  40   n_drop NA    87      none           no       FGF1       none
# 26250  40   n_drop NA    87      none           no       BL6        none
# 26251  48   n_drop NA    94      none           no       FGF1       none
# 26252  48   n_drop NA    94      none           no       BL6        none
# 26253  93   n_drop NA    89      none           no       FGF1       none
# 26254  93   n_drop NA    89      none           no       BL6        none
# 26255 124   n_drop NA    83      none           no       FGF1       none
# 26256 124   n_drop NA    83      none           no       BL6        none
# 26257 152   n_drop NA    87      none           no       FGF1       none
# 26258 152   n_drop NA    87      none           no       BL6        none
# 26259 213   n_drop NA    94      none           no       FGF1       none
# 26260 213   n_drop NA    94      none           no       BL6        none
# 26261 216   n_drop NA    91      none           no       FGF1       none
# 26262 216   n_drop NA    91      none           no       BL6        none
# 26263  67   n_drop NA    60      none           no       FGF1       none
# 26264  67   n_drop NA    60      none           no       BL6        none
# 26265 111   n_drop NA    88      none           no       FGF1       none
# 26266 111   n_drop NA    88      none           no       BL6        none
# 26267 130   n_drop NA    83      none           no       FGF1       none
# 26268 130   n_drop NA    83      none           no       BL6        none
# 26269 180   n_drop NA    58      none           no       FGF1       none
# 26270 180   n_drop NA    58      none           no       BL6        none
#       SpatialFDR   logFC       label.group
# 1     5.913861e-07  5.7880850  other.FGF1
# 2     9.587951e-01  0.3291051  other.BL6
# 3     5.913861e-07  6.6390950  other.FGF1
# 4     7.890363e-01  1.3817936  other.BL6
# 5     8.770765e-07  5.0318362  other.FGF1
# 6     9.607907e-01 -0.2793494  other.BL6
# 7     1.180133e-06  4.9838278  other.FGF1
# 8     9.597985e-01 -0.2828503  other.BL6
# 9     1.274122e-06  4.8487326  other.FGF1
# 10    9.587951e-01  0.3220766  other.BL6
# 11    1.274122e-06  5.0269720  other.FGF1
# 12    9.587951e-01 -0.3224039  other.BL6
# 13    6.052378e-06  4.7014970  other.FGF1
# 14    8.749193e-01  0.9301953  other.BL6
# 15    7.658657e-06  5.0623193  other.FGF1
# 16    8.769715e-01  0.9646290  other.BL6
# 17    9.129425e-06  3.8592223  other.FGF1
# 18    9.564646e-01  0.2966381  other.BL6
# 19    1.317436e-05 -2.7476670  other.FGF1
# 20    8.959882e-01  0.2927778  other.BL6
# 21    1.467114e-05  4.3451336  other.FGF1
# 22    8.959882e-01  0.6776351  other.BL6
# 23    2.726878e-05 -2.6699531  other.FGF1
# 24    9.230792e-01 -0.2066130  other.BL6
# 25    1.176061e-04 -2.4407205  other.FGF1
# 26    7.140145e-01 -0.9778234  other.BL6
# 27    2.680089e-04  3.8095735  other.FGF1
# 28    9.463741e-01  0.3727679  other.BL6
# 29    3.326519e-04  2.2808152  other.FGF1
# 30    8.202219e-01 -0.6377935  other.BL6
# ⋮     ⋮            ⋮           ⋮
# 26241 0.9817844     0.05903083 n_drop.FGF1
# 26242 0.9808137    -0.54963026 n_drop.BL6
# 26243 0.9817844    -0.05197703 n_drop.FGF1
# 26244 0.9808137    -0.49363381 n_drop.BL6
# 26245 0.9817844    -0.06088132 n_drop.FGF1
# 26246 0.9808137    -1.16469312 n_drop.BL6
# 26247 0.9817844     0.05497624 n_drop.FGF1
# 26248 0.9808137    -0.77734518 n_drop.BL6
# 26249 0.9852958    -0.03213721 n_drop.FGF1
# 26250 0.9808137    -0.59073334 n_drop.BL6
# 26251 0.9852958    -0.02130335 n_drop.FGF1
# 26252 0.9808137     0.69686477 n_drop.BL6
# 26253 0.9852958     0.01903830 n_drop.FGF1
# 26254 0.9808137     0.54896426 n_drop.BL6
# 26255 0.9852958     0.02566014 n_drop.FGF1
# 26256 0.9808137     0.54283787 n_drop.BL6
# 26257 0.9852958    -0.02152667 n_drop.FGF1
# 26258 0.9976965    -0.09408671 n_drop.BL6
# 26259 0.9852958    -0.05705411 n_drop.FGF1
# 26260 0.2314760     4.61886896 n_drop.BL6
# 26261 0.9852958     0.03761151 n_drop.FGF1
# 26262 0.9808137    -0.58832074 n_drop.BL6
# 26263 0.9853851     0.01528507 n_drop.FGF1
# 26264 0.9808137     0.90820365 n_drop.BL6
# 26265 0.9861245     0.01912979 n_drop.FGF1
# 26266 0.1379820     4.38575621 n_drop.BL6
# 26267 0.9868480     0.01320706 n_drop.FGF1
# 26268 0.1379820     4.29714743 n_drop.BL6
# 26269 0.9888123    -0.01278414 n_drop.FGF1
# 26270 0.9808137     1.21904622 n_drop.BL6

# %%
beeswarm_tibble %>% head %>% print
# Out:
# # A tibble: 6 × 11
#   Nhood labels class n_cells exact_grouping restored comparison polarity
#   <dbl> <fct>  <chr>   <dbl> <chr>          <fct>    <chr>      <fct>
# 1   386 other  NA         80 pos_FGF1       no       FGF1       pos.FGF1
# 2   386 other  NA         80 pos_FGF1       no       BL6        none
# 3   822 other  NA         70 pos_FGF1       no       FGF1       pos.FGF1
# 4   822 other  NA         70 pos_FGF1       no       BL6        none
# 5   464 other  NA         72 pos_FGF1       no       FGF1       pos.FGF1
# 6   464 other  NA         72 pos_FGF1       no       BL6        none
# # ℹ 3 more variables: SpatialFDR <dbl>, logFC <dbl>, label.group <chr>

# %%
beeswarm_tibble %>% pull(polarity) %>% unique
beeswarm_tibble %>% pull(polarity) %>% levels
# Out:
# [1] pos.FGF1 none     neg.FGF1 pos.BL6  neg.BL6
# Levels: pos.FGF1 neg.FGF1 pos.BL6 neg.BL6 none
# [1] "pos.FGF1" "neg.FGF1" "pos.BL6"  "neg.BL6"  "none"

# %%
beeswarm_tibble %>% filter(restored == 'yes') %>% dim
# Out:
# [1] 428  11

# %%
options(repr.plot.width=3.5, repr.plot.height=10)

# Creating a separate tibble for the labels
label_tibble <- beeswarm_tibble %>%
  filter(class == 'other')  %>%
#   filter(!(labels %in% unchanged_labels)) %>%
  distinct(labels)

beeswarm_other = beeswarm_tibble %>%
  filter(class == 'other') %>%
#   filter(!(labels %in% unchanged_labels)) %>%
  arrange(labels, polarity, restored) %>%
  ggplot(aes(logFC, labels, group=comparison, color=polarity, alpha=polarity, shape=restored)) + 
  geom_quasirandom(size=1, dodge.width = 1, orientation='y') +
  scale_shape_manual(values = c(yes=19, no=1)) +
  scale_color_manual(values = c('none' =  "#a1a1a1",
                                'neg.FGF1' = "#d73027",
                                'pos.FGF1' = "#4575b4",
                                'neg.BL6' = "#00441b",
                                'pos.BL6' = "#40004b")) + 
  scale_alpha_manual(values = c('none' =  0.25,
                                'neg.FGF1' = 0.25,
                                'pos.FGF1' = 0.25,
                                'neg.BL6' = 0.25,
                                'pos.BL6' = 0.25)) +
  geom_text(data = label_tibble, aes(x = 0, y = labels, label = labels), size=3, hjust = 0.5, vjust = 0.5, inherit.aes = FALSE) +
  theme_classic() +
  theme(axis.title.y = element_blank(),
        axis.ticks.y = element_blank(),
        axis.text.y = element_blank())  + 
theme(legend.position=c(0.9,0.08)) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))
beeswarm_other
# Out:
# plot without title

# %%
options(repr.plot.width=7, repr.plot.height=10)
layout <- '
AB
AC
AD
'

ggp = wrap_plots(A = beeswarm_other,
           B = umap_fgf1_other,
           C = umap_bl6_other,
           D = umap_restored_other,
    design = layout) +
plot_layout(guides = 'auto') + plot_annotation(tag_levels = c('A', 'B', 'C', 'D'))

ggp %>% ggsave('beeswarm_umap_other_d5_MAST_v2.pdf', plot = ., width = 7, height=9)
ggp
# Out:
# plot without title

# %%
unchanged_labels_bl6 = da_results %>%
group_by(labels) %>%
summarise(polarities = polarity_bl6 %>% unique) %>%
group_by(labels) %>%
summarise(n=n()) %>%
# filter(n == 1) %>%
pull(labels)

unchanged_labels_bl6
# Out:
# Warning message:
# “Returning more (or less) than 1 row per `summarise()` group was deprecated in
# dplyr 1.1.0.
# ℹ Please use `reframe()` instead.
# ℹ When switching from `summarise()` to `reframe()`, remember that `reframe()`
#   always returns an ungrouped data frame and adjust accordingly.”
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
#  [1] "Agrp"                "Arx__Nr5a2"          "Astrocytes"
#  [4] "Dlk1"                "Endothelial_cells"   "Ependymal_cells"
#  [7] "Esr1"                "Fez1"                "Ghrh"
# [10] "Gpr50__Tac2"         "Hdc"                 "Htr3b"
# [13] "Irx5__Lmx1a"         "Kiss1__Tac2"         "Lepr15"
# [16] "Lepr67"              "Lepr89"              "Lpar1_oligo"
# [19] "Met__Pappa2"         "Met__Prlh"           "Microglia"
# [22] "Nfib_1"              "Nfib_2"              "Nfib_3"
# [25] "Nfix__Nfib"          "Nfix__Nfib__Hgf"     "Nfix__Nfib__Lhx6"
# [28] "Npsr1__Epha3"        "OPC"                 "Oligodendrocytes"
# [31] "Pomc__Anxa2"         "Pomc__Glipr1"        "Pomc__Ttr"
# [34] "Pou6f2__Prkcq__Whrn" "Ppp1r17"             "Ppp1r17__Ltbp1"
# [37] "Ppp1r17__Tafa4"      "Reln__Lef1"          "Sim1"
# [40] "Slc17a6__Trhr"       "Sst__Nts"            "Sst__Pthlh"
# [43] "Sst__Unc13c"         "Tanycytes"           "Tbx19__Pirt"
# [46] "Th__Nfib"            "Th__Slc6a3"          "Tmem215__Dach2"
# [49] "Tmem215__Greb1"      "Trh__Cxcl12"         "Trh__Lef1"
# [52] "g1"                  "g2"                  "g3"
# [55] "g4"                  "g_drop"              "n0"
# [58] "n1"                  "n2"                  "n3"
# [61] "n4"                  "n5"                  "n6"
# [64] "n8"                  "n_drop"              "neuron"
# [67] "other"

# %%
options(repr.plot.width=3.5, repr.plot.height=3.5)

unchanged_labels_bl6 = da_results %>%
group_by(labels) %>%
summarise(polarities = polarity_bl6 %>% unique) %>%
group_by(labels) %>%
summarise(n=n()) %>%
filter(n == 1) %>%
pull(labels)
unchanged_labels_bl6 %>% length

label_data <- da_results %>%
  filter(class == 'neuron') %>%
  filter(!(labels %in% unchanged_labels_bl6)) %>%
  mutate(labels = str_replace(labels, fixed('__'), '\n')) %>%
  group_by(labels) %>%
  summarise(umap_1 = mean(umap_1, na.rm = TRUE),
            umap_2 = mean(umap_2, na.rm =TRUE),
            label = first(labels))

umap_bl6_neuron = da_results %>%
filter(class == 'neuron') %>%
mutate(polarity_bl6 = factor(polarity_bl6, levels = c("none", "neg", "pos"))) %>%
arrange(polarity_bl6) %>%
ggplot(aes(x = umap_1, y = umap_2, color=polarity_bl6, alpha=polarity_bl6)) + 
geom_point(size=0.5, shape = 16) + 
scale_color_manual(values = c('none' =  "#a1a1a1",
                              'neg' = "#1b7837",
                              'pos' = "#762a83")) +
scale_alpha_manual(values = c("none" = 1, "neg" = 1, "pos"=1)) +
geom_text_repel(data = label_data, aes(x = umap_1, y = umap_2, label = label), 
              size = 2, 
              box.padding = unit(0, "lines"), 
              point.padding = unit(0, "lines"),
              segment.color = 'grey50',
              inherit.aes = FALSE) +
theme_minimal() + theme(legend.position=c(0.9,0.125)) + theme(
  axis.ticks = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank()
) + theme(
  axis.text = element_blank(),
  axis.title.x = element_blank(),
  axis.text.x = element_blank(),
  axis.text.y = element_blank(),
  axis.title.y = element_blank()
) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))

umap_bl6_neuron
# Out:
# Warning message:
# “Returning more (or less) than 1 row per `summarise()` group was deprecated in
# dplyr 1.1.0.
# ℹ Please use `reframe()` instead.
# ℹ When switching from `summarise()` to `reframe()`, remember that `reframe()`
#   always returns an ungrouped data frame and adjust accordingly.”
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# [1] 35
# plot without title

# %%
options(repr.plot.width=3.5, repr.plot.height=3.5)

unchanged_labels_fgf1 = da_results %>%
group_by(labels) %>%
summarise(polarities = polarity_fgf1 %>% unique) %>%
group_by(labels) %>%
summarise(n=n()) %>%
filter(n == 1) %>%
pull(labels)
unchanged_labels_fgf1 %>% length

label_data <- da_results %>%
  filter(class == 'neuron') %>%
  filter(!(labels %in% unchanged_labels_fgf1)) %>%
  mutate(labels = str_replace(labels, fixed('__'), '\n')) %>%
  group_by(labels) %>%
  summarise(umap_1 = mean(umap_1, na.rm = TRUE),
            umap_2 = mean(umap_2, na.rm =TRUE),
            label = first(labels))

umap_fgf1_neuron = da_results %>%
filter(class == 'neuron') %>%
mutate(polarity_fgf1 = factor(polarity_fgf1, levels = c("none", "neg", "pos"))) %>%
arrange(polarity_fgf1) %>%
ggplot(aes(x = umap_1, y = umap_2, color=polarity_fgf1, alpha=polarity_fgf1)) + 
geom_point(size=0.5, shape = 16) + 
scale_color_manual(values = c('none' =  "#a1a1a1",
                              'neg' = "#d73027",
                              'pos' = "#4575b4")) +
scale_alpha_manual(values = c("none" = 0.25, "neg" = 0.5, "pos"=0.5)) +
geom_text_repel(data = label_data, aes(x = umap_1, y = umap_2, label = label), 
              size = 2, 
              box.padding = unit(0, "lines"), 
              point.padding = unit(0, "lines"),
              segment.color = 'grey50',
              inherit.aes = FALSE) +
theme_minimal() + theme(legend.position=c(0.9,0.125)) + theme(
  axis.ticks = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank()
) + theme(
  axis.text = element_blank(),
  axis.title.x = element_blank(),
  axis.text.x = element_blank(),
  axis.text.y = element_blank(),
  axis.title.y = element_blank()
) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))


umap_fgf1_neuron
# Out:
# Warning message:
# “Returning more (or less) than 1 row per `summarise()` group was deprecated in
# dplyr 1.1.0.
# ℹ Please use `reframe()` instead.
# ℹ When switching from `summarise()` to `reframe()`, remember that `reframe()`
#   always returns an ungrouped data frame and adjust accordingly.”
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# [1] 41
# plot without title

# %%
options(repr.plot.width=3.5, repr.plot.height=3.5)

label_data <- da_results %>%
  filter(class == 'neuron') %>%
  filter(!(labels %in% unchanged_labels_fgf1)) %>%
  filter(!(labels %in% unchanged_labels_bl6)) %>%
  mutate(labels = str_replace(labels, fixed('__'), '\n')) %>%
  group_by(labels) %>%
  summarise(umap_1 = mean(umap_1, na.rm = TRUE),
            umap_2 = mean(umap_2, na.rm =TRUE),
            label = first(labels))

umap_restored_neuron = da_results %>%
filter(class == 'neuron') %>%
mutate(polarity = case_when(exact_grouping == 'pos_restored' ~ "pos",
                             exact_grouping == 'neg_restored' ~ "neg",
                             TRUE ~ 'other')) %>%
mutate(polarity = factor(polarity, levels = c("other", "neg", "pos"))) %>%
arrange(polarity) %>%
ggplot(aes(x = umap_1, y = umap_2, color=polarity, alpha=polarity)) + 
geom_point(size=0.5, shape = 16) + 
scale_color_manual(values = c('other' =  "#a1a1a1",
                              'neg' = "#a50026",
                              'pos' = "#313695")) +
scale_alpha_manual(values = c("other" = 0.25, "neg" = 0.5, "pos"=0.5)) +
geom_text_repel(data = label_data, aes(x = umap_1, y = umap_2, label = label), 
              size = 2, 
              box.padding = unit(0, "lines"), 
              point.padding = unit(0, "lines"),
              segment.color = 'grey50',
              inherit.aes = FALSE) +
theme_minimal() + theme(legend.position=c(0.9,0.125)) + theme(
  axis.ticks = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank()
) + theme(
  axis.text = element_blank(),
  axis.title.x = element_blank(),
  axis.text.x = element_blank(),
  axis.text.y = element_blank(),
  axis.title.y = element_blank()
) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))

umap_restored_neuron
# Out:
# plot without title

# %%
options(repr.plot.width=3.5, repr.plot.height=10)

# Creating a separate tibble for the labels
label_tibble <- da_results %>%
  filter(class == 'neuron') %>%
  filter((polarity_fgf1 %in% c('pos', 'neg')) | (polarity_bl6 %in% c('pos', 'neg'))) %>%
  distinct(labels)

beeswarm_neuron = beeswarm_tibble %>%
  filter(class == 'neuron') %>%
  filter((labels %in% label_tibble$labels)) %>%
  arrange(labels, polarity, restored) %>%
  ggplot(aes(logFC, labels, group=comparison, color=polarity, alpha=polarity, shape=restored)) + 
  geom_quasirandom(size=1, dodge.width = 1, orientation='y') +
  scale_shape_manual(values = c(yes=19, no=1)) +
  scale_color_manual(values = c('none' =  "#a1a1a1",
                                'neg.FGF1' = "#d73027",
                                'pos.FGF1' = "#4575b4",
                                'neg.BL6' = "#00441b",
                                'pos.BL6' = "#40004b")) + 
  scale_alpha_manual(values = c('none' =  0.25,
                                'neg.FGF1' = 0.25,
                                'pos.FGF1' = 0.25,
                                'neg.BL6' = 0.25,
                                'pos.BL6' = 0.25)) +
  geom_text(data = label_tibble, aes(x = 0, y = labels, label = labels), size=3, hjust = 0.5, vjust = 0.5, inherit.aes = FALSE) +
  theme_classic() +
  theme(axis.title.y = element_blank(),
        axis.ticks.y = element_blank(),
        axis.text.y = element_blank())  + 
theme(legend.position=c(0.85,0.3)) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))

beeswarm_neuron
# Out:
# plot without title

# %%
options(repr.plot.width=7, repr.plot.height=9.5)
layout <- '
AB
AC
AD
'

ggp = wrap_plots(A = beeswarm_neuron,
           B = umap_fgf1_neuron,
           C = umap_bl6_neuron,
           D = umap_restored_neuron,
    design = layout) +
plot_layout(guides = 'auto') + plot_annotation(tag_levels = c('A', 'B', 'C', 'D'))

ggp %>% ggsave('beeswarm_umap_neurons_d5_MAST_v2.pdf', plot = ., width = 7, height=9)
ggp
# Out:
# plot without title

# %%
beeswarm_tibble %>% qs::qsave('beeswarm_tibble_d5_MAST_v2.qs')
da_results %>% qs::qsave('beeswarm_da_results_d5_MAST_v2.qs')
