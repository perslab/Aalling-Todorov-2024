# %%
library(tidyverse)
library(targets)
library(tarchetypes)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.2     ✔ purrr   0.3.4
# ✔ tibble  3.2.1     ✔ dplyr   1.1.2
# ✔ tidyr   1.2.1     ✔ stringr 1.4.1
# ✔ readr   2.1.2     ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
clusters_tibble = qs::qread('clusters_tibble_labels_chunk.qs')

clusters_tibble$milo_obj = clusters_tibble %>%
    pull(label) %>%
    paste0("milo_", .) %>%
    rlang::syms()
clusters_tibble$milo_index_obj = clusters_tibble %>%
    pull(label) %>%
    paste0("milo_index_tibble_", .) %>%
    rlang::syms()
clusters_tibble$design_df = clusters_tibble %>%
    pull(label) %>%
    paste0("design_df_", .) %>%
    rlang::syms()
clusters_tibble$mm = clusters_tibble %>%
    pull(label) %>%
    paste0("mm_", .) %>%
    rlang::syms()
clusters_tibble
# Out:
#    label        object              day   cluster milo_obj
# 1  g_drop       exp_labelled_other  all   g_drop  milo_g_drop
# 2  Day14.g_drop exp_labelled_other  Day14 g_drop  milo_Day14.g_drop
# 3  Day5.g_drop  exp_labelled_other  Day5  g_drop  milo_Day5.g_drop
# 4  g1           exp_labelled_other  all   g1      milo_g1
# 5  Day14.g1     exp_labelled_other  Day14 g1      milo_Day14.g1
# 6  Day5.g1      exp_labelled_other  Day5  g1      milo_Day5.g1
# 7  g2           exp_labelled_other  all   g2      milo_g2
# 8  Day14.g2     exp_labelled_other  Day14 g2      milo_Day14.g2
# 9  Day5.g2      exp_labelled_other  Day5  g2      milo_Day5.g2
# 10 g3           exp_labelled_other  all   g3      milo_g3
# 11 Day14.g3     exp_labelled_other  Day14 g3      milo_Day14.g3
# 12 Day5.g3      exp_labelled_other  Day5  g3      milo_Day5.g3
# 13 g4           exp_labelled_other  all   g4      milo_g4
# 14 Day14.g4     exp_labelled_other  Day14 g4      milo_Day14.g4
# 15 Day5.g4      exp_labelled_other  Day5  g4      milo_Day5.g4
# 16 g7           exp_labelled_other  all   g7      milo_g7
# 17 Day14.g7     exp_labelled_other  Day14 g7      milo_Day14.g7
# 18 Day5.g7      exp_labelled_other  Day5  g7      milo_Day5.g7
# 19 n_drop       exp_labelled_neuron all   n_drop  milo_n_drop
# 20 Day14.n_drop exp_labelled_neuron Day14 n_drop  milo_Day14.n_drop
# 21 Day5.n_drop  exp_labelled_neuron Day5  n_drop  milo_Day5.n_drop
# 22 n0           exp_labelled_neuron all   n0      milo_n0
# 23 Day14.n0     exp_labelled_neuron Day14 n0      milo_Day14.n0
# 24 Day5.n0      exp_labelled_neuron Day5  n0      milo_Day5.n0
# 25 n1           exp_labelled_neuron all   n1      milo_n1
# 26 Day14.n1     exp_labelled_neuron Day14 n1      milo_Day14.n1
# 27 Day5.n1      exp_labelled_neuron Day5  n1      milo_Day5.n1
# 28 n2           exp_labelled_neuron all   n2      milo_n2
# 29 Day14.n2     exp_labelled_neuron Day14 n2      milo_Day14.n2
# 30 Day5.n2      exp_labelled_neuron Day5  n2      milo_Day5.n2
# 31 n3           exp_labelled_neuron all   n3      milo_n3
# 32 Day14.n3     exp_labelled_neuron Day14 n3      milo_Day14.n3
# 33 Day5.n3      exp_labelled_neuron Day5  n3      milo_Day5.n3
# 34 n4           exp_labelled_neuron all   n4      milo_n4
# 35 Day14.n4     exp_labelled_neuron Day14 n4      milo_Day14.n4
# 36 Day5.n4      exp_labelled_neuron Day5  n4      milo_Day5.n4
# 37 n5           exp_labelled_neuron all   n5      milo_n5
# 38 Day14.n5     exp_labelled_neuron Day14 n5      milo_Day14.n5
# 39 Day5.n5      exp_labelled_neuron Day5  n5      milo_Day5.n5
# 40 n6           exp_labelled_neuron all   n6      milo_n6
# 41 Day14.n6     exp_labelled_neuron Day14 n6      milo_Day14.n6
# 42 Day5.n6      exp_labelled_neuron Day5  n6      milo_Day5.n6
# 43 n8           exp_labelled_neuron all   n8      milo_n8
# 44 Day14.n8     exp_labelled_neuron Day14 n8      milo_Day14.n8
# 45 Day5.n8      exp_labelled_neuron Day5  n8      milo_Day5.n8
#    milo_index_obj                 design_df              mm
# 1  milo_index_tibble_g_drop       design_df_g_drop       mm_g_drop
# 2  milo_index_tibble_Day14.g_drop design_df_Day14.g_drop mm_Day14.g_drop
# 3  milo_index_tibble_Day5.g_drop  design_df_Day5.g_drop  mm_Day5.g_drop
# 4  milo_index_tibble_g1           design_df_g1           mm_g1
# 5  milo_index_tibble_Day14.g1     design_df_Day14.g1     mm_Day14.g1
# 6  milo_index_tibble_Day5.g1      design_df_Day5.g1      mm_Day5.g1
# 7  milo_index_tibble_g2           design_df_g2           mm_g2
# 8  milo_index_tibble_Day14.g2     design_df_Day14.g2     mm_Day14.g2
# 9  milo_index_tibble_Day5.g2      design_df_Day5.g2      mm_Day5.g2
# 10 milo_index_tibble_g3           design_df_g3           mm_g3
# 11 milo_index_tibble_Day14.g3     design_df_Day14.g3     mm_Day14.g3
# 12 milo_index_tibble_Day5.g3      design_df_Day5.g3      mm_Day5.g3
# 13 milo_index_tibble_g4           design_df_g4           mm_g4
# 14 milo_index_tibble_Day14.g4     design_df_Day14.g4     mm_Day14.g4
# 15 milo_index_tibble_Day5.g4      design_df_Day5.g4      mm_Day5.g4
# 16 milo_index_tibble_g7           design_df_g7           mm_g7
# 17 milo_index_tibble_Day14.g7     design_df_Day14.g7     mm_Day14.g7
# 18 milo_index_tibble_Day5.g7      design_df_Day5.g7      mm_Day5.g7
# 19 milo_index_tibble_n_drop       design_df_n_drop       mm_n_drop
# 20 milo_index_tibble_Day14.n_drop design_df_Day14.n_drop mm_Day14.n_drop
# 21 milo_index_tibble_Day5.n_drop  design_df_Day5.n_drop  mm_Day5.n_drop
# 22 milo_index_tibble_n0           design_df_n0           mm_n0
# 23 milo_index_tibble_Day14.n0     design_df_Day14.n0     mm_Day14.n0
# 24 milo_index_tibble_Day5.n0      design_df_Day5.n0      mm_Day5.n0
# 25 milo_index_tibble_n1           design_df_n1           mm_n1
# 26 milo_index_tibble_Day14.n1     design_df_Day14.n1     mm_Day14.n1
# 27 milo_index_tibble_Day5.n1      design_df_Day5.n1      mm_Day5.n1
# 28 milo_index_tibble_n2           design_df_n2           mm_n2
# 29 milo_index_tibble_Day14.n2     design_df_Day14.n2     mm_Day14.n2
# 30 milo_index_tibble_Day5.n2      design_df_Day5.n2      mm_Day5.n2
# 31 milo_index_tibble_n3           design_df_n3           mm_n3
# 32 milo_index_tibble_Day14.n3     design_df_Day14.n3     mm_Day14.n3
# 33 milo_index_tibble_Day5.n3      design_df_Day5.n3      mm_Day5.n3
# 34 milo_index_tibble_n4           design_df_n4           mm_n4
# 35 milo_index_tibble_Day14.n4     design_df_Day14.n4     mm_Day14.n4
# 36 milo_index_tibble_Day5.n4      design_df_Day5.n4      mm_Day5.n4
# 37 milo_index_tibble_n5           design_df_n5           mm_n5
# 38 milo_index_tibble_Day14.n5     design_df_Day14.n5     mm_Day14.n5
# 39 milo_index_tibble_Day5.n5      design_df_Day5.n5      mm_Day5.n5
# 40 milo_index_tibble_n6           design_df_n6           mm_n6
# 41 milo_index_tibble_Day14.n6     design_df_Day14.n6     mm_Day14.n6
# 42 milo_index_tibble_Day5.n6      design_df_Day5.n6      mm_Day5.n6
# 43 milo_index_tibble_n8           design_df_n8           mm_n8
# 44 milo_index_tibble_Day14.n8     design_df_Day14.n8     mm_Day14.n8
# 45 milo_index_tibble_Day5.n8      design_df_Day5.n8      mm_Day5.n8

# %%
contrasts_tibble = tibble(
    contrast_name = c("obob5v5",
                      "obob14v14",
                      "obobBL6",
                      "obobBL6d5",
                      "obobBL6d14",
                      "obob5vBL6",
                      "obob14vBL6",
                      "obobFGF1BL6d5",
                      "obobFGF1BL6d14",
                      "BL6d5d14",
                      "obobVeh_PFd5d14"),
    contrast = c("groupFGF1.Day5.obob - groupVeh_PF.Day5.obob",
                 "groupFGF1.Day14.obob - groupVeh_PF.Day14.obob",
                 "((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)",
                 "groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6",
                 "groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6",
                 "groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)",
                 "groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)",
                 "groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6",
                 "groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6",
                 "groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6",
                 "groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob")
)
contrasts_tibble
# Out:
#    contrast_name
# 1  obob5v5
# 2  obob14v14
# 3  obobBL6
# 4  obobBL6d5
# 5  obobBL6d14
# 6  obob5vBL6
# 7  obob14vBL6
# 8  obobFGF1BL6d5
# 9  obobFGF1BL6d14
# 10 BL6d5d14
# 11 obobVeh_PFd5d14
#    contrast
# 1  groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 2  groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 3  ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 4  groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 5  groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 6  groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 7  groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 8  groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 9  groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 10 groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 11 groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob

# %%
da_recipe = tidyr::crossing(clusters_tibble, contrasts_tibble)
da_recipe$label = paste0(da_recipe$label, '___', da_recipe$contrast_name)
head(da_recipe)
# Out:
#   label                     object             day   cluster milo_obj
# 1 Day14.g_drop___BL6d5d14   exp_labelled_other Day14 g_drop  milo_Day14.g_drop
# 2 Day14.g_drop___obob14v14  exp_labelled_other Day14 g_drop  milo_Day14.g_drop
# 3 Day14.g_drop___obob14vBL6 exp_labelled_other Day14 g_drop  milo_Day14.g_drop
# 4 Day14.g_drop___obob5v5    exp_labelled_other Day14 g_drop  milo_Day14.g_drop
# 5 Day14.g_drop___obob5vBL6  exp_labelled_other Day14 g_drop  milo_Day14.g_drop
# 6 Day14.g_drop___obobBL6    exp_labelled_other Day14 g_drop  milo_Day14.g_drop
#   milo_index_obj                 design_df              mm
# 1 milo_index_tibble_Day14.g_drop design_df_Day14.g_drop mm_Day14.g_drop
# 2 milo_index_tibble_Day14.g_drop design_df_Day14.g_drop mm_Day14.g_drop
# 3 milo_index_tibble_Day14.g_drop design_df_Day14.g_drop mm_Day14.g_drop
# 4 milo_index_tibble_Day14.g_drop design_df_Day14.g_drop mm_Day14.g_drop
# 5 milo_index_tibble_Day14.g_drop design_df_Day14.g_drop mm_Day14.g_drop
# 6 milo_index_tibble_Day14.g_drop design_df_Day14.g_drop mm_Day14.g_drop
#   contrast_name
# 1 BL6d5d14
# 2 obob14v14
# 3 obob14vBL6
# 4 obob5v5
# 5 obob5vBL6
# 6 obobBL6
#   contrast
# 1 groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 2 groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 3 groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 4 groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 5 groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 6 ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)

# %%
da_recipe = da_recipe %>%
filter(!(str_detect(contrast_name, "obob5v5") & day == 'Day14')) %>%
filter(!(str_detect(contrast_name, "obob14v14") & day == 'Day5')) %>%
# filter(!(contrast_name == 'obobBL6' & day != 'all')) %>% # this one is good to have, as they may be equivalent
filter(!(contrast_name == 'obobBL6d5' & (day == 'Day14'))) %>%
filter(!(contrast_name == 'obobBL6d14' & (day == 'Day5'))) %>%
filter(!(contrast_name == 'obobFGF1BL6d5' & (day == 'Day14'))) %>% 
filter(!(contrast_name == 'obobFGF1BL6d14' & (day == 'Day5'))) %>%
filter(!(contrast_name == "obob5vBL6" & (day != 'all'))) %>% 
filter(!(contrast_name == "obob14vBL6" & (day != 'all'))) %>%
filter(!(contrast_name == 'BL6d5d14' & (day != 'all'))) %>%
filter(!(contrast_name == 'obobVeh_PFd5d14' & (day != 'all')))

# %%
da_recipe
# Out:
#     label                         object              day   cluster
# 1   Day14.g_drop___obob14v14      exp_labelled_other  Day14 g_drop
# 2   Day14.g_drop___obobBL6        exp_labelled_other  Day14 g_drop
# 3   Day14.g_drop___obobBL6d14     exp_labelled_other  Day14 g_drop
# 4   Day14.g_drop___obobFGF1BL6d14 exp_labelled_other  Day14 g_drop
# 5   Day14.g1___obob14v14          exp_labelled_other  Day14 g1
# 6   Day14.g1___obobBL6            exp_labelled_other  Day14 g1
# 7   Day14.g1___obobBL6d14         exp_labelled_other  Day14 g1
# 8   Day14.g1___obobFGF1BL6d14     exp_labelled_other  Day14 g1
# 9   Day14.g2___obob14v14          exp_labelled_other  Day14 g2
# 10  Day14.g2___obobBL6            exp_labelled_other  Day14 g2
# 11  Day14.g2___obobBL6d14         exp_labelled_other  Day14 g2
# 12  Day14.g2___obobFGF1BL6d14     exp_labelled_other  Day14 g2
# 13  Day14.g3___obob14v14          exp_labelled_other  Day14 g3
# 14  Day14.g3___obobBL6            exp_labelled_other  Day14 g3
# 15  Day14.g3___obobBL6d14         exp_labelled_other  Day14 g3
# 16  Day14.g3___obobFGF1BL6d14     exp_labelled_other  Day14 g3
# 17  Day14.g4___obob14v14          exp_labelled_other  Day14 g4
# 18  Day14.g4___obobBL6            exp_labelled_other  Day14 g4
# 19  Day14.g4___obobBL6d14         exp_labelled_other  Day14 g4
# 20  Day14.g4___obobFGF1BL6d14     exp_labelled_other  Day14 g4
# 21  Day14.g7___obob14v14          exp_labelled_other  Day14 g7
# 22  Day14.g7___obobBL6            exp_labelled_other  Day14 g7
# 23  Day14.g7___obobBL6d14         exp_labelled_other  Day14 g7
# 24  Day14.g7___obobFGF1BL6d14     exp_labelled_other  Day14 g7
# 25  Day14.n_drop___obob14v14      exp_labelled_neuron Day14 n_drop
# 26  Day14.n_drop___obobBL6        exp_labelled_neuron Day14 n_drop
# 27  Day14.n_drop___obobBL6d14     exp_labelled_neuron Day14 n_drop
# 28  Day14.n_drop___obobFGF1BL6d14 exp_labelled_neuron Day14 n_drop
# 29  Day14.n0___obob14v14          exp_labelled_neuron Day14 n0
# 30  Day14.n0___obobBL6            exp_labelled_neuron Day14 n0
# ⋮   ⋮                             ⋮                   ⋮     ⋮
# 256 n5___obob5v5                  exp_labelled_neuron all   n5
# 257 n5___obob5vBL6                exp_labelled_neuron all   n5
# 258 n5___obobBL6                  exp_labelled_neuron all   n5
# 259 n5___obobBL6d14               exp_labelled_neuron all   n5
# 260 n5___obobBL6d5                exp_labelled_neuron all   n5
# 261 n5___obobFGF1BL6d14           exp_labelled_neuron all   n5
# 262 n5___obobFGF1BL6d5            exp_labelled_neuron all   n5
# 263 n5___obobVeh_PFd5d14          exp_labelled_neuron all   n5
# 264 n6___BL6d5d14                 exp_labelled_neuron all   n6
# 265 n6___obob14v14                exp_labelled_neuron all   n6
# 266 n6___obob14vBL6               exp_labelled_neuron all   n6
# 267 n6___obob5v5                  exp_labelled_neuron all   n6
# 268 n6___obob5vBL6                exp_labelled_neuron all   n6
# 269 n6___obobBL6                  exp_labelled_neuron all   n6
# 270 n6___obobBL6d14               exp_labelled_neuron all   n6
# 271 n6___obobBL6d5                exp_labelled_neuron all   n6
# 272 n6___obobFGF1BL6d14           exp_labelled_neuron all   n6
# 273 n6___obobFGF1BL6d5            exp_labelled_neuron all   n6
# 274 n6___obobVeh_PFd5d14          exp_labelled_neuron all   n6
# 275 n8___BL6d5d14                 exp_labelled_neuron all   n8
# 276 n8___obob14v14                exp_labelled_neuron all   n8
# 277 n8___obob14vBL6               exp_labelled_neuron all   n8
# 278 n8___obob5v5                  exp_labelled_neuron all   n8
# 279 n8___obob5vBL6                exp_labelled_neuron all   n8
# 280 n8___obobBL6                  exp_labelled_neuron all   n8
# 281 n8___obobBL6d14               exp_labelled_neuron all   n8
# 282 n8___obobBL6d5                exp_labelled_neuron all   n8
# 283 n8___obobFGF1BL6d14           exp_labelled_neuron all   n8
# 284 n8___obobFGF1BL6d5            exp_labelled_neuron all   n8
# 285 n8___obobVeh_PFd5d14          exp_labelled_neuron all   n8
#     milo_obj          milo_index_obj                 design_df
# 1   milo_Day14.g_drop milo_index_tibble_Day14.g_drop design_df_Day14.g_drop
# 2   milo_Day14.g_drop milo_index_tibble_Day14.g_drop design_df_Day14.g_drop
# 3   milo_Day14.g_drop milo_index_tibble_Day14.g_drop design_df_Day14.g_drop
# 4   milo_Day14.g_drop milo_index_tibble_Day14.g_drop design_df_Day14.g_drop
# 5   milo_Day14.g1     milo_index_tibble_Day14.g1     design_df_Day14.g1
# 6   milo_Day14.g1     milo_index_tibble_Day14.g1     design_df_Day14.g1
# 7   milo_Day14.g1     milo_index_tibble_Day14.g1     design_df_Day14.g1
# 8   milo_Day14.g1     milo_index_tibble_Day14.g1     design_df_Day14.g1
# 9   milo_Day14.g2     milo_index_tibble_Day14.g2     design_df_Day14.g2
# 10  milo_Day14.g2     milo_index_tibble_Day14.g2     design_df_Day14.g2
# 11  milo_Day14.g2     milo_index_tibble_Day14.g2     design_df_Day14.g2
# 12  milo_Day14.g2     milo_index_tibble_Day14.g2     design_df_Day14.g2
# 13  milo_Day14.g3     milo_index_tibble_Day14.g3     design_df_Day14.g3
# 14  milo_Day14.g3     milo_index_tibble_Day14.g3     design_df_Day14.g3
# 15  milo_Day14.g3     milo_index_tibble_Day14.g3     design_df_Day14.g3
# 16  milo_Day14.g3     milo_index_tibble_Day14.g3     design_df_Day14.g3
# 17  milo_Day14.g4     milo_index_tibble_Day14.g4     design_df_Day14.g4
# 18  milo_Day14.g4     milo_index_tibble_Day14.g4     design_df_Day14.g4
# 19  milo_Day14.g4     milo_index_tibble_Day14.g4     design_df_Day14.g4
# 20  milo_Day14.g4     milo_index_tibble_Day14.g4     design_df_Day14.g4
# 21  milo_Day14.g7     milo_index_tibble_Day14.g7     design_df_Day14.g7
# 22  milo_Day14.g7     milo_index_tibble_Day14.g7     design_df_Day14.g7
# 23  milo_Day14.g7     milo_index_tibble_Day14.g7     design_df_Day14.g7
# 24  milo_Day14.g7     milo_index_tibble_Day14.g7     design_df_Day14.g7
# 25  milo_Day14.n_drop milo_index_tibble_Day14.n_drop design_df_Day14.n_drop
# 26  milo_Day14.n_drop milo_index_tibble_Day14.n_drop design_df_Day14.n_drop
# 27  milo_Day14.n_drop milo_index_tibble_Day14.n_drop design_df_Day14.n_drop
# 28  milo_Day14.n_drop milo_index_tibble_Day14.n_drop design_df_Day14.n_drop
# 29  milo_Day14.n0     milo_index_tibble_Day14.n0     design_df_Day14.n0
# 30  milo_Day14.n0     milo_index_tibble_Day14.n0     design_df_Day14.n0
# ⋮   ⋮                 ⋮                              ⋮
# 256 milo_n5           milo_index_tibble_n5           design_df_n5
# 257 milo_n5           milo_index_tibble_n5           design_df_n5
# 258 milo_n5           milo_index_tibble_n5           design_df_n5
# 259 milo_n5           milo_index_tibble_n5           design_df_n5
# 260 milo_n5           milo_index_tibble_n5           design_df_n5
# 261 milo_n5           milo_index_tibble_n5           design_df_n5
# 262 milo_n5           milo_index_tibble_n5           design_df_n5
# 263 milo_n5           milo_index_tibble_n5           design_df_n5
# 264 milo_n6           milo_index_tibble_n6           design_df_n6
# 265 milo_n6           milo_index_tibble_n6           design_df_n6
# 266 milo_n6           milo_index_tibble_n6           design_df_n6
# 267 milo_n6           milo_index_tibble_n6           design_df_n6
# 268 milo_n6           milo_index_tibble_n6           design_df_n6
# 269 milo_n6           milo_index_tibble_n6           design_df_n6
# 270 milo_n6           milo_index_tibble_n6           design_df_n6
# 271 milo_n6           milo_index_tibble_n6           design_df_n6
# 272 milo_n6           milo_index_tibble_n6           design_df_n6
# 273 milo_n6           milo_index_tibble_n6           design_df_n6
# 274 milo_n6           milo_index_tibble_n6           design_df_n6
# 275 milo_n8           milo_index_tibble_n8           design_df_n8
# 276 milo_n8           milo_index_tibble_n8           design_df_n8
# 277 milo_n8           milo_index_tibble_n8           design_df_n8
# 278 milo_n8           milo_index_tibble_n8           design_df_n8
# 279 milo_n8           milo_index_tibble_n8           design_df_n8
# 280 milo_n8           milo_index_tibble_n8           design_df_n8
# 281 milo_n8           milo_index_tibble_n8           design_df_n8
# 282 milo_n8           milo_index_tibble_n8           design_df_n8
# 283 milo_n8           milo_index_tibble_n8           design_df_n8
# 284 milo_n8           milo_index_tibble_n8           design_df_n8
# 285 milo_n8           milo_index_tibble_n8           design_df_n8
#     mm              contrast_name
# 1   mm_Day14.g_drop obob14v14
# 2   mm_Day14.g_drop obobBL6
# 3   mm_Day14.g_drop obobBL6d14
# 4   mm_Day14.g_drop obobFGF1BL6d14
# 5   mm_Day14.g1     obob14v14
# 6   mm_Day14.g1     obobBL6
# 7   mm_Day14.g1     obobBL6d14
# 8   mm_Day14.g1     obobFGF1BL6d14
# 9   mm_Day14.g2     obob14v14
# 10  mm_Day14.g2     obobBL6
# 11  mm_Day14.g2     obobBL6d14
# 12  mm_Day14.g2     obobFGF1BL6d14
# 13  mm_Day14.g3     obob14v14
# 14  mm_Day14.g3     obobBL6
# 15  mm_Day14.g3     obobBL6d14
# 16  mm_Day14.g3     obobFGF1BL6d14
# 17  mm_Day14.g4     obob14v14
# 18  mm_Day14.g4     obobBL6
# 19  mm_Day14.g4     obobBL6d14
# 20  mm_Day14.g4     obobFGF1BL6d14
# 21  mm_Day14.g7     obob14v14
# 22  mm_Day14.g7     obobBL6
# 23  mm_Day14.g7     obobBL6d14
# 24  mm_Day14.g7     obobFGF1BL6d14
# 25  mm_Day14.n_drop obob14v14
# 26  mm_Day14.n_drop obobBL6
# 27  mm_Day14.n_drop obobBL6d14
# 28  mm_Day14.n_drop obobFGF1BL6d14
# 29  mm_Day14.n0     obob14v14
# 30  mm_Day14.n0     obobBL6
# ⋮   ⋮               ⋮
# 256 mm_n5           obob5v5
# 257 mm_n5           obob5vBL6
# 258 mm_n5           obobBL6
# 259 mm_n5           obobBL6d14
# 260 mm_n5           obobBL6d5
# 261 mm_n5           obobFGF1BL6d14
# 262 mm_n5           obobFGF1BL6d5
# 263 mm_n5           obobVeh_PFd5d14
# 264 mm_n6           BL6d5d14
# 265 mm_n6           obob14v14
# 266 mm_n6           obob14vBL6
# 267 mm_n6           obob5v5
# 268 mm_n6           obob5vBL6
# 269 mm_n6           obobBL6
# 270 mm_n6           obobBL6d14
# 271 mm_n6           obobBL6d5
# 272 mm_n6           obobFGF1BL6d14
# 273 mm_n6           obobFGF1BL6d5
# 274 mm_n6           obobVeh_PFd5d14
# 275 mm_n8           BL6d5d14
# 276 mm_n8           obob14v14
# 277 mm_n8           obob14vBL6
# 278 mm_n8           obob5v5
# 279 mm_n8           obob5vBL6
# 280 mm_n8           obobBL6
# 281 mm_n8           obobBL6d14
# 282 mm_n8           obobBL6d5
# 283 mm_n8           obobFGF1BL6d14
# 284 mm_n8           obobFGF1BL6d5
# 285 mm_n8           obobVeh_PFd5d14
#     contrast
# 1   groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 2   ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 3   groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 4   groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 5   groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 6   ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 7   groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 8   groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 9   groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 10  ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 11  groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 12  groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 13  groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 14  ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 15  groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 16  groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 17  groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 18  ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 19  groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 20  groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 21  groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 22  ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 23  groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 24  groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 25  groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 26  ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 27  groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 28  groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 29  groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 30  ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# ⋮   ⋮
# 256 groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 257 groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 258 ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 259 groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 260 groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 261 groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 262 groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 263 groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob
# 264 groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 265 groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 266 groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 267 groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 268 groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 269 ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 270 groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 271 groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 272 groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 273 groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 274 groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob
# 275 groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 276 groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 277 groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 278 groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 279 groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 280 ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 281 groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 282 groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 283 groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 284 groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 285 groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob

# %%
qs::qsave(da_recipe, 'da_recipe_labels_chunk.qs')
