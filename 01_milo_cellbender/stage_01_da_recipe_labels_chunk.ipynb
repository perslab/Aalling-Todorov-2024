# %%
library(tidyverse)
library(targets)
library(tarchetypes)

# %%
clusters_tibble = qs::qread('clusters_tibble_labels_chunk.qs')

clusters_tibble$milo_obj = clusters_tibble %>%
    pull(label) %>%
    paste0("milo_", .) %>%
    rlang::syms()
clusters_tibble$milo_index_obj = clusters_tibble %>%
    pull(label) %>%
    paste0("milo_index_tibble_", .) %>%
    rlang::syms()
clusters_tibble$design_df = clusters_tibble %>%
    pull(label) %>%
    paste0("design_df_", .) %>%
    rlang::syms()
clusters_tibble$mm = clusters_tibble %>%
    pull(label) %>%
    paste0("mm_", .) %>%
    rlang::syms()
clusters_tibble
# Out:
#    label        object              day   cluster milo_obj
# 1  g_drop       exp_labelled_other  all   g_drop  milo_g_drop
# 2  Day14.g_drop exp_labelled_other  Day14 g_drop  milo_Day14.g_drop
# 3  Day5.g_drop  exp_labelled_other  Day5  g_drop  milo_Day5.g_drop
# 4  g1           exp_labelled_other  all   g1      milo_g1
# 5  Day14.g1     exp_labelled_other  Day14 g1      milo_Day14.g1
# 6  Day5.g1      exp_labelled_other  Day5  g1      milo_Day5.g1
# 7  g2           exp_labelled_other  all   g2      milo_g2
# 8  Day14.g2     exp_labelled_other  Day14 g2      milo_Day14.g2
# 9  Day5.g2      exp_labelled_other  Day5  g2      milo_Day5.g2
# 10 g3           exp_labelled_other  all   g3      milo_g3
# 11 Day14.g3     exp_labelled_other  Day14 g3      milo_Day14.g3
# 12 Day5.g3      exp_labelled_other  Day5  g3      milo_Day5.g3
# 13 g4           exp_labelled_other  all   g4      milo_g4
# 14 Day14.g4     exp_labelled_other  Day14 g4      milo_Day14.g4
# 15 Day5.g4      exp_labelled_other  Day5  g4      milo_Day5.g4
# 16 g5           exp_labelled_other  all   g5      milo_g5
# 17 Day14.g5     exp_labelled_other  Day14 g5      milo_Day14.g5
# 18 Day5.g5      exp_labelled_other  Day5  g5      milo_Day5.g5
# 19 g6           exp_labelled_other  all   g6      milo_g6
# 20 Day14.g6     exp_labelled_other  Day14 g6      milo_Day14.g6
# 21 Day5.g6      exp_labelled_other  Day5  g6      milo_Day5.g6
# 22 g7           exp_labelled_other  all   g7      milo_g7
# 23 Day14.g7     exp_labelled_other  Day14 g7      milo_Day14.g7
# 24 Day5.g7      exp_labelled_other  Day5  g7      milo_Day5.g7
# 25 n_drop       exp_labelled_neuron all   n_drop  milo_n_drop
# 26 Day14.n_drop exp_labelled_neuron Day14 n_drop  milo_Day14.n_drop
# 27 Day5.n_drop  exp_labelled_neuron Day5  n_drop  milo_Day5.n_drop
# 28 n0           exp_labelled_neuron all   n0      milo_n0
# 29 Day14.n0     exp_labelled_neuron Day14 n0      milo_Day14.n0
# 30 Day5.n0      exp_labelled_neuron Day5  n0      milo_Day5.n0
# 31 n1           exp_labelled_neuron all   n1      milo_n1
# 32 Day14.n1     exp_labelled_neuron Day14 n1      milo_Day14.n1
# 33 Day5.n1      exp_labelled_neuron Day5  n1      milo_Day5.n1
# 34 n10          exp_labelled_neuron all   n10     milo_n10
# 35 Day14.n10    exp_labelled_neuron Day14 n10     milo_Day14.n10
# 36 Day5.n10     exp_labelled_neuron Day5  n10     milo_Day5.n10
# 37 n2           exp_labelled_neuron all   n2      milo_n2
# 38 Day14.n2     exp_labelled_neuron Day14 n2      milo_Day14.n2
# 39 Day5.n2      exp_labelled_neuron Day5  n2      milo_Day5.n2
# 40 n3           exp_labelled_neuron all   n3      milo_n3
# 41 Day14.n3     exp_labelled_neuron Day14 n3      milo_Day14.n3
# 42 Day5.n3      exp_labelled_neuron Day5  n3      milo_Day5.n3
# 43 n4           exp_labelled_neuron all   n4      milo_n4
# 44 Day14.n4     exp_labelled_neuron Day14 n4      milo_Day14.n4
# 45 Day5.n4      exp_labelled_neuron Day5  n4      milo_Day5.n4
# 46 n5           exp_labelled_neuron all   n5      milo_n5
# 47 Day14.n5     exp_labelled_neuron Day14 n5      milo_Day14.n5
# 48 Day5.n5      exp_labelled_neuron Day5  n5      milo_Day5.n5
# 49 n6           exp_labelled_neuron all   n6      milo_n6
# 50 Day14.n6     exp_labelled_neuron Day14 n6      milo_Day14.n6
# 51 Day5.n6      exp_labelled_neuron Day5  n6      milo_Day5.n6
# 52 n7           exp_labelled_neuron all   n7      milo_n7
# 53 Day14.n7     exp_labelled_neuron Day14 n7      milo_Day14.n7
# 54 Day5.n7      exp_labelled_neuron Day5  n7      milo_Day5.n7
# 55 n8           exp_labelled_neuron all   n8      milo_n8
# 56 Day14.n8     exp_labelled_neuron Day14 n8      milo_Day14.n8
# 57 Day5.n8      exp_labelled_neuron Day5  n8      milo_Day5.n8
# 58 n9           exp_labelled_neuron all   n9      milo_n9
# 59 Day14.n9     exp_labelled_neuron Day14 n9      milo_Day14.n9
# 60 Day5.n9      exp_labelled_neuron Day5  n9      milo_Day5.n9
#    milo_index_obj                 design_df              mm
# 1  milo_index_tibble_g_drop       design_df_g_drop       mm_g_drop
# 2  milo_index_tibble_Day14.g_drop design_df_Day14.g_drop mm_Day14.g_drop
# 3  milo_index_tibble_Day5.g_drop  design_df_Day5.g_drop  mm_Day5.g_drop
# 4  milo_index_tibble_g1           design_df_g1           mm_g1
# 5  milo_index_tibble_Day14.g1     design_df_Day14.g1     mm_Day14.g1
# 6  milo_index_tibble_Day5.g1      design_df_Day5.g1      mm_Day5.g1
# 7  milo_index_tibble_g2           design_df_g2           mm_g2
# 8  milo_index_tibble_Day14.g2     design_df_Day14.g2     mm_Day14.g2
# 9  milo_index_tibble_Day5.g2      design_df_Day5.g2      mm_Day5.g2
# 10 milo_index_tibble_g3           design_df_g3           mm_g3
# 11 milo_index_tibble_Day14.g3     design_df_Day14.g3     mm_Day14.g3
# 12 milo_index_tibble_Day5.g3      design_df_Day5.g3      mm_Day5.g3
# 13 milo_index_tibble_g4           design_df_g4           mm_g4
# 14 milo_index_tibble_Day14.g4     design_df_Day14.g4     mm_Day14.g4
# 15 milo_index_tibble_Day5.g4      design_df_Day5.g4      mm_Day5.g4
# 16 milo_index_tibble_g5           design_df_g5           mm_g5
# 17 milo_index_tibble_Day14.g5     design_df_Day14.g5     mm_Day14.g5
# 18 milo_index_tibble_Day5.g5      design_df_Day5.g5      mm_Day5.g5
# 19 milo_index_tibble_g6           design_df_g6           mm_g6
# 20 milo_index_tibble_Day14.g6     design_df_Day14.g6     mm_Day14.g6
# 21 milo_index_tibble_Day5.g6      design_df_Day5.g6      mm_Day5.g6
# 22 milo_index_tibble_g7           design_df_g7           mm_g7
# 23 milo_index_tibble_Day14.g7     design_df_Day14.g7     mm_Day14.g7
# 24 milo_index_tibble_Day5.g7      design_df_Day5.g7      mm_Day5.g7
# 25 milo_index_tibble_n_drop       design_df_n_drop       mm_n_drop
# 26 milo_index_tibble_Day14.n_drop design_df_Day14.n_drop mm_Day14.n_drop
# 27 milo_index_tibble_Day5.n_drop  design_df_Day5.n_drop  mm_Day5.n_drop
# 28 milo_index_tibble_n0           design_df_n0           mm_n0
# 29 milo_index_tibble_Day14.n0     design_df_Day14.n0     mm_Day14.n0
# 30 milo_index_tibble_Day5.n0      design_df_Day5.n0      mm_Day5.n0
# 31 milo_index_tibble_n1           design_df_n1           mm_n1
# 32 milo_index_tibble_Day14.n1     design_df_Day14.n1     mm_Day14.n1
# 33 milo_index_tibble_Day5.n1      design_df_Day5.n1      mm_Day5.n1
# 34 milo_index_tibble_n10          design_df_n10          mm_n10
# 35 milo_index_tibble_Day14.n10    design_df_Day14.n10    mm_Day14.n10
# 36 milo_index_tibble_Day5.n10     design_df_Day5.n10     mm_Day5.n10
# 37 milo_index_tibble_n2           design_df_n2           mm_n2
# 38 milo_index_tibble_Day14.n2     design_df_Day14.n2     mm_Day14.n2
# 39 milo_index_tibble_Day5.n2      design_df_Day5.n2      mm_Day5.n2
# 40 milo_index_tibble_n3           design_df_n3           mm_n3
# 41 milo_index_tibble_Day14.n3     design_df_Day14.n3     mm_Day14.n3
# 42 milo_index_tibble_Day5.n3      design_df_Day5.n3      mm_Day5.n3
# 43 milo_index_tibble_n4           design_df_n4           mm_n4
# 44 milo_index_tibble_Day14.n4     design_df_Day14.n4     mm_Day14.n4
# 45 milo_index_tibble_Day5.n4      design_df_Day5.n4      mm_Day5.n4
# 46 milo_index_tibble_n5           design_df_n5           mm_n5
# 47 milo_index_tibble_Day14.n5     design_df_Day14.n5     mm_Day14.n5
# 48 milo_index_tibble_Day5.n5      design_df_Day5.n5      mm_Day5.n5
# 49 milo_index_tibble_n6           design_df_n6           mm_n6
# 50 milo_index_tibble_Day14.n6     design_df_Day14.n6     mm_Day14.n6
# 51 milo_index_tibble_Day5.n6      design_df_Day5.n6      mm_Day5.n6
# 52 milo_index_tibble_n7           design_df_n7           mm_n7
# 53 milo_index_tibble_Day14.n7     design_df_Day14.n7     mm_Day14.n7
# 54 milo_index_tibble_Day5.n7      design_df_Day5.n7      mm_Day5.n7
# 55 milo_index_tibble_n8           design_df_n8           mm_n8
# 56 milo_index_tibble_Day14.n8     design_df_Day14.n8     mm_Day14.n8
# 57 milo_index_tibble_Day5.n8      design_df_Day5.n8      mm_Day5.n8
# 58 milo_index_tibble_n9           design_df_n9           mm_n9
# 59 milo_index_tibble_Day14.n9     design_df_Day14.n9     mm_Day14.n9
# 60 milo_index_tibble_Day5.n9      design_df_Day5.n9      mm_Day5.n9

# %%
contrasts_tibble = tibble(
    contrast_name = c("obob5v5",
                      "obob14v14",
                      "obobBL6",
                      "obobBL6d5",
                      "obobBL6d14",
                      "obob5vBL6",
                      "obob14vBL6",
                      "obobFGF1BL6d5",
                      "obobFGF1BL6d14",
                      "BL6d5d14",
                      "obobVeh_PFd5d14"),
    contrast = c("groupFGF1.Day5.obob - groupVeh_PF.Day5.obob",
                 "groupFGF1.Day14.obob - groupVeh_PF.Day14.obob",
                 "((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)",
                 "groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6",
                 "groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6",
                 "groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)",
                 "groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)",
                 "groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6",
                 "groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6",
                 "groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6",
                 "groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob")
)
contrasts_tibble
# Out:
#    contrast_name
# 1  obob5v5
# 2  obob14v14
# 3  obobBL6
# 4  obobBL6d5
# 5  obobBL6d14
# 6  obob5vBL6
# 7  obob14vBL6
# 8  obobFGF1BL6d5
# 9  obobFGF1BL6d14
# 10 BL6d5d14
# 11 obobVeh_PFd5d14
#    contrast
# 1  groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 2  groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 3  ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 4  groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 5  groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 6  groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 7  groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 8  groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 9  groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 10 groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 11 groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob

# %%
da_recipe = tidyr::crossing(clusters_tibble, contrasts_tibble)
da_recipe$label = paste0(da_recipe$label, '___', da_recipe$contrast_name)
head(da_recipe)
# Out:
#   label                     object             day   cluster milo_obj
# 1 Day14.g_drop___BL6d5d14   exp_labelled_other Day14 g_drop  milo_Day14.g_drop
# 2 Day14.g_drop___obob14v14  exp_labelled_other Day14 g_drop  milo_Day14.g_drop
# 3 Day14.g_drop___obob14vBL6 exp_labelled_other Day14 g_drop  milo_Day14.g_drop
# 4 Day14.g_drop___obob5v5    exp_labelled_other Day14 g_drop  milo_Day14.g_drop
# 5 Day14.g_drop___obob5vBL6  exp_labelled_other Day14 g_drop  milo_Day14.g_drop
# 6 Day14.g_drop___obobBL6    exp_labelled_other Day14 g_drop  milo_Day14.g_drop
#   milo_index_obj                 design_df              mm
# 1 milo_index_tibble_Day14.g_drop design_df_Day14.g_drop mm_Day14.g_drop
# 2 milo_index_tibble_Day14.g_drop design_df_Day14.g_drop mm_Day14.g_drop
# 3 milo_index_tibble_Day14.g_drop design_df_Day14.g_drop mm_Day14.g_drop
# 4 milo_index_tibble_Day14.g_drop design_df_Day14.g_drop mm_Day14.g_drop
# 5 milo_index_tibble_Day14.g_drop design_df_Day14.g_drop mm_Day14.g_drop
# 6 milo_index_tibble_Day14.g_drop design_df_Day14.g_drop mm_Day14.g_drop
#   contrast_name
# 1 BL6d5d14
# 2 obob14v14
# 3 obob14vBL6
# 4 obob5v5
# 5 obob5vBL6
# 6 obobBL6
#   contrast
# 1 groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 2 groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 3 groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 4 groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 5 groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 6 ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)

# %%
da_recipe = da_recipe %>%
filter(!(str_detect(contrast_name, "obob5v5") & day == 'Day14')) %>%
filter(!(str_detect(contrast_name, "obob14v14") & day == 'Day5')) %>%
# filter(!(contrast_name == 'obobBL6' & day != 'all')) %>% # this one is good to have, as they may be equivalent
filter(!(contrast_name == 'obobBL6d5' & (day == 'Day14'))) %>%
filter(!(contrast_name == 'obobBL6d14' & (day == 'Day5'))) %>%
filter(!(contrast_name == 'obobFGF1BL6d5' & (day == 'Day14'))) %>% 
filter(!(contrast_name == 'obobFGF1BL6d14' & (day == 'Day5'))) %>%
filter(!(contrast_name == "obob5vBL6" & (day != 'all'))) %>% 
filter(!(contrast_name == "obob14vBL6" & (day != 'all'))) %>%
filter(!(contrast_name == 'BL6d5d14' & (day != 'all'))) %>%
filter(!(contrast_name == 'obobVeh_PFd5d14' & (day != 'all')))

# %%
da_recipe
# Out:
#     label                         object              day   cluster
# 1   Day14.g_drop___obob14v14      exp_labelled_other  Day14 g_drop
# 2   Day14.g_drop___obobBL6        exp_labelled_other  Day14 g_drop
# 3   Day14.g_drop___obobBL6d14     exp_labelled_other  Day14 g_drop
# 4   Day14.g_drop___obobFGF1BL6d14 exp_labelled_other  Day14 g_drop
# 5   Day14.g1___obob14v14          exp_labelled_other  Day14 g1
# 6   Day14.g1___obobBL6            exp_labelled_other  Day14 g1
# 7   Day14.g1___obobBL6d14         exp_labelled_other  Day14 g1
# 8   Day14.g1___obobFGF1BL6d14     exp_labelled_other  Day14 g1
# 9   Day14.g2___obob14v14          exp_labelled_other  Day14 g2
# 10  Day14.g2___obobBL6            exp_labelled_other  Day14 g2
# 11  Day14.g2___obobBL6d14         exp_labelled_other  Day14 g2
# 12  Day14.g2___obobFGF1BL6d14     exp_labelled_other  Day14 g2
# 13  Day14.g3___obob14v14          exp_labelled_other  Day14 g3
# 14  Day14.g3___obobBL6            exp_labelled_other  Day14 g3
# 15  Day14.g3___obobBL6d14         exp_labelled_other  Day14 g3
# 16  Day14.g3___obobFGF1BL6d14     exp_labelled_other  Day14 g3
# 17  Day14.g4___obob14v14          exp_labelled_other  Day14 g4
# 18  Day14.g4___obobBL6            exp_labelled_other  Day14 g4
# 19  Day14.g4___obobBL6d14         exp_labelled_other  Day14 g4
# 20  Day14.g4___obobFGF1BL6d14     exp_labelled_other  Day14 g4
# 21  Day14.g5___obob14v14          exp_labelled_other  Day14 g5
# 22  Day14.g5___obobBL6            exp_labelled_other  Day14 g5
# 23  Day14.g5___obobBL6d14         exp_labelled_other  Day14 g5
# 24  Day14.g5___obobFGF1BL6d14     exp_labelled_other  Day14 g5
# 25  Day14.g6___obob14v14          exp_labelled_other  Day14 g6
# 26  Day14.g6___obobBL6            exp_labelled_other  Day14 g6
# 27  Day14.g6___obobBL6d14         exp_labelled_other  Day14 g6
# 28  Day14.g6___obobFGF1BL6d14     exp_labelled_other  Day14 g6
# 29  Day14.g7___obob14v14          exp_labelled_other  Day14 g7
# 30  Day14.g7___obobBL6            exp_labelled_other  Day14 g7
# ⋮   ⋮                             ⋮                   ⋮     ⋮
# 351 n7___obob5v5                  exp_labelled_neuron all   n7
# 352 n7___obob5vBL6                exp_labelled_neuron all   n7
# 353 n7___obobBL6                  exp_labelled_neuron all   n7
# 354 n7___obobBL6d14               exp_labelled_neuron all   n7
# 355 n7___obobBL6d5                exp_labelled_neuron all   n7
# 356 n7___obobFGF1BL6d14           exp_labelled_neuron all   n7
# 357 n7___obobFGF1BL6d5            exp_labelled_neuron all   n7
# 358 n7___obobVeh_PFd5d14          exp_labelled_neuron all   n7
# 359 n8___BL6d5d14                 exp_labelled_neuron all   n8
# 360 n8___obob14v14                exp_labelled_neuron all   n8
# 361 n8___obob14vBL6               exp_labelled_neuron all   n8
# 362 n8___obob5v5                  exp_labelled_neuron all   n8
# 363 n8___obob5vBL6                exp_labelled_neuron all   n8
# 364 n8___obobBL6                  exp_labelled_neuron all   n8
# 365 n8___obobBL6d14               exp_labelled_neuron all   n8
# 366 n8___obobBL6d5                exp_labelled_neuron all   n8
# 367 n8___obobFGF1BL6d14           exp_labelled_neuron all   n8
# 368 n8___obobFGF1BL6d5            exp_labelled_neuron all   n8
# 369 n8___obobVeh_PFd5d14          exp_labelled_neuron all   n8
# 370 n9___BL6d5d14                 exp_labelled_neuron all   n9
# 371 n9___obob14v14                exp_labelled_neuron all   n9
# 372 n9___obob14vBL6               exp_labelled_neuron all   n9
# 373 n9___obob5v5                  exp_labelled_neuron all   n9
# 374 n9___obob5vBL6                exp_labelled_neuron all   n9
# 375 n9___obobBL6                  exp_labelled_neuron all   n9
# 376 n9___obobBL6d14               exp_labelled_neuron all   n9
# 377 n9___obobBL6d5                exp_labelled_neuron all   n9
# 378 n9___obobFGF1BL6d14           exp_labelled_neuron all   n9
# 379 n9___obobFGF1BL6d5            exp_labelled_neuron all   n9
# 380 n9___obobVeh_PFd5d14          exp_labelled_neuron all   n9
#     milo_obj          milo_index_obj                 design_df
# 1   milo_Day14.g_drop milo_index_tibble_Day14.g_drop design_df_Day14.g_drop
# 2   milo_Day14.g_drop milo_index_tibble_Day14.g_drop design_df_Day14.g_drop
# 3   milo_Day14.g_drop milo_index_tibble_Day14.g_drop design_df_Day14.g_drop
# 4   milo_Day14.g_drop milo_index_tibble_Day14.g_drop design_df_Day14.g_drop
# 5   milo_Day14.g1     milo_index_tibble_Day14.g1     design_df_Day14.g1
# 6   milo_Day14.g1     milo_index_tibble_Day14.g1     design_df_Day14.g1
# 7   milo_Day14.g1     milo_index_tibble_Day14.g1     design_df_Day14.g1
# 8   milo_Day14.g1     milo_index_tibble_Day14.g1     design_df_Day14.g1
# 9   milo_Day14.g2     milo_index_tibble_Day14.g2     design_df_Day14.g2
# 10  milo_Day14.g2     milo_index_tibble_Day14.g2     design_df_Day14.g2
# 11  milo_Day14.g2     milo_index_tibble_Day14.g2     design_df_Day14.g2
# 12  milo_Day14.g2     milo_index_tibble_Day14.g2     design_df_Day14.g2
# 13  milo_Day14.g3     milo_index_tibble_Day14.g3     design_df_Day14.g3
# 14  milo_Day14.g3     milo_index_tibble_Day14.g3     design_df_Day14.g3
# 15  milo_Day14.g3     milo_index_tibble_Day14.g3     design_df_Day14.g3
# 16  milo_Day14.g3     milo_index_tibble_Day14.g3     design_df_Day14.g3
# 17  milo_Day14.g4     milo_index_tibble_Day14.g4     design_df_Day14.g4
# 18  milo_Day14.g4     milo_index_tibble_Day14.g4     design_df_Day14.g4
# 19  milo_Day14.g4     milo_index_tibble_Day14.g4     design_df_Day14.g4
# 20  milo_Day14.g4     milo_index_tibble_Day14.g4     design_df_Day14.g4
# 21  milo_Day14.g5     milo_index_tibble_Day14.g5     design_df_Day14.g5
# 22  milo_Day14.g5     milo_index_tibble_Day14.g5     design_df_Day14.g5
# 23  milo_Day14.g5     milo_index_tibble_Day14.g5     design_df_Day14.g5
# 24  milo_Day14.g5     milo_index_tibble_Day14.g5     design_df_Day14.g5
# 25  milo_Day14.g6     milo_index_tibble_Day14.g6     design_df_Day14.g6
# 26  milo_Day14.g6     milo_index_tibble_Day14.g6     design_df_Day14.g6
# 27  milo_Day14.g6     milo_index_tibble_Day14.g6     design_df_Day14.g6
# 28  milo_Day14.g6     milo_index_tibble_Day14.g6     design_df_Day14.g6
# 29  milo_Day14.g7     milo_index_tibble_Day14.g7     design_df_Day14.g7
# 30  milo_Day14.g7     milo_index_tibble_Day14.g7     design_df_Day14.g7
# ⋮   ⋮                 ⋮                              ⋮
# 351 milo_n7           milo_index_tibble_n7           design_df_n7
# 352 milo_n7           milo_index_tibble_n7           design_df_n7
# 353 milo_n7           milo_index_tibble_n7           design_df_n7
# 354 milo_n7           milo_index_tibble_n7           design_df_n7
# 355 milo_n7           milo_index_tibble_n7           design_df_n7
# 356 milo_n7           milo_index_tibble_n7           design_df_n7
# 357 milo_n7           milo_index_tibble_n7           design_df_n7
# 358 milo_n7           milo_index_tibble_n7           design_df_n7
# 359 milo_n8           milo_index_tibble_n8           design_df_n8
# 360 milo_n8           milo_index_tibble_n8           design_df_n8
# 361 milo_n8           milo_index_tibble_n8           design_df_n8
# 362 milo_n8           milo_index_tibble_n8           design_df_n8
# 363 milo_n8           milo_index_tibble_n8           design_df_n8
# 364 milo_n8           milo_index_tibble_n8           design_df_n8
# 365 milo_n8           milo_index_tibble_n8           design_df_n8
# 366 milo_n8           milo_index_tibble_n8           design_df_n8
# 367 milo_n8           milo_index_tibble_n8           design_df_n8
# 368 milo_n8           milo_index_tibble_n8           design_df_n8
# 369 milo_n8           milo_index_tibble_n8           design_df_n8
# 370 milo_n9           milo_index_tibble_n9           design_df_n9
# 371 milo_n9           milo_index_tibble_n9           design_df_n9
# 372 milo_n9           milo_index_tibble_n9           design_df_n9
# 373 milo_n9           milo_index_tibble_n9           design_df_n9
# 374 milo_n9           milo_index_tibble_n9           design_df_n9
# 375 milo_n9           milo_index_tibble_n9           design_df_n9
# 376 milo_n9           milo_index_tibble_n9           design_df_n9
# 377 milo_n9           milo_index_tibble_n9           design_df_n9
# 378 milo_n9           milo_index_tibble_n9           design_df_n9
# 379 milo_n9           milo_index_tibble_n9           design_df_n9
# 380 milo_n9           milo_index_tibble_n9           design_df_n9
#     mm              contrast_name
# 1   mm_Day14.g_drop obob14v14
# 2   mm_Day14.g_drop obobBL6
# 3   mm_Day14.g_drop obobBL6d14
# 4   mm_Day14.g_drop obobFGF1BL6d14
# 5   mm_Day14.g1     obob14v14
# 6   mm_Day14.g1     obobBL6
# 7   mm_Day14.g1     obobBL6d14
# 8   mm_Day14.g1     obobFGF1BL6d14
# 9   mm_Day14.g2     obob14v14
# 10  mm_Day14.g2     obobBL6
# 11  mm_Day14.g2     obobBL6d14
# 12  mm_Day14.g2     obobFGF1BL6d14
# 13  mm_Day14.g3     obob14v14
# 14  mm_Day14.g3     obobBL6
# 15  mm_Day14.g3     obobBL6d14
# 16  mm_Day14.g3     obobFGF1BL6d14
# 17  mm_Day14.g4     obob14v14
# 18  mm_Day14.g4     obobBL6
# 19  mm_Day14.g4     obobBL6d14
# 20  mm_Day14.g4     obobFGF1BL6d14
# 21  mm_Day14.g5     obob14v14
# 22  mm_Day14.g5     obobBL6
# 23  mm_Day14.g5     obobBL6d14
# 24  mm_Day14.g5     obobFGF1BL6d14
# 25  mm_Day14.g6     obob14v14
# 26  mm_Day14.g6     obobBL6
# 27  mm_Day14.g6     obobBL6d14
# 28  mm_Day14.g6     obobFGF1BL6d14
# 29  mm_Day14.g7     obob14v14
# 30  mm_Day14.g7     obobBL6
# ⋮   ⋮               ⋮
# 351 mm_n7           obob5v5
# 352 mm_n7           obob5vBL6
# 353 mm_n7           obobBL6
# 354 mm_n7           obobBL6d14
# 355 mm_n7           obobBL6d5
# 356 mm_n7           obobFGF1BL6d14
# 357 mm_n7           obobFGF1BL6d5
# 358 mm_n7           obobVeh_PFd5d14
# 359 mm_n8           BL6d5d14
# 360 mm_n8           obob14v14
# 361 mm_n8           obob14vBL6
# 362 mm_n8           obob5v5
# 363 mm_n8           obob5vBL6
# 364 mm_n8           obobBL6
# 365 mm_n8           obobBL6d14
# 366 mm_n8           obobBL6d5
# 367 mm_n8           obobFGF1BL6d14
# 368 mm_n8           obobFGF1BL6d5
# 369 mm_n8           obobVeh_PFd5d14
# 370 mm_n9           BL6d5d14
# 371 mm_n9           obob14v14
# 372 mm_n9           obob14vBL6
# 373 mm_n9           obob5v5
# 374 mm_n9           obob5vBL6
# 375 mm_n9           obobBL6
# 376 mm_n9           obobBL6d14
# 377 mm_n9           obobBL6d5
# 378 mm_n9           obobFGF1BL6d14
# 379 mm_n9           obobFGF1BL6d5
# 380 mm_n9           obobVeh_PFd5d14
#     contrast
# 1   groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 2   ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 3   groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 4   groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 5   groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 6   ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 7   groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 8   groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 9   groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 10  ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 11  groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 12  groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 13  groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 14  ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 15  groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 16  groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 17  groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 18  ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 19  groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 20  groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 21  groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 22  ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 23  groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 24  groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 25  groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 26  ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 27  groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 28  groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 29  groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 30  ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# ⋮   ⋮
# 351 groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 352 groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 353 ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 354 groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 355 groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 356 groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 357 groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 358 groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob
# 359 groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 360 groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 361 groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 362 groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 363 groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 364 ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 365 groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 366 groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 367 groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 368 groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 369 groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob
# 370 groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 371 groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 372 groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 373 groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 374 groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 375 ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 376 groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 377 groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 378 groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 379 groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 380 groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob

# %%
qs::qsave(da_recipe, 'da_recipe_labels_chunk.qs')
