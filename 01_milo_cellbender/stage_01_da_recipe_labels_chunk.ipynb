# %%
library(tidyverse)
library(targets)
library(tarchetypes)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.2     ✔ purrr   0.3.4
# ✔ tibble  3.2.1     ✔ dplyr   1.1.2
# ✔ tidyr   1.2.1     ✔ stringr 1.4.1
# ✔ readr   2.1.2     ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
clusters_tibble = qs::qread('clusters_tibble_labels_chunk.qs')

clusters_tibble$milo_obj = clusters_tibble %>%
    pull(label) %>%
    paste0("milo_", .) %>%
    rlang::syms()
clusters_tibble$milo_index_obj = clusters_tibble %>%
    pull(label) %>%
    paste0("milo_index_tibble_", .) %>%
    rlang::syms()
clusters_tibble$design_df = clusters_tibble %>%
    pull(label) %>%
    paste0("design_df_", .) %>%
    rlang::syms()
clusters_tibble$mm = clusters_tibble %>%
    pull(label) %>%
    paste0("mm_", .) %>%
    rlang::syms()
clusters_tibble
# Out:
#    label        object              day   cluster milo_obj
# 1  Day14.g_drop exp_labelled_other  Day14 g_drop  milo_Day14.g_drop
# 2  Day5.g_drop  exp_labelled_other  Day5  g_drop  milo_Day5.g_drop
# 3  Day14.g1     exp_labelled_other  Day14 g1      milo_Day14.g1
# 4  Day5.g1      exp_labelled_other  Day5  g1      milo_Day5.g1
# 5  Day14.g2     exp_labelled_other  Day14 g2      milo_Day14.g2
# 6  Day5.g2      exp_labelled_other  Day5  g2      milo_Day5.g2
# 7  Day14.g3     exp_labelled_other  Day14 g3      milo_Day14.g3
# 8  Day5.g3      exp_labelled_other  Day5  g3      milo_Day5.g3
# 9  Day14.g4     exp_labelled_other  Day14 g4      milo_Day14.g4
# 10 Day5.g4      exp_labelled_other  Day5  g4      milo_Day5.g4
# 11 Day14.g7     exp_labelled_other  Day14 g7      milo_Day14.g7
# 12 Day5.g7      exp_labelled_other  Day5  g7      milo_Day5.g7
# 13 Day14.n_drop exp_labelled_neuron Day14 n_drop  milo_Day14.n_drop
# 14 Day5.n_drop  exp_labelled_neuron Day5  n_drop  milo_Day5.n_drop
# 15 Day14.n0     exp_labelled_neuron Day14 n0      milo_Day14.n0
# 16 Day5.n0      exp_labelled_neuron Day5  n0      milo_Day5.n0
# 17 Day14.n1     exp_labelled_neuron Day14 n1      milo_Day14.n1
# 18 Day5.n1      exp_labelled_neuron Day5  n1      milo_Day5.n1
# 19 Day14.n2     exp_labelled_neuron Day14 n2      milo_Day14.n2
# 20 Day5.n2      exp_labelled_neuron Day5  n2      milo_Day5.n2
# 21 Day14.n3     exp_labelled_neuron Day14 n3      milo_Day14.n3
# 22 Day5.n3      exp_labelled_neuron Day5  n3      milo_Day5.n3
# 23 Day14.n4     exp_labelled_neuron Day14 n4      milo_Day14.n4
# 24 Day5.n4      exp_labelled_neuron Day5  n4      milo_Day5.n4
# 25 Day14.n5     exp_labelled_neuron Day14 n5      milo_Day14.n5
# 26 Day5.n5      exp_labelled_neuron Day5  n5      milo_Day5.n5
# 27 Day14.n6     exp_labelled_neuron Day14 n6      milo_Day14.n6
# 28 Day5.n6      exp_labelled_neuron Day5  n6      milo_Day5.n6
# 29 Day14.n8     exp_labelled_neuron Day14 n8      milo_Day14.n8
# 30 Day5.n8      exp_labelled_neuron Day5  n8      milo_Day5.n8
#    milo_index_obj                 design_df              mm
# 1  milo_index_tibble_Day14.g_drop design_df_Day14.g_drop mm_Day14.g_drop
# 2  milo_index_tibble_Day5.g_drop  design_df_Day5.g_drop  mm_Day5.g_drop
# 3  milo_index_tibble_Day14.g1     design_df_Day14.g1     mm_Day14.g1
# 4  milo_index_tibble_Day5.g1      design_df_Day5.g1      mm_Day5.g1
# 5  milo_index_tibble_Day14.g2     design_df_Day14.g2     mm_Day14.g2
# 6  milo_index_tibble_Day5.g2      design_df_Day5.g2      mm_Day5.g2
# 7  milo_index_tibble_Day14.g3     design_df_Day14.g3     mm_Day14.g3
# 8  milo_index_tibble_Day5.g3      design_df_Day5.g3      mm_Day5.g3
# 9  milo_index_tibble_Day14.g4     design_df_Day14.g4     mm_Day14.g4
# 10 milo_index_tibble_Day5.g4      design_df_Day5.g4      mm_Day5.g4
# 11 milo_index_tibble_Day14.g7     design_df_Day14.g7     mm_Day14.g7
# 12 milo_index_tibble_Day5.g7      design_df_Day5.g7      mm_Day5.g7
# 13 milo_index_tibble_Day14.n_drop design_df_Day14.n_drop mm_Day14.n_drop
# 14 milo_index_tibble_Day5.n_drop  design_df_Day5.n_drop  mm_Day5.n_drop
# 15 milo_index_tibble_Day14.n0     design_df_Day14.n0     mm_Day14.n0
# 16 milo_index_tibble_Day5.n0      design_df_Day5.n0      mm_Day5.n0
# 17 milo_index_tibble_Day14.n1     design_df_Day14.n1     mm_Day14.n1
# 18 milo_index_tibble_Day5.n1      design_df_Day5.n1      mm_Day5.n1
# 19 milo_index_tibble_Day14.n2     design_df_Day14.n2     mm_Day14.n2
# 20 milo_index_tibble_Day5.n2      design_df_Day5.n2      mm_Day5.n2
# 21 milo_index_tibble_Day14.n3     design_df_Day14.n3     mm_Day14.n3
# 22 milo_index_tibble_Day5.n3      design_df_Day5.n3      mm_Day5.n3
# 23 milo_index_tibble_Day14.n4     design_df_Day14.n4     mm_Day14.n4
# 24 milo_index_tibble_Day5.n4      design_df_Day5.n4      mm_Day5.n4
# 25 milo_index_tibble_Day14.n5     design_df_Day14.n5     mm_Day14.n5
# 26 milo_index_tibble_Day5.n5      design_df_Day5.n5      mm_Day5.n5
# 27 milo_index_tibble_Day14.n6     design_df_Day14.n6     mm_Day14.n6
# 28 milo_index_tibble_Day5.n6      design_df_Day5.n6      mm_Day5.n6
# 29 milo_index_tibble_Day14.n8     design_df_Day14.n8     mm_Day14.n8
# 30 milo_index_tibble_Day5.n8      design_df_Day5.n8      mm_Day5.n8

# %%
contrasts_tibble = tibble(
    contrast_name = c("obob5v5",
                      "obob14v14",
                      "obobBL6",
                      "obobBL6d5",
                      "obobBL6d14",
                      "obob5vBL6",
                      "obob14vBL6",
                      "obobFGF1BL6d5",
                      "obobFGF1BL6d14",
                      "BL6d5d14",
                      "obobVeh_PFd5d14"),
    contrast = c("groupFGF1.Day5.obob - groupVeh_PF.Day5.obob",
                 "groupFGF1.Day14.obob - groupVeh_PF.Day14.obob",
                 "((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)",
                 "groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6",
                 "groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6",
                 "groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)",
                 "groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)",
                 "groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6",
                 "groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6",
                 "groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6",
                 "groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob")
)
contrasts_tibble
# Out:
#    contrast_name
# 1  obob5v5
# 2  obob14v14
# 3  obobBL6
# 4  obobBL6d5
# 5  obobBL6d14
# 6  obob5vBL6
# 7  obob14vBL6
# 8  obobFGF1BL6d5
# 9  obobFGF1BL6d14
# 10 BL6d5d14
# 11 obobVeh_PFd5d14
#    contrast
# 1  groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 2  groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 3  ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 4  groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 5  groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 6  groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 7  groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 8  groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 9  groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 10 groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 11 groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob

# %%
contrasts_tibble = contrasts_tibble %>%
filter(contrast_name %in% c("obob5v5", "obob14v14", "obobBL6d5", "obobBL6d14"))

contrasts_tibble
# Out:
#   contrast_name contrast
# 1 obob5v5       groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 2 obob14v14     groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 3 obobBL6d5     groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 4 obobBL6d14    groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6

# %%
da_recipe = tidyr::crossing(clusters_tibble, contrasts_tibble)
da_recipe$label = paste0(da_recipe$label, '___', da_recipe$contrast_name)
head(da_recipe)
# Out:
#   label                     object             day   cluster milo_obj
# 1 Day14.g_drop___obob14v14  exp_labelled_other Day14 g_drop  milo_Day14.g_drop
# 2 Day14.g_drop___obob5v5    exp_labelled_other Day14 g_drop  milo_Day14.g_drop
# 3 Day14.g_drop___obobBL6d14 exp_labelled_other Day14 g_drop  milo_Day14.g_drop
# 4 Day14.g_drop___obobBL6d5  exp_labelled_other Day14 g_drop  milo_Day14.g_drop
# 5 Day14.g1___obob14v14      exp_labelled_other Day14 g1      milo_Day14.g1
# 6 Day14.g1___obob5v5        exp_labelled_other Day14 g1      milo_Day14.g1
#   milo_index_obj                 design_df              mm
# 1 milo_index_tibble_Day14.g_drop design_df_Day14.g_drop mm_Day14.g_drop
# 2 milo_index_tibble_Day14.g_drop design_df_Day14.g_drop mm_Day14.g_drop
# 3 milo_index_tibble_Day14.g_drop design_df_Day14.g_drop mm_Day14.g_drop
# 4 milo_index_tibble_Day14.g_drop design_df_Day14.g_drop mm_Day14.g_drop
# 5 milo_index_tibble_Day14.g1     design_df_Day14.g1     mm_Day14.g1
# 6 milo_index_tibble_Day14.g1     design_df_Day14.g1     mm_Day14.g1
#   contrast_name contrast
# 1 obob14v14     groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 2 obob5v5       groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 3 obobBL6d14    groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 4 obobBL6d5     groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 5 obob14v14     groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 6 obob5v5       groupFGF1.Day5.obob - groupVeh_PF.Day5.obob

# %%
da_recipe = da_recipe %>%
filter(!(str_detect(contrast_name, "obob5v5") & day == 'Day14')) %>%
filter(!(str_detect(contrast_name, "obob14v14") & day == 'Day5')) %>%
# filter(!(contrast_name == 'obobBL6' & day != 'all')) %>% # this one is good to have, as they may be equivalent
filter(!(contrast_name == 'obobBL6d5' & (day == 'Day14'))) %>%
filter(!(contrast_name == 'obobBL6d14' & (day == 'Day5'))) %>%
filter(!(contrast_name == 'obobFGF1BL6d5' & (day == 'Day14'))) %>% 
filter(!(contrast_name == 'obobFGF1BL6d14' & (day == 'Day5'))) %>%
filter(!(contrast_name == "obob5vBL6" & (day != 'all'))) %>% 
filter(!(contrast_name == "obob14vBL6" & (day != 'all'))) %>%
filter(!(contrast_name == 'BL6d5d14' & (day != 'all'))) %>%
filter(!(contrast_name == 'obobVeh_PFd5d14' & (day != 'all')))

# %%
da_recipe
# Out:
#    label                     object              day   cluster
# 1  Day14.g_drop___obob14v14  exp_labelled_other  Day14 g_drop
# 2  Day14.g_drop___obobBL6d14 exp_labelled_other  Day14 g_drop
# 3  Day14.g1___obob14v14      exp_labelled_other  Day14 g1
# 4  Day14.g1___obobBL6d14     exp_labelled_other  Day14 g1
# 5  Day14.g2___obob14v14      exp_labelled_other  Day14 g2
# 6  Day14.g2___obobBL6d14     exp_labelled_other  Day14 g2
# 7  Day14.g3___obob14v14      exp_labelled_other  Day14 g3
# 8  Day14.g3___obobBL6d14     exp_labelled_other  Day14 g3
# 9  Day14.g4___obob14v14      exp_labelled_other  Day14 g4
# 10 Day14.g4___obobBL6d14     exp_labelled_other  Day14 g4
# 11 Day14.g7___obob14v14      exp_labelled_other  Day14 g7
# 12 Day14.g7___obobBL6d14     exp_labelled_other  Day14 g7
# 13 Day14.n_drop___obob14v14  exp_labelled_neuron Day14 n_drop
# 14 Day14.n_drop___obobBL6d14 exp_labelled_neuron Day14 n_drop
# 15 Day14.n0___obob14v14      exp_labelled_neuron Day14 n0
# 16 Day14.n0___obobBL6d14     exp_labelled_neuron Day14 n0
# 17 Day14.n1___obob14v14      exp_labelled_neuron Day14 n1
# 18 Day14.n1___obobBL6d14     exp_labelled_neuron Day14 n1
# 19 Day14.n2___obob14v14      exp_labelled_neuron Day14 n2
# 20 Day14.n2___obobBL6d14     exp_labelled_neuron Day14 n2
# 21 Day14.n3___obob14v14      exp_labelled_neuron Day14 n3
# 22 Day14.n3___obobBL6d14     exp_labelled_neuron Day14 n3
# 23 Day14.n4___obob14v14      exp_labelled_neuron Day14 n4
# 24 Day14.n4___obobBL6d14     exp_labelled_neuron Day14 n4
# 25 Day14.n5___obob14v14      exp_labelled_neuron Day14 n5
# 26 Day14.n5___obobBL6d14     exp_labelled_neuron Day14 n5
# 27 Day14.n6___obob14v14      exp_labelled_neuron Day14 n6
# 28 Day14.n6___obobBL6d14     exp_labelled_neuron Day14 n6
# 29 Day14.n8___obob14v14      exp_labelled_neuron Day14 n8
# 30 Day14.n8___obobBL6d14     exp_labelled_neuron Day14 n8
# 31 Day5.g_drop___obob5v5     exp_labelled_other  Day5  g_drop
# 32 Day5.g_drop___obobBL6d5   exp_labelled_other  Day5  g_drop
# 33 Day5.g1___obob5v5         exp_labelled_other  Day5  g1
# 34 Day5.g1___obobBL6d5       exp_labelled_other  Day5  g1
# 35 Day5.g2___obob5v5         exp_labelled_other  Day5  g2
# 36 Day5.g2___obobBL6d5       exp_labelled_other  Day5  g2
# 37 Day5.g3___obob5v5         exp_labelled_other  Day5  g3
# 38 Day5.g3___obobBL6d5       exp_labelled_other  Day5  g3
# 39 Day5.g4___obob5v5         exp_labelled_other  Day5  g4
# 40 Day5.g4___obobBL6d5       exp_labelled_other  Day5  g4
# 41 Day5.g7___obob5v5         exp_labelled_other  Day5  g7
# 42 Day5.g7___obobBL6d5       exp_labelled_other  Day5  g7
# 43 Day5.n_drop___obob5v5     exp_labelled_neuron Day5  n_drop
# 44 Day5.n_drop___obobBL6d5   exp_labelled_neuron Day5  n_drop
# 45 Day5.n0___obob5v5         exp_labelled_neuron Day5  n0
# 46 Day5.n0___obobBL6d5       exp_labelled_neuron Day5  n0
# 47 Day5.n1___obob5v5         exp_labelled_neuron Day5  n1
# 48 Day5.n1___obobBL6d5       exp_labelled_neuron Day5  n1
# 49 Day5.n2___obob5v5         exp_labelled_neuron Day5  n2
# 50 Day5.n2___obobBL6d5       exp_labelled_neuron Day5  n2
# 51 Day5.n3___obob5v5         exp_labelled_neuron Day5  n3
# 52 Day5.n3___obobBL6d5       exp_labelled_neuron Day5  n3
# 53 Day5.n4___obob5v5         exp_labelled_neuron Day5  n4
# 54 Day5.n4___obobBL6d5       exp_labelled_neuron Day5  n4
# 55 Day5.n5___obob5v5         exp_labelled_neuron Day5  n5
# 56 Day5.n5___obobBL6d5       exp_labelled_neuron Day5  n5
# 57 Day5.n6___obob5v5         exp_labelled_neuron Day5  n6
# 58 Day5.n6___obobBL6d5       exp_labelled_neuron Day5  n6
# 59 Day5.n8___obob5v5         exp_labelled_neuron Day5  n8
# 60 Day5.n8___obobBL6d5       exp_labelled_neuron Day5  n8
#    milo_obj          milo_index_obj                 design_df
# 1  milo_Day14.g_drop milo_index_tibble_Day14.g_drop design_df_Day14.g_drop
# 2  milo_Day14.g_drop milo_index_tibble_Day14.g_drop design_df_Day14.g_drop
# 3  milo_Day14.g1     milo_index_tibble_Day14.g1     design_df_Day14.g1
# 4  milo_Day14.g1     milo_index_tibble_Day14.g1     design_df_Day14.g1
# 5  milo_Day14.g2     milo_index_tibble_Day14.g2     design_df_Day14.g2
# 6  milo_Day14.g2     milo_index_tibble_Day14.g2     design_df_Day14.g2
# 7  milo_Day14.g3     milo_index_tibble_Day14.g3     design_df_Day14.g3
# 8  milo_Day14.g3     milo_index_tibble_Day14.g3     design_df_Day14.g3
# 9  milo_Day14.g4     milo_index_tibble_Day14.g4     design_df_Day14.g4
# 10 milo_Day14.g4     milo_index_tibble_Day14.g4     design_df_Day14.g4
# 11 milo_Day14.g7     milo_index_tibble_Day14.g7     design_df_Day14.g7
# 12 milo_Day14.g7     milo_index_tibble_Day14.g7     design_df_Day14.g7
# 13 milo_Day14.n_drop milo_index_tibble_Day14.n_drop design_df_Day14.n_drop
# 14 milo_Day14.n_drop milo_index_tibble_Day14.n_drop design_df_Day14.n_drop
# 15 milo_Day14.n0     milo_index_tibble_Day14.n0     design_df_Day14.n0
# 16 milo_Day14.n0     milo_index_tibble_Day14.n0     design_df_Day14.n0
# 17 milo_Day14.n1     milo_index_tibble_Day14.n1     design_df_Day14.n1
# 18 milo_Day14.n1     milo_index_tibble_Day14.n1     design_df_Day14.n1
# 19 milo_Day14.n2     milo_index_tibble_Day14.n2     design_df_Day14.n2
# 20 milo_Day14.n2     milo_index_tibble_Day14.n2     design_df_Day14.n2
# 21 milo_Day14.n3     milo_index_tibble_Day14.n3     design_df_Day14.n3
# 22 milo_Day14.n3     milo_index_tibble_Day14.n3     design_df_Day14.n3
# 23 milo_Day14.n4     milo_index_tibble_Day14.n4     design_df_Day14.n4
# 24 milo_Day14.n4     milo_index_tibble_Day14.n4     design_df_Day14.n4
# 25 milo_Day14.n5     milo_index_tibble_Day14.n5     design_df_Day14.n5
# 26 milo_Day14.n5     milo_index_tibble_Day14.n5     design_df_Day14.n5
# 27 milo_Day14.n6     milo_index_tibble_Day14.n6     design_df_Day14.n6
# 28 milo_Day14.n6     milo_index_tibble_Day14.n6     design_df_Day14.n6
# 29 milo_Day14.n8     milo_index_tibble_Day14.n8     design_df_Day14.n8
# 30 milo_Day14.n8     milo_index_tibble_Day14.n8     design_df_Day14.n8
# 31 milo_Day5.g_drop  milo_index_tibble_Day5.g_drop  design_df_Day5.g_drop
# 32 milo_Day5.g_drop  milo_index_tibble_Day5.g_drop  design_df_Day5.g_drop
# 33 milo_Day5.g1      milo_index_tibble_Day5.g1      design_df_Day5.g1
# 34 milo_Day5.g1      milo_index_tibble_Day5.g1      design_df_Day5.g1
# 35 milo_Day5.g2      milo_index_tibble_Day5.g2      design_df_Day5.g2
# 36 milo_Day5.g2      milo_index_tibble_Day5.g2      design_df_Day5.g2
# 37 milo_Day5.g3      milo_index_tibble_Day5.g3      design_df_Day5.g3
# 38 milo_Day5.g3      milo_index_tibble_Day5.g3      design_df_Day5.g3
# 39 milo_Day5.g4      milo_index_tibble_Day5.g4      design_df_Day5.g4
# 40 milo_Day5.g4      milo_index_tibble_Day5.g4      design_df_Day5.g4
# 41 milo_Day5.g7      milo_index_tibble_Day5.g7      design_df_Day5.g7
# 42 milo_Day5.g7      milo_index_tibble_Day5.g7      design_df_Day5.g7
# 43 milo_Day5.n_drop  milo_index_tibble_Day5.n_drop  design_df_Day5.n_drop
# 44 milo_Day5.n_drop  milo_index_tibble_Day5.n_drop  design_df_Day5.n_drop
# 45 milo_Day5.n0      milo_index_tibble_Day5.n0      design_df_Day5.n0
# 46 milo_Day5.n0      milo_index_tibble_Day5.n0      design_df_Day5.n0
# 47 milo_Day5.n1      milo_index_tibble_Day5.n1      design_df_Day5.n1
# 48 milo_Day5.n1      milo_index_tibble_Day5.n1      design_df_Day5.n1
# 49 milo_Day5.n2      milo_index_tibble_Day5.n2      design_df_Day5.n2
# 50 milo_Day5.n2      milo_index_tibble_Day5.n2      design_df_Day5.n2
# 51 milo_Day5.n3      milo_index_tibble_Day5.n3      design_df_Day5.n3
# 52 milo_Day5.n3      milo_index_tibble_Day5.n3      design_df_Day5.n3
# 53 milo_Day5.n4      milo_index_tibble_Day5.n4      design_df_Day5.n4
# 54 milo_Day5.n4      milo_index_tibble_Day5.n4      design_df_Day5.n4
# 55 milo_Day5.n5      milo_index_tibble_Day5.n5      design_df_Day5.n5
# 56 milo_Day5.n5      milo_index_tibble_Day5.n5      design_df_Day5.n5
# 57 milo_Day5.n6      milo_index_tibble_Day5.n6      design_df_Day5.n6
# 58 milo_Day5.n6      milo_index_tibble_Day5.n6      design_df_Day5.n6
# 59 milo_Day5.n8      milo_index_tibble_Day5.n8      design_df_Day5.n8
# 60 milo_Day5.n8      milo_index_tibble_Day5.n8      design_df_Day5.n8
#    mm              contrast_name contrast
# 1  mm_Day14.g_drop obob14v14     groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 2  mm_Day14.g_drop obobBL6d14    groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 3  mm_Day14.g1     obob14v14     groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 4  mm_Day14.g1     obobBL6d14    groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 5  mm_Day14.g2     obob14v14     groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 6  mm_Day14.g2     obobBL6d14    groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 7  mm_Day14.g3     obob14v14     groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 8  mm_Day14.g3     obobBL6d14    groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 9  mm_Day14.g4     obob14v14     groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 10 mm_Day14.g4     obobBL6d14    groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 11 mm_Day14.g7     obob14v14     groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 12 mm_Day14.g7     obobBL6d14    groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 13 mm_Day14.n_drop obob14v14     groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 14 mm_Day14.n_drop obobBL6d14    groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 15 mm_Day14.n0     obob14v14     groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 16 mm_Day14.n0     obobBL6d14    groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 17 mm_Day14.n1     obob14v14     groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 18 mm_Day14.n1     obobBL6d14    groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 19 mm_Day14.n2     obob14v14     groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 20 mm_Day14.n2     obobBL6d14    groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 21 mm_Day14.n3     obob14v14     groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 22 mm_Day14.n3     obobBL6d14    groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 23 mm_Day14.n4     obob14v14     groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 24 mm_Day14.n4     obobBL6d14    groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 25 mm_Day14.n5     obob14v14     groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 26 mm_Day14.n5     obobBL6d14    groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 27 mm_Day14.n6     obob14v14     groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 28 mm_Day14.n6     obobBL6d14    groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 29 mm_Day14.n8     obob14v14     groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 30 mm_Day14.n8     obobBL6d14    groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 31 mm_Day5.g_drop  obob5v5       groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 32 mm_Day5.g_drop  obobBL6d5     groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 33 mm_Day5.g1      obob5v5       groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 34 mm_Day5.g1      obobBL6d5     groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 35 mm_Day5.g2      obob5v5       groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 36 mm_Day5.g2      obobBL6d5     groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 37 mm_Day5.g3      obob5v5       groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 38 mm_Day5.g3      obobBL6d5     groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 39 mm_Day5.g4      obob5v5       groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 40 mm_Day5.g4      obobBL6d5     groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 41 mm_Day5.g7      obob5v5       groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 42 mm_Day5.g7      obobBL6d5     groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 43 mm_Day5.n_drop  obob5v5       groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 44 mm_Day5.n_drop  obobBL6d5     groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 45 mm_Day5.n0      obob5v5       groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 46 mm_Day5.n0      obobBL6d5     groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 47 mm_Day5.n1      obob5v5       groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 48 mm_Day5.n1      obobBL6d5     groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 49 mm_Day5.n2      obob5v5       groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 50 mm_Day5.n2      obobBL6d5     groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 51 mm_Day5.n3      obob5v5       groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 52 mm_Day5.n3      obobBL6d5     groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 53 mm_Day5.n4      obob5v5       groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 54 mm_Day5.n4      obobBL6d5     groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 55 mm_Day5.n5      obob5v5       groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 56 mm_Day5.n5      obobBL6d5     groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 57 mm_Day5.n6      obob5v5       groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 58 mm_Day5.n6      obobBL6d5     groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 59 mm_Day5.n8      obob5v5       groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 60 mm_Day5.n8      obobBL6d5     groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6

# %%
qs::qsave(da_recipe, 'da_recipe_labels_chunk.qs')
