# %%
library(Seurat)
library(tidyverse)
library(ggplot2)
library(ggrepel)
library(ggbeeswarm)
library(patchwork)
library(miloR)
options(ggrepel.max.overlaps = Inf)

# %%
source('milo_cellbender.R')

# %%
obj_neuron = qs::qread('_targets/objects/obj_neuron') %>%
             set_labels_to_lvl1 %>%
             #set_batch_to_lane %>% # do not set batch to lane for cluster splits
             prep_obj_for_milo_cb_v01 
obj_neuron
# Out:
# An object of class Seurat
# 29128 features across 104587 samples within 2 assays
# Active assay: integrated (2000 features, 2000 variable features)
#  2 layers present: data, scale.data
#  1 other assay present: RNA
#  2 dimensional reductions calculated: pca, umap

# %%
DimPlot(obj_neuron)
# Out:
# Rasterizing points since number of points exceeds 100,000.
# To disable this behavior set `raster=FALSE`
# plot without title

# %%
obj_other = qs::qread('_targets/objects/obj_other') %>%
             set_labels_to_lvl1 %>%
             #set_batch_to_lane %>% # do not set batch to lane for cluster splits
             prep_obj_for_milo_cb_v01 
obj_other
# Out:
# An object of class Seurat
# 25033 features across 29782 samples within 2 assays
# Active assay: integrated (2000 features, 2000 variable features)
#  2 layers present: data, scale.data
#  1 other assay present: RNA
#  2 dimensional reductions calculated: pca, umap

# %%
DimPlot(obj_other)
# Out:
# plot without title

# %%
labels_classes_tib = (obj_other@meta.data %>% select(labels) %>% mutate(class = 'other') %>% tibble %>% distinct(labels, class)) %>%
bind_rows(obj_neuron@meta.data %>% select(labels) %>% mutate(class = 'neuron') %>% tibble %>% distinct(labels, class)) %>%
mutate(labels = str_replace(labels, fixed('-'), '__'))

# %%
umap_coords_neuron = obj_neuron %>%
`@`('reductions') %>%
`$`('umap') %>%
`@`('cell.embeddings') %>%
as.data.frame %>%
rownames_to_column('cell_barcode')

umap_coords_neuron %>% head
# Out:
#   cell_barcode               umap_1    umap_2
# 1 SI-TT-A11_AAACCCAAGGTGGTTG  1.060039  -9.89935829
# 2 SI-TT-A11_AAACCCACATACAGCT  4.324369   1.16208909
# 3 SI-TT-A11_AAACCCACATGAGGGT  4.696438  -3.14927985
# 4 SI-TT-A11_AAACCCAGTACGTTCA  1.344125 -13.86531212
# 5 SI-TT-A11_AAACCCATCCAAGCAT -5.445605  12.35118530
# 6 SI-TT-A11_AAACCCATCCCATAAG -9.186716   0.09222025

# %%
umap_coords_other = obj_other %>%
`@`('reductions') %>%
`$`('umap') %>%
`@`('cell.embeddings') %>%
as.data.frame %>%
rownames_to_column('cell_barcode')

umap_coords_other %>% head
# Out:
#   cell_barcode               umap_1    umap_2
# 1 SI-TT-A11_AAACCCAGTATCGGTT  9.741567  -6.3410525
# 2 SI-TT-A11_AAACGAAAGGTTCTTG -8.439921 -10.6500720
# 3 SI-TT-A11_AAACGAACAAGGAGTC -3.407435  -0.5645014
# 4 SI-TT-A11_AAACGAACAGCCTTCT -4.795028   1.1611348
# 5 SI-TT-A11_AAACGCTAGTGCTAGG 12.090093  -5.6987538
# 6 SI-TT-A11_AAAGGATTCAACCCGG  8.568621  -2.9679698

# %%
ambiguous_cells = intersect(umap_coords_neuron %>% pull(cell_barcode), umap_coords_other %>% pull(cell_barcode))
ambiguous_cells %>% length
# Out:
# [1] 0

# %%
umap_coords_neuron = umap_coords_neuron %>% filter(!(cell_barcode %in% ambiguous_cells))
umap_coords_other = umap_coords_other %>% filter(!(cell_barcode %in% ambiguous_cells))
umap_coords = bind_rows(umap_coords_neuron, umap_coords_other)
umap_coords %>% dim
# Out:
# [1] 134369      3

# %%
# da_results_restored = qs::qread('_targets/objects/combined_da_results_nhg_all.obob14v14__v__all.obobBL6')
da_results_restored = qs::qread('_targets/objects/combined_da_results_nhg_all.obob14v14__v__all.obobBL6d14')
# column_to_rownames('hash.mcl.ID')

dim(da_results_restored)
da_results_restored %>% head
# Out:
# [1] 26179    18
#   logFC        logCPM   F            PValue      FDR       Nhood SpatialFDR
# 1 -2.320045141 12.19832 9.838683e+00 0.002213171 0.7414122 142   0.9234267
# 2 -1.798599545 12.39617 8.534432e+00 0.004487855 0.7517157 191   0.9234267
# 3  0.002565596 12.11837 4.207191e-06 0.998367400 1.0000000   1   1.0000000
# 4  0.030158423 12.32363 1.516155e-03 0.969017914 1.0000000   2   1.0000000
# 5 -0.646116135 12.40520 1.472211e+00 0.227777395 1.0000000   3   1.0000000
# 6 -0.774713929 12.38027 2.120968e+00 0.148433252 1.0000000   4   1.0000000
#   polarity labels labels_fraction comparison                       restored
# 1 none     Agrp   1               all.obob14v14__v__all.obobBL6d14 FALSE
# 2 none     Agrp   1               all.obob14v14__v__all.obobBL6d14 FALSE
# 3 none     Agrp   1               all.obob14v14__v__all.obobBL6d14 FALSE
# 4 none     Agrp   1               all.obob14v14__v__all.obobBL6d14 FALSE
# 5 none     Agrp   1               all.obob14v14__v__all.obobBL6d14 FALSE
# 6 none     Agrp   1               all.obob14v14__v__all.obobBL6d14 FALSE
#   exact_grouping restored_grouping fgf1_grouping bl6_grouping
# 1 none           none              none          none
# 2 pos_BL6        none              none          pos
# 3 pos_BL6        none              none          pos
# 4 none           none              none          none
# 5 pos_BL6        none              none          pos
# 6 pos_BL6        none              none          pos
#   hash.mcl.ID                n_cells
# 1 SI-TT-E12_AACCACACACAGTGAG  75
# 2 SI-TT-F11_ATTACCTTCACTCCGT  93
# 3 SI-TT-H10_GTCGTAAAGCCAGTAG  71
# 4 SI-TT-H10_TGTCCCAGTTACAGCT  87
# 5 SI-TT-F10_TGATCAGAGATGCCGA 109
# 6 SI-TT-F10_CCTTCAGGTCAGGAGT 103

# %%
# da_results_bl6 = qs::qread('_targets/objects/combined_da_results_idx_all.obobBL6') %>%
da_results_bl6 = qs::qread('_targets/objects/combined_da_results_idx_all.obobBL6d14') %>%
rename(n_cells = n_cells.x) %>%
select(-n_cells.y) %>%
mutate(polarity = case_when(polarity == 'none' ~ 'none',
                            polarity == 'pos' ~ 'neg',
                            polarity == 'neg' ~ 'pos')) %>%
mutate(logFC = -logFC)


dim(da_results_bl6)
da_results_bl6 %>% head
# Out:
# [1] 26179    12
#   logFC    logCPM   F        PValue       FDR          Nhood SpatialFDR
# 1 7.910787 12.95989 176.0758 4.249652e-22 1.423633e-19 220   1.395663e-19
# 2 7.366741 12.97996 138.8569 8.915418e-20 1.307085e-17  42   9.707356e-18
# 3 7.850247 12.79002 141.6009 1.560699e-19 1.307085e-17  20   1.026215e-17
# 4 7.759150 12.80822 142.1439 1.412203e-19 1.307085e-17 278   1.026215e-17
# 5 7.438715 12.92120 139.7553 2.196308e-19 1.471526e-17  97   1.035649e-17
# 6 7.821255 12.65653 125.6513 1.267865e-18 7.078911e-17 239   5.107277e-17
#   polarity labels labels_fraction n_cells hash.mcl.ID
# 1 pos      Agrp   1               111     SI-TT-G10_TTCTTCCCACGGTGTC
# 2 pos      Agrp   1               112     SI-TT-F10_GATGTTGCATGTGACT
# 3 pos      Agrp   1                97     SI-TT-F10_GACGTTAAGACATCCT
# 4 pos      Agrp   1                98     SI-TT-G10_GCTCAAACAGGCTACC
# 5 pos      Agrp   1               107     SI-TT-G10_ACTTCGCGTCGGTACC
# 6 pos      Agrp   1                85     SI-TT-A11_ATAGACCGTCGTGGAA

# %%
da_results_fgf1 = qs::qread('_targets/objects/combined_da_results_idx_all.obob14v14') %>%
rename(n_cells = n_cells.x) %>%
select(-n_cells.y)


dim(da_results_fgf1)
da_results_fgf1 %>% head
# Out:
# [1] 26179    12
#   logFC        logCPM   F            PValue      FDR       Nhood SpatialFDR
# 1 -2.320045141 12.19832 9.838683e+00 0.002213171 0.7414122 142   0.9234267
# 2 -1.798599545 12.39617 8.534432e+00 0.004487855 0.7517157 191   0.9234267
# 3  0.002565596 12.11837 4.207191e-06 0.998367400 1.0000000   1   1.0000000
# 4  0.030158423 12.32363 1.516155e-03 0.969017914 1.0000000   2   1.0000000
# 5 -0.646116135 12.40520 1.472211e+00 0.227777395 1.0000000   3   1.0000000
# 6 -0.774713929 12.38027 2.120968e+00 0.148433252 1.0000000   4   1.0000000
#   polarity labels labels_fraction n_cells hash.mcl.ID
# 1 none     Agrp   1                75     SI-TT-E12_AACCACACACAGTGAG
# 2 none     Agrp   1                93     SI-TT-F11_ATTACCTTCACTCCGT
# 3 none     Agrp   1                71     SI-TT-H10_GTCGTAAAGCCAGTAG
# 4 none     Agrp   1                87     SI-TT-H10_TGTCCCAGTTACAGCT
# 5 none     Agrp   1               109     SI-TT-F10_TGATCAGAGATGCCGA
# 6 none     Agrp   1               103     SI-TT-F10_CCTTCAGGTCAGGAGT

# %%
da_results_2 = full_join(da_results_fgf1, da_results_bl6, by=c('Nhood', 'labels'), suffix = c('_fgf1', '_bl6'))
da_results_2 %>% head
# Out:
#   logFC_fgf1   logCPM_fgf1 F_fgf1       PValue_fgf1 FDR_fgf1  Nhood
# 1 -2.320045141 12.19832    9.838683e+00 0.002213171 0.7414122 142
# 2 -1.798599545 12.39617    8.534432e+00 0.004487855 0.7517157 191
# 3  0.002565596 12.11837    4.207191e-06 0.998367400 1.0000000   1
# 4  0.030158423 12.32363    1.516155e-03 0.969017914 1.0000000   2
# 5 -0.646116135 12.40520    1.472211e+00 0.227777395 1.0000000   3
# 6 -0.774713929 12.38027    2.120968e+00 0.148433252 1.0000000   4
#   SpatialFDR_fgf1 polarity_fgf1 labels labels_fraction_fgf1 ⋯ logFC_bl6
# 1 0.9234267       none          Agrp   1                    ⋯ -1.0035185
# 2 0.9234267       none          Agrp   1                    ⋯ -6.0403595
# 3 1.0000000       none          Agrp   1                    ⋯ -4.2880346
# 4 1.0000000       none          Agrp   1                    ⋯ -0.9407593
# 5 1.0000000       none          Agrp   1                    ⋯ -5.4527799
# 6 1.0000000       none          Agrp   1                    ⋯ -5.6895845
#   logCPM_bl6 F_bl6      PValue_bl6   FDR_bl6     SpatialFDR_bl6 polarity_bl6
# 1 12.19832    1.0536335 0.3070125806 0.330704870 0.322388939    none
# 2 12.39617   13.4124070 0.0004388933 0.002042073 0.001598093    neg
# 3 12.11837    5.5578667 0.0202907903 0.028441066 0.026424159    neg
# 4 12.32363    0.6612086 0.4180736968 0.443211039 0.434530068    none
# 5 12.40520   13.0644384 0.0004678716 0.002118067 0.001664318    neg
# 6 12.38027   14.2262837 0.0002749432 0.001395545 0.001069751    neg
#   labels_fraction_bl6 n_cells_bl6 hash.mcl.ID_bl6
# 1 1                    75         SI-TT-E12_AACCACACACAGTGAG
# 2 1                    93         SI-TT-F11_ATTACCTTCACTCCGT
# 3 1                    71         SI-TT-H10_GTCGTAAAGCCAGTAG
# 4 1                    87         SI-TT-H10_TGTCCCAGTTACAGCT
# 5 1                   109         SI-TT-F10_TGATCAGAGATGCCGA
# 6 1                   103         SI-TT-F10_CCTTCAGGTCAGGAGT

# %%
da_results = da_results_restored %>% full_join(da_results_2, by=c('Nhood', 'labels')) %>%
mutate(exact_grouping = case_when(is.na(exact_grouping) & (polarity_bl6 != 'none') ~ paste0(polarity_bl6, '_BL6'),
                                  is.na(exact_grouping) & (polarity_bl6 == 'none') ~ paste0(polarity_bl6),
                                  TRUE ~ exact_grouping)) %>%
mutate(n_cells = n_cells_fgf1) %>%
left_join(labels_classes_tib, by='labels') %>%
mutate(cell_barcode = hash.mcl.ID_fgf1) %>%
relocate(cell_barcode, .after='hash.mcl.ID') %>%
select(-all_of(c("hash.mcl.ID", "hash.mcl.ID_fgf1", "hash.mcl.ID_bl6"))) %>%
left_join(umap_coords, by='cell_barcode') %>%
mutate(polarity_bl6 = case_when(logFC_bl6 > 0 & SpatialFDR_bl6 < 0.1 ~ 'pos',
                                logFC_bl6 < 0 & SpatialFDR_bl6 < 0.1 ~ 'neg',
                                TRUE ~ 'none')) %>%
mutate(polarity_fgf1 = case_when(logFC_fgf1 > 0 & SpatialFDR_fgf1 < 0.1 ~ 'pos',
                                logFC_fgf1 < 0 & SpatialFDR_fgf1 < 0.1 ~ 'neg',
                                TRUE ~ 'none'))

da_results %>% dim
da_results %>% head
# Out:
# [1] 26179    39
#   logFC        logCPM   F            PValue      FDR       Nhood SpatialFDR
# 1 -2.320045141 12.19832 9.838683e+00 0.002213171 0.7414122 142   0.9234267
# 2 -1.798599545 12.39617 8.534432e+00 0.004487855 0.7517157 191   0.9234267
# 3  0.002565596 12.11837 4.207191e-06 0.998367400 1.0000000   1   1.0000000
# 4  0.030158423 12.32363 1.516155e-03 0.969017914 1.0000000   2   1.0000000
# 5 -0.646116135 12.40520 1.472211e+00 0.227777395 1.0000000   3   1.0000000
# 6 -0.774713929 12.38027 2.120968e+00 0.148433252 1.0000000   4   1.0000000
#   polarity labels labels_fraction ⋯ F_bl6      PValue_bl6   FDR_bl6
# 1 none     Agrp   1               ⋯  1.0536335 0.3070125806 0.330704870
# 2 none     Agrp   1               ⋯ 13.4124070 0.0004388933 0.002042073
# 3 none     Agrp   1               ⋯  5.5578667 0.0202907903 0.028441066
# 4 none     Agrp   1               ⋯  0.6612086 0.4180736968 0.443211039
# 5 none     Agrp   1               ⋯ 13.0644384 0.0004678716 0.002118067
# 6 none     Agrp   1               ⋯ 14.2262837 0.0002749432 0.001395545
#   SpatialFDR_bl6 polarity_bl6 labels_fraction_bl6 n_cells_bl6 class  umap_1
# 1 0.322388939    none         1                    75         neuron 1.749498
# 2 0.001598093    neg          1                    93         neuron 3.920698
# 3 0.026424159    neg          1                    71         neuron 2.174257
# 4 0.434530068    none         1                    87         neuron 4.259051
# 5 0.001664318    neg          1                   109         neuron 1.299426
# 6 0.001069751    neg          1                   103         neuron 1.450076
#   umap_2
# 1 -15.74457
# 2 -15.08390
# 3 -14.59240
# 4 -13.95177
# 5 -14.56250
# 6 -14.22874

# %%
da_results_restored
# Out:
#       logFC         logCPM   F            PValue      FDR       Nhood
# 1     -2.320045141  12.19832 9.838683e+00 0.002213171 0.7414122 142
# 2     -1.798599545  12.39617 8.534432e+00 0.004487855 0.7517157 191
# 3      0.002565596  12.11837 4.207191e-06 0.998367400 1.0000000   1
# 4      0.030158423  12.32363 1.516155e-03 0.969017914 1.0000000   2
# 5     -0.646116135  12.40520 1.472211e+00 0.227777395 1.0000000   3
# 6     -0.774713929  12.38027 2.120968e+00 0.148433252 1.0000000   4
# 7     -0.443050178  12.32072 6.198371e-01 0.432973354 1.0000000   5
# 8     -0.026950551  12.51651 2.615940e-10 0.999987134 1.0000000   6
# 9     -0.731780795  12.51198 2.002351e+00 0.160445534 1.0000000   7
# 10     0.496469269  12.34419 6.706578e-01 0.414662978 1.0000000   8
# 11     0.902819534  12.74492 1.274545e+00 0.301508104 1.0000000   9
# 12    -0.159583670  12.45421 9.041118e-02 0.764262280 1.0000000  10
# 13    -0.547621810  12.21735 5.462225e-01 0.461599818 1.0000000  11
# 14    -0.929281973  12.32526 2.133654e+00 0.147059920 1.0000000  12
# 15     0.008253018  12.20170 7.250925e-05 0.993222903 1.0000000  13
# 16    -0.683840159  12.48415 1.795517e+00 0.183550858 1.0000000  14
# 17    -0.063627701  12.65256 5.535801e-10 1.000000000 1.0000000  15
# 18     0.774445811  12.48186 1.775731e+00 0.185739234 1.0000000  16
# 19    -1.590983390  12.12988 3.769581e+00 0.054852022 1.0000000  17
# 20    -0.584973253  12.19033 5.689860e-01 0.452386386 1.0000000  18
# 21    -0.144938748  12.64676 1.477481e-09 1.000000000 1.0000000  19
# 22    -0.108751000  12.79002 3.899029e-10 0.999984293 1.0000000  20
# 23     0.092873878  12.25928 2.349321e-02 0.878482333 1.0000000  21
# 24     0.042572420  12.33869 5.561167e-03 0.940716863 1.0000000  22
# 25    -0.512250126  12.39145 8.119620e-01 0.369646807 1.0000000  23
# 26    -0.017127019  12.62146 1.883557e-10 1.000000000 1.0000000  24
# 27    -0.031417606  12.24526 2.308924e-03 0.961765965 1.0000000  25
# 28    -0.442982845  12.11061 4.813879e-01 0.489405910 1.0000000  26
# 29    -0.552675183  12.36198 1.068520e+00 0.303781912 1.0000000  27
# 30     0.285194879  12.56503 3.171021e-01 0.712104342 1.0000000  28
# ⋮     ⋮             ⋮        ⋮            ⋮           ⋮         ⋮
# 26150 -0.0446147259 13.76720 4.946378e-03 0.9439330   0.9996153 145
# 26151 -0.1954457037 13.54764 7.657752e-02 0.7820000   0.9996153 148
# 26152  0.2038223792 13.51742 9.264808e-02 0.7608482   0.9996153 149
# 26153  0.0245021906 13.66903 1.247880e-03 0.9718215   0.9996153 153
# 26154 -0.1583206852 13.75870 6.738373e-02 0.7951941   0.9996153 154
# 26155 -0.3957550757 13.46160 2.999713e-01 0.5839287   0.9996153 158
# 26156 -0.4107081415 13.56866 3.067631e-01 0.5796947   0.9996153 162
# 26157  0.2694605819 13.48190 8.360302e-02 0.7724832   0.9996153 164
# 26158  0.0632404023 13.71535 1.083579e-02 0.9170975   0.9996153 166
# 26159  0.2512583814 13.39432 1.219470e-01 0.7269450   0.9996153 167
# 26160  0.3707715893 13.45774 3.253994e-01 0.5684028   0.9996153 168
# 26161 -0.0279352291 13.71080 2.469667e-03 0.9603666   0.9996153 169
# 26162 -0.2980989533 13.54290 1.011705e-01 0.7504410   0.9996153 170
# 26163 -0.1763768691 13.45894 4.682291e-02 0.8287143   0.9996153 171
# 26164 -0.3699845730 13.42564 2.600623e-01 0.6100968   0.9996153 172
# 26165 -0.2591896560 13.67013 1.630274e-01 0.6863993   0.9996153 173
# 26166 -0.2931050363 13.62330 1.816972e-01 0.6699345   0.9996153 175
# 26167  0.3570233058 13.46832 2.264335e-01 0.6342457   0.9996153 178
# 26168  0.4504411041 13.47777 4.077772e-01 0.5231251   0.9996153 180
# 26169 -0.2928980533 13.49110 1.598060e-01 0.6893499   0.9996153 181
# 26170 -0.1158388824 13.46936 2.641215e-02 0.8709035   0.9996153 182
# 26171 -0.0004633235 13.71284 3.272022e-06 0.9985568   0.9996153 183
# 26172  0.0072988012 13.63068 1.332639e-04 0.9907898   0.9996153 186
# 26173 -0.1719073064 13.57379 7.910973e-02 0.7785176   0.9996153 192
# 26174 -0.2481107129 13.54849 9.505697e-02 0.7578708   0.9996153 197
# 26175  0.3293222444 13.48387 2.224352e-01 0.6372084   0.9996153 199
# 26176  0.0296335564 13.47168 1.735957e-03 0.9667673   0.9996153 201
# 26177 -0.2067644046 13.61565 7.827244e-02 0.7796883   0.9996153 202
# 26178 -0.1673892555 13.61470 5.985811e-02 0.8067290   0.9996153 205
# 26179  0.0533413363 13.46241 5.575703e-03 0.9404794   0.9996153 206
#       SpatialFDR polarity labels    labels_fraction
# 1     0.9234267  none     Agrp      1
# 2     0.9234267  none     Agrp      1
# 3     1.0000000  none     Agrp      1
# 4     1.0000000  none     Agrp      1
# 5     1.0000000  none     Agrp      1
# 6     1.0000000  none     Agrp      1
# 7     1.0000000  none     Agrp      1
# 8     1.0000000  none     Agrp      1
# 9     1.0000000  none     Agrp      1
# 10    1.0000000  none     Agrp      1
# 11    1.0000000  none     Agrp      1
# 12    1.0000000  none     Agrp      1
# 13    1.0000000  none     Agrp      1
# 14    1.0000000  none     Agrp      1
# 15    1.0000000  none     Agrp      1
# 16    1.0000000  none     Agrp      1
# 17    1.0000000  none     Agrp      1
# 18    1.0000000  none     Agrp      1
# 19    1.0000000  none     Agrp      1
# 20    1.0000000  none     Agrp      1
# 21    1.0000000  none     Agrp      1
# 22    1.0000000  none     Agrp      1
# 23    1.0000000  none     Agrp      1
# 24    1.0000000  none     Agrp      1
# 25    1.0000000  none     Agrp      1
# 26    1.0000000  none     Agrp      1
# 27    1.0000000  none     Agrp      1
# 28    1.0000000  none     Agrp      1
# 29    1.0000000  none     Agrp      1
# 30    1.0000000  none     Agrp      1
# ⋮     ⋮          ⋮        ⋮         ⋮
# 26150 0.9996153  none     Trh__Lef1 1
# 26151 0.9996153  none     Trh__Lef1 1
# 26152 0.9996153  none     Trh__Lef1 1
# 26153 0.9996153  none     Trh__Lef1 1
# 26154 0.9996153  none     Trh__Lef1 1
# 26155 0.9996153  none     Trh__Lef1 1
# 26156 0.9996153  none     Trh__Lef1 1
# 26157 0.9996153  none     Trh__Lef1 1
# 26158 0.9996153  none     Trh__Lef1 1
# 26159 0.9996153  none     Trh__Lef1 1
# 26160 0.9996153  none     Trh__Lef1 1
# 26161 0.9996153  none     Trh__Lef1 1
# 26162 0.9996153  none     Trh__Lef1 1
# 26163 0.9996153  none     Trh__Lef1 1
# 26164 0.9996153  none     Trh__Lef1 1
# 26165 0.9996153  none     Trh__Lef1 1
# 26166 0.9996153  none     Trh__Lef1 1
# 26167 0.9996153  none     Trh__Lef1 1
# 26168 0.9996153  none     Trh__Lef1 1
# 26169 0.9996153  none     Trh__Lef1 1
# 26170 0.9996153  none     Trh__Lef1 1
# 26171 0.9996153  none     Trh__Lef1 1
# 26172 0.9996153  none     Trh__Lef1 1
# 26173 0.9996153  none     Trh__Lef1 1
# 26174 0.9996153  none     Trh__Lef1 1
# 26175 0.9996153  none     Trh__Lef1 1
# 26176 0.9996153  none     Trh__Lef1 1
# 26177 0.9996153  none     Trh__Lef1 1
# 26178 0.9996153  none     Trh__Lef1 1
# 26179 0.9996153  none     Trh__Lef1 1
#       comparison                       restored exact_grouping
# 1     all.obob14v14__v__all.obobBL6d14 FALSE    none
# 2     all.obob14v14__v__all.obobBL6d14 FALSE    pos_BL6
# 3     all.obob14v14__v__all.obobBL6d14 FALSE    pos_BL6
# 4     all.obob14v14__v__all.obobBL6d14 FALSE    none
# 5     all.obob14v14__v__all.obobBL6d14 FALSE    pos_BL6
# 6     all.obob14v14__v__all.obobBL6d14 FALSE    pos_BL6
# 7     all.obob14v14__v__all.obobBL6d14 FALSE    pos_BL6
# 8     all.obob14v14__v__all.obobBL6d14 FALSE    neg_BL6
# 9     all.obob14v14__v__all.obobBL6d14 FALSE    pos_BL6
# 10    all.obob14v14__v__all.obobBL6d14 FALSE    none
# 11    all.obob14v14__v__all.obobBL6d14 FALSE    neg_BL6
# 12    all.obob14v14__v__all.obobBL6d14 FALSE    pos_BL6
# 13    all.obob14v14__v__all.obobBL6d14 FALSE    pos_BL6
# 14    all.obob14v14__v__all.obobBL6d14 FALSE    none
# 15    all.obob14v14__v__all.obobBL6d14 FALSE    pos_BL6
# 16    all.obob14v14__v__all.obobBL6d14 FALSE    pos_BL6
# 17    all.obob14v14__v__all.obobBL6d14 FALSE    neg_BL6
# 18    all.obob14v14__v__all.obobBL6d14 FALSE    pos_BL6
# 19    all.obob14v14__v__all.obobBL6d14 FALSE    none
# 20    all.obob14v14__v__all.obobBL6d14 FALSE    pos_BL6
# 21    all.obob14v14__v__all.obobBL6d14 FALSE    neg_BL6
# 22    all.obob14v14__v__all.obobBL6d14 FALSE    neg_BL6
# 23    all.obob14v14__v__all.obobBL6d14 FALSE    pos_BL6
# 24    all.obob14v14__v__all.obobBL6d14 FALSE    pos_BL6
# 25    all.obob14v14__v__all.obobBL6d14 FALSE    pos_BL6
# 26    all.obob14v14__v__all.obobBL6d14 FALSE    neg_BL6
# 27    all.obob14v14__v__all.obobBL6d14 FALSE    none
# 28    all.obob14v14__v__all.obobBL6d14 FALSE    pos_BL6
# 29    all.obob14v14__v__all.obobBL6d14 FALSE    pos_BL6
# 30    all.obob14v14__v__all.obobBL6d14 FALSE    pos_BL6
# ⋮     ⋮                                ⋮        ⋮
# 26150 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26151 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26152 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26153 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26154 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26155 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26156 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26157 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26158 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26159 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26160 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26161 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26162 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26163 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26164 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26165 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26166 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26167 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26168 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26169 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26170 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26171 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26172 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26173 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26174 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26175 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26176 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26177 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26178 all.obob14v14__v__all.obobBL6d14 FALSE    none
# 26179 all.obob14v14__v__all.obobBL6d14 FALSE    none
#       restored_grouping fgf1_grouping bl6_grouping hash.mcl.ID
# 1     none              none          none         SI-TT-E12_AACCACACACAGTGAG
# 2     none              none          pos          SI-TT-F11_ATTACCTTCACTCCGT
# 3     none              none          pos          SI-TT-H10_GTCGTAAAGCCAGTAG
# 4     none              none          none         SI-TT-H10_TGTCCCAGTTACAGCT
# 5     none              none          pos          SI-TT-F10_TGATCAGAGATGCCGA
# 6     none              none          pos          SI-TT-F10_CCTTCAGGTCAGGAGT
# 7     none              none          pos          SI-TT-F10_ACCGTTCTCTTACCAT
# 8     none              none          neg          SI-TT-G10_CGGACACCAAGAGTAT
# 9     none              none          pos          SI-TT-A11_TTTAGTCGTCGGTAAG
# 10    none              none          none         SI-TT-A11_GCCGTGAGTCAGGTGA
# 11    none              none          neg          SI-TT-A11_TACGGTAGTCTATGAC
# 12    none              none          pos          SI-TT-G10_CCACAAACAAAGCTAA
# 13    none              none          pos          SI-TT-F10_ACACGCGCACCGGTCA
# 14    none              none          none         SI-TT-G10_GTCATTTGTGGGCTTC
# 15    none              none          pos          SI-TT-H10_AGGGTGATCGATTTCT
# 16    none              none          pos          SI-TT-A11_ATTCCTAAGGCCTAGA
# 17    none              none          neg          SI-TT-B12_TGAGTCATCCTTATCA
# 18    none              none          pos          SI-TT-G10_GTCTCACAGATAGCAT
# 19    none              none          none         SI-TT-C12_GGCGTCAGTCGAATGG
# 20    none              none          pos          SI-TT-G10_CATCCACTCGGAATTC
# 21    none              none          neg          SI-TT-G10_AACAGGGCACTCTCGT
# 22    none              none          neg          SI-TT-F10_GACGTTAAGACATCCT
# 23    none              none          pos          SI-TT-E12_CAATTTCAGATACGAT
# 24    none              none          pos          SI-TT-B12_GACTGATCAATGTGGG
# 25    none              none          pos          SI-TT-F10_CAGCAATCAGTAGTTC
# 26    none              none          neg          SI-TT-F10_CCATCACGTTACTCAG
# 27    none              none          none         SI-TT-G10_TTTACGTGTACAGTCT
# 28    none              none          pos          SI-TT-G10_GACATCAAGACCGCCT
# 29    none              none          pos          SI-TT-F10_GTGTCCTTCATCACTT
# 30    none              none          pos          SI-TT-A11_TGTAAGCTCGAACGCC
# ⋮     ⋮                 ⋮             ⋮            ⋮
# 26150 none              none          none         SI-TT-B12_CTAGGTACAATAGTAG
# 26151 none              none          none         SI-TT-G11_AATGACCAGTAACGAT
# 26152 none              none          none         SI-TT-F11_GAGTCATTCGGTAAGG
# 26153 none              none          none         SI-TT-C12_TCAGTTTCATCCTGTC
# 26154 none              none          none         SI-TT-F10_GATCACAAGCAACAAT
# 26155 none              none          none         SI-TT-G11_TTACTGTCATAAGCGG
# 26156 none              none          none         SI-TT-G11_ACAAGCTTCCGTAATG
# 26157 none              none          none         SI-TT-E12_CAGTTCCTCATGGCCG
# 26158 none              none          none         SI-TT-G11_ATCGTGAAGAGTTGAT
# 26159 none              none          none         SI-TT-D11_CACAGATCAGCGACAA
# 26160 none              none          none         SI-TT-B12_GGACGTCGTCGGTGTC
# 26161 none              none          none         SI-TT-A12_GTAAGTCGTCCAGCCA
# 26162 none              none          none         SI-TT-F10_TAATTCCGTTACACTG
# 26163 none              none          none         SI-TT-G11_AGTTAGCCATAATCCG
# 26164 none              none          none         SI-TT-A12_CTCAGGGAGTAGGCCA
# 26165 none              none          none         SI-TT-F10_TGGATGTTCCACACAA
# 26166 none              none          none         SI-TT-C12_ACTGCAAAGGCACTAG
# 26167 none              none          none         SI-TT-H10_TCATTTGAGTGTGTTC
# 26168 none              none          none         SI-TT-D11_CTCAGTCTCTCCTGAC
# 26169 none              none          none         SI-TT-A11_TTATTGCTCGACCATA
# 26170 none              none          none         SI-TT-F11_TTGCATTTCAAAGCCT
# 26171 none              none          none         SI-TT-A11_GGAGGTACACCGTGAC
# 26172 none              none          none         SI-TT-E12_AAAGGTATCCTAACAG
# 26173 none              none          none         SI-TT-A12_TCGTGGGTCATAGACC
# 26174 none              none          none         SI-TT-C12_GGAATGGTCAAACGAA
# 26175 none              none          none         SI-TT-C12_GTAAGTCTCGGCTTCT
# 26176 none              none          none         SI-TT-E10_GATCCCTGTGGATCAG
# 26177 none              none          none         SI-TT-E12_GACTATGGTGAGACGT
# 26178 none              none          none         SI-TT-F10_AGAGAATGTTGTGGCC
# 26179 none              none          none         SI-TT-H10_CATAAGCGTTCGGTTA
#       n_cells
# 1      75
# 2      93
# 3      71
# 4      87
# 5     109
# 6     103
# 7      95
# 8      74
# 9     121
# 10     92
# 11     93
# 12    110
# 13     86
# 14     91
# 15     80
# 16    115
# 17     84
# 18    127
# 19     61
# 20     80
# 21     84
# 22     97
# 23     85
# 24    101
# 25    102
# 26     82
# 27     88
# 28     71
# 29    101
# 30    127
# ⋮     ⋮
# 26150 94
# 26151 69
# 26152 65
# 26153 80
# 26154 91
# 26155 65
# 26156 75
# 26157 69
# 26158 83
# 26159 57
# 26160 59
# 26161 85
# 26162 76
# 26163 65
# 26164 55
# 26165 78
# 26166 76
# 26167 66
# 26168 63
# 26169 63
# 26170 65
# 26171 88
# 26172 78
# 26173 68
# 26174 74
# 26175 64
# 26176 61
# 26177 82
# 26178 78
# 26179 61

# %%
options(repr.plot.width=3.5, repr.plot.height=3.5)
umap_bl6_other = da_results %>%
filter(class == 'other') %>%
mutate(polarity_bl6 = factor(polarity_bl6, levels = c("none", "neg", "pos"))) %>%
arrange(polarity_bl6) %>%
ggplot(aes(x = umap_1, y = umap_2, color=polarity_bl6, alpha=polarity_bl6)) + 
geom_point(size=0.5, shape = 16) + 
scale_color_manual(values = c('none' =  "#a1a1a1",
                              'neg' = "#1b7837",
                              'pos' = "#762a83")) +
scale_alpha_manual(values = c("none" = 0.25, "neg" = 0.5, "pos"=0.5)) +
theme_minimal() + theme(legend.position=c(0.9,0.125)) + theme(
  axis.ticks = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank()
) + theme(
  axis.text = element_blank(),
  axis.title.x = element_blank(),
  axis.text.x = element_blank(),
  axis.text.y = element_blank(),
  axis.title.y = element_blank()
) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))

umap_bl6_other
# Out:
# plot without title

# %%
options(repr.plot.width=3.5, repr.plot.height=3.5)
label_data <- da_results %>%
  filter(class == 'other') %>%
  mutate(labels = str_replace(labels, fixed('__'), '\n')) %>%
  group_by(labels) %>%
  summarise(umap_1 = mean(umap_1, na.rm = TRUE),
            umap_2 = mean(umap_2, na.rm =TRUE),
            label = first(labels))

umap_fgf1_other = da_results %>%
filter(class == 'other') %>%
mutate(polarity_fgf1 = factor(polarity_fgf1, levels = c("none", "neg", "pos"))) %>%
arrange(polarity_fgf1) %>%
ggplot(aes(x = umap_1, y = umap_2, color=polarity_fgf1, alpha=polarity_fgf1)) + 
geom_point(size=0.5, shape = 16) + 
scale_color_manual(values = c('none' =  "#a1a1a1",
                              'neg' = "#d73027",
                              'pos' = "#4575b4")) +
scale_alpha_manual(values = c("none" = 0.25, "neg" = 0.5, "pos"=0.5)) +
geom_text_repel(data = label_data, aes(x = umap_1, y = umap_2, label = label), 
              size = 2, 
              box.padding = unit(1, "lines"), 
              point.padding = unit(2, "lines"),
              segment.color = 'grey50',
              inherit.aes = FALSE) +
theme_minimal() + theme(legend.position=c(0.9,0.125)) + theme(
  axis.ticks = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank()
) + theme(
  axis.text = element_blank(),
  axis.title.x = element_blank(),
  axis.text.x = element_blank(),
  axis.text.y = element_blank(),
  axis.title.y = element_blank()
) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))


umap_fgf1_other
# Out:
# plot without title

# %%
options(repr.plot.width=3.5, repr.plot.height=3.5)
umap_restored_other = da_results %>%
filter(class == 'other') %>%
mutate(polarity = case_when(exact_grouping == 'pos_restored' ~ "pos",
                             exact_grouping == 'neg_restored' ~ "neg",
                             TRUE ~ 'other')) %>%
mutate(polarity = factor(polarity, levels = c("other", "neg", "pos"))) %>%
arrange(polarity) %>%
ggplot(aes(x = umap_1, y = umap_2, color=polarity, alpha=polarity)) + 
geom_point(size=0.5, shape = 16) + 
scale_color_manual(values = c('other' =  "#a1a1a1",
                              'neg' = "#a50026",
                              'pos' = "#313695")) +
scale_alpha_manual(values = c("other" = 0.25, "neg" = 0.5, "pos"=0.5)) +
theme_minimal() + theme(legend.position=c(0.9,0.125)) + theme(
  axis.ticks = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank()
) + theme(
  axis.text = element_blank(),
  axis.title.x = element_blank(),
  axis.text.x = element_blank(),
  axis.text.y = element_blank(),
  axis.title.y = element_blank()
) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))

umap_restored_other
# Out:
# plot without title

# %%
all_restored_summary = qs::qread('_targets/objects/all_restored_summary') %>%
filter(comparison == 'all.obob14v14__v__all.obobBL6d14') %>%
mutate(prop_fgf1 = n_fgf1/n_total) %>%
mutate(prop_BL6 = n_BL6/n_total) %>%
mutate(prop_sum = prop_fgf1 + prop_BL6) %>%
mutate(n_sum = n_fgf1 + n_BL6) %>%
arrange(desc(n_fgf1))

all_restored_summary %>% head

label_order = all_restored_summary %>% pull(labels)
label_order
# Out:
#   labels           n_total n_fgf1 n_fgf1.pos n_fgf1.neg prop_fgf1.pos n_BL6
# 1 g3               349     7       7         NA          1             0
# 2 Ghrh             148     2       2         NA          1            81
# 3 Sim1             141     2      NA          2         NA             0
# 4 Tmem215__Greb1   173     2       2         NA          1            97
# 5 g1               739     2      NA          2         NA             0
# 6 Oligodendrocytes 197     1       1         NA          1            33
#   n_restored n_restored.pos n_restored.neg prop_restored_BL6 prop_restored_FGF1
# 1 0          0              0                     NaN        0
# 2 0          0              0              0.00000000        0
# 3 0          0              0                     NaN        0
# 4 2          2              0              0.02061856        1
# 5 0          0              0                     NaN        0
# 6 0          0              0              0.00000000        0
#   comparison                       prop_fgf1   prop_BL6  prop_sum   n_sum
# 1 all.obob14v14__v__all.obobBL6d14 0.020057307 0.0000000 0.02005731  7
# 2 all.obob14v14__v__all.obobBL6d14 0.013513514 0.5472973 0.56081081 83
# 3 all.obob14v14__v__all.obobBL6d14 0.014184397 0.0000000 0.01418440  2
# 4 all.obob14v14__v__all.obobBL6d14 0.011560694 0.5606936 0.57225434 99
# 5 all.obob14v14__v__all.obobBL6d14 0.002706360 0.0000000 0.00270636  2
# 6 all.obob14v14__v__all.obobBL6d14 0.005076142 0.1675127 0.17258883 34
#  [1] "g3"                  "Ghrh"                "Sim1"
#  [4] "Tmem215__Greb1"      "g1"                  "Oligodendrocytes"
#  [7] "n2"                  "Agrp"                "Arx__Nr5a2"
# [10] "Astrocytes"          "Dlk1"                "Endothelial_cells"
# [13] "Ependymal_cells"     "Esr1"                "Fez1"
# [16] "Gpr50__Tac2"         "Hdc"                 "Htr3b"
# [19] "Irx5__Lmx1a"         "Kiss1__Tac2"         "Lepr15"
# [22] "Lepr67"              "Lepr89"              "Lpar1_oligo"
# [25] "Met__Pappa2"         "Met__Prlh"           "Microglia"
# [28] "Nfib_1"              "Nfib_2"              "Nfib_3"
# [31] "Nfix__Nfib"          "Nfix__Nfib__Hgf"     "Nfix__Nfib__Lhx6"
# [34] "Npsr1__Epha3"        "OPC"                 "Pomc__Anxa2"
# [37] "Pomc__Glipr1"        "Pomc__Ttr"           "Pou6f2__Prkcq__Whrn"
# [40] "Ppp1r17"             "Ppp1r17__Ltbp1"      "Ppp1r17__Tafa4"
# [43] "Reln__Lef1"          "Slc17a6__Trhr"       "Sst__Nts"
# [46] "Sst__Pthlh"          "Sst__Unc13c"         "Tanycytes"
# [49] "Tbx19__Pirt"         "Th__Nfib"            "Th__Slc6a3"
# [52] "Tmem215__Dach2"      "Trh__Cxcl12"         "Trh__Lef1"
# [55] "g2"                  "g4"                  "g_drop"
# [58] "n0"                  "n1"                  "n3"
# [61] "n4"                  "n5"                  "n6"
# [64] "n8"                  "n_drop"              "neuron"
# [67] "other"

# %%
all_restored_summary %>% filter(prop_sum > 0) %>%
left_join(labels_classes_tib, by='labels') %>%
group_by(class) %>% summarise(n=n())
# Out:
#   class  n
# 1 neuron 17
# 2 other   3
# 3 NA     10

# %%
all_restored_summary %>%
left_join(labels_classes_tib, by='labels') %>%
filter(class=='neuron') %>%
arrange(desc(n_sum)) %>%
head(20)
# Out:
#    labels         n_total n_fgf1 n_fgf1.pos n_fgf1.neg prop_fgf1.pos n_BL6
# 1  Agrp           335     0      NA         NA         NA            286
# 2  Trh__Cxcl12    268     0      NA         NA         NA            137
# 3  Kiss1__Tac2    213     0      NA         NA         NA            123
# 4  Tmem215__Greb1 173     2       2         NA          1             97
# 5  Ghrh           148     2       2         NA          1             81
# 6  Sst__Unc13c    242     0      NA         NA         NA             64
# 7  Pomc__Glipr1   166     0      NA         NA         NA             49
# 8  Htr3b          254     0      NA         NA         NA             38
# 9  Pomc__Ttr      105     0      NA         NA         NA             37
# 10 Th__Nfib        66     0      NA         NA         NA             27
# 11 Pomc__Anxa2     50     0      NA         NA         NA             20
# 12 Th__Slc6a3      60     0      NA         NA         NA             20
# 13 Arx__Nr5a2      28     0      NA         NA         NA              8
# 14 Lpar1_oligo     62     0      NA         NA         NA              8
# 15 Gpr50__Tac2     74     0      NA         NA         NA              5
# 16 Met__Prlh      276     0      NA         NA         NA              5
# 17 Sim1           141     2      NA          2         NA              0
# 18 Dlk1           182     0      NA         NA         NA              0
# 19 Esr1           255     0      NA         NA         NA              0
# 20 Fez1           266     0      NA         NA         NA              0
#    n_restored n_restored.pos n_restored.neg prop_restored_BL6
# 1  0          0              0              0.00000000
# 2  0          0              0              0.00000000
# 3  0          0              0              0.00000000
# 4  2          2              0              0.02061856
# 5  0          0              0              0.00000000
# 6  0          0              0              0.00000000
# 7  0          0              0              0.00000000
# 8  0          0              0              0.00000000
# 9  0          0              0              0.00000000
# 10 0          0              0              0.00000000
# 11 0          0              0              0.00000000
# 12 0          0              0              0.00000000
# 13 0          0              0              0.00000000
# 14 0          0              0              0.00000000
# 15 0          0              0              0.00000000
# 16 0          0              0              0.00000000
# 17 0          0              0                     NaN
# 18 0          0              0                     NaN
# 19 0          0              0                     NaN
# 20 0          0              0                     NaN
#    prop_restored_FGF1 comparison                       prop_fgf1  prop_BL6
# 1  NaN                all.obob14v14__v__all.obobBL6d14 0.00000000 0.85373134
# 2  NaN                all.obob14v14__v__all.obobBL6d14 0.00000000 0.51119403
# 3  NaN                all.obob14v14__v__all.obobBL6d14 0.00000000 0.57746479
# 4    1                all.obob14v14__v__all.obobBL6d14 0.01156069 0.56069364
# 5    0                all.obob14v14__v__all.obobBL6d14 0.01351351 0.54729730
# 6  NaN                all.obob14v14__v__all.obobBL6d14 0.00000000 0.26446281
# 7  NaN                all.obob14v14__v__all.obobBL6d14 0.00000000 0.29518072
# 8  NaN                all.obob14v14__v__all.obobBL6d14 0.00000000 0.14960630
# 9  NaN                all.obob14v14__v__all.obobBL6d14 0.00000000 0.35238095
# 10 NaN                all.obob14v14__v__all.obobBL6d14 0.00000000 0.40909091
# 11 NaN                all.obob14v14__v__all.obobBL6d14 0.00000000 0.40000000
# 12 NaN                all.obob14v14__v__all.obobBL6d14 0.00000000 0.33333333
# 13 NaN                all.obob14v14__v__all.obobBL6d14 0.00000000 0.28571429
# 14 NaN                all.obob14v14__v__all.obobBL6d14 0.00000000 0.12903226
# 15 NaN                all.obob14v14__v__all.obobBL6d14 0.00000000 0.06756757
# 16 NaN                all.obob14v14__v__all.obobBL6d14 0.00000000 0.01811594
# 17   0                all.obob14v14__v__all.obobBL6d14 0.01418440 0.00000000
# 18 NaN                all.obob14v14__v__all.obobBL6d14 0.00000000 0.00000000
# 19 NaN                all.obob14v14__v__all.obobBL6d14 0.00000000 0.00000000
# 20 NaN                all.obob14v14__v__all.obobBL6d14 0.00000000 0.00000000
#    prop_sum   n_sum class
# 1  0.85373134 286   neuron
# 2  0.51119403 137   neuron
# 3  0.57746479 123   neuron
# 4  0.57225434  99   neuron
# 5  0.56081081  83   neuron
# 6  0.26446281  64   neuron
# 7  0.29518072  49   neuron
# 8  0.14960630  38   neuron
# 9  0.35238095  37   neuron
# 10 0.40909091  27   neuron
# 11 0.40000000  20   neuron
# 12 0.33333333  20   neuron
# 13 0.28571429   8   neuron
# 14 0.12903226   8   neuron
# 15 0.06756757   5   neuron
# 16 0.01811594   5   neuron
# 17 0.01418440   2   neuron
# 18 0.00000000   0   neuron
# 19 0.00000000   0   neuron
# 20 0.00000000   0   neuron

# %%
unchanged_labels = all_restored_summary %>%
filter(!(prop_sum > 0)) %>%
pull(labels)
unchanged_labels
# Out:
#  [1] "Dlk1"                "Ependymal_cells"     "Esr1"
#  [4] "Fez1"                "Hdc"                 "Irx5__Lmx1a"
#  [7] "Lepr15"              "Lepr67"              "Lepr89"
# [10] "Met__Pappa2"         "Microglia"           "Nfib_1"
# [13] "Nfib_2"              "Nfib_3"              "Nfix__Nfib"
# [16] "Nfix__Nfib__Hgf"     "Nfix__Nfib__Lhx6"    "Npsr1__Epha3"
# [19] "OPC"                 "Pou6f2__Prkcq__Whrn" "Ppp1r17"
# [22] "Ppp1r17__Ltbp1"      "Ppp1r17__Tafa4"      "Reln__Lef1"
# [25] "Slc17a6__Trhr"       "Sst__Nts"            "Sst__Pthlh"
# [28] "Tanycytes"           "Tbx19__Pirt"         "Tmem215__Dach2"
# [31] "Trh__Lef1"           "g4"                  "g_drop"
# [34] "n4"                  "n6"                  "n8"
# [37] "n_drop"

# %%
all_restored_summary %>%
filter(str_detect(labels, 'Ghrh'))
# Out:
#   labels n_total n_fgf1 n_fgf1.pos n_fgf1.neg prop_fgf1.pos n_BL6 n_restored
# 1 Ghrh   148     2      2          NA         1             81    0
#   n_restored.pos n_restored.neg prop_restored_BL6 prop_restored_FGF1
# 1 0              0              0                 0
#   comparison                       prop_fgf1  prop_BL6  prop_sum  n_sum
# 1 all.obob14v14__v__all.obobBL6d14 0.01351351 0.5472973 0.5608108 83

# %%
beeswarm_tibble = da_results %>%
select(Nhood, labels, class, n_cells, polarity_fgf1, SpatialFDR_fgf1, logFC_fgf1, polarity_bl6, SpatialFDR_bl6, logFC_bl6, exact_grouping) %>%
mutate(restored = case_when(exact_grouping == 'pos_restored' ~ 'yes',
                             exact_grouping == 'neg_restored' ~ 'yes',
                             TRUE ~ 'no')) %>%
mutate(restored = factor(restored, levels=c('no', 'yes')))

# Separate data frames for each type of measurement
polarity_df <- beeswarm_tibble %>%
  select(Nhood, labels, class, n_cells, starts_with("polarity"), exact_grouping, restored) %>%
  pivot_longer(cols = starts_with("polarity"),
               names_to = "comparison",
               values_to = "polarity") %>%
  mutate(comparison = ifelse(str_detect(comparison, "bl6"), "BL6", "FGF1"))

spatial_df <- beeswarm_tibble %>%
  select(Nhood, labels, class, n_cells, starts_with("SpatialFDR"), exact_grouping, restored) %>%
  pivot_longer(cols = starts_with("SpatialFDR"),
               names_to = "comparison",
               values_to = "SpatialFDR") %>%
  mutate(comparison = ifelse(str_detect(comparison, "bl6"), "BL6", "FGF1"))

logfc_df <- beeswarm_tibble %>%
  select(Nhood, labels, class, n_cells, starts_with("logFC"), exact_grouping, restored) %>%
  pivot_longer(cols = starts_with("logFC"),
               names_to = "comparison",
               values_to = "logFC") %>%
  mutate(comparison = ifelse(str_detect(comparison, "bl6"), "BL6", "FGF1"))

# Join all dataframes
beeswarm_tibble <- polarity_df %>%
  inner_join(spatial_df, by = c("Nhood", "labels", "class", "n_cells", "comparison", "exact_grouping", "restored")) %>%
  inner_join(logfc_df, by = c("Nhood", "labels", "class", "n_cells", "comparison", "exact_grouping", "restored"))


beeswarm_tibble = beeswarm_tibble %>%
mutate(labels = factor(labels, levels=rev(label_order))) %>%
rowwise %>%
mutate(label.group = paste0(labels, '.', comparison)) %>% 
ungroup %>%
mutate(polarity = paste0(polarity, '.', comparison)) %>%
mutate(polarity = case_when(str_detect(polarity, 'none') ~ 'none',
                            TRUE ~ polarity)) %>%
mutate(polarity = factor(polarity, levels=rev(c('none', 'neg.BL6', 'pos.BL6', 'neg.FGF1', 'pos.FGF1')))) %>%
arrange(desc(labels))

beeswarm_tibble
# Out:
#       Nhood labels class n_cells exact_grouping restored comparison polarity
# 1      55   g3     NA     84     pos_FGF1       no       FGF1       pos.FGF1
# 2      55   g3     NA     84     pos_FGF1       no       BL6        none
# 3      63   g3     NA     83     pos_FGF1       no       FGF1       pos.FGF1
# 4      63   g3     NA     83     pos_FGF1       no       BL6        none
# 5     311   g3     NA     59     pos_FGF1       no       FGF1       pos.FGF1
# 6     311   g3     NA     59     pos_FGF1       no       BL6        none
# 7      47   g3     NA     84     pos_FGF1       no       FGF1       pos.FGF1
# 8      47   g3     NA     84     pos_FGF1       no       BL6        none
# 9      62   g3     NA     81     pos_FGF1       no       FGF1       pos.FGF1
# 10     62   g3     NA     81     pos_FGF1       no       BL6        none
# 11    304   g3     NA     79     pos_FGF1       no       FGF1       pos.FGF1
# 12    304   g3     NA     79     pos_FGF1       no       BL6        none
# 13    189   g3     NA     82     pos_FGF1       no       FGF1       pos.FGF1
# 14    189   g3     NA     82     pos_FGF1       no       BL6        none
# 15    138   g3     NA     83     none           no       FGF1       none
# 16    138   g3     NA     83     none           no       BL6        none
# 17    245   g3     NA    130     none           no       FGF1       none
# 18    245   g3     NA    130     none           no       BL6        none
# 19    162   g3     NA     65     none           no       FGF1       none
# 20    162   g3     NA     65     none           no       BL6        none
# 21     76   g3     NA    113     none           no       FGF1       none
# 22     76   g3     NA    113     none           no       BL6        none
# 23     69   g3     NA    135     none           no       FGF1       none
# 24     69   g3     NA    135     none           no       BL6        none
# 25    129   g3     NA    152     none           no       FGF1       none
# 26    129   g3     NA    152     none           no       BL6        none
# 27    186   g3     NA    140     none           no       FGF1       none
# 28    186   g3     NA    140     none           no       BL6        none
# 29    196   g3     NA    111     none           no       FGF1       none
# 30    196   g3     NA    111     none           no       BL6        none
# ⋮     ⋮     ⋮      ⋮     ⋮       ⋮              ⋮        ⋮          ⋮
# 52329 1185  other  NA    130     none           no       FGF1       none
# 52330 1185  other  NA    130     none           no       BL6        none
# 52331 1662  other  NA     68     none           no       FGF1       none
# 52332 1662  other  NA     68     none           no       BL6        none
# 52333  285  other  NA     91     none           no       FGF1       none
# 52334  285  other  NA     91     none           no       BL6        none
# 52335   55  other  NA    118     none           no       FGF1       none
# 52336   55  other  NA    118     none           no       BL6        none
# 52337  125  other  NA    121     none           no       FGF1       none
# 52338  125  other  NA    121     none           no       BL6        none
# 52339  339  other  NA    188     none           no       FGF1       none
# 52340  339  other  NA    188     none           no       BL6        none
# 52341  673  other  NA    108     none           no       FGF1       none
# 52342  673  other  NA    108     none           no       BL6        none
# 52343 1044  other  NA    101     none           no       FGF1       none
# 52344 1044  other  NA    101     none           no       BL6        none
# 52345 1428  other  NA     79     none           no       FGF1       none
# 52346 1428  other  NA     79     none           no       BL6        none
# 52347   24  other  NA    206     none           no       FGF1       none
# 52348   24  other  NA    206     none           no       BL6        none
# 52349 1316  other  NA     88     none           no       FGF1       none
# 52350 1316  other  NA     88     none           no       BL6        none
# 52351 1633  other  NA     67     none           no       FGF1       none
# 52352 1633  other  NA     67     none           no       BL6        none
# 52353  590  other  NA    107     none           no       FGF1       none
# 52354  590  other  NA    107     none           no       BL6        none
# 52355 1500  other  NA    187     none           no       FGF1       none
# 52356 1500  other  NA    187     none           no       BL6        none
# 52357 1698  other  NA    129     none           no       FGF1       none
# 52358 1698  other  NA    129     none           no       BL6        none
#       SpatialFDR logFC         label.group
# 1     0.03041599  1.921086148  g3.FGF1
# 2     0.76593457  0.661952847  g3.BL6
# 3     0.03041599  1.888611203  g3.FGF1
# 4     0.95588314  0.248217206  g3.BL6
# 5     0.03041599  2.037393622  g3.FGF1
# 6     0.69729167 -1.427037043  g3.BL6
# 7     0.03468843  1.838599634  g3.FGF1
# 8     0.70611538  0.808811530  g3.BL6
# 9     0.03468843  1.870091304  g3.FGF1
# 10    0.69729167  0.956498858  g3.BL6
# 11    0.03532683  1.786924327  g3.FGF1
# 12    0.99880474  0.001838353  g3.BL6
# 13    0.08700459  1.576238164  g3.FGF1
# 14    0.95588314 -0.274781354  g3.BL6
# 15    0.10504153  1.580671576  g3.FGF1
# 16    0.75447401  0.699045677  g3.BL6
# 17    0.12924438 -1.451229861  g3.FGF1
# 18    0.80367776 -0.359263811  g3.BL6
# 19    0.20065472  1.567604984  g3.FGF1
# 20    0.69729167  0.940045690  g3.BL6
# 21    0.22997695  1.416447811  g3.FGF1
# 22    0.77620870  0.547175987  g3.BL6
# 23    0.27581578 -1.167740907  g3.FGF1
# 24    0.95588314 -0.125039828  g3.BL6
# 25    0.27581578 -1.034858470  g3.FGF1
# 26    0.94064245 -0.174186296  g3.BL6
# 27    0.27581578 -1.145302216  g3.FGF1
# 28    0.95588314 -0.150696944  g3.BL6
# 29    0.27581578  1.295814136  g3.FGF1
# 30    0.93207673  0.282048158  g3.BL6
# ⋮     ⋮          ⋮             ⋮
# 52329 0.9954018   7.612853e-03 other.FGF1
# 52330 0.4244604  -1.387265e+00 other.BL6
# 52331 0.9954018  -1.153764e-02 other.FGF1
# 52332 0.7557002   7.317040e-01 other.BL6
# 52333 0.9956467  -5.711530e-03 other.FGF1
# 52334 0.5730312  -1.285841e+00 other.BL6
# 52335 0.9966191   5.551845e-03 other.FGF1
# 52336 0.5546585  -9.642797e-01 other.BL6
# 52337 0.9966191  -3.618293e-03 other.FGF1
# 52338 0.9586228   9.258122e-02 other.BL6
# 52339 0.9966191  -3.569952e-03 other.FGF1
# 52340 0.4815236   7.849588e-01 other.BL6
# 52341 0.9966191  -6.294616e-03 other.FGF1
# 52342 0.9020735  -2.697573e-01 other.BL6
# 52343 0.9966191  -4.284029e-03 other.FGF1
# 52344 0.8874994   3.343282e-01 other.BL6
# 52345 0.9966191  -5.580102e-03 other.FGF1
# 52346 0.4893336  -2.533788e+00 other.BL6
# 52347 0.9980607   1.267333e-03 other.FGF1
# 52348 0.8736278  -2.608389e-01 other.BL6
# 52349 0.9980607  -2.766520e-03 other.FGF1
# 52350 0.3036351  -2.856657e+00 other.BL6
# 52351 0.9980607  -7.742468e-03 other.FGF1
# 52352 0.8182745   6.338650e-01 other.BL6
# 52353 0.9988961  -2.885741e-03 other.FGF1
# 52354 0.3570426  -1.755719e+00 other.BL6
# 52355 0.9988961  -1.747396e-03 other.FGF1
# 52356 0.9260035  -1.479412e-01 other.BL6
# 52357 0.9998853  -5.705667e-06 other.FGF1
# 52358 0.9236188   1.658302e-01 other.BL6

# %%
beeswarm_tibble %>% head %>% print
# Out:
# # A tibble: 6 × 11
#   Nhood labels class n_cells exact_grouping restored comparison polarity
#   <dbl> <fct>  <chr>   <dbl> <chr>          <fct>    <chr>      <fct>
# 1    55 g3     NA         84 pos_FGF1       no       FGF1       pos.FGF1
# 2    55 g3     NA         84 pos_FGF1       no       BL6        none
# 3    63 g3     NA         83 pos_FGF1       no       FGF1       pos.FGF1
# 4    63 g3     NA         83 pos_FGF1       no       BL6        none
# 5   311 g3     NA         59 pos_FGF1       no       FGF1       pos.FGF1
# 6   311 g3     NA         59 pos_FGF1       no       BL6        none
# # ℹ 3 more variables: SpatialFDR <dbl>, logFC <dbl>, label.group <chr>

# %%
beeswarm_tibble %>% pull(polarity) %>% unique
beeswarm_tibble %>% pull(polarity) %>% levels
# Out:
# [1] pos.FGF1 none     neg.BL6  pos.BL6  neg.FGF1
# Levels: pos.FGF1 neg.FGF1 pos.BL6 neg.BL6 none
# [1] "pos.FGF1" "neg.FGF1" "pos.BL6"  "neg.BL6"  "none"

# %%
beeswarm_tibble %>% filter(restored == 'yes') %>% dim
# Out:
# [1]  6 11

# %%
options(repr.plot.width=3.5, repr.plot.height=10)

# Creating a separate tibble for the labels
label_tibble <- beeswarm_tibble %>%
  filter(class == 'other')  %>%
#   filter(!(labels %in% unchanged_labels)) %>%
  distinct(labels)

beeswarm_other = beeswarm_tibble %>%
  filter(class == 'other') %>%
#   filter(!(labels %in% unchanged_labels)) %>%
  arrange(labels, polarity, restored) %>%
  ggplot(aes(logFC, labels, group=comparison, color=polarity, alpha=polarity, shape=restored)) + 
  geom_quasirandom(size=1, dodge.width = 1, orientation='y') +
  scale_shape_manual(values = c(yes=19, no=1)) +
  scale_color_manual(values = c('none' =  "#a1a1a1",
                                'neg.FGF1' = "#d73027",
                                'pos.FGF1' = "#4575b4",
                                'neg.BL6' = "#00441b",
                                'pos.BL6' = "#40004b")) + 
  scale_alpha_manual(values = c('none' =  0.25,
                                'neg.FGF1' = 0.25,
                                'pos.FGF1' = 0.25,
                                'neg.BL6' = 0.25,
                                'pos.BL6' = 0.25)) +
  geom_text(data = label_tibble, aes(x = 0, y = labels, label = labels), size=3, hjust = 0.5, vjust = 0.5, inherit.aes = FALSE) +
  theme_classic() +
  theme(axis.title.y = element_blank(),
        axis.ticks.y = element_blank(),
        axis.text.y = element_blank())  + 
theme(legend.position=c(0.9,0.08)) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))
beeswarm_other
# Out:
# plot without title

# %%
options(repr.plot.width=7, repr.plot.height=10)
layout <- '
AB
AC
AD
'

ggp = wrap_plots(A = beeswarm_other,
           B = umap_fgf1_other,
           C = umap_bl6_other,
           D = umap_restored_other,
    design = layout) +
plot_layout(guides = 'auto') + plot_annotation(tag_levels = c('A', 'B', 'C', 'D'))

ggp %>% ggsave('beeswarm_umap_other_all_d14.pdf', plot = ., width = 7, height=9)
ggp
# Out:
# plot without title

# %%
unchanged_labels_bl6 = da_results %>%
group_by(labels) %>%
summarise(polarities = polarity_bl6 %>% unique) %>%
group_by(labels) %>%
summarise(n=n()) %>%
# filter(n == 1) %>%
pull(labels)

unchanged_labels_bl6
# Out:
# Warning message:
# “Returning more (or less) than 1 row per `summarise()` group was deprecated in
# dplyr 1.1.0.
# ℹ Please use `reframe()` instead.
# ℹ When switching from `summarise()` to `reframe()`, remember that `reframe()`
#   always returns an ungrouped data frame and adjust accordingly.”
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
#  [1] "Agrp"                "Arx__Nr5a2"          "Astrocytes"
#  [4] "Dlk1"                "Endothelial_cells"   "Ependymal_cells"
#  [7] "Esr1"                "Fez1"                "Ghrh"
# [10] "Gpr50__Tac2"         "Hdc"                 "Htr3b"
# [13] "Irx5__Lmx1a"         "Kiss1__Tac2"         "Lepr15"
# [16] "Lepr67"              "Lepr89"              "Lpar1_oligo"
# [19] "Met__Pappa2"         "Met__Prlh"           "Microglia"
# [22] "Nfib_1"              "Nfib_2"              "Nfib_3"
# [25] "Nfix__Nfib"          "Nfix__Nfib__Hgf"     "Nfix__Nfib__Lhx6"
# [28] "Npsr1__Epha3"        "OPC"                 "Oligodendrocytes"
# [31] "Pomc__Anxa2"         "Pomc__Glipr1"        "Pomc__Ttr"
# [34] "Pou6f2__Prkcq__Whrn" "Ppp1r17"             "Ppp1r17__Ltbp1"
# [37] "Ppp1r17__Tafa4"      "Reln__Lef1"          "Sim1"
# [40] "Slc17a6__Trhr"       "Sst__Nts"            "Sst__Pthlh"
# [43] "Sst__Unc13c"         "Tanycytes"           "Tbx19__Pirt"
# [46] "Th__Nfib"            "Th__Slc6a3"          "Tmem215__Dach2"
# [49] "Tmem215__Greb1"      "Trh__Cxcl12"         "Trh__Lef1"
# [52] "g1"                  "g2"                  "g3"
# [55] "g4"                  "g_drop"              "n0"
# [58] "n1"                  "n2"                  "n3"
# [61] "n4"                  "n5"                  "n6"
# [64] "n8"                  "n_drop"              "neuron"
# [67] "other"

# %%
options(repr.plot.width=3.5, repr.plot.height=3.5)

unchanged_labels_bl6 = da_results %>%
group_by(labels) %>%
summarise(polarities = polarity_bl6 %>% unique) %>%
group_by(labels) %>%
summarise(n=n()) %>%
filter(n == 1) %>%
pull(labels)
unchanged_labels_bl6 %>% length

label_data <- da_results %>%
  filter(class == 'neuron') %>%
  filter(!(labels %in% unchanged_labels_bl6)) %>%
  mutate(labels = str_replace(labels, fixed('__'), '\n')) %>%
  group_by(labels) %>%
  summarise(umap_1 = mean(umap_1, na.rm = TRUE),
            umap_2 = mean(umap_2, na.rm =TRUE),
            label = first(labels))

umap_bl6_neuron = da_results %>%
filter(class == 'neuron') %>%
mutate(polarity_bl6 = factor(polarity_bl6, levels = c("none", "neg", "pos"))) %>%
arrange(polarity_bl6) %>%
ggplot(aes(x = umap_1, y = umap_2, color=polarity_bl6, alpha=polarity_bl6)) + 
geom_point(size=0.5, shape = 16) + 
scale_color_manual(values = c('none' =  "#a1a1a1",
                              'neg' = "#1b7837",
                              'pos' = "#762a83")) +
scale_alpha_manual(values = c("none" = 1, "neg" = 1, "pos"=1)) +
geom_text_repel(data = label_data, aes(x = umap_1, y = umap_2, label = label), 
              size = 2, 
              box.padding = unit(0, "lines"), 
              point.padding = unit(0, "lines"),
              segment.color = 'grey50',
              inherit.aes = FALSE) +
theme_minimal() + theme(legend.position=c(0.9,0.125)) + theme(
  axis.ticks = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank()
) + theme(
  axis.text = element_blank(),
  axis.title.x = element_blank(),
  axis.text.x = element_blank(),
  axis.text.y = element_blank(),
  axis.title.y = element_blank()
) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))

umap_bl6_neuron
# Out:
# Warning message:
# “Returning more (or less) than 1 row per `summarise()` group was deprecated in
# dplyr 1.1.0.
# ℹ Please use `reframe()` instead.
# ℹ When switching from `summarise()` to `reframe()`, remember that `reframe()`
#   always returns an ungrouped data frame and adjust accordingly.”
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# [1] 40
# plot without title

# %%
options(repr.plot.width=3.5, repr.plot.height=3.5)

unchanged_labels_fgf1 = da_results %>%
group_by(labels) %>%
summarise(polarities = polarity_fgf1 %>% unique) %>%
group_by(labels) %>%
summarise(n=n()) %>%
filter(n == 1) %>%
pull(labels)
unchanged_labels_fgf1 %>% length

label_data <- da_results %>%
  filter(class == 'neuron') %>%
  filter(!(labels %in% unchanged_labels_fgf1)) %>%
  mutate(labels = str_replace(labels, fixed('__'), '\n')) %>%
  group_by(labels) %>%
  summarise(umap_1 = mean(umap_1, na.rm = TRUE),
            umap_2 = mean(umap_2, na.rm =TRUE),
            label = first(labels))

umap_fgf1_neuron = da_results %>%
filter(class == 'neuron') %>%
mutate(polarity_fgf1 = factor(polarity_fgf1, levels = c("none", "neg", "pos"))) %>%
arrange(polarity_fgf1) %>%
ggplot(aes(x = umap_1, y = umap_2, color=polarity_fgf1, alpha=polarity_fgf1)) + 
geom_point(size=0.5, shape = 16) + 
scale_color_manual(values = c('none' =  "#a1a1a1",
                              'neg' = "#d73027",
                              'pos' = "#4575b4")) +
scale_alpha_manual(values = c("none" = 0.25, "neg" = 0.5, "pos"=0.5)) +
geom_text_repel(data = label_data, aes(x = umap_1, y = umap_2, label = label), 
              size = 2, 
              box.padding = unit(0, "lines"), 
              point.padding = unit(0, "lines"),
              segment.color = 'grey50',
              inherit.aes = FALSE) +
theme_minimal() + theme(legend.position=c(0.9,0.125)) + theme(
  axis.ticks = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank()
) + theme(
  axis.text = element_blank(),
  axis.title.x = element_blank(),
  axis.text.x = element_blank(),
  axis.text.y = element_blank(),
  axis.title.y = element_blank()
) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))


umap_fgf1_neuron
# Out:
# Warning message:
# “Returning more (or less) than 1 row per `summarise()` group was deprecated in
# dplyr 1.1.0.
# ℹ Please use `reframe()` instead.
# ℹ When switching from `summarise()` to `reframe()`, remember that `reframe()`
#   always returns an ungrouped data frame and adjust accordingly.”
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# [1] 60
# plot without title

# %%
options(repr.plot.width=3.5, repr.plot.height=3.5)

label_data <- da_results %>%
  filter(class == 'neuron') %>%
  filter(!(labels %in% unchanged_labels_fgf1)) %>%
  filter(!(labels %in% unchanged_labels_bl6)) %>%
  mutate(labels = str_replace(labels, fixed('__'), '\n')) %>%
  group_by(labels) %>%
  summarise(umap_1 = mean(umap_1, na.rm = TRUE),
            umap_2 = mean(umap_2, na.rm =TRUE),
            label = first(labels))

umap_restored_neuron = da_results %>%
filter(class == 'neuron') %>%
mutate(polarity = case_when(exact_grouping == 'pos_restored' ~ "pos",
                             exact_grouping == 'neg_restored' ~ "neg",
                             TRUE ~ 'other')) %>%
mutate(polarity = factor(polarity, levels = c("other", "neg", "pos"))) %>%
arrange(polarity) %>%
ggplot(aes(x = umap_1, y = umap_2, color=polarity, alpha=polarity)) + 
geom_point(size=0.5, shape = 16) + 
scale_color_manual(values = c('other' =  "#a1a1a1",
                              'neg' = "#a50026",
                              'pos' = "#313695")) +
scale_alpha_manual(values = c("other" = 0.25, "neg" = 0.5, "pos"=0.5)) +
geom_text_repel(data = label_data, aes(x = umap_1, y = umap_2, label = label), 
              size = 2, 
              box.padding = unit(0, "lines"), 
              point.padding = unit(0, "lines"),
              segment.color = 'grey50',
              inherit.aes = FALSE) +
theme_minimal() + theme(legend.position=c(0.9,0.125)) + theme(
  axis.ticks = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank()
) + theme(
  axis.text = element_blank(),
  axis.title.x = element_blank(),
  axis.text.x = element_blank(),
  axis.text.y = element_blank(),
  axis.title.y = element_blank()
) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))

umap_restored_neuron
# Out:
# plot without title

# %%
options(repr.plot.width=3.5, repr.plot.height=10)

# Creating a separate tibble for the labels
label_tibble <- da_results %>%
  filter(class == 'neuron') %>%
  filter((polarity_fgf1 %in% c('pos', 'neg')) | (polarity_bl6 %in% c('pos', 'neg'))) %>%
  distinct(labels)

beeswarm_neuron = beeswarm_tibble %>%
  filter(class == 'neuron') %>%
  filter((labels %in% label_tibble$labels)) %>%
  arrange(labels, polarity, restored) %>%
  ggplot(aes(logFC, labels, group=comparison, color=polarity, alpha=polarity, shape=restored)) + 
  geom_quasirandom(size=1, dodge.width = 1, orientation='y') +
  scale_shape_manual(values = c(yes=19, no=1)) +
  scale_color_manual(values = c('none' =  "#a1a1a1",
                                'neg.FGF1' = "#d73027",
                                'pos.FGF1' = "#4575b4",
                                'neg.BL6' = "#00441b",
                                'pos.BL6' = "#40004b")) + 
  scale_alpha_manual(values = c('none' =  0.25,
                                'neg.FGF1' = 0.25,
                                'pos.FGF1' = 0.25,
                                'neg.BL6' = 0.25,
                                'pos.BL6' = 0.25)) +
  geom_text(data = label_tibble, aes(x = 0, y = labels, label = labels), size=3, hjust = 0.5, vjust = 0.5, inherit.aes = FALSE) +
  theme_classic() +
  theme(axis.title.y = element_blank(),
        axis.ticks.y = element_blank(),
        axis.text.y = element_blank())  + 
theme(legend.position=c(0.85,0.3)) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))

beeswarm_neuron
# Out:
# plot without title

# %%
options(repr.plot.width=7, repr.plot.height=9.5)
layout <- '
AB
AC
AD
'

ggp = wrap_plots(A = beeswarm_neuron,
           B = umap_fgf1_neuron,
           C = umap_bl6_neuron,
           D = umap_restored_neuron,
    design = layout) +
plot_layout(guides = 'auto') + plot_annotation(tag_levels = c('A', 'B', 'C', 'D'))

ggp %>% ggsave('beeswarm_umap_neurons_all_d14.pdf', plot = ., width = 7, height=9)
ggp
# Out:
# plot without title

# %%
beeswarm_tibble %>% qs::qsave('beeswarm_tibble_d14.qs')
da_results %>% qs::qsave('beeswarm_da_results_d14.qs')
