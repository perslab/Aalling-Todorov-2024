# %%
library(Seurat)
library(tidyverse)
library(ggplot2)
library(ggrepel)
library(ggbeeswarm)
library(patchwork)
library(miloR)
options(ggrepel.max.overlaps = Inf)

# %%
source('milo_cellbender.R')

# %%
obj_neuron = qs::qread('_targets/objects/obj_neuron') %>%
             set_labels_to_lvl1 %>%
             #set_batch_to_lane %>% # do not set batch to lane for cluster splits
             prep_obj_for_milo_cb_v01 
obj_neuron
# Out:
# An object of class Seurat
# 29114 features across 104287 samples within 2 assays
# Active assay: integrated (2000 features, 2000 variable features)
#  2 layers present: data, scale.data
#  1 other assay present: RNA
#  2 dimensional reductions calculated: pca, umap

# %%
DimPlot(obj_neuron)
# Out:
# Rasterizing points since number of points exceeds 100,000.
# To disable this behavior set `raster=FALSE`
# plot without title

# %%
obj_other = qs::qread('_targets/objects/obj_other') %>%
             set_labels_to_lvl1 %>%
             #set_batch_to_lane %>% # do not set batch to lane for cluster splits
             prep_obj_for_milo_cb_v01 
obj_other
# Out:
# An object of class Seurat
# 25126 features across 32121 samples within 2 assays
# Active assay: integrated (2000 features, 2000 variable features)
#  2 layers present: data, scale.data
#  1 other assay present: RNA
#  2 dimensional reductions calculated: pca, umap

# %%
DimPlot(obj_other)
# Out:
# plot without title

# %%
labels_classes_tib = (obj_other@meta.data %>% select(labels) %>% mutate(class = 'other') %>% tibble %>% distinct(labels, class)) %>%
bind_rows(obj_neuron@meta.data %>% select(labels) %>% mutate(class = 'neuron') %>% tibble %>% distinct(labels, class)) %>%
mutate(labels = str_replace(labels, fixed('-'), '__'))

# %%
umap_coords_neuron = obj_neuron %>%
`@`('reductions') %>%
`$`('umap') %>%
`@`('cell.embeddings') %>%
as.data.frame %>%
rownames_to_column('cell_barcode')

umap_coords_neuron %>% head
# Out:
#   cell_barcode               umap_1     umap_2
# 1 SI-TT-A11_AAACCCAAGGTGGTTG -0.2297173  -8.9081404
# 2 SI-TT-A11_AAACCCACATACAGCT  7.5590410   2.2857907
# 3 SI-TT-A11_AAACCCAGTACGTTCA  7.7914410 -12.4340565
# 4 SI-TT-A11_AAACCCATCCAAGCAT -6.3445525  12.1587455
# 5 SI-TT-A11_AAACCCATCCCATAAG -9.1913304   0.1722547
# 6 SI-TT-A11_AAACCCATCGTCCTCA  9.1011243   1.8562883

# %%
umap_coords_other = obj_other %>%
`@`('reductions') %>%
`$`('umap') %>%
`@`('cell.embeddings') %>%
as.data.frame %>%
rownames_to_column('cell_barcode')

umap_coords_other %>% head
# Out:
#   cell_barcode               umap_1     umap_2
# 1 SI-TT-A11_AAACCCAGTATCGGTT -11.677323   2.8312042
# 2 SI-TT-A11_AAACGAAAGCAACAAT   5.244560 -11.4948561
# 3 SI-TT-A11_AAACGAAAGGTTCTTG  12.237945   8.5842693
# 4 SI-TT-A11_AAACGAACAAGGAGTC   3.364908   4.0688338
# 5 SI-TT-A11_AAACGAACAGCCTTCT   3.744040   1.6572222
# 6 SI-TT-A11_AAACGCTAGTGCTAGG -13.495440   0.9611907

# %%
ambiguous_cells = intersect(umap_coords_neuron %>% pull(cell_barcode), umap_coords_other %>% pull(cell_barcode))
ambiguous_cells %>% length
# Out:
# [1] 0

# %%
umap_coords_neuron = umap_coords_neuron %>% filter(!(cell_barcode %in% ambiguous_cells))
umap_coords_other = umap_coords_other %>% filter(!(cell_barcode %in% ambiguous_cells))
umap_coords = bind_rows(umap_coords_neuron, umap_coords_other)
umap_coords %>% dim
# Out:
# [1] 136408      3

# %%
# da_results_restored = qs::qread('_targets/objects/combined_da_results_nhg_all.obob5v5__v__all.obobBL6')
da_results_restored = qs::qread('_targets/objects/combined_da_results_nhg_Day5.obob5v5__v__Day5.obobBL6d5')
# column_to_rownames('hash.mcl.ID')

dim(da_results_restored)
da_results_restored %>% head
# Out:
# [1] 10124    18
#   logFC     logCPM   F        PValue       FDR          Nhood SpatialFDR
# 1  2.888189 13.75687 45.52857 2.743637e-07 2.990564e-05 90    3.222835e-05
# 2  3.621216 13.51200 37.19681 1.506139e-06 8.208458e-05 75    9.322746e-05
# 3  3.854941 13.28068 29.56951 8.859335e-06 3.218892e-04 84    3.701515e-04
# 4  2.736253 13.33721 27.13807 1.642929e-05 4.476981e-04  5    4.971582e-04
# 5 -2.091388 13.17733 24.61492 4.331900e-05 9.443543e-04 80    1.011507e-03
# 6  1.801392 13.91092 22.62730 5.792913e-05 1.052379e-03 21    1.094498e-03
#   polarity labels labels_fraction comparison                      restored
# 1 pos      Agrp   1               Day5.obob5v5__v__Day5.obobBL6d5 TRUE
# 2 pos      Agrp   1               Day5.obob5v5__v__Day5.obobBL6d5 TRUE
# 3 pos      Agrp   1               Day5.obob5v5__v__Day5.obobBL6d5 TRUE
# 4 pos      Agrp   1               Day5.obob5v5__v__Day5.obobBL6d5 TRUE
# 5 neg      Agrp   1               Day5.obob5v5__v__Day5.obobBL6d5 TRUE
# 6 pos      Agrp   1               Day5.obob5v5__v__Day5.obobBL6d5 TRUE
#   exact_grouping restored_grouping fgf1_grouping bl6_grouping
# 1 pos_restored   pos_restored      pos           neg
# 2 pos_restored   pos_restored      pos           neg
# 3 pos_restored   pos_restored      pos           neg
# 4 pos_restored   pos_restored      pos           neg
# 5 neg_restored   neg_restored      neg           pos
# 6 pos_restored   pos_restored      pos           neg
#   hash.mcl.ID                n_cells
# 1 SI-TT-F11_CACTTCGGTAAGTAGT 146
# 2 SI-TT-H10_TGTTGGAGTAGCTTTG 104
# 3 SI-TT-H10_ACATCGACAAGACTGG  83
# 4 SI-TT-C11_GTTACAGGTTACCTTT 122
# 5 SI-TT-H10_CTCTCAGTCCGGCTTT 130
# 6 SI-TT-H10_TGTCCCAGTTACAGCT 198

# %%
# da_results_bl6 = qs::qread('_targets/objects/combined_da_results_idx_all.obobBL6') %>%
da_results_bl6 = qs::qread('_targets/objects/combined_da_results_idx_Day5.obobBL6d5') %>%
rename(n_cells = n_cells.x) %>%
select(-n_cells.y) %>%
mutate(polarity = case_when(polarity == 'none' ~ 'none',
                            polarity == 'pos' ~ 'neg',
                            polarity == 'neg' ~ 'pos')) %>%
mutate(logFC = -logFC)


dim(da_results_bl6)
da_results_bl6 %>% head
# Out:
# [1] 10124    12
#   logFC    logCPM   F        PValue       FDR          Nhood SpatialFDR
# 1 8.849173 14.31990 410.9206 1.651620e-15 1.800266e-13 71    1.534913e-13
# 2 8.776353 14.24684 374.8979 4.220395e-15 2.300115e-13 23    2.197192e-13
# 3 8.719417 14.19623 359.6394 6.445510e-15 2.341868e-13 55    2.253772e-13
# 4 8.665627 14.11755 328.4025 1.621603e-14 4.206605e-13 70    4.150629e-13
# 5 9.526587 14.00518 322.8084 1.929636e-14 4.206605e-13 98    4.150629e-13
# 6 8.506939 13.92242 267.6632 1.269773e-13 2.306755e-12 19    2.335715e-12
#   polarity labels labels_fraction n_cells hash.mcl.ID
# 1 pos      Agrp   1               144     SI-TT-A11_AATCACGCAGTTGGTT
# 2 pos      Agrp   1               136     SI-TT-G10_CCTTTGGGTTCCCACT
# 3 pos      Agrp   1               133     SI-TT-H10_GGTAGAGCAAATACAG
# 4 pos      Agrp   1               126     SI-TT-C12_AGGACTTAGGTTCTAC
# 5 pos      Agrp   1               117     SI-TT-F11_ACCATTTCACAGCGCT
# 6 pos      Agrp   1               112     SI-TT-F11_AATGACCGTAGTGTGG

# %%
da_results_fgf1 = qs::qread('_targets/objects/combined_da_results_idx_Day5.obob5v5') %>%
rename(n_cells = n_cells.x) %>%
select(-n_cells.y)


dim(da_results_fgf1)
da_results_fgf1 %>% head
# Out:
# [1] 10124    12
#   logFC     logCPM   F        PValue       FDR          Nhood SpatialFDR
# 1  2.888189 13.75687 45.52857 2.743637e-07 2.990564e-05 90    3.222835e-05
# 2  3.621216 13.51200 37.19681 1.506139e-06 8.208458e-05 75    9.322746e-05
# 3  3.854941 13.28068 29.56951 8.859335e-06 3.218892e-04 84    3.701515e-04
# 4  2.736253 13.33721 27.13807 1.642929e-05 4.476981e-04  5    4.971582e-04
# 5 -2.091388 13.17733 24.61492 4.331900e-05 9.443543e-04 80    1.011507e-03
# 6  1.801392 13.91092 22.62730 5.792913e-05 1.052379e-03 21    1.094498e-03
#   polarity labels labels_fraction n_cells hash.mcl.ID
# 1 pos      Agrp   1               146     SI-TT-F11_CACTTCGGTAAGTAGT
# 2 pos      Agrp   1               104     SI-TT-H10_TGTTGGAGTAGCTTTG
# 3 pos      Agrp   1                83     SI-TT-H10_ACATCGACAAGACTGG
# 4 pos      Agrp   1               122     SI-TT-C11_GTTACAGGTTACCTTT
# 5 neg      Agrp   1               130     SI-TT-H10_CTCTCAGTCCGGCTTT
# 6 pos      Agrp   1               198     SI-TT-H10_TGTCCCAGTTACAGCT

# %%
da_results_2 = full_join(da_results_fgf1, da_results_bl6, by=c('Nhood', 'labels'), suffix = c('_fgf1', '_bl6'))
da_results_2 %>% head
# Out:
#   logFC_fgf1 logCPM_fgf1 F_fgf1   PValue_fgf1  FDR_fgf1     Nhood
# 1  2.888189  13.75687    45.52857 2.743637e-07 2.990564e-05 90
# 2  3.621216  13.51200    37.19681 1.506139e-06 8.208458e-05 75
# 3  3.854941  13.28068    29.56951 8.859335e-06 3.218892e-04 84
# 4  2.736253  13.33721    27.13807 1.642929e-05 4.476981e-04  5
# 5 -2.091388  13.17733    24.61492 4.331900e-05 9.443543e-04 80
# 6  1.801392  13.91092    22.62730 5.792913e-05 1.052379e-03 21
#   SpatialFDR_fgf1 polarity_fgf1 labels labels_fraction_fgf1 ⋯ logFC_bl6
# 1 3.222835e-05    pos           Agrp   1                    ⋯  4.682708
# 2 9.322746e-05    pos           Agrp   1                    ⋯  6.823027
# 3 3.701515e-04    pos           Agrp   1                    ⋯  7.695127
# 4 4.971582e-04    pos           Agrp   1                    ⋯  2.937303
# 5 1.011507e-03    neg           Agrp   1                    ⋯ -6.505125
# 6 1.094498e-03    pos           Agrp   1                    ⋯  1.938554
#   logCPM_bl6 F_bl6     PValue_bl6   FDR_bl6      SpatialFDR_bl6 polarity_bl6
# 1 13.75687    94.82970 2.055591e-10 1.400371e-09 1.365334e-09   pos
# 2 13.51200   145.53465 1.676724e-12 1.405869e-11 1.361109e-11   pos
# 3 13.28068   150.69007 1.116673e-12 1.163903e-11 1.108965e-11   pos
# 4 13.33721    17.99325 2.253781e-04 5.459159e-04 5.303839e-04   pos
# 5 13.17733    23.43533 5.898680e-05 1.785989e-04 1.741181e-04   neg
# 6 13.91092    13.85889 9.121331e-04 1.744255e-03 1.673373e-03   pos
#   labels_fraction_bl6 n_cells_bl6 hash.mcl.ID_bl6
# 1 1                   146         SI-TT-F11_CACTTCGGTAAGTAGT
# 2 1                   104         SI-TT-H10_TGTTGGAGTAGCTTTG
# 3 1                    83         SI-TT-H10_ACATCGACAAGACTGG
# 4 1                   122         SI-TT-C11_GTTACAGGTTACCTTT
# 5 1                   130         SI-TT-H10_CTCTCAGTCCGGCTTT
# 6 1                   198         SI-TT-H10_TGTCCCAGTTACAGCT

# %%
da_results = da_results_restored %>% full_join(da_results_2, by=c('Nhood', 'labels')) %>%
mutate(exact_grouping = case_when(is.na(exact_grouping) & (polarity_bl6 != 'none') ~ paste0(polarity_bl6, '_BL6'),
                                  is.na(exact_grouping) & (polarity_bl6 == 'none') ~ paste0(polarity_bl6),
                                  TRUE ~ exact_grouping)) %>%
mutate(n_cells = n_cells_fgf1) %>%
left_join(labels_classes_tib, by='labels') %>%
mutate(cell_barcode = hash.mcl.ID_fgf1) %>%
relocate(cell_barcode, .after='hash.mcl.ID') %>%
select(-all_of(c("hash.mcl.ID", "hash.mcl.ID_fgf1", "hash.mcl.ID_bl6"))) %>%
left_join(umap_coords, by='cell_barcode') %>%
mutate(polarity_bl6 = case_when(logFC_bl6 > 0 & SpatialFDR_bl6 < 0.1 ~ 'pos',
                                logFC_bl6 < 0 & SpatialFDR_bl6 < 0.1 ~ 'neg',
                                TRUE ~ 'none')) %>%
mutate(polarity_fgf1 = case_when(logFC_fgf1 > 0 & SpatialFDR_fgf1 < 0.1 ~ 'pos',
                                logFC_fgf1 < 0 & SpatialFDR_fgf1 < 0.1 ~ 'neg',
                                TRUE ~ 'none'))

da_results %>% dim
da_results %>% head
# Out:
# [1] 10124    39
#   logFC     logCPM   F        PValue       FDR          Nhood SpatialFDR
# 1  2.888189 13.75687 45.52857 2.743637e-07 2.990564e-05 90    3.222835e-05
# 2  3.621216 13.51200 37.19681 1.506139e-06 8.208458e-05 75    9.322746e-05
# 3  3.854941 13.28068 29.56951 8.859335e-06 3.218892e-04 84    3.701515e-04
# 4  2.736253 13.33721 27.13807 1.642929e-05 4.476981e-04  5    4.971582e-04
# 5 -2.091388 13.17733 24.61492 4.331900e-05 9.443543e-04 80    1.011507e-03
# 6  1.801392 13.91092 22.62730 5.792913e-05 1.052379e-03 21    1.094498e-03
#   polarity labels labels_fraction ⋯ F_bl6     PValue_bl6   FDR_bl6
# 1 pos      Agrp   1               ⋯  94.82970 2.055591e-10 1.400371e-09
# 2 pos      Agrp   1               ⋯ 145.53465 1.676724e-12 1.405869e-11
# 3 pos      Agrp   1               ⋯ 150.69007 1.116673e-12 1.163903e-11
# 4 pos      Agrp   1               ⋯  17.99325 2.253781e-04 5.459159e-04
# 5 neg      Agrp   1               ⋯  23.43533 5.898680e-05 1.785989e-04
# 6 pos      Agrp   1               ⋯  13.85889 9.121331e-04 1.744255e-03
#   SpatialFDR_bl6 polarity_bl6 labels_fraction_bl6 n_cells_bl6 class  umap_1
# 1 1.365334e-09   pos          1                   146         neuron 6.182579
# 2 1.361109e-11   pos          1                   104         neuron 6.118061
# 3 1.108965e-11   pos          1                    83         neuron 6.103095
# 4 5.303839e-04   pos          1                   122         neuron 6.258937
# 5 1.741181e-04   neg          1                   130         neuron 5.950283
# 6 1.673373e-03   pos          1                   198         neuron 6.124133
#   umap_2
# 1 -11.01147
# 2 -10.91027
# 3 -10.68353
# 4 -11.74414
# 5 -14.22009
# 6 -11.63973

# %%
da_results_restored
# Out:
#       logFC        logCPM   F            PValue       FDR          Nhood
# 1      2.8881893   13.75687 45.528568    2.743637e-07 2.990564e-05  90
# 2      3.6212160   13.51200 37.196809    1.506139e-06 8.208458e-05  75
# 3      3.8549411   13.28068 29.569506    8.859335e-06 3.218892e-04  84
# 4      2.7362526   13.33721 27.138071    1.642929e-05 4.476981e-04   5
# 5     -2.0913883   13.17733 24.614916    4.331900e-05 9.443543e-04  80
# 6      1.8013917   13.91092 22.627296    5.792913e-05 1.052379e-03  21
# 7      5.1512858   14.06837 25.845040    1.091237e-04 1.699211e-03  33
# 8      2.0978526   13.35599 18.720951    1.793365e-04 2.443460e-03  91
# 9     -2.2189129   12.58639 18.132287    2.635283e-04 3.191621e-03  27
# 10     2.2786085   13.73263 16.635178    4.168412e-04 4.543569e-03  82
# 11    -1.7288898   13.37979 15.928918    5.216587e-04 5.169163e-03  50
# 12    -1.5466394   13.37196 14.882060    7.322583e-04 6.651347e-03 101
# 13    -1.4258074   13.04247 13.016367    1.375580e-03 1.098869e-02  56
# 14     1.5374465   13.18398 12.233125    1.613018e-03 1.098869e-02  63
# 15     1.1398749   13.83964 12.518844    1.451965e-03 1.098869e-02  67
# 16     2.2396892   13.19154 12.638855    1.568523e-03 1.098869e-02  74
# 17     2.3122907   13.41983 12.087283    1.907553e-03 1.223078e-02 100
# 18     3.8150656   13.81633 11.184252    4.096395e-03 2.480595e-02  88
# 19    -1.4712970   13.30540  9.192537    5.296333e-03 3.038423e-02  49
# 20    -1.1124957   13.56028  7.898142    9.007339e-03 4.909000e-02  54
# 21     1.6383874   13.11033  7.508579    1.127305e-02 5.585282e-02  30
# 22    -0.8777252   13.72354  7.530051    1.117492e-02 5.585282e-02  46
# 23     0.8256054   13.79242  7.021940    1.318671e-02 6.249352e-02  37
# 24    -1.3819143   13.11609  6.774029    1.616704e-02 7.342532e-02  86
# 25     3.1996290   14.04834  6.998665    1.758399e-02 7.371749e-02  29
# 26    -1.3426058   13.23212  6.601669    1.740641e-02 7.371749e-02  34
# 27     0.8900620   13.81043  6.074025    2.023637e-02 8.169496e-02  14
# 28     0.8816966   13.20632  5.129843    3.159185e-02 1.229826e-01  69
# 29     0.8997070   13.55000  5.056570    3.273168e-02 1.230260e-01  83
# 30    -0.8666881   13.44298  4.794675    3.828608e-02 1.391061e-01  43
# ⋮     ⋮            ⋮        ⋮            ⋮            ⋮            ⋮
# 10095  0.347630609 13.70965 3.418542e-01 0.5609227    0.8746825    69
# 10096 -0.240316650 13.94046 2.150950e-01 0.6439205    0.8945718    35
# 10097  0.226934076 14.09430 2.109397e-01 0.6471370    0.8945718    59
# 10098 -0.236902531 13.81741 2.312203e-01 0.6317850    0.8945718    75
# 10099 -0.228313973 13.58487 1.676417e-01 0.6831871    0.9307186    42
# 10100  0.206335907 13.87111 1.488421e-01 0.7005530    0.9407426    91
# 10101  0.148257950 14.38043 1.163537e-01 0.7338168    0.9715321    78
# 10102  0.153529033 13.83856 9.374836e-02 0.7601706    0.9924450    58
# 10103  0.164002876 13.87254 3.018516e-02 0.8645096    0.9926634     2
# 10104  0.057633834 14.14568 1.545269e-02 0.9013474    0.9926634     3
# 10105 -0.025930473 14.51079 3.206760e-03 0.9549666    0.9926634     7
# 10106 -0.099770324 14.31915 5.685718e-02 0.8120751    0.9926634     8
# 10107 -0.014681149 14.24835 1.185718e-03 0.9726070    0.9926634    10
# 10108 -0.028273172 13.92407 3.459259e-03 0.9532292    0.9926634    20
# 10109 -0.009970022 14.20551 6.780471e-04 0.9792835    0.9926634    21
# 10110  0.064170614 14.13304 1.864207e-02 0.8917019    0.9926634    22
# 10111 -0.053131107 13.98094 1.076027e-02 0.9176126    0.9926634    30
# 10112  0.008432458 14.17843 2.919011e-04 0.9864065    0.9926634    32
# 10113  0.076902794 14.18913 2.701990e-02 0.8698020    0.9926634    33
# 10114 -0.007141054 14.41945 3.251832e-04 0.9856525    0.9926634    37
# 10115 -0.153320859 13.57925 6.354579e-02 0.8015506    0.9926634    40
# 10116 -0.102246008 14.04850 4.087959e-02 0.8402259    0.9926634    44
# 10117 -0.075962229 14.14274 2.731797e-02 0.8690924    0.9926634    47
# 10118 -0.101444109 13.98985 4.241488e-02 0.8372952    0.9926634    51
# 10119 -0.051528085 14.15564 1.214615e-02 0.9124881    0.9926634    57
# 10120  0.101065607 13.69804 3.178490e-02 0.8589005    0.9926634    68
# 10121  0.010402429 13.77939 5.502287e-04 0.9813376    0.9926634    70
# 10122  0.109117467 14.03820 5.247838e-02 0.8193242    0.9926634    82
# 10123  0.055723068 13.77280 1.208751e-02 0.9126987    0.9926634    93
# 10124 -0.005270053 13.94742 8.502264e-05 0.9926634    0.9926634    94
#       SpatialFDR   polarity labels    labels_fraction
# 1     3.222835e-05 pos      Agrp      1
# 2     9.322746e-05 pos      Agrp      1
# 3     3.701515e-04 pos      Agrp      1
# 4     4.971582e-04 pos      Agrp      1
# 5     1.011507e-03 neg      Agrp      1
# 6     1.094498e-03 pos      Agrp      1
# 7     1.774442e-03 pos      Agrp      1
# 8     2.550295e-03 pos      Agrp      1
# 9     3.368091e-03 neg      Agrp      1
# 10    4.827136e-03 pos      Agrp      1
# 11    5.413370e-03 neg      Agrp      1
# 12    6.879897e-03 neg      Agrp      1
# 13    1.135421e-02 neg      Agrp      1
# 14    1.135421e-02 pos      Agrp      1
# 15    1.135421e-02 pos      Agrp      1
# 16    1.135421e-02 pos      Agrp      1
# 17    1.271475e-02 pos      Agrp      1
# 18    2.595730e-02 pos      Agrp      1
# 19    3.138746e-02 neg      Agrp      1
# 20    5.005285e-02 neg      Agrp      1
# 21    5.687914e-02 pos      Agrp      1
# 22    5.687914e-02 neg      Agrp      1
# 23    6.328146e-02 pos      Agrp      1
# 24    7.394311e-02 neg      Agrp      1
# 25    7.410433e-02 pos      Agrp      1
# 26    7.410433e-02 neg      Agrp      1
# 27    8.207010e-02 pos      Agrp      1
# 28    1.236699e-01 none     Agrp      1
# 29    1.248063e-01 none     Agrp      1
# 30    1.404943e-01 none     Agrp      1
# ⋮     ⋮            ⋮        ⋮         ⋮
# 10095 0.8659200    none     Trh__Lef1 1
# 10096 0.8889482    none     Trh__Lef1 1
# 10097 0.8889482    none     Trh__Lef1 1
# 10098 0.8889482    none     Trh__Lef1 1
# 10099 0.9268446    none     Trh__Lef1 1
# 10100 0.9377553    none     Trh__Lef1 1
# 10101 0.9676269    none     Trh__Lef1 1
# 10102 0.9885047    none     Trh__Lef1 1
# 10103 0.9926634    none     Trh__Lef1 1
# 10104 0.9926634    none     Trh__Lef1 1
# 10105 0.9926634    none     Trh__Lef1 1
# 10106 0.9926634    none     Trh__Lef1 1
# 10107 0.9926634    none     Trh__Lef1 1
# 10108 0.9926634    none     Trh__Lef1 1
# 10109 0.9926634    none     Trh__Lef1 1
# 10110 0.9926634    none     Trh__Lef1 1
# 10111 0.9926634    none     Trh__Lef1 1
# 10112 0.9926634    none     Trh__Lef1 1
# 10113 0.9926634    none     Trh__Lef1 1
# 10114 0.9926634    none     Trh__Lef1 1
# 10115 0.9926634    none     Trh__Lef1 1
# 10116 0.9926634    none     Trh__Lef1 1
# 10117 0.9926634    none     Trh__Lef1 1
# 10118 0.9926634    none     Trh__Lef1 1
# 10119 0.9926634    none     Trh__Lef1 1
# 10120 0.9926634    none     Trh__Lef1 1
# 10121 0.9926634    none     Trh__Lef1 1
# 10122 0.9926634    none     Trh__Lef1 1
# 10123 0.9926634    none     Trh__Lef1 1
# 10124 0.9926634    none     Trh__Lef1 1
#       comparison                      restored exact_grouping restored_grouping
# 1     Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 2     Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 3     Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 4     Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 5     Day5.obob5v5__v__Day5.obobBL6d5  TRUE    neg_restored   neg_restored
# 6     Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 7     Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 8     Day5.obob5v5__v__Day5.obobBL6d5 FALSE    pos_FGF1       pos_FGF1
# 9     Day5.obob5v5__v__Day5.obobBL6d5  TRUE    neg_restored   neg_restored
# 10    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 11    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    neg_restored   neg_restored
# 12    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    neg_restored   neg_restored
# 13    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    neg_restored   neg_restored
# 14    Day5.obob5v5__v__Day5.obobBL6d5 FALSE    pos_FGF1       pos_FGF1
# 15    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 16    Day5.obob5v5__v__Day5.obobBL6d5 FALSE    pos_FGF1       pos_FGF1
# 17    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 18    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 19    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    neg_restored   neg_restored
# 20    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    neg_restored   neg_restored
# 21    Day5.obob5v5__v__Day5.obobBL6d5 FALSE    pos_FGF1       pos_FGF1
# 22    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    neg_restored   neg_restored
# 23    Day5.obob5v5__v__Day5.obobBL6d5 FALSE    pos_away       pos_away
# 24    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    neg_restored   neg_restored
# 25    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    pos_restored   pos_restored
# 26    Day5.obob5v5__v__Day5.obobBL6d5  TRUE    neg_restored   neg_restored
# 27    Day5.obob5v5__v__Day5.obobBL6d5 FALSE    pos_FGF1       pos_FGF1
# 28    Day5.obob5v5__v__Day5.obobBL6d5 FALSE    pos_BL6        none
# 29    Day5.obob5v5__v__Day5.obobBL6d5 FALSE    neg_BL6        none
# 30    Day5.obob5v5__v__Day5.obobBL6d5 FALSE    pos_BL6        none
# ⋮     ⋮                               ⋮        ⋮              ⋮
# 10095 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10096 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10097 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10098 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10099 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10100 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10101 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10102 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10103 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10104 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10105 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10106 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10107 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10108 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10109 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10110 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10111 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10112 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10113 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10114 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10115 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10116 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10117 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10118 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10119 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10120 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10121 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10122 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10123 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
# 10124 Day5.obob5v5__v__Day5.obobBL6d5 FALSE    none           none
#       fgf1_grouping bl6_grouping hash.mcl.ID                n_cells
# 1     pos           neg          SI-TT-F11_CACTTCGGTAAGTAGT 146
# 2     pos           neg          SI-TT-H10_TGTTGGAGTAGCTTTG 104
# 3     pos           neg          SI-TT-H10_ACATCGACAAGACTGG  83
# 4     pos           neg          SI-TT-C11_GTTACAGGTTACCTTT 122
# 5     neg           pos          SI-TT-H10_CTCTCAGTCCGGCTTT 130
# 6     pos           neg          SI-TT-H10_TGTCCCAGTTACAGCT 198
# 7     pos           neg          SI-TT-A11_TTCTAGTGTGGAAATT 137
# 8     pos           none         SI-TT-F11_CACGGGTAGCAAGGAA 133
# 9     neg           pos          SI-TT-C11_AGACCCGCAAATGGAT  75
# 10    pos           neg          SI-TT-G10_GTTAGTGGTTAGAGAT 144
# 11    neg           pos          SI-TT-C12_TTCATTGCAGCAATTC 158
# 12    neg           pos          SI-TT-A11_GTCACGGAGGTCATTC 150
# 13    neg           pos          SI-TT-H10_ACAAAGATCCATATGG 113
# 14    pos           none         SI-TT-C11_TGGAACTTCCGACATA 120
# 15    pos           neg          SI-TT-A11_GTACAACAGTCTCCTC 190
# 16    pos           none         SI-TT-C12_GTTGAACAGTAGTCTC 115
# 17    pos           neg          SI-TT-A11_TCCCATGTCTTCGGTC 113
# 18    pos           neg          SI-TT-F11_ATAGGCTAGAAACCAT 109
# 19    neg           pos          SI-TT-C11_ACTATGGAGCAACAGC 139
# 20    neg           pos          SI-TT-A11_TCATGGATCATACGAC 181
# 21    pos           none         SI-TT-E11_TCAGTTTTCGCCGTGA 107
# 22    neg           pos          SI-TT-F11_TCACAAGCACCGTCTT 206
# 23    pos           pos          SI-TT-G10_TTTGTTGGTATACCTG 203
# 24    neg           pos          SI-TT-C12_GTGATGTCACAAATCC 118
# 25    pos           neg          SI-TT-H10_CACACAATCCTGGGTG 124
# 26    neg           pos          SI-TT-A11_TTGGTTTCACTCCGGA 128
# 27    pos           none         SI-TT-G10_CTCATTATCTCATTTG 193
# 28    none          pos          SI-TT-F11_AACCTTTTCGCTACAA 132
# 29    none          neg          SI-TT-F11_TCCTCTTAGTAAATGC 124
# 30    none          pos          SI-TT-H10_TCAGTCCCAGGCTCTG 164
# ⋮     ⋮             ⋮            ⋮                          ⋮
# 10095 none          none         SI-TT-D11_CGTGTCTTCTCATTAC  67
# 10096 none          none         SI-TT-F10_TGGATGTTCCACACAA  81
# 10097 none          none         SI-TT-F11_CGGGTGTAGTTGGACG 102
# 10098 none          none         SI-TT-C11_GTAGTACAGCTTGTGT  78
# 10099 none          none         SI-TT-D11_TAATTCCTCATATGGC  59
# 10100 none          none         SI-TT-D11_CTCGAGGTCAGAGTGG  78
# 10101 none          none         SI-TT-C12_GTATTGGCATTCAGGT 132
# 10102 none          none         SI-TT-C11_GACCAATCACATAGCT  80
# 10103 none          none         SI-TT-C12_CTCAGGGGTTGGACCC  88
# 10104 none          none         SI-TT-B12_CCTCCAATCTGTTCAT 112
# 10105 none          none         SI-TT-C11_GTCACTCAGCATATGA 152
# 10106 none          none         SI-TT-A11_TTTAGTCCAACTCATG 129
# 10107 none          none         SI-TT-E12_GCCCAGAGTATGAGAT 117
# 10108 none          none         SI-TT-G11_TCGCTTGTCAAATGCC  85
# 10109 none          none         SI-TT-G11_CTGCAGGGTTAAGAAC 120
# 10110 none          none         SI-TT-E11_GATGACTGTTGCAAGG 106
# 10111 none          none         SI-TT-E12_CCCGAAGAGGCAGGGA  87
# 10112 none          none         SI-TT-C11_TTGTTGTCAGCATGCC 112
# 10113 none          none         SI-TT-D11_CTCAGTCTCTCCTGAC 109
# 10114 none          none         SI-TT-C11_GATTCTTAGCCTCTCT 139
# 10115 none          none         SI-TT-G11_CATGCAAGTATACCTG  56
# 10116 none          none         SI-TT-G10_CATCCGTCATTCTTCA  95
# 10117 none          none         SI-TT-G11_AGTACTGAGTCCCGGT 104
# 10118 none          none         SI-TT-G11_TCAGTGATCTGCGTCT  91
# 10119 none          none         SI-TT-E11_CTCTCGAGTAGCTGCC 103
# 10120 none          none         SI-TT-C11_CCGTTCATCGGCTTGG  69
# 10121 none          none         SI-TT-E11_TTTCAGTAGGCATCAG  76
# 10122 none          none         SI-TT-B12_CTCACTGGTACCAATC  98
# 10123 none          none         SI-TT-F10_GACTATGGTCCTGGGT  76
# 10124 none          none         SI-TT-C11_TTCAATCCAACACGAG  93

# %%
options(repr.plot.width=3.5, repr.plot.height=3.5)
umap_bl6_other = da_results %>%
filter(class == 'other') %>%
mutate(polarity_bl6 = factor(polarity_bl6, levels = c("none", "neg", "pos"))) %>%
arrange(polarity_bl6) %>%
ggplot(aes(x = umap_1, y = umap_2, color=polarity_bl6, alpha=polarity_bl6)) + 
geom_point(size=0.5, shape = 16) + 
scale_color_manual(values = c('none' =  "#a1a1a1",
                              'neg' = "#1b7837",
                              'pos' = "#762a83")) +
scale_alpha_manual(values = c("none" = 0.25, "neg" = 0.5, "pos"=0.5)) +
theme_minimal() + theme(legend.position=c(0.9,0.125)) + theme(
  axis.ticks = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank()
) + theme(
  axis.text = element_blank(),
  axis.title.x = element_blank(),
  axis.text.x = element_blank(),
  axis.text.y = element_blank(),
  axis.title.y = element_blank()
) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))

umap_bl6_other
# Out:
# plot without title

# %%
options(repr.plot.width=3.5, repr.plot.height=3.5)
label_data <- da_results %>%
  filter(class == 'other') %>%
  mutate(labels = str_replace(labels, fixed('__'), '\n')) %>%
  group_by(labels) %>%
  summarise(umap_1 = mean(umap_1, na.rm = TRUE),
            umap_2 = mean(umap_2, na.rm =TRUE),
            label = first(labels))

umap_fgf1_other = da_results %>%
filter(class == 'other') %>%
mutate(polarity_fgf1 = factor(polarity_fgf1, levels = c("none", "neg", "pos"))) %>%
arrange(polarity_fgf1) %>%
ggplot(aes(x = umap_1, y = umap_2, color=polarity_fgf1, alpha=polarity_fgf1)) + 
geom_point(size=0.5, shape = 16) + 
scale_color_manual(values = c('none' =  "#a1a1a1",
                              'neg' = "#d73027",
                              'pos' = "#4575b4")) +
scale_alpha_manual(values = c("none" = 0.25, "neg" = 0.5, "pos"=0.5)) +
geom_text_repel(data = label_data, aes(x = umap_1, y = umap_2, label = label), 
              size = 2, 
              box.padding = unit(1, "lines"), 
              point.padding = unit(2, "lines"),
              segment.color = 'grey50',
              inherit.aes = FALSE) +
theme_minimal() + theme(legend.position=c(0.9,0.125)) + theme(
  axis.ticks = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank()
) + theme(
  axis.text = element_blank(),
  axis.title.x = element_blank(),
  axis.text.x = element_blank(),
  axis.text.y = element_blank(),
  axis.title.y = element_blank()
) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))


umap_fgf1_other
# Out:
# plot without title

# %%
options(repr.plot.width=3.5, repr.plot.height=3.5)
umap_restored_other = da_results %>%
filter(class == 'other') %>%
mutate(polarity = case_when(exact_grouping == 'pos_restored' ~ "pos",
                             exact_grouping == 'neg_restored' ~ "neg",
                             TRUE ~ 'other')) %>%
mutate(polarity = factor(polarity, levels = c("other", "neg", "pos"))) %>%
arrange(polarity) %>%
ggplot(aes(x = umap_1, y = umap_2, color=polarity, alpha=polarity)) + 
geom_point(size=0.5, shape = 16) + 
scale_color_manual(values = c('other' =  "#a1a1a1",
                              'neg' = "#a50026",
                              'pos' = "#313695")) +
scale_alpha_manual(values = c("other" = 0.25, "neg" = 0.5, "pos"=0.5)) +
theme_minimal() + theme(legend.position=c(0.9,0.125)) + theme(
  axis.ticks = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank()
) + theme(
  axis.text = element_blank(),
  axis.title.x = element_blank(),
  axis.text.x = element_blank(),
  axis.text.y = element_blank(),
  axis.title.y = element_blank()
) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))

umap_restored_other
# Out:
# plot without title

# %%
all_restored_summary = qs::qread('_targets/objects/all_restored_summary') %>%
filter(comparison == 'Day5.obob5v5__v__Day5.obobBL6d5') %>%
mutate(prop_fgf1 = n_fgf1/n_total) %>%
mutate(prop_BL6 = n_BL6/n_total) %>%
mutate(prop_sum = prop_fgf1 + prop_BL6) %>%
mutate(n_sum = n_fgf1 + n_BL6) %>%
arrange(desc(n_fgf1))

all_restored_summary %>% head

label_order = all_restored_summary %>% pull(labels)
label_order
# Out:
#   labels     n_total n_fgf1 n_fgf1.pos n_fgf1.neg prop_fgf1.pos n_BL6
# 1 other      819     314    151        163        0.4808917      0
# 2 g2         250      98     44         54        0.4489796     71
# 3 Astrocytes 260      95     43         52        0.4526316     74
# 4 OPC         77      60     34         26        0.5666667      0
# 5 g1         279      60     35         25        0.5833333      0
# 6 Htr3b       94      57     27         30        0.4736842     15
#   n_restored n_restored.pos n_restored.neg prop_restored_BL6 prop_restored_FGF1
# 1  0         0               0                    NaN        0.00000000
# 2 16         1              15             0.22535211        0.16326531
# 3 14         3              11             0.18918919        0.14736842
# 4  0         0               0                    NaN        0.00000000
# 5  0         0               0                    NaN        0.00000000
# 6  1         1               0             0.06666667        0.01754386
#   comparison                      prop_fgf1 prop_BL6  prop_sum  n_sum
# 1 Day5.obob5v5__v__Day5.obobBL6d5 0.3833944 0.0000000 0.3833944 314
# 2 Day5.obob5v5__v__Day5.obobBL6d5 0.3920000 0.2840000 0.6760000 169
# 3 Day5.obob5v5__v__Day5.obobBL6d5 0.3653846 0.2846154 0.6500000 169
# 4 Day5.obob5v5__v__Day5.obobBL6d5 0.7792208 0.0000000 0.7792208  60
# 5 Day5.obob5v5__v__Day5.obobBL6d5 0.2150538 0.0000000 0.2150538  60
# 6 Day5.obob5v5__v__Day5.obobBL6d5 0.6063830 0.1595745 0.7659574  72
#  [1] "other"               "g2"                  "Astrocytes"
#  [4] "OPC"                 "g1"                  "Htr3b"
#  [7] "n1"                  "Tanycytes"           "Trh__Lef1"
# [10] "g3"                  "Agrp"                "Oligodendrocytes"
# [13] "n10"                 "Slc17a6__Trhr"       "Ghrh"
# [16] "Ependymal_cells"     "Pou6f2__Prkcq__Whrn" "Ppp1r17__Tafa4"
# [19] "Sst__Pthlh"          "Tbx19__Pirt"         "Kiss1__Tac2"
# [22] "Pomc__Glipr1"        "n7"                  "Npsr1__Epha3"
# [25] "Irx5__Lmx1a"         "Tmem215__Greb1"      "n2"
# [28] "Arx__Nr5a2"          "Dlk1"                "Esr1"
# [31] "Fez1"                "Gpr50__Tac2"         "Hdc"
# [34] "Lepr15"              "Lepr67"              "Lepr89"
# [37] "Lpar1_oligo"         "Met__Pappa2"         "Met__Prlh"
# [40] "Microglia"           "Nfib_1"              "Nfib_2"
# [43] "Nfib_3"              "Nfix__Nfib"          "Nfix__Nfib__Hgf"
# [46] "Nfix__Nfib__Lhx6"    "Pomc__Anxa2"         "Pomc__Ttr"
# [49] "Ppp1r17"             "Ppp1r17__Ltbp1"      "Reln__Lef1"
# [52] "Sim1"                "Sst__Nts"            "Sst__Unc13c"
# [55] "Th__Nfib"            "Th__Slc6a3"          "Tmem215__Dach2"
# [58] "Trh__Cxcl12"         "g4"                  "n0"
# [61] "n3"                  "n4"                  "n5"
# [64] "n6"                  "n8"                  "n9"
# [67] "n_drop"              "neuron"

# %%
all_restored_summary %>% filter(prop_sum > 0) %>%
left_join(labels_classes_tib, by='labels') %>%
group_by(class) %>% summarise(n=n())
# Out:
#   class  n
# 1 neuron 23
# 2 other   5
# 3 NA     13

# %%
all_restored_summary %>%
left_join(labels_classes_tib, by='labels') %>%
filter(class=='neuron') %>%
arrange(desc(n_sum)) %>%
head(20)
# Out:
#    labels              n_total n_fgf1 n_fgf1.pos n_fgf1.neg prop_fgf1.pos n_BL6
# 1  Agrp                109     27     17         10         0.6296296     90
# 2  Htr3b                94     57     27         30         0.4736842     15
# 3  Trh__Cxcl12         102      0     NA         NA                NA     52
# 4  Kiss1__Tac2          71      5      2          3         0.4000000     35
# 5  Ghrh                 48      9      6          3         0.6666667     29
# 6  Trh__Lef1            94     34     23         11         0.6764706      1
# 7  Pomc__Glipr1         71      5      1          4         0.2000000     25
# 8  Tmem215__Greb1       61      2      1          1         0.5000000     19
# 9  Tbx19__Pirt          63      6      5          1         0.8333333     10
# 10 Pou6f2__Prkcq__Whrn  64      7      4          3         0.5714286      8
# 11 Sst__Unc13c          66      0     NA         NA                NA     14
# 12 Slc17a6__Trhr       108     11      8          3         0.7272727      0
# 13 Irx5__Lmx1a         133      3      3         NA         1.0000000      4
# 14 Pomc__Anxa2          16      0     NA         NA                NA      7
# 15 Ppp1r17__Tafa4      111      6      2          4         0.3333333      0
# 16 Sst__Pthlh           40      6      5          1         0.8333333      0
# 17 Th__Slc6a3           26      0     NA         NA                NA      6
# 18 Pomc__Ttr            35      0     NA         NA                NA      5
# 19 Npsr1__Epha3         52      4      2          2         0.5000000      0
# 20 Lpar1_oligo          24      0     NA         NA                NA      4
#    n_restored n_restored.pos n_restored.neg prop_restored_BL6
# 1  21         11             10             0.23333333
# 2   1          1              0             0.06666667
# 3   0          0              0             0.00000000
# 4   5          2              3             0.14285714
# 5   8          5              3             0.27586207
# 6   0          0              0             0.00000000
# 7   4          1              3             0.16000000
# 8   0          0              0             0.00000000
# 9   3          2              1             0.30000000
# 10  6          4              2             0.75000000
# 11  0          0              0             0.00000000
# 12  0          0              0                    NaN
# 13  3          3              0             0.75000000
# 14  0          0              0             0.00000000
# 15  0          0              0                    NaN
# 16  0          0              0                    NaN
# 17  0          0              0             0.00000000
# 18  0          0              0             0.00000000
# 19  0          0              0                    NaN
# 20  0          0              0             0.00000000
#    prop_restored_FGF1 comparison                      prop_fgf1  prop_BL6
# 1  0.77777778         Day5.obob5v5__v__Day5.obobBL6d5 0.24770642 0.82568807
# 2  0.01754386         Day5.obob5v5__v__Day5.obobBL6d5 0.60638298 0.15957447
# 3         NaN         Day5.obob5v5__v__Day5.obobBL6d5 0.00000000 0.50980392
# 4  1.00000000         Day5.obob5v5__v__Day5.obobBL6d5 0.07042254 0.49295775
# 5  0.88888889         Day5.obob5v5__v__Day5.obobBL6d5 0.18750000 0.60416667
# 6  0.00000000         Day5.obob5v5__v__Day5.obobBL6d5 0.36170213 0.01063830
# 7  0.80000000         Day5.obob5v5__v__Day5.obobBL6d5 0.07042254 0.35211268
# 8  0.00000000         Day5.obob5v5__v__Day5.obobBL6d5 0.03278689 0.31147541
# 9  0.50000000         Day5.obob5v5__v__Day5.obobBL6d5 0.09523810 0.15873016
# 10 0.85714286         Day5.obob5v5__v__Day5.obobBL6d5 0.10937500 0.12500000
# 11        NaN         Day5.obob5v5__v__Day5.obobBL6d5 0.00000000 0.21212121
# 12 0.00000000         Day5.obob5v5__v__Day5.obobBL6d5 0.10185185 0.00000000
# 13 1.00000000         Day5.obob5v5__v__Day5.obobBL6d5 0.02255639 0.03007519
# 14        NaN         Day5.obob5v5__v__Day5.obobBL6d5 0.00000000 0.43750000
# 15 0.00000000         Day5.obob5v5__v__Day5.obobBL6d5 0.05405405 0.00000000
# 16 0.00000000         Day5.obob5v5__v__Day5.obobBL6d5 0.15000000 0.00000000
# 17        NaN         Day5.obob5v5__v__Day5.obobBL6d5 0.00000000 0.23076923
# 18        NaN         Day5.obob5v5__v__Day5.obobBL6d5 0.00000000 0.14285714
# 19 0.00000000         Day5.obob5v5__v__Day5.obobBL6d5 0.07692308 0.00000000
# 20        NaN         Day5.obob5v5__v__Day5.obobBL6d5 0.00000000 0.16666667
#    prop_sum   n_sum class
# 1  1.07339450 117   neuron
# 2  0.76595745  72   neuron
# 3  0.50980392  52   neuron
# 4  0.56338028  40   neuron
# 5  0.79166667  38   neuron
# 6  0.37234043  35   neuron
# 7  0.42253521  30   neuron
# 8  0.34426230  21   neuron
# 9  0.25396825  16   neuron
# 10 0.23437500  15   neuron
# 11 0.21212121  14   neuron
# 12 0.10185185  11   neuron
# 13 0.05263158   7   neuron
# 14 0.43750000   7   neuron
# 15 0.05405405   6   neuron
# 16 0.15000000   6   neuron
# 17 0.23076923   6   neuron
# 18 0.14285714   5   neuron
# 19 0.07692308   4   neuron
# 20 0.16666667   4   neuron

# %%
unchanged_labels = all_restored_summary %>%
filter(!(prop_sum > 0)) %>%
pull(labels)
unchanged_labels
# Out:
#  [1] "Arx__Nr5a2"       "Dlk1"             "Esr1"             "Fez1"
#  [5] "Gpr50__Tac2"      "Hdc"              "Lepr15"           "Lepr67"
#  [9] "Lepr89"           "Met__Pappa2"      "Met__Prlh"        "Microglia"
# [13] "Nfib_1"           "Nfib_2"           "Nfib_3"           "Nfix__Nfib__Lhx6"
# [17] "Ppp1r17__Ltbp1"   "Reln__Lef1"       "Sim1"             "Sst__Nts"
# [21] "Th__Nfib"         "Tmem215__Dach2"   "g4"               "n4"
# [25] "n6"               "n8"               "n_drop"

# %%
all_restored_summary %>%
filter(str_detect(labels, 'Ghrh'))
# Out:
#   labels n_total n_fgf1 n_fgf1.pos n_fgf1.neg prop_fgf1.pos n_BL6 n_restored
# 1 Ghrh   48      9      6          3          0.6666667     29    8
#   n_restored.pos n_restored.neg prop_restored_BL6 prop_restored_FGF1
# 1 5              3              0.2758621         0.8888889
#   comparison                      prop_fgf1 prop_BL6  prop_sum  n_sum
# 1 Day5.obob5v5__v__Day5.obobBL6d5 0.1875    0.6041667 0.7916667 38

# %%
beeswarm_tibble = da_results %>%
select(Nhood, labels, class, n_cells, polarity_fgf1, SpatialFDR_fgf1, logFC_fgf1, polarity_bl6, SpatialFDR_bl6, logFC_bl6, exact_grouping) %>%
mutate(restored = case_when(exact_grouping == 'pos_restored' ~ 'yes',
                             exact_grouping == 'neg_restored' ~ 'yes',
                             TRUE ~ 'no')) %>%
mutate(restored = factor(restored, levels=c('no', 'yes')))

# Separate data frames for each type of measurement
polarity_df <- beeswarm_tibble %>%
  select(Nhood, labels, class, n_cells, starts_with("polarity"), exact_grouping, restored) %>%
  pivot_longer(cols = starts_with("polarity"),
               names_to = "comparison",
               values_to = "polarity") %>%
  mutate(comparison = ifelse(str_detect(comparison, "bl6"), "BL6", "FGF1"))

spatial_df <- beeswarm_tibble %>%
  select(Nhood, labels, class, n_cells, starts_with("SpatialFDR"), exact_grouping, restored) %>%
  pivot_longer(cols = starts_with("SpatialFDR"),
               names_to = "comparison",
               values_to = "SpatialFDR") %>%
  mutate(comparison = ifelse(str_detect(comparison, "bl6"), "BL6", "FGF1"))

logfc_df <- beeswarm_tibble %>%
  select(Nhood, labels, class, n_cells, starts_with("logFC"), exact_grouping, restored) %>%
  pivot_longer(cols = starts_with("logFC"),
               names_to = "comparison",
               values_to = "logFC") %>%
  mutate(comparison = ifelse(str_detect(comparison, "bl6"), "BL6", "FGF1"))

# Join all dataframes
beeswarm_tibble <- polarity_df %>%
  inner_join(spatial_df, by = c("Nhood", "labels", "class", "n_cells", "comparison", "exact_grouping", "restored")) %>%
  inner_join(logfc_df, by = c("Nhood", "labels", "class", "n_cells", "comparison", "exact_grouping", "restored"))


beeswarm_tibble = beeswarm_tibble %>%
mutate(labels = factor(labels, levels=rev(label_order))) %>%
rowwise %>%
mutate(label.group = paste0(labels, '.', comparison)) %>% 
ungroup %>%
mutate(polarity = paste0(polarity, '.', comparison)) %>%
mutate(polarity = case_when(str_detect(polarity, 'none') ~ 'none',
                            TRUE ~ polarity)) %>%
mutate(polarity = factor(polarity, levels=rev(c('none', 'neg.BL6', 'pos.BL6', 'neg.FGF1', 'pos.FGF1')))) %>%
arrange(desc(labels))

beeswarm_tibble
# Out:
#       Nhood labels class n_cells exact_grouping restored comparison polarity
# 1     221   other  NA    76      pos_FGF1       no       FGF1       pos.FGF1
# 2     221   other  NA    76      pos_FGF1       no       BL6        none
# 3      82   other  NA    81      pos_FGF1       no       FGF1       pos.FGF1
# 4      82   other  NA    81      pos_FGF1       no       BL6        none
# 5     155   other  NA    66      pos_FGF1       no       FGF1       pos.FGF1
# 6     155   other  NA    66      pos_FGF1       no       BL6        none
# 7     161   other  NA    85      pos_FGF1       no       FGF1       pos.FGF1
# 8     161   other  NA    85      pos_FGF1       no       BL6        none
# 9     660   other  NA    70      pos_FGF1       no       FGF1       pos.FGF1
# 10    660   other  NA    70      pos_FGF1       no       BL6        none
# 11    762   other  NA    87      pos_FGF1       no       FGF1       pos.FGF1
# 12    762   other  NA    87      pos_FGF1       no       BL6        none
# 13    311   other  NA    73      pos_FGF1       no       FGF1       pos.FGF1
# 14    311   other  NA    73      pos_FGF1       no       BL6        none
# 15    766   other  NA    67      pos_FGF1       no       FGF1       pos.FGF1
# 16    766   other  NA    67      pos_FGF1       no       BL6        none
# 17    605   other  NA    74      pos_FGF1       no       FGF1       pos.FGF1
# 18    605   other  NA    74      pos_FGF1       no       BL6        none
# 19    682   other  NA    74      pos_FGF1       no       FGF1       pos.FGF1
# 20    682   other  NA    74      pos_FGF1       no       BL6        none
# 21    813   other  NA    73      pos_FGF1       no       FGF1       pos.FGF1
# 22    813   other  NA    73      pos_FGF1       no       BL6        none
# 23    195   other  NA    71      pos_FGF1       no       FGF1       pos.FGF1
# 24    195   other  NA    71      pos_FGF1       no       BL6        none
# 25    639   other  NA    84      pos_FGF1       no       FGF1       pos.FGF1
# 26    639   other  NA    84      pos_FGF1       no       BL6        none
# 27    143   other  NA    76      pos_FGF1       no       FGF1       pos.FGF1
# 28    143   other  NA    76      pos_FGF1       no       BL6        none
# 29    585   other  NA    68      pos_FGF1       no       FGF1       pos.FGF1
# 30    585   other  NA    68      pos_FGF1       no       BL6        none
# ⋮     ⋮     ⋮      ⋮     ⋮       ⋮              ⋮        ⋮          ⋮
# 20219 2340  neuron NA     70     none           no       FGF1       none
# 20220 2340  neuron NA     70     none           no       BL6        none
# 20221 2368  neuron NA     89     none           no       FGF1       none
# 20222 2368  neuron NA     89     none           no       BL6        none
# 20223 2384  neuron NA    162     none           no       FGF1       none
# 20224 2384  neuron NA    162     none           no       BL6        none
# 20225 2394  neuron NA     95     none           no       FGF1       none
# 20226 2394  neuron NA     95     none           no       BL6        none
# 20227 2400  neuron NA    115     none           no       FGF1       none
# 20228 2400  neuron NA    115     none           no       BL6        none
# 20229 2422  neuron NA     87     pos_BL6        no       FGF1       none
# 20230 2422  neuron NA     87     pos_BL6        no       BL6        neg.BL6
# 20231 2440  neuron NA    110     none           no       FGF1       none
# 20232 2440  neuron NA    110     none           no       BL6        none
# 20233 2444  neuron NA    154     none           no       FGF1       none
# 20234 2444  neuron NA    154     none           no       BL6        none
# 20235 2473  neuron NA    178     none           no       FGF1       none
# 20236 2473  neuron NA    178     none           no       BL6        none
# 20237 2492  neuron NA    135     none           no       FGF1       none
# 20238 2492  neuron NA    135     none           no       BL6        none
# 20239 2514  neuron NA    101     none           no       FGF1       none
# 20240 2514  neuron NA    101     none           no       BL6        none
# 20241 2532  neuron NA     54     none           no       FGF1       none
# 20242 2532  neuron NA     54     none           no       BL6        none
# 20243 2540  neuron NA    216     none           no       FGF1       none
# 20244 2540  neuron NA    216     none           no       BL6        none
# 20245 1789  neuron NA     90     none           no       FGF1       none
# 20246 1789  neuron NA     90     none           no       BL6        none
# 20247 2302  neuron NA    103     none           no       FGF1       none
# 20248 2302  neuron NA    103     none           no       BL6        none
#       SpatialFDR   logFC         label.group
# 1     4.668847e-07  6.849131301  other.FGF1
# 2     7.335810e-01  1.375233540  other.BL6
# 3     4.904140e-07  4.819241705  other.FGF1
# 4     9.229264e-01  0.506370888  other.BL6
# 5     4.904140e-07  6.654423842  other.FGF1
# 6     7.335810e-01  1.447723144  other.BL6
# 7     4.904140e-07  4.633804731  other.FGF1
# 8     6.626888e-01 -2.397022498  other.BL6
# 9     4.904140e-07  6.726852867  other.FGF1
# 10    9.999859e-01 -0.082334616  other.BL6
# 11    4.904140e-07  4.305012239  other.FGF1
# 12    9.915855e-01 -0.092466679  other.BL6
# 13    7.031072e-07  4.723328248  other.FGF1
# 14    9.978859e-01 -0.003369947  other.BL6
# 15    8.394607e-07  5.015867158  other.FGF1
# 16    9.804993e-01 -0.178511437  other.BL6
# 17    8.904821e-07  4.729742900  other.FGF1
# 18    8.776064e-01  0.794813829  other.BL6
# 19    9.502018e-07  4.705495381  other.FGF1
# 20    8.795729e-01  0.752118666  other.BL6
# 21    1.129468e-06  4.711359773  other.FGF1
# 22    9.118000e-01 -0.663230947  other.BL6
# 23    1.640509e-06  4.647484059  other.FGF1
# 24    9.203063e-01 -0.642080098  other.BL6
# 25    1.640509e-06  3.599439793  other.FGF1
# 26    9.250521e-01 -0.336776298  other.BL6
# 27    4.470139e-06  4.383654985  other.FGF1
# 28    8.820055e-01  0.728732392  other.BL6
# 29    3.069373e-05  4.206853260  other.FGF1
# 30    8.875228e-01  0.731491191  other.BL6
# ⋮     ⋮            ⋮             ⋮
# 20219 0.99664379    0.0148077407 neuron.FGF1
# 20220 0.85839404    0.3235461596 neuron.BL6
# 20221 0.99664379   -0.0364043930 neuron.FGF1
# 20222 0.74257294   -0.7059443488 neuron.BL6
# 20223 0.99664379   -0.0149947181 neuron.FGF1
# 20224 0.48958173   -0.7035170355 neuron.BL6
# 20225 0.99664379   -0.0044677016 neuron.FGF1
# 20226 0.50046097    1.3187954005 neuron.BL6
# 20227 0.99664379   -0.0036470811 neuron.FGF1
# 20228 0.88124013    0.3013656513 neuron.BL6
# 20229 0.99664379   -0.0079238143 neuron.FGF1
# 20230 0.04597155   -3.2114380900 neuron.BL6
# 20231 0.99664379   -0.0088431905 neuron.FGF1
# 20232 0.59853235    0.7685626482 neuron.BL6
# 20233 0.99664379   -0.0253468959 neuron.FGF1
# 20234 0.93420152   -0.1666820539 neuron.BL6
# 20235 0.99664379    0.0144319337 neuron.FGF1
# 20236 0.66735214   -0.4851809656 neuron.BL6
# 20237 0.99664379   -0.0518249932 neuron.FGF1
# 20238 0.93803230   -0.2811194043 neuron.BL6
# 20239 0.99664379    0.0290534324 neuron.FGF1
# 20240 0.22824044    0.9543696486 neuron.BL6
# 20241 0.99664379    0.0128413498 neuron.FGF1
# 20242 0.91724035   -0.2477038926 neuron.BL6
# 20243 0.99664379   -0.0115765509 neuron.FGF1
# 20244 0.41605128   -1.0033569819 neuron.BL6
# 20245 0.99909989    0.0008101398 neuron.FGF1
# 20246 0.78051395    0.3773595273 neuron.BL6
# 20247 0.99909989   -0.0015603241 neuron.FGF1
# 20248 0.84575955   -0.3107002035 neuron.BL6

# %%
beeswarm_tibble %>% head %>% print
# Out:
# # A tibble: 6 × 11
#   Nhood labels class n_cells exact_grouping restored comparison polarity
#   <dbl> <fct>  <chr>   <dbl> <chr>          <fct>    <chr>      <fct>
# 1   221 other  NA         76 pos_FGF1       no       FGF1       pos.FGF1
# 2   221 other  NA         76 pos_FGF1       no       BL6        none
# 3    82 other  NA         81 pos_FGF1       no       FGF1       pos.FGF1
# 4    82 other  NA         81 pos_FGF1       no       BL6        none
# 5   155 other  NA         66 pos_FGF1       no       FGF1       pos.FGF1
# 6   155 other  NA         66 pos_FGF1       no       BL6        none
# # ℹ 3 more variables: SpatialFDR <dbl>, logFC <dbl>, label.group <chr>

# %%
beeswarm_tibble %>% pull(polarity) %>% unique
beeswarm_tibble %>% pull(polarity) %>% levels
# Out:
# [1] pos.FGF1 none     neg.FGF1 neg.BL6  pos.BL6
# Levels: pos.FGF1 neg.FGF1 pos.BL6 neg.BL6 none
# [1] "pos.FGF1" "neg.FGF1" "pos.BL6"  "neg.BL6"  "none"

# %%
beeswarm_tibble %>% filter(restored == 'yes') %>% dim
# Out:
# [1] 302  11

# %%
options(repr.plot.width=3.5, repr.plot.height=10)

# Creating a separate tibble for the labels
label_tibble <- beeswarm_tibble %>%
  filter(class == 'other')  %>%
#   filter(!(labels %in% unchanged_labels)) %>%
  distinct(labels)

beeswarm_other = beeswarm_tibble %>%
  filter(class == 'other') %>%
#   filter(!(labels %in% unchanged_labels)) %>%
  arrange(labels, polarity, restored) %>%
  ggplot(aes(logFC, labels, group=comparison, color=polarity, alpha=polarity, shape=restored)) + 
  geom_quasirandom(size=1, dodge.width = 1, orientation='y') +
  scale_shape_manual(values = c(yes=19, no=1)) +
  scale_color_manual(values = c('none' =  "#a1a1a1",
                                'neg.FGF1' = "#d73027",
                                'pos.FGF1' = "#4575b4",
                                'neg.BL6' = "#00441b",
                                'pos.BL6' = "#40004b")) + 
  scale_alpha_manual(values = c('none' =  0.25,
                                'neg.FGF1' = 0.25,
                                'pos.FGF1' = 0.25,
                                'neg.BL6' = 0.25,
                                'pos.BL6' = 0.25)) +
  geom_text(data = label_tibble, aes(x = 0, y = labels, label = labels), size=3, hjust = 0.5, vjust = 0.5, inherit.aes = FALSE) +
  theme_classic() +
  theme(axis.title.y = element_blank(),
        axis.ticks.y = element_blank(),
        axis.text.y = element_blank())  + 
theme(legend.position=c(0.9,0.08)) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))
beeswarm_other
# Out:
# plot without title

# %%
options(repr.plot.width=7, repr.plot.height=10)
layout <- '
AB
AC
AD
'

ggp = wrap_plots(A = beeswarm_other,
           B = umap_fgf1_other,
           C = umap_bl6_other,
           D = umap_restored_other,
    design = layout) +
plot_layout(guides = 'auto') + plot_annotation(tag_levels = c('A', 'B', 'C', 'D'))

ggp %>% ggsave('beeswarm_umap_other_d5.pdf', plot = ., width = 7, height=9)
ggp
# Out:
# plot without title

# %%
unchanged_labels_bl6 = da_results %>%
group_by(labels) %>%
summarise(polarities = polarity_bl6 %>% unique) %>%
group_by(labels) %>%
summarise(n=n()) %>%
# filter(n == 1) %>%
pull(labels)

unchanged_labels_bl6
# Out:
# Warning message:
# “Returning more (or less) than 1 row per `summarise()` group was deprecated in
# dplyr 1.1.0.
# ℹ Please use `reframe()` instead.
# ℹ When switching from `summarise()` to `reframe()`, remember that `reframe()`
#   always returns an ungrouped data frame and adjust accordingly.”
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
#  [1] "Agrp"                "Arx__Nr5a2"          "Astrocytes"
#  [4] "Dlk1"                "Ependymal_cells"     "Esr1"
#  [7] "Fez1"                "Ghrh"                "Gpr50__Tac2"
# [10] "Hdc"                 "Htr3b"               "Irx5__Lmx1a"
# [13] "Kiss1__Tac2"         "Lepr15"              "Lepr67"
# [16] "Lepr89"              "Lpar1_oligo"         "Met__Pappa2"
# [19] "Met__Prlh"           "Microglia"           "Nfib_1"
# [22] "Nfib_2"              "Nfib_3"              "Nfix__Nfib"
# [25] "Nfix__Nfib__Hgf"     "Nfix__Nfib__Lhx6"    "Npsr1__Epha3"
# [28] "OPC"                 "Oligodendrocytes"    "Pomc__Anxa2"
# [31] "Pomc__Glipr1"        "Pomc__Ttr"           "Pou6f2__Prkcq__Whrn"
# [34] "Ppp1r17"             "Ppp1r17__Ltbp1"      "Ppp1r17__Tafa4"
# [37] "Reln__Lef1"          "Sim1"                "Slc17a6__Trhr"
# [40] "Sst__Nts"            "Sst__Pthlh"          "Sst__Unc13c"
# [43] "Tanycytes"           "Tbx19__Pirt"         "Th__Nfib"
# [46] "Th__Slc6a3"          "Tmem215__Dach2"      "Tmem215__Greb1"
# [49] "Trh__Cxcl12"         "Trh__Lef1"           "g1"
# [52] "g2"                  "g3"                  "g4"
# [55] "n0"                  "n1"                  "n10"
# [58] "n2"                  "n3"                  "n4"
# [61] "n5"                  "n6"                  "n7"
# [64] "n8"                  "n9"                  "n_drop"
# [67] "neuron"              "other"

# %%
options(repr.plot.width=3.5, repr.plot.height=3.5)

unchanged_labels_bl6 = da_results %>%
group_by(labels) %>%
summarise(polarities = polarity_bl6 %>% unique) %>%
group_by(labels) %>%
summarise(n=n()) %>%
filter(n == 1) %>%
pull(labels)
unchanged_labels_bl6 %>% length

label_data <- da_results %>%
  filter(class == 'neuron') %>%
  filter(!(labels %in% unchanged_labels_bl6)) %>%
  mutate(labels = str_replace(labels, fixed('__'), '\n')) %>%
  group_by(labels) %>%
  summarise(umap_1 = mean(umap_1, na.rm = TRUE),
            umap_2 = mean(umap_2, na.rm =TRUE),
            label = first(labels))

umap_bl6_neuron = da_results %>%
filter(class == 'neuron') %>%
mutate(polarity_bl6 = factor(polarity_bl6, levels = c("none", "neg", "pos"))) %>%
arrange(polarity_bl6) %>%
ggplot(aes(x = umap_1, y = umap_2, color=polarity_bl6, alpha=polarity_bl6)) + 
geom_point(size=0.5, shape = 16) + 
scale_color_manual(values = c('none' =  "#a1a1a1",
                              'neg' = "#1b7837",
                              'pos' = "#762a83")) +
scale_alpha_manual(values = c("none" = 1, "neg" = 1, "pos"=1)) +
geom_text_repel(data = label_data, aes(x = umap_1, y = umap_2, label = label), 
              size = 2, 
              box.padding = unit(0, "lines"), 
              point.padding = unit(0, "lines"),
              segment.color = 'grey50',
              inherit.aes = FALSE) +
theme_minimal() + theme(legend.position=c(0.9,0.125)) + theme(
  axis.ticks = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank()
) + theme(
  axis.text = element_blank(),
  axis.title.x = element_blank(),
  axis.text.x = element_blank(),
  axis.text.y = element_blank(),
  axis.title.y = element_blank()
) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))

umap_bl6_neuron
# Out:
# Warning message:
# “Returning more (or less) than 1 row per `summarise()` group was deprecated in
# dplyr 1.1.0.
# ℹ Please use `reframe()` instead.
# ℹ When switching from `summarise()` to `reframe()`, remember that `reframe()`
#   always returns an ungrouped data frame and adjust accordingly.”
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# [1] 36
# plot without title

# %%
options(repr.plot.width=3.5, repr.plot.height=3.5)

unchanged_labels_fgf1 = da_results %>%
group_by(labels) %>%
summarise(polarities = polarity_fgf1 %>% unique) %>%
group_by(labels) %>%
summarise(n=n()) %>%
filter(n == 1) %>%
pull(labels)
unchanged_labels_fgf1 %>% length

label_data <- da_results %>%
  filter(class == 'neuron') %>%
  filter(!(labels %in% unchanged_labels_fgf1)) %>%
  mutate(labels = str_replace(labels, fixed('__'), '\n')) %>%
  group_by(labels) %>%
  summarise(umap_1 = mean(umap_1, na.rm = TRUE),
            umap_2 = mean(umap_2, na.rm =TRUE),
            label = first(labels))

umap_fgf1_neuron = da_results %>%
filter(class == 'neuron') %>%
mutate(polarity_fgf1 = factor(polarity_fgf1, levels = c("none", "neg", "pos"))) %>%
arrange(polarity_fgf1) %>%
ggplot(aes(x = umap_1, y = umap_2, color=polarity_fgf1, alpha=polarity_fgf1)) + 
geom_point(size=0.5, shape = 16) + 
scale_color_manual(values = c('none' =  "#a1a1a1",
                              'neg' = "#d73027",
                              'pos' = "#4575b4")) +
scale_alpha_manual(values = c("none" = 0.25, "neg" = 0.5, "pos"=0.5)) +
geom_text_repel(data = label_data, aes(x = umap_1, y = umap_2, label = label), 
              size = 2, 
              box.padding = unit(0, "lines"), 
              point.padding = unit(0, "lines"),
              segment.color = 'grey50',
              inherit.aes = FALSE) +
theme_minimal() + theme(legend.position=c(0.9,0.125)) + theme(
  axis.ticks = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank()
) + theme(
  axis.text = element_blank(),
  axis.title.x = element_blank(),
  axis.text.x = element_blank(),
  axis.text.y = element_blank(),
  axis.title.y = element_blank()
) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))


umap_fgf1_neuron
# Out:
# Warning message:
# “Returning more (or less) than 1 row per `summarise()` group was deprecated in
# dplyr 1.1.0.
# ℹ Please use `reframe()` instead.
# ℹ When switching from `summarise()` to `reframe()`, remember that `reframe()`
#   always returns an ungrouped data frame and adjust accordingly.”
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# [1] 41
# plot without title

# %%
options(repr.plot.width=3.5, repr.plot.height=3.5)

label_data <- da_results %>%
  filter(class == 'neuron') %>%
  filter(!(labels %in% unchanged_labels_fgf1)) %>%
  filter(!(labels %in% unchanged_labels_bl6)) %>%
  mutate(labels = str_replace(labels, fixed('__'), '\n')) %>%
  group_by(labels) %>%
  summarise(umap_1 = mean(umap_1, na.rm = TRUE),
            umap_2 = mean(umap_2, na.rm =TRUE),
            label = first(labels))

umap_restored_neuron = da_results %>%
filter(class == 'neuron') %>%
mutate(polarity = case_when(exact_grouping == 'pos_restored' ~ "pos",
                             exact_grouping == 'neg_restored' ~ "neg",
                             TRUE ~ 'other')) %>%
mutate(polarity = factor(polarity, levels = c("other", "neg", "pos"))) %>%
arrange(polarity) %>%
ggplot(aes(x = umap_1, y = umap_2, color=polarity, alpha=polarity)) + 
geom_point(size=0.5, shape = 16) + 
scale_color_manual(values = c('other' =  "#a1a1a1",
                              'neg' = "#a50026",
                              'pos' = "#313695")) +
scale_alpha_manual(values = c("other" = 0.25, "neg" = 0.5, "pos"=0.5)) +
geom_text_repel(data = label_data, aes(x = umap_1, y = umap_2, label = label), 
              size = 2, 
              box.padding = unit(0, "lines"), 
              point.padding = unit(0, "lines"),
              segment.color = 'grey50',
              inherit.aes = FALSE) +
theme_minimal() + theme(legend.position=c(0.9,0.125)) + theme(
  axis.ticks = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank()
) + theme(
  axis.text = element_blank(),
  axis.title.x = element_blank(),
  axis.text.x = element_blank(),
  axis.text.y = element_blank(),
  axis.title.y = element_blank()
) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))

umap_restored_neuron
# Out:
# plot without title

# %%
options(repr.plot.width=3.5, repr.plot.height=10)

# Creating a separate tibble for the labels
label_tibble <- da_results %>%
  filter(class == 'neuron') %>%
  filter((polarity_fgf1 %in% c('pos', 'neg')) | (polarity_bl6 %in% c('pos', 'neg'))) %>%
  distinct(labels)

beeswarm_neuron = beeswarm_tibble %>%
  filter(class == 'neuron') %>%
  filter((labels %in% label_tibble$labels)) %>%
  arrange(labels, polarity, restored) %>%
  ggplot(aes(logFC, labels, group=comparison, color=polarity, alpha=polarity, shape=restored)) + 
  geom_quasirandom(size=1, dodge.width = 1, orientation='y') +
  scale_shape_manual(values = c(yes=19, no=1)) +
  scale_color_manual(values = c('none' =  "#a1a1a1",
                                'neg.FGF1' = "#d73027",
                                'pos.FGF1' = "#4575b4",
                                'neg.BL6' = "#00441b",
                                'pos.BL6' = "#40004b")) + 
  scale_alpha_manual(values = c('none' =  0.25,
                                'neg.FGF1' = 0.25,
                                'pos.FGF1' = 0.25,
                                'neg.BL6' = 0.25,
                                'pos.BL6' = 0.25)) +
  geom_text(data = label_tibble, aes(x = 0, y = labels, label = labels), size=3, hjust = 0.5, vjust = 0.5, inherit.aes = FALSE) +
  theme_classic() +
  theme(axis.title.y = element_blank(),
        axis.ticks.y = element_blank(),
        axis.text.y = element_blank())  + 
theme(legend.position=c(0.85,0.3)) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))

beeswarm_neuron
# Out:
# plot without title

# %%
options(repr.plot.width=7, repr.plot.height=9.5)
layout <- '
AB
AC
AD
'

ggp = wrap_plots(A = beeswarm_neuron,
           B = umap_fgf1_neuron,
           C = umap_bl6_neuron,
           D = umap_restored_neuron,
    design = layout) +
plot_layout(guides = 'auto') + plot_annotation(tag_levels = c('A', 'B', 'C', 'D'))

ggp %>% ggsave('beeswarm_umap_neurons_d5.pdf', plot = ., width = 7, height=9)
ggp
# Out:
# plot without title

# %%
beeswarm_tibble %>% qs::qsave('beeswarm_tibble_d5.qs')
da_results %>% qs::qsave('beeswarm_da_results_d5.qs')
