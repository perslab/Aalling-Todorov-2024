# %%
## library(igraph)
library(Seurat)
library(tidyverse)
library(ggplot2)
library(ggrepel)
library(ggbeeswarm)
library(patchwork)
library(writexl)
options(ggrepel.max.overlaps = Inf)
# Out:
# Loading required package: SeuratObject
#
# Loading required package: sp
#
#
# Attaching package: ‘SeuratObject’
#
#
# The following object is masked from ‘package:base’:
#
#     intersect
#
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.2     ✔ purrr   0.3.4
# ✔ tibble  3.2.1     ✔ dplyr   1.1.2
# ✔ tidyr   1.2.1     ✔ stringr 1.4.1
# ✔ readr   2.1.2     ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
cgsf_all = qs::qread('_targets_negbinom/objects/combined_gost_seurat_formatted')
cgsf_all %>% head(1)
# Out:
#   tag
# 1 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_rest
#   data_day cluster fgf1_day fgf1_comparison bl6_day bl6_comparison grouping
# 1 all      Agrp    Day14    obob14v14       Day14   obobBL6d14     bl6_grouping
#   cells_a cells_b ⋯ recall     term_id   source
# 1 neg     rest    ⋯ 0.04761905 WP:WP1983 WP
#   term_name                                        effective_domain_size
# 1 Splicing factor NOVA regulated synaptic proteins 4529
#   source_order parents   evidence_codes intersection
# 1 14           WP:000000 WP,WP          ENSMUSG00000028519,ENSMUSG00000059857
#   gene_ids
# 1 Dab1,Ntng1

# %%
cgsf_all = qs::qread('_targets_negbinom/objects/combined_gost_seurat_formatted')
cgsf_all %>% head(1)
# Out:
#   tag
# 1 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_rest
#   data_day cluster fgf1_day fgf1_comparison bl6_day bl6_comparison grouping
# 1 all      Agrp    Day14    obob14v14       Day14   obobBL6d14     bl6_grouping
#   cells_a cells_b ⋯ recall     term_id   source
# 1 neg     rest    ⋯ 0.04761905 WP:WP1983 WP
#   term_name                                        effective_domain_size
# 1 Splicing factor NOVA regulated synaptic proteins 4529
#   source_order parents   evidence_codes intersection
# 1 14           WP:000000 WP,WP          ENSMUSG00000028519,ENSMUSG00000059857
#   gene_ids
# 1 Dab1,Ntng1

# %%
cgsf_all %>% colnames
# Out:
#  [1] "tag"                   "data_day"              "cluster"
#  [4] "fgf1_day"              "fgf1_comparison"       "bl6_day"
#  [7] "bl6_comparison"        "grouping"              "cells_a"
# [10] "cells_b"               "query"                 "significant"
# [13] "p_value"               "term_size"             "query_size"
# [16] "intersection_size"     "precision"             "recall"
# [19] "term_id"               "source"                "term_name"
# [22] "effective_domain_size" "source_order"          "parents"
# [25] "evidence_codes"        "intersection"          "gene_ids"

# %%
cgsf_all %>% filter(fgf1_day == 'Day14' & bl6_day == 'Day14')
# Out:
#        tag
# 1      Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_rest
# 2      Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 3      Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 4      Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 5      Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 6      Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 7      Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 8      Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 9      Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 10     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 11     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 12     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 13     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 14     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 15     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 16     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 17     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 18     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 19     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 20     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 21     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 22     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 23     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 24     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 25     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 26     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 27     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 28     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 29     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# 30     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_neg
# ⋮      ⋮
# 133076 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133077 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133078 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133079 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133080 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133081 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133082 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133083 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133084 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133085 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133086 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133087 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133088 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133089 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133090 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133091 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133092 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133093 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133094 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133095 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133096 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133097 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133098 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133099 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133100 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133101 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133102 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133103 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133104 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 133105 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
#        data_day cluster     fgf1_day fgf1_comparison bl6_day bl6_comparison
# 1      all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 2      all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 3      all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 4      all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 5      all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 6      all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 7      all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 8      all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 9      all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 10     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 11     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 12     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 13     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 14     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 15     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 16     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 17     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 18     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 19     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 20     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 21     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 22     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 23     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 24     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 25     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 26     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 27     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 28     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 29     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 30     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# ⋮      ⋮        ⋮           ⋮        ⋮               ⋮       ⋮
# 133076 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133077 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133078 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133079 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133080 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133081 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133082 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133083 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133084 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133085 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133086 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133087 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133088 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133089 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133090 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133091 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133092 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133093 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133094 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133095 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133096 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133097 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133098 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133099 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133100 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133101 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133102 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133103 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133104 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 133105 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
#        grouping     cells_a cells_b ⋯ recall      term_id     source
# 1      bl6_grouping neg     rest    ⋯ 0.047619048 WP:WP1983   WP
# 2      bl6_grouping pos     neg     ⋯ 0.011152416 GO:0050808  GO:BP
# 3      bl6_grouping pos     neg     ⋯ 0.006244425 GO:0031175  GO:BP
# 4      bl6_grouping pos     neg     ⋯ 0.007398274 GO:0034330  GO:BP
# 5      bl6_grouping pos     neg     ⋯ 0.005490196 GO:0048666  GO:BP
# 6      bl6_grouping pos     neg     ⋯ 0.010482180 GO:0007409  GO:BP
# 7      bl6_grouping pos     neg     ⋯ 0.014545455 GO:0098742  GO:BP
# 8      bl6_grouping pos     neg     ⋯ 0.181818182 GO:0070593  GO:BP
# 9      bl6_grouping pos     neg     ⋯ 0.003575685 GO:0007399  GO:BP
# 10     bl6_grouping pos     neg     ⋯ 0.002698724 GO:0048731  GO:BP
# 11     bl6_grouping pos     neg     ⋯ 0.016194332 GO:0007411  GO:BP
# 12     bl6_grouping pos     neg     ⋯ 0.016194332 GO:0097485  GO:BP
# 13     bl6_grouping pos     neg     ⋯ 0.009242144 GO:0061564  GO:BP
# 14     bl6_grouping pos     neg     ⋯ 0.010351967 GO:0097060  GO:CC
# 15     bl6_grouping pos     neg     ⋯ 0.017621145 GO:0042734  GO:CC
# 16     bl6_grouping pos     neg     ⋯ 0.003516484 GO:0030054  GO:CC
# 17     bl6_grouping pos     neg     ⋯ 0.004216867 GO:0045202  GO:CC
# 18     bl6_grouping pos     neg     ⋯ 0.006675567 GO:0098793  GO:CC
# 19     bl6_grouping pos     neg     ⋯ 0.006313131 GO:0030424  GO:CC
# 20     bl6_grouping pos     neg     ⋯ 0.048780488 GO:0008328  GO:CC
# 21     bl6_grouping pos     neg     ⋯ 0.021505376 GO:0034705  GO:CC
# 22     bl6_grouping pos     neg     ⋯ 0.047619048 GO:0098878  GO:CC
# 23     bl6_grouping pos     neg     ⋯ 0.001720430 GO:0071944  GO:CC
# 24     bl6_grouping pos     neg     ⋯ 0.090909091 GO:0098632  GO:MF
# 25     bl6_grouping pos     neg     ⋯ 0.068181818 GO:0098631  GO:MF
# 26     bl6_grouping pos     neg     ⋯ 0.025000000 GO:0005267  GO:MF
# 27     bl6_grouping pos     neg     ⋯ 0.018987342 GO:0015079  GO:MF
# 28     bl6_grouping pos     neg     ⋯ 0.047619048 WP:WP1983   WP
# 29     bl6_grouping pos     neg     ⋯ 0.002208047 GO:0048731  GO:BP
# 30     bl6_grouping pos     neg     ⋯ 0.002383790 GO:0007399  GO:BP
# ⋮      ⋮            ⋮       ⋮       ⋱ ⋮           ⋮           ⋮
# 133076 bl6_grouping pos     rest    ⋯ 0.016016427 TF:M01587   TF
# 133077 bl6_grouping pos     rest    ⋯ 0.011284722 TF:M00189   TF
# 133078 bl6_grouping pos     rest    ⋯ 0.015619189 TF:M08867_1 TF
# 133079 bl6_grouping pos     rest    ⋯ 0.013888889 TF:M10412   TF
# 133080 bl6_grouping pos     rest    ⋯ 0.010140585 TF:M00931   TF
# 133081 bl6_grouping pos     rest    ⋯ 0.010763074 TF:M05494   TF
# 133082 bl6_grouping pos     rest    ⋯ 0.012253992 TF:M07380_1 TF
# 133083 bl6_grouping pos     rest    ⋯ 0.010206975 TF:M07380   TF
# 133084 bl6_grouping pos     rest    ⋯ 0.017127800 TF:M01873_1 TF
# 133085 bl6_grouping pos     rest    ⋯ 0.015783084 TF:M01253   TF
# 133086 bl6_grouping pos     rest    ⋯ 0.013287117 TF:M02744   TF
# 133087 bl6_grouping pos     rest    ⋯ 0.016658501 TF:M02837_1 TF
# 133088 bl6_grouping pos     rest    ⋯ 0.010926366 TF:M00649   TF
# 133089 bl6_grouping pos     rest    ⋯ 0.015476190 TF:M05547_1 TF
# 133090 bl6_grouping pos     rest    ⋯ 0.014063873 TF:M00470_1 TF
# 133091 bl6_grouping pos     rest    ⋯ 0.011323920 TF:M02874_1 TF
# 133092 bl6_grouping pos     rest    ⋯ 0.009479994 TF:M08995   TF
# 133093 bl6_grouping pos     rest    ⋯ 0.014464168 TF:M00649_1 TF
# 133094 bl6_grouping pos     rest    ⋯ 0.012439807 TF:M03814   TF
# 133095 bl6_grouping pos     rest    ⋯ 0.021298174 TF:M01837_1 TF
# 133096 bl6_grouping pos     rest    ⋯ 0.010095643 TF:M02089   TF
# 133097 bl6_grouping pos     rest    ⋯ 0.014207297 TF:M01865_1 TF
# 133098 bl6_grouping pos     rest    ⋯ 0.025276461 TF:M07083   TF
# 133099 bl6_grouping pos     rest    ⋯ 0.012007168 TF:M07249   TF
# 133100 bl6_grouping pos     rest    ⋯ 0.016377171 TF:M07329_1 TF
# 133101 bl6_grouping pos     rest    ⋯ 0.015696203 TF:M01175_1 TF
# 133102 bl6_grouping pos     rest    ⋯ 0.011859028 TF:M12438   TF
# 133103 bl6_grouping pos     rest    ⋯ 0.011872146 TF:M00932_1 TF
# 133104 bl6_grouping pos     rest    ⋯ 0.022118743 TF:M00243_1 TF
# 133105 bl6_grouping pos     rest    ⋯ 0.010720887 TF:M10212   TF
#        term_name
# 1      Splicing factor NOVA regulated synaptic proteins
# 2      synapse organization
# 3      neuron projection development
# 4      cell junction organization
# 5      neuron development
# 6      axonogenesis
# 7      cell-cell adhesion via plasma-membrane adhesion molecules
# 8      dendrite self-avoidance
# 9      nervous system development
# 10     system development
# 11     axon guidance
# 12     neuron projection guidance
# 13     axon development
# 14     synaptic membrane
# 15     presynaptic membrane
# 16     cell junction
# 17     synapse
# 18     presynapse
# 19     axon
# 20     ionotropic glutamate receptor complex
# 21     potassium channel complex
# 22     neurotransmitter receptor complex
# 23     cell periphery
# 24     cell-cell adhesion mediator activity
# 25     cell adhesion mediator activity
# 26     potassium channel activity
# 27     potassium ion transmembrane transporter activity
# 28     Splicing factor NOVA regulated synaptic proteins
# 29     system development
# 30     nervous system development
# ⋮      ⋮
# 133076 Factor: FPM315; motif: SRGGGAGGAGGN
# 133077 Factor: AP-2; motif: MKCCCSCNGGCG
# 133078 Factor: AP2; motif: GCCYGSGGSN; match class: 1
# 133079 Factor: ZNF151; motif: GGSGGNGGGGGAGGGGMGG
# 133080 Factor: Sp1; motif: GGGGCGGGGC
# 133081 Factor: Egr-2; motif: GCGTGGGCGG
# 133082 Factor: E2F-4; motif: NTTTCSCGCC; match class: 1
# 133083 Factor: E2F-4; motif: NTTTCSCGCC
# 133084 Factor: Egr-1; motif: GCGGGGGCGG; match class: 1
# 133085 Factor: CNOT3; motif: GGCCGCGSSS
# 133086 Factor: Egr1; motif: NCCGCCCCCGCANN
# 133087 Factor: Zic3; motif: NMCCCCCGGGGGGGN; match class: 1
# 133088 Factor: MAZ; motif: GGGGAGGG
# 133089 Factor: ZAC; motif: KGGGCCR; match class: 1
# 133090 Factor: AP-2gamma; motif: GCCYNNGGS; match class: 1
# 133091 Factor: IRF6; motif: NNNACTCYCGGKNNN; match class: 1
# 133092 Factor: CTCF; motif: NAGGGGGCGCNNKNNNN
# 133093 Factor: MAZ; motif: GGGGAGGG; match class: 1
# 133094 Factor: BTEB2; motif: GNAGGGGGNGGGSSNN
# 133095 Factor: FKLF; motif: BGGGNGGVMD; match class: 1
# 133096 Factor: E2F-3; motif: GGCGGGN
# 133097 Factor: BTEB3; motif: BNRNGGGAGGNGT; match class: 1
# 133098 Factor: E2F-3; motif: YTCCCGCCCNCNSNN
# 133099 Factor: ctcf; motif: CCNCNAGRKGGCRSTN
# 133100 Factor: Osx; motif: CCNCCCCCNNN; match class: 1
# 133101 Factor: CKROX; motif: SCCCTCCCC; match class: 1
# 133102 Factor: Wt1; motif: NNCCTCCCCCACNN
# 133103 Factor: Sp1; motif: NNGGGGCGGGGNN; match class: 1
# 133104 Factor: Egr-1; motif: WTGCGTGGGCGK; match class: 1
# 133105 Factor: E2F-7; motif: GRGGCGGGAANNN
#        effective_domain_size source_order parents
# 1       4529                    14        WP:000000
# 2      26856                 13932        GO:0034330
# 3      26856                  7422        GO:0048666, GO:0120036
# 4      26856                  8964        GO:0016043
# 5      26856                 13576        GO:0030182, GO:0048468
# 6      26856                  2958        GO:0048667, GO:0048812, GO:0061564
# 7      26856                 19760        GO:0098609
# 8      26856                 17000        GO:0008038
# 9      26856                  2951        GO:0048731
# 10     26856                 13640        GO:0007275, GO:0048856
# 11     26856                  2959        GO:0007409, GO:0097485
# 12     26856                 19562        GO:0031175, GO:0048812
# 13     26856                 16344        GO:0031175
# 14     26959                  2905        GO:0045202, GO:0098590
# 15     26959                  1838        GO:0097060, GO:0098793
# 16     26959                   871        GO:0110165
# 17     26959                  2145        GO:0030054
# 18     26959                  3263        GO:0045202, GO:0110165
# 19     26959                   935        GO:0043005
# 20     26959                   509        GO:0034702, GO:0098878
# 21     26959                  1542        GO:0034703
# 22     26959                  3304        GO:0098802
# 23     26959                  2799        GO:0110165
# 24     24945                  9237        GO:0098631
# 25     24945                  9236        GO:0050839
# 26     24945                  1389        GO:0005261, GO:0015079
# 27     24945                  2306        GO:0046873, GO:1901702
# 28      4529                    14        WP:000000
# 29     26856                 13640        GO:0007275, GO:0048856
# 30     26856                  2951        GO:0048731
# ⋮      ⋮                     ⋮            ⋮
# 133076 21787                 1196         TF:M00000
# 133077 21787                  118         TF:M00000
# 133078 21787                  117         TF:M08867
# 133079 21787                 2094         TF:M00000
# 133080 21787                 3236         TF:M00000
# 133081 21787                  840         TF:M00000
# 133082 21787                  761         TF:M07380
# 133083 21787                  760         TF:M00000
# 133084 21787                  837         TF:M01873
# 133085 21787                  508         TF:M00000
# 133086 21787                  824         TF:M00000
# 133087 21787                 4129         TF:M02837
# 133088 21787                 2024         TF:M00000
# 133089 21787                 3773         TF:M05547
# 133090 21787                  103         TF:M00470
# 133091 21787                 1767         TF:M02874
# 133092 21787                  612         TF:M00000
# 133093 21787                 2025         TF:M00649
# 133094 21787                  330         TF:M00000
# 133095 21787                 1063         TF:M01837
# 133096 21787                  752         TF:M00000
# 133097 21787                  337         TF:M01865
# 133098 21787                  748         TF:M00000
# 133099 21787                  618         TF:M00000
# 133100 21787                 2551         TF:M07329
# 133101 21787                  477         TF:M01175
# 133102 21787                 3736         TF:M00000
# 133103 21787                 3233         TF:M00932
# 133104 21787                  819         TF:M00243
# 133105 21787                  766         TF:M00000
#        evidence_codes
# 1      WP,WP
# 2      IDA IMP IEP ISO IEA,IDA IMP,ISO,IDA IMP ISO IEA,ISO IEA,ISO IEA
# 3      IDA IMP,IBA,ISS ISO IEA,IDA ISO,IBA,ISO IEA,IEA
# 4      IDA IMP IEP ISO IEA,IDA IMP,ISO,IDA IMP ISO IEA,ISO IEA,ISO IEA
# 5      IDA IMP,IBA,ISS ISO IEA,IDA ISO,IBA,ISO IEA,IEA
# 6      IDA,IBA,IDA,IBA,IEA
# 7      IDA IMP IEP ISO IEA,IBA,IEA,IBA
# 8      IBA,IBA
# 9      IDA IMP IEA,IDA IMP IBA,ISS ISO IEA,IDA ISO IEA,IDA IMP,IBA,ISO IEA,ISO IEA,IEA
# 10     IDA IMP IEA,IDA IMP IBA,IMP,ISS ISO IEA,IDA ISO IBA IEA,IEA,IDA IMP,IBA,ISO IEA,ISO IEA,IEA
# 11     IBA,IDA,IBA,IEA
# 12     IBA,IDA,IBA,IEA
# 13     IDA,IBA,IDA,IBA,IEA
# 14     IDA,IDA IEP,IDA IMP IBA IEA,IDA ISO IEA,IDA IEP
# 15     IDA,IDA IEP,IDA IBA,IDA IEP
# 16     IDA IMP IEP,IDA IMP IEP,EXP IDA IMP IEP ISO IBA TAS IEA,IDA,IDA IMP ISO IEA,IDA IEP,ISO IEA,ISO IEA
# 17     IDA IMP IEP,IDA IMP IEP,EXP IDA IMP IEP ISO IBA TAS IEA,IDA IMP ISO IEA,IDA IEP,ISO IEA,ISO IEA
# 18     IDA,IDA IEP,IDA ISO IBA IEA,IDA IEP,ISO IEA
# 19     IBA,ISO IEA,ISS ISO IEA,IBA,ISO IEA
# 20     IPI ISO IBA IC IEA,IDA
# 21     IDA ISS ISO IBA IEA,IPI IBA
# 22     IPI ISO IBA IC IEA,IDA
# 23     IDA ISO IEA,IDA ISS ISO IBA IEA,IDA IEP IBA IEA,IBA,ISS ISO IEA,IDA IPI IMP ISO IBA IC IEA,IEA,IEA,IDA ISS ISO IEA,IDA ISO IBA IEA,IDA IEP IBA TAS IEA,ISO IEA
# 24     ISO IEA,IBA,IBA
# 25     ISO IEA,IBA,IBA
# 26     IEA,IDA IMP IGI ISO IBA IEA,IEA
# 27     IEA,IDA IMP IGI ISO IBA IEA,IEA
# 28     WP,WP
# 29     IEA,ISO IEA,ISO IEA,IBA,IDA IMP,IEA,IDA ISO IBA IEA,ISS ISO IEA,IMP
# 30     IEA,ISO IEA,ISO IEA,IBA,IDA IMP,IDA ISO IEA
# ⋮      ⋮
# 133076 TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF,TF
# 
pcdh7,Cpne7,Ikzf2,Nos1ap,Hecw2,Vps13b,Fhod3,Parp8,Gabra4,Aifm3,Atrnl1,Ttc39c,Hlf,Mcc,Dgki,Cadps,Grk3,Ptprn2,Map1b,Plcl1,Gpatch8,Il1rap,Bcl9,Grin2b,Limch1,Ryr2,Slco3a1,Farp1,Ubr5,Zfp536,Ntrk2,Map7,Chga,Grik4,Gnaq,Srrm3,Ppp1r21,Sh3gl2,Ncoa2,Grid1,Tmem131,Map2,Ssbp2,Exoc4,Atxn1,Rab10,Clasp1,Xpo7,Ctif,Klhdc10,Maged1,Cacna1c,Magi2

# %%
cgsf = cgsf_all %>%
filter(
#        fgf1_comparison == 'obob5v5' &
#        bl6_comparison == 'obobBL6' &
#        fgf1_day == 'all' &
#        bl6_day == 'all' &
#        grouping == 'fgf1_grouping' &
# LIMITING TO DAY5 HELPS
# TOO MANY THINGS GOING ON OTHERWISE
       fgf1_comparison == 'obob14v14' &
       bl6_comparison == 'obobBL6d14' &
       fgf1_day == 'Day14' &
       bl6_day == 'Day14' &
       grouping == 'restored_grouping' &
       query == 'up' &
       term_size <= 500 &
       source == 'GO:BP' &
       !(str_detect(cells_b, '(rest|neg|pos)'))
)

# %%
cgsf = cgsf_all %>%
filter(
       fgf1_comparison == 'obob5v5' &
       bl6_comparison == 'obobBL6d5' &
       fgf1_day == 'Day5' &
       bl6_day == 'Day5' &
       grouping == 'restored_grouping' &
       query == 'up' &
       term_size <= 1000 &
       source == 'GO:BP' &
       !(str_detect(cells_b, '(rest|neg|pos)'))
)

# %%
cgsf = cgsf_all %>%
filter(
       fgf1_comparison == 'obob14v14' &
       bl6_comparison == 'obobBL6d14' &
       fgf1_day == 'Day14' &
       bl6_day == 'Day14' &
       grouping == 'fgf1_grouping' &
       query == 'up' &
       term_size <= 1000 &
       source == 'GO:BP' &
       !(str_detect(cells_b, '(rest|neg|pos)'))
)

# %%
cgsf_all %>% pull(cells_a) %>% unique
# Out:
# [1] "neg"          "pos"          "neg_restored" "pos_restored"

# %%
cgsf %>% group_by(tag) %>% summarise(n=n())
# Out:
#   tag
# 1 Nfix__Nfib___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_none
# 2 Oligodendrocytes___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.pos_vs_none
# 3 g2___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.pos_vs_none
# 4 g3___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.pos_vs_none
# 5 n2___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.pos_vs_none
# 6 other___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_none
# 7 other___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.pos_vs_none
#   n
# 1   3
# 2 466
# 3 736
# 4 189
# 5  50
# 6  96
# 7 248

# %%
df = cgsf %>% filter(cluster == 'Agrp' &
                     cells_a == 'neg')
df %>% dim
# Out:
# [1]  0 27

# %%
library(igraph)

make_grouped_gost = function(df){
    #uses tidyverse, igraph
    # Your original transformation
    df_long <- df %>% 
      tidyr::unnest(parents) %>%  # parents is a list column containing one vector of go terms per row
    #   rename(to=term_id, from=parents) %>% 
      filter((parents %in% term_id)) %>%
      rename(to=parents, from=term_id) %>% 
      select(to, from) %>%
      distinct()

    all_term_ids = data.frame(name = df %>% distinct(term_id) %>% pull(term_id))
    # Create a directed graph from the long format data frame
    g <- graph_from_data_frame(df_long, vertices=all_term_ids,  directed = TRUE)

    # Get all node names
    all_nodes <- V(g)$name

    # Find nodes with no incoming edges (i.e., no parents)
    only_parent_nodes <- all_nodes[degree(g, mode = "in") == 0]

    # Create an empty tibble to store our results
    results <- tibble(hub_node = character(), contained_nodes = list(), path=list(), terminal_nodes = list())

    # Iterate over each parent node
    for (hub_node in only_parent_nodes) {
      # Find all directed paths from the current node to all other nodes
      paths <- all_simple_paths(g, from = hub_node, mode = "out")  # Modified to find directed paths

      # Extract the downstream nodes from each path, flatten into a single vector, remove duplicates, and convert indices to GO terms
      downstream_nodes <- unique(unlist(paths))
      downstream_nodes <- get.vertex.attribute(g, "name", index = downstream_nodes)

      chain_of_nodes = downstream_nodes
      # Exclude the hub_node itself from the downstream_nodes
      downstream_nodes <- setdiff(downstream_nodes, hub_node)

      # Exclude parent nodes from downstream_nodes
      parent_nodes <- df_long$from[df_long$to == hub_node]
      downstream_nodes <- setdiff(downstream_nodes, parent_nodes)

      # Get terminal (leaf) nodes for each path
      terminal_nodes <- downstream_nodes[degree(g, downstream_nodes, mode = "out") == 0]

      # Add the current parent node and its downstream nodes to our results tibble
      results <- results %>% add_row(hub_node = hub_node, contained_nodes = list(downstream_nodes), path=list(chain_of_nodes), terminal_nodes=list(terminal_nodes))
    }

    results_joined <- results %>% 
      left_join(df, by = c("hub_node" = "term_id")) %>% 
      rename(hub_node_name = term_name) %>% 
      mutate(path_names = map(path, ~df$term_name[df$term_id %in% .x])) %>%
      mutate(terminal_names = map(terminal_nodes, ~df$term_name[df$term_id %in% .x]))

    # If you wish to remove the original 'contained_nodes' column you can use the select() function:
    # results <- results %>% select(-contained_nodes)

    grouped_gost = results_joined
    grouped_gost
}
# Out:
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     as_data_frame, groups, union
#
#
# The following objects are masked from ‘package:purrr’:
#
#     compose, simplify
#
#
# The following object is masked from ‘package:tidyr’:
#
#     crossing
#
#
# The following object is masked from ‘package:tibble’:
#
#     as_data_frame
#
#
# The following object is masked from ‘package:Seurat’:
#
#     components
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union

# %%
cgsf %>% colnames
# Out:
#  [1] "tag"                   "data_day"              "cluster"
#  [4] "fgf1_day"              "fgf1_comparison"       "bl6_day"
#  [7] "bl6_comparison"        "grouping"              "cells_a"
# [10] "cells_b"               "query"                 "significant"
# [13] "p_value"               "term_size"             "query_size"
# [16] "intersection_size"     "precision"             "recall"
# [19] "term_id"               "source"                "term_name"
# [22] "effective_domain_size" "source_order"          "parents"
# [25] "evidence_codes"        "intersection"          "gene_ids"

# %%
format_grouped_gost = function(grouped_gost){
    grouped_gost = grouped_gost %>%
        distinct(hub_node, .keep_all = TRUE) %>%
        select(tag, cluster, fgf1_day, fgf1_comparison, bl6_day, bl6_comparison, 
               grouping, cells_a, cells_b, 
               hub_node, hub_node_name, terminal_names, term_size, query_size, intersection_size, p_value, gene_ids) %>%
        rowwise %>%
    mutate(gene_ids = str_replace_all(gene_ids, ',', '; ')) %>%
    ungroup %>%
    rowwise %>%
    mutate(terminal_names = terminal_names %>% unlist %>% paste0(collapse = '; ')) %>%
    ungroup %>%
        arrange(p_value)
    grouped_gost
}

# %%
df %>% make_grouped_gost %>% format_grouped_gost
# Out:
#      tag cluster fgf1_day fgf1_comparison bl6_day bl6_comparison grouping
#      cells_a cells_b hub_node hub_node_name terminal_names term_size query_size
#      intersection_size p_value gene_ids

# %%
cgsf = cgsf_all %>%
filter(
       fgf1_comparison == 'obob5v5' &
       bl6_comparison == 'obobBL6d5' &
       fgf1_day == 'Day5' &
       bl6_day == 'Day5' &
       grouping == 'fgf1_grouping' &
       query == 'up' &
       term_size <= 1000 &
       source == 'GO:BP' &
       !(str_detect(cells_b, '(rest|neg|pos)'))
)

df_grouped <- cgsf_all %>%
filter(query == 'up' &
       term_size <= 1000 &
       source == 'GO:BP' &
       !(str_detect(cells_b, '(rest|neg|pos)')) &
       fgf1_day != 'all' &
       bl6_day != 'all'
#        cluster == 'Agrp' 
#        cells_a == 'neg'
       ) %>%
  # Group the data by the `cluster` and `cells_a` columns
#   group_by(tag) %>%
  # Split the data into a list of tibbles, one per group
  group_split(tag) %>%
  # Apply your functions to each tibble
  purrr::map(~ .x %>%
    make_grouped_gost %>%
    format_grouped_gost) %>%
  # Combine all the tibbles into one
  bind_rows()

# %%
df_grouped %>% filter(tag == 'Agrp___Day5.obob5v5__v__Day5.obobBL6d5___restored_grouping.neg_restored_vs_none') %>% head(1)
# Out:
#   tag
# 1 Agrp___Day5.obob5v5__v__Day5.obobBL6d5___restored_grouping.neg_restored_vs_none
#   cluster fgf1_day fgf1_comparison bl6_day bl6_comparison grouping
# 1 Agrp    Day5     obob5v5         Day5    obobBL6d5      restored_grouping
#   cells_a      cells_b hub_node   hub_node_name    terminal_names
# 1 neg_restored none    GO:0090130 tissue migration epithelial cell migration
#   term_size query_size intersection_size p_value    gene_ids
# 1 324       5          3                 0.03560135 Cdh13; Hdac9; Ptprr

# %%
df_grouped %>% filter(tag == 'Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_none') %>% filter(str_detect(hub_node_name, 'MAPK'))
# Out:
#      tag cluster fgf1_day fgf1_comparison bl6_day bl6_comparison grouping
#      cells_a cells_b hub_node hub_node_name terminal_names term_size query_size
#      intersection_size p_value gene_ids

# %%
df_grouped %>% pull(fgf1_day) %>% unique
# Out:
# [1] "Day14" "Day5"

# %%
df_grouped %>% filter(fgf1_day != bl6_day) %>% dim
# Out:
# [1]  0 17

# %%
df_grouped %>% pull(fgf1_comparison) %>% unique
# Out:
# [1] "obob14v14" "obob5v5"

# %%
df_grouped %>% pull(bl6_comparison) %>% unique
# Out:
# [1] "obobBL6d14" "obobBL6d5"

# %%
df_grouped %>% 
mutate(fgf1_day = factor(fgf1_day, levels=c('Day5', 'Day14'))) %>%
group_split(fgf1_day) %>%
set_names(c('Day5', 'Day14')) %>%
write_xlsx('grouped_gost_d5_d14.xlsx')

# %%
df_grouped %>% 
mutate(fgf1_day = factor(fgf1_day, levels=c('Day5', 'Day14'))) %>%
group_split(fgf1_day)
# Out:
# <list_of<
#   tbl_df<
#     tag              : character
#     cluster          : character
#     fgf1_day         : factor<7c666>
#     fgf1_comparison  : character
#     bl6_day          : character
#     bl6_comparison   : character
#     grouping         : character
#     cells_a          : character
#     cells_b          : character
#     hub_node         : character
#     hub_node_name    : character
#     terminal_names   : character
#     term_size        : integer
#     query_size       : integer
#     intersection_size: integer
#     p_value          : double
#     gene_ids         : character
#   >
# >[2]>
# [[1]]
# # A tibble: 4,443 × 17
#    tag          cluster fgf1_day fgf1_comparison bl6_day bl6_comparison grouping
#    <chr>        <chr>   <fct>    <chr>           <chr>   <chr>          <chr>
#  1 Agrp___Day5… Agrp    Day5     obob5v5         Day5    obobBL6d5      bl6_gro…
#  2 Agrp___Day5… Agrp    Day5     obob5v5         Day5    obobBL6d5      fgf1_gr…
#  3 Agrp___Day5… Agrp    Day5     obob5v5         Day5    obobBL6d5      fgf1_gr…
#  4 Agrp___Day5… Agrp    Day5     obob5v5         Day5    obobBL6d5      fgf1_gr…
#  5 Agrp___Day5… Agrp    Day5     obob5v5         Day5    obobBL6d5      fgf1_gr…
#  6 Agrp___Day5… Agrp    Day5     obob5v5         Day5    obobBL6d5      fgf1_gr…
#  7 Agrp___Day5… Agrp    Day5     obob5v5         Day5    obobBL6d5      fgf1_gr…
#  8 Agrp___Day5… Agrp    Day5     obob5v5         Day5    obobBL6d5      fgf1_gr…
#  9 Agrp___Day5… Agrp    Day5     obob5v5         Day5    obobBL6d5      fgf1_gr…
# 10 Agrp___Day5… Agrp    Day5     obob5v5         Day5    obobBL6d5      fgf1_gr…
# # ℹ 4,433 more rows
# # ℹ 10 more variables: cells_a <chr>, cells_b <chr>, hub_node <chr>,
# #   hub_node_name <chr>, terminal_names <chr>, term_size <int>,
# #   query_size <int>, intersection_size <int>, p_value <dbl>, gene_ids <chr>
#
# [[2]]
# # A tibble: 1,370 × 17
#    tag          cluster fgf1_day fgf1_comparison bl6_day bl6_comparison grouping
#    <chr>        <chr>   <fct>    <chr>           <chr>   <chr>          <chr>
#  1 Agrp___Day1… Agrp    Day14    obob14v14       Day14   obobBL6d14     bl6_gro…
#  2 Agrp___Day1… Agrp    Day14    obob14v14       Day14   obobBL6d14     bl6_gro…
#  3 Agrp___Day1… Agrp    Day14    obob14v14       Day14   obobBL6d14     bl6_gro…
#  4 Agrp___Day1… Agrp    Day14    obob14v14       Day14   obobBL6d14     bl6_gro…
#  5 Agrp___Day1… Agrp    Day14    obob14v14       Day14   obobBL6d14     bl6_gro…
#  6 Agrp___Day1… Agrp    Day14    obob14v14       Day14   obobBL6d14     bl6_gro…
#  7 Agrp___Day1… Agrp    Day14    obob14v14       Day14   obobBL6d14     bl6_gro…
#  8 Agrp___Day1… Agrp    Day14    obob14v14       Day14   obobBL6d14     bl6_gro…
#  9 Astrocytes_… Astroc… Day14    obob14v14       Day14   obobBL6d14     bl6_gro…
# 10 Astrocytes_… Astroc… Day14    obob14v14       Day14   obobBL6d14     bl6_gro…
# # ℹ 1,360 more rows
# # ℹ 10 more variables: cells_a <chr>, cells_b <chr>, hub_node <chr>,
# #   hub_node_name <chr>, terminal_names <chr>, term_size <int>,
# #   query_size <int>, intersection_size <int>, p_value <dbl>, gene_ids <chr>

# %%
df_grouped %>% write_xlsx('_targets_negbinom/grouped_gost_d5_d14_onesheet_negbinom.xlsx')
