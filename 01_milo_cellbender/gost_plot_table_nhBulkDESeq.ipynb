# %%
## library(igraph)
library(Seurat)
library(tidyverse)
library(ggplot2)
library(ggrepel)
library(ggbeeswarm)
library(patchwork)
library(writexl)
options(ggrepel.max.overlaps = Inf)
# Out:
# Loading required package: SeuratObject
#
# Loading required package: sp
#
#
# Attaching package: ‘SeuratObject’
#
#
# The following object is masked from ‘package:base’:
#
#     intersect
#
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.2     ✔ purrr   0.3.4
# ✔ tibble  3.2.1     ✔ dplyr   1.1.2
# ✔ tidyr   1.2.1     ✔ stringr 1.4.1
# ✔ readr   2.1.2     ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
cgsf_all = qs::qread('_targets_nhBulkDESeq/objects/combined_gost_seurat_formatted')
cgsf_all %>% head(1)
# Out:
#   tag
# 1 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
#   data_day cluster fgf1_day fgf1_comparison bl6_day bl6_comparison grouping
# 1 all      Agrp    Day14    obob14v14       Day14   obobBL6d14     bl6_grouping
#   cells_a cells_b ⋯ recall     term_id    source term_name
# 1 neg     none    ⋯ 0.00686948 GO:0048731 GO:BP  system development
#   effective_domain_size source_order parents
# 1 26856                 13640        GO:0007275, GO:0048856
#   evidence_codes
# 1 IDA IMP IGI ISO IBA TAS IEA,IDA,IEA,ISO,IDA IBA,ISS ISO IEA,ISO,ISO IEA,ISS,IEA,IBA,IMP,IMP,IDA IMP IGI IBA,IMP,IMP,IGI,IMP,IEA,ISS ISO IBA IEA,IEA,IMP,IDA IMP IGI,IDA IMP ISS ISO IBA IEA,IMP IGI,IMP ISO IEA,IDA IMP IBA,ISS ISO IEA
#   intersection
# 1 ENSMUSG00000022306,ENSMUSG00000020027,ENSMUSG00000052516,ENSMUSG00000021219,ENSMUSG00000059187,ENSMUSG00000056755,ENSMUSG00000054555,ENSMUSG00000032006,ENSMUSG00000006586,ENSMUSG00000038048,ENSMUSG00000039539,ENSMUSG00000044042,ENSMUSG00000020422,ENSMUSG00000046532,ENSMUSG00000036356,ENSMUSG00000039298,ENSMUSG00000045875,ENSMUSG00000036466,ENSMUSG00000026104,ENSMUSG00000055407,ENSMUSG00000055421,ENSMUSG00000022656,ENSMUSG00000004040,ENSMUSG00000020598,ENSMUSG00000024085,ENSMUSG00000019505,ENSMUSG00000066129,ENSMUSG00000031503
#   gene_ids
# 1 Zfpm2,Socs2,Robo2,Rgs6,Tafa1,Grm7,Adam12,Pdgfd,Runx1t1,Cntnap5c,Sgcz,Fmn1,Tns3,Ar,Csgalnact1,Cdk5rap2,Adra1a,Megf11,Stat1,Map6,Pcdh9,Nectin3,Stat3,Nrcam,Man2a1,Ubb,Kndc1,Col4a2

# %%
cgsf_all = qs::qread('_targets_nhBulkDESeq/objects/combined_gost_seurat_formatted')
cgsf_all %>% head(1)
# Out:
#   tag
# 1 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
#   data_day cluster fgf1_day fgf1_comparison bl6_day bl6_comparison grouping
# 1 all      Agrp    Day14    obob14v14       Day14   obobBL6d14     bl6_grouping
#   cells_a cells_b ⋯ recall     term_id    source term_name
# 1 neg     none    ⋯ 0.00686948 GO:0048731 GO:BP  system development
#   effective_domain_size source_order parents
# 1 26856                 13640        GO:0007275, GO:0048856
#   evidence_codes
# 1 IDA IMP IGI ISO IBA TAS IEA,IDA,IEA,ISO,IDA IBA,ISS ISO IEA,ISO,ISO IEA,ISS,IEA,IBA,IMP,IMP,IDA IMP IGI IBA,IMP,IMP,IGI,IMP,IEA,ISS ISO IBA IEA,IEA,IMP,IDA IMP IGI,IDA IMP ISS ISO IBA IEA,IMP IGI,IMP ISO IEA,IDA IMP IBA,ISS ISO IEA
#   intersection
# 1 ENSMUSG00000022306,ENSMUSG00000020027,ENSMUSG00000052516,ENSMUSG00000021219,ENSMUSG00000059187,ENSMUSG00000056755,ENSMUSG00000054555,ENSMUSG00000032006,ENSMUSG00000006586,ENSMUSG00000038048,ENSMUSG00000039539,ENSMUSG00000044042,ENSMUSG00000020422,ENSMUSG00000046532,ENSMUSG00000036356,ENSMUSG00000039298,ENSMUSG00000045875,ENSMUSG00000036466,ENSMUSG00000026104,ENSMUSG00000055407,ENSMUSG00000055421,ENSMUSG00000022656,ENSMUSG00000004040,ENSMUSG00000020598,ENSMUSG00000024085,ENSMUSG00000019505,ENSMUSG00000066129,ENSMUSG00000031503
#   gene_ids
# 1 Zfpm2,Socs2,Robo2,Rgs6,Tafa1,Grm7,Adam12,Pdgfd,Runx1t1,Cntnap5c,Sgcz,Fmn1,Tns3,Ar,Csgalnact1,Cdk5rap2,Adra1a,Megf11,Stat1,Map6,Pcdh9,Nectin3,Stat3,Nrcam,Man2a1,Ubb,Kndc1,Col4a2

# %%
cgsf_all %>% colnames
# Out:
#  [1] "tag"                   "data_day"              "cluster"
#  [4] "fgf1_day"              "fgf1_comparison"       "bl6_day"
#  [7] "bl6_comparison"        "grouping"              "cells_a"
# [10] "cells_b"               "query"                 "significant"
# [13] "p_value"               "term_size"             "query_size"
# [16] "intersection_size"     "precision"             "recall"
# [19] "term_id"               "source"                "term_name"
# [22] "effective_domain_size" "source_order"          "parents"
# [25] "evidence_codes"        "intersection"          "gene_ids"

# %%
cgsf_all %>% filter(fgf1_day == 'Day14' & bl6_day == 'Day14')
# Out:
#       tag
# 1     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 2     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 3     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 4     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 5     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 6     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 7     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 8     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 9     Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 10    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 11    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 12    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 13    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 14    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 15    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 16    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 17    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 18    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 19    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 20    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 21    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 22    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 23    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 24    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 25    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 26    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 27    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 28    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 29    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# 30    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.neg_vs_none
# ⋮     ⋮
# 33661 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33662 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33663 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33664 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33665 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33666 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33667 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33668 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33669 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33670 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33671 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33672 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33673 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33674 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33675 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33676 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33677 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33678 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33679 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33680 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33681 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33682 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33683 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33684 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33685 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33686 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33687 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33688 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33689 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
# 33690 Trh__Cxcl12___Day14.obob14v14__v__Day14.obobBL6d14___bl6_grouping.pos_vs_rest
#       data_day cluster     fgf1_day fgf1_comparison bl6_day bl6_comparison
# 1     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 2     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 3     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 4     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 5     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 6     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 7     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 8     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 9     all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 10    all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 11    all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 12    all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 13    all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 14    all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 15    all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 16    all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 17    all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 18    all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 19    all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 20    all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 21    all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 22    all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 23    all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 24    all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 25    all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 26    all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 27    all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 28    all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 29    all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# 30    all      Agrp        Day14    obob14v14       Day14   obobBL6d14
# ⋮     ⋮        ⋮           ⋮        ⋮               ⋮       ⋮
# 33661 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33662 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33663 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33664 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33665 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33666 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33667 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33668 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33669 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33670 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33671 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33672 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33673 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33674 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33675 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33676 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33677 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33678 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33679 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33680 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33681 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33682 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33683 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33684 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33685 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33686 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33687 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33688 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33689 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
# 33690 all      Trh__Cxcl12 Day14    obob14v14       Day14   obobBL6d14
#       grouping     cells_a cells_b ⋯ recall      term_id     source
# 1     bl6_grouping neg     none    ⋯ 0.006869480 GO:0048731  GO:BP
# 2     bl6_grouping neg     none    ⋯ 0.006213753 GO:0007275  GO:BP
# 3     bl6_grouping neg     none    ⋯ 0.005625201 GO:0048856  GO:BP
# 4     bl6_grouping neg     none    ⋯ 0.005141011 GO:0032502  GO:BP
# 5     bl6_grouping neg     none    ⋯ 0.007016473 GO:0048513  GO:BP
# 6     bl6_grouping neg     none    ⋯ 0.007436399 GO:0035556  GO:BP
# 7     bl6_grouping neg     none    ⋯ 0.005277602 GO:0030154  GO:BP
# 8     bl6_grouping neg     none    ⋯ 0.005276488 GO:0048869  GO:BP
# 9     bl6_grouping neg     none    ⋯ 0.005417830 GO:0048522  GO:BP
# 10    bl6_grouping neg     none    ⋯ 0.006688963 GO:0023051  GO:BP
# 11    bl6_grouping neg     none    ⋯ 0.006683375 GO:0010646  GO:BP
# 12    bl6_grouping neg     none    ⋯ 0.006491165 GO:0009653  GO:BP
# 13    bl6_grouping neg     none    ⋯ 0.051948052 GO:0060042  GO:BP
# 14    bl6_grouping neg     none    ⋯ 0.008531383 GO:1902531  GO:BP
# 15    bl6_grouping neg     none    ⋯ 0.007432819 GO:0045595  GO:BP
# 16    bl6_grouping neg     none    ⋯ 0.005140611 GO:0048518  GO:BP
# 17    bl6_grouping neg     none    ⋯ 0.007438895 GO:0022008  GO:BP
# 18    bl6_grouping neg     none    ⋯ 0.007025761 GO:0009966  GO:BP
# 19    bl6_grouping neg     none    ⋯ 0.007955936 GO:0048699  GO:BP
# 20    bl6_grouping neg     none    ⋯ 0.007472527 GO:0030054  GO:CC
# 21    bl6_grouping neg     none    ⋯ 0.005010599 GO:0005515  GO:MF
# 22    bl6_grouping neg     none    ⋯ 0.010113780 GO:0019904  GO:MF
# 23    bl6_grouping neg     none    ⋯ 0.003540241 GO:0043169  GO:MF
# 24    bl6_grouping neg     none    ⋯ 0.002345100 GO:0005488  GO:MF
# 25    bl6_grouping neg     none    ⋯ 0.003383277 GO:0046872  GO:MF
# 26    bl6_grouping neg     none    ⋯ 0.005173029 TF:M00333_1 TF
# 27    bl6_grouping neg     none    ⋯ 0.004517756 TF:M02933   TF
# 28    bl6_grouping neg     none    ⋯ 0.005436710 TF:M07040_1 TF
# 29    bl6_grouping neg     none    ⋯ 0.004925193 TF:M10375   TF
# 30    bl6_grouping neg     none    ⋯ 0.004349627 TF:M00333   TF
# ⋮     ⋮            ⋮       ⋮       ⋱ ⋮           ⋮           ⋮
# 33661 bl6_grouping pos     rest    ⋯ 0.01719722  TF:M01199_1 TF
# 33662 bl6_grouping pos     rest    ⋯ 0.01859100  TF:M00982_1 TF
# 33663 bl6_grouping pos     rest    ⋯ 0.01673193  TF:M05494_1 TF
# 33664 bl6_grouping pos     rest    ⋯ 0.01241565  TF:M10375_1 TF
# 33665 bl6_grouping pos     rest    ⋯ 0.01288498  TF:M01199   TF
# 33666 bl6_grouping pos     rest    ⋯ 0.01044367  TF:M10276   TF
# 33667 bl6_grouping pos     rest    ⋯ 0.01265823  TF:M02933_1 TF
# 33668 bl6_grouping pos     rest    ⋯ 0.01075892  TF:M00716_1 TF
# 33669 bl6_grouping pos     rest    ⋯ 0.01699717  TF:M01253   TF
# 33670 bl6_grouping pos     rest    ⋯ 0.01122244  TF:M10276_1 TF
# 33671 bl6_grouping pos     rest    ⋯ 0.01293174  TF:M07354   TF
# 33672 bl6_grouping pos     rest    ⋯ 0.01204577  TF:M01837   TF
# 33673 bl6_grouping pos     rest    ⋯ 0.01444583  TF:M02810   TF
# 33674 bl6_grouping pos     rest    ⋯ 0.01228094  TF:M05494   TF
# 33675 bl6_grouping pos     rest    ⋯ 0.01406534  TF:M10213   TF
# 33676 bl6_grouping pos     rest    ⋯ 0.01232818  TF:M00803_1 TF
# 33677 bl6_grouping pos     rest    ⋯ 0.01334927  TF:M01873   TF
# 33678 bl6_grouping pos     rest    ⋯ 0.01279863  TF:M03876_1 TF
# 33679 bl6_grouping pos     rest    ⋯ 0.01079201  TF:M00333_1 TF
# 33680 bl6_grouping pos     rest    ⋯ 0.01414260  TF:M01219_1 TF
# 33681 bl6_grouping pos     rest    ⋯ 0.01193476  TF:M02036   TF
# 33682 bl6_grouping pos     rest    ⋯ 0.01315510  TF:M02090_1 TF
# 33683 bl6_grouping pos     rest    ⋯ 0.00997103  TF:M00716   TF
# 33684 bl6_grouping pos     rest    ⋯ 0.01089100  TF:M10209_1 TF
# 33685 bl6_grouping pos     rest    ⋯ 0.01128568  TF:M07250   TF
# 33686 bl6_grouping pos     rest    ⋯ 0.01184573  TF:M05665   TF
# 33687 bl6_grouping pos     rest    ⋯ 0.01184573  TF:M05455   TF
# 33688 bl6_grouping pos     rest    ⋯ 0.01184573  TF:M05301   TF
# 33689 bl6_grouping pos     rest    ⋯ 0.01184573  TF:M05391   TF
# 33690 bl6_grouping pos     rest    ⋯ 0.01232227  TF:M05541   TF
#       term_name
# 1     system development
# 2     multicellular organism development
# 3     anatomical structure development
# 4     developmental process
# 5     animal organ development
# 6     intracellular signal transduction
# 7     cell differentiation
# 8     cellular developmental process
# 9     positive regulation of cellular process
# 10    regulation of signaling
# 11    regulation of cell communication
# 12    anatomical structure morphogenesis
# 13    retina morphogenesis in camera-type eye
# 14    regulation of intracellular signal transduction
# 15    regulation of cell differentiation
# 16    positive regulation of biological process
# 17    neurogenesis
# 18    regulation of signal transduction
# 19    generation of neurons
# 20    cell junction
# 21    protein binding
# 22    protein domain specific binding
# 23    cation binding
# 24    binding
# 25    metal ion binding
# 26    Factor: ZF5; motif: NRNGNGCGCGCWN; match class: 1
# 27    Factor: ZF5; motif: GYCGCGCARNGCNN
# 28    Factor: GKLF; motif: NNRRGRRNGNSNNN; match class: 1
# 29    Factor: Sp1; motif: GGNGGGGGNGGGGGMGGGGCNGGG
# 30    Factor: ZF5; motif: NRNGNGCGCGCWN
# ⋮     ⋮
# 33661 Factor: RNF96; motif: BCCCGCRGCC; match class: 1
# 33662 Factor: KROX; motif: CCCGCCCCCRCCCC; match class: 1
# 33663 Factor: Egr-2; motif: GCGTGGGCGG; match class: 1
# 33664 Factor: Sp1; motif: GGNGGGGGNGGGGGMGGGGCNGGG; match class: 1
# 33665 Factor: RNF96; motif: BCCCGCRGCC
# 33666 Factor: Kaiso; motif: SARNYCTCGCGAGAN
# 33667 Factor: ZF5; motif: GYCGCGCARNGCNN; match class: 1
# 33668 Factor: ZF5; motif: GSGCGCGR; match class: 1
# 33669 Factor: CNOT3; motif: GGCCGCGSSS
# 33670 Factor: Kaiso; motif: SARNYCTCGCGAGAN; match class: 1
# 33671 Factor: Egr-1; motif: GCGGGGGCGG
# 33672 Factor: FKLF; motif: BGGGNGGVMD
# 33673 Factor: Sp4; motif: NNNNMCGCCCCCTNNNN
# 33674 Factor: Egr-2; motif: GCGTGGGCGG
# 33675 Factor: Egr-1; motif: NNGCGKGGGCGGGG
# 33676 Factor: E2F; motif: GGCGSG; match class: 1
# 33677 Factor: Egr-1; motif: GCGGGGGCGG
# 33678 Factor: Kaiso; motif: GCMGGGRGCRGS; match class: 1
# 33679 Factor: ZF5; motif: NRNGNGCGCGCWN; match class: 1
# 33680 Factor: SP1:SP3; motif: CCSCCCCCYCC; match class: 1
# 33681 Factor: WT1; motif: CGCCCCCNCN
# 33682 Factor: E2F-4; motif: GCGGGAAANA; match class: 1
# 33683 Factor: ZF5; motif: GSGCGCGR
# 33684 Factor: E2F-1; motif: GNGGGCGGGRMN; match class: 1
# 33685 Factor: E2F-1; motif: NNNSSCGCSAANN
# 33686 Factor: Sp3; motif: AGGGCGG
# 33687 Factor: SP6; motif: WGGGCGG
# 33688 Factor: CPBP; motif: NGGGCGG
# 33689 Factor: LKLF; motif: NGGGCGG
# 33690 Factor: Zfp536; motif: NCGGAKG
#       effective_domain_size source_order
# 1     26856                 13640
# 2     26856                  2853
# 3     26856                 13752
# 4     26856                  7976
# 5     26856                 13448
# 6     26856                  9527
# 7     26856                  7002
# 8     26856                 13764
# 9     26856                 13455
# 10    26856                  6954
# 11    26856                  4364
# 12    26856                  3628
# 13    26856                 15035
# 14    26856                 23244
# 15    26856                 12061
# 16    26856                 13451
# 17    26856                  6877
# 18    26856                  3862
# 19    26856                 13608
# 20    26959                   871
# 21    24945                  1495
# 22    24945                  3755
# 23    24945                  5755
# 24    24945                  1483
# 25    24945                  6274
# 26    21787                  3827
# 27    21787                  3838
# 28    21787                  1349
# 29    21787                  3226
# 30    21787                  3826
# ⋮     ⋮                     ⋮
# 33661 21787                 2915
# 33662 21787                 1855
# 33663 21787                  841
# 33664 21787                 3227
# 33665 21787                 2914
# 33666 21787                 3790
# 33667 21787                 3839
# 33668 21787                 3825
# 33669 21787                  508
# 33670 21787                 3791
# 33671 21787                  834
# 33672 21787                 1062
# 33673 21787                 3248
# 33674 21787                  840
# 33675 21787                  832
# 33676 21787                  775
# 33677 21787                  836
# 33678 21787                 1819
# 33679 21787                 3827
# 33680 21787                 3221
# 33681 21787                 3742
# 33682 21787                  763
# 33683 21787                 3824
# 33684 21787                  729
# 33685 21787                  736
# 33686 21787                 3244
# 33687 21787                 3264
# 33688 21787                  540
# 33689 21787                 1916
# 33690 21787                 3968
#       parents
# 1     GO:0007275, GO:0048856
# 2     GO:0032501, GO:0048856
# 3     GO:0032502
# 4     GO:0008150
# 5     GO:0048856
# 6     GO:0007165
# 7     GO:0048869
# 8     GO:0009987, GO:0032502
# 9     GO:0009987, GO:0048518, GO:0050794
# 10    GO:0023052, GO:0050789
# 11    GO:0007154, GO:0050794
# 12    GO:0032502, GO:0048856
# 13    GO:0009653, GO:0048593, GO:0060041
# 14    GO:0009966, GO:0035556
# 15    GO:0030154, GO:0050793, GO:0050794
# 16    GO:0008150, GO:0050789
# 17    GO:0007399, GO:0030154
# 18    GO:0007165, GO:0010646, GO:0023051, GO:0048583
# 19    GO:0022008
# 20    GO:0110165
# 21    GO:0005488
# 22    GO:0005515
# 23    GO:0043167
# 24    GO:0003674
# 25    GO:0043169
# 26    TF:M00333
# 27    TF:M00000
# 28    TF:M07040
# 29    TF:M00000
# 30    TF:M00000
# ⋮     ⋮
# 33661 TF:M01199
# 33662 TF:M00982
# 33663 TF:M05494
# 33664 TF:M10375
# 33665 TF:M00000
# 33666 TF:M00000
# 33667 TF:M02933
# 33668 TF:M00716
# 33669 TF:M00000
# 33670 TF:M10276
# 33671 TF:M00000
# 33672 TF:M00000
# 33673 TF:M00000
# 33674 TF:M00000
# 33675 TF:M00000
# 33676 TF:M00803
# 33677 TF:M00000
# 33678 TF:M03876
# 33679 TF:M00333
# 33680 TF:M01219
# 33681 TF:M00000
# 33682 TF:M02090
# 33683 TF:M00000
# 33684 TF:M10209
# 33685 TF:M00000
# 33686 TF:M00000
# 33687 TF:M00000
# 33688 TF:M00000
# 33689 TF:M00000
# 33690 TF:M00000
#       evidence_codes
# 1     IDA IMP IGI ISO IBA TAS IEA,IDA,IEA,ISO,IDA IBA,ISS ISO IEA,ISO,ISO IEA,ISS,IEA,IBA,IMP,IMP,IDA IMP IGI IBA,IMP,IMP,IGI,IMP,IEA,ISS ISO IBA IEA,IEA,IMP,IDA IMP IGI,IDA IMP ISS ISO IBA IEA,IMP IGI,IMP ISO IEA,IDA IMP IBA,ISS ISO IEA
# 2     IDA IMP IGI ISO IBA TAS IEA,IDA,IEA,ISO,IDA IBA,IMP,ISS ISO IEA,ISO,ISO IEA,ISS,IEA,IBA,IMP,IMP,IDA IMP IGI ISO IBA,IMP,IMP,IMP IGI,IGI,IMP,IEA,ISS ISO IBA IEA,IEA,IMP,IDA IMP IGI ISS ISO IEA,IDA IMP ISS ISO IBA IEA,IMP IGI,IMP ISO IEA,IDA IMP IBA,ISS ISO IEA
# 3     IDA IMP IGI ISO IBA TAS IEA,IDA IMP IGI,IEA,ISO,IDA IBA,IMP,ISS ISO IEA,ISO,ISO IEA,ISS,IEA,IBA,IMP,IMP,IDA IMP IGI ISO IBA,IMP,ISO IEA,IMP,IMP IGI,IGI IBA,IGI,IMP,IEA,ISS ISO IBA IEA,IEA,IMP,IDA IMP IGI ISS ISO IEA,IDA IMP ISS ISO IBA IEA,IMP IGI,IMP,IMP ISO IEA,IDA IMP IBA,ISS ISO IEA,IEA,IDA
# 33690 Slc25a43,Myo1b,Rab31,Doc2b,Hlf,Ttc39c,Astn2,Pcsk5,Vps13b,Epha7,Cdk14,Gabrq,Cables1,Rgs3,Sppl2a,Utrn,Fam114a2,Sorcs3,Ccdc12,Mcc,Otulinl,Bcl9,Ube2e3,Pitpnm1,Setdb2,Klf9,Sox11,Cab39l,Arhgap17,Gabbr2,Map4k4,Secisbp2l,Primpol,Tcf7l1,Farp1,Per3,Dync1i1,Pdss2,Fig4,Atxn3,Mov10,Dram1,Tlk1,Trpm7,Ppp2r5a,Ctnnd2,Cpsf3,Bmerb1,Unc80,Ahi1,Srrm2,Sybu,Cplane1,Gnao1,Myt1l,Pafah1b1,Rims2,Bicd1,Mycbp2,Tanc2,Kmt2e,Fbxl17,Usp9x,Nrxn1,Nalcn,Kif21a,Golgb1,Smg1,Stox2,Ubr1,Dtnb,Arih1,Glg1,Thoc1,Cdk13,Phc2,Dnmt3a,Aff4

# %%
cgsf = cgsf_all %>%
filter(
#        fgf1_comparison == 'obob5v5' &
#        bl6_comparison == 'obobBL6' &
#        fgf1_day == 'all' &
#        bl6_day == 'all' &
#        grouping == 'fgf1_grouping' &
# LIMITING TO DAY5 HELPS
# TOO MANY THINGS GOING ON OTHERWISE
       fgf1_comparison == 'obob14v14' &
       bl6_comparison == 'obobBL6d14' &
       fgf1_day == 'Day14' &
       bl6_day == 'Day14' &
       grouping == 'restored_grouping' &
       query == 'up' &
       term_size <= 500 &
       source == 'GO:BP' &
       !(str_detect(cells_b, '(rest|neg|pos)'))
)

# %%
cgsf = cgsf_all %>%
filter(
       fgf1_comparison == 'obob5v5' &
       bl6_comparison == 'obobBL6d5' &
       fgf1_day == 'Day5' &
       bl6_day == 'Day5' &
       grouping == 'restored_grouping' &
       query == 'up' &
       term_size <= 1000 &
       source == 'GO:BP' &
       !(str_detect(cells_b, '(rest|neg|pos)'))
)

# %%
cgsf = cgsf_all %>%
filter(
       fgf1_comparison == 'obob14v14' &
       bl6_comparison == 'obobBL6d14' &
       fgf1_day == 'Day14' &
       bl6_day == 'Day14' &
       grouping == 'fgf1_grouping' &
       query == 'up' &
       term_size <= 1000 &
       source == 'GO:BP' &
       !(str_detect(cells_b, '(rest|neg|pos)'))
)

# %%
cgsf_all %>% pull(cells_a) %>% unique
# Out:
# [1] "neg"          "pos"          "neg_restored" "pos_restored"

# %%
cgsf %>% group_by(tag) %>% summarise(n=n())
# Out:
#      tag n

# %%
df = cgsf %>% filter(cluster == 'Agrp' &
                     cells_a == 'neg')
df %>% dim
# Out:
# [1]  0 27

# %%
library(igraph)

make_grouped_gost = function(df){
    #uses tidyverse, igraph
    # Your original transformation
    df_long <- df %>% 
      tidyr::unnest(parents) %>%  # parents is a list column containing one vector of go terms per row
    #   rename(to=term_id, from=parents) %>% 
      filter((parents %in% term_id)) %>%
      rename(to=parents, from=term_id) %>% 
      select(to, from) %>%
      distinct()

    all_term_ids = data.frame(name = df %>% distinct(term_id) %>% pull(term_id))
    # Create a directed graph from the long format data frame
    g <- graph_from_data_frame(df_long, vertices=all_term_ids,  directed = TRUE)

    # Get all node names
    all_nodes <- V(g)$name

    # Find nodes with no incoming edges (i.e., no parents)
    only_parent_nodes <- all_nodes[degree(g, mode = "in") == 0]

    # Create an empty tibble to store our results
    results <- tibble(hub_node = character(), contained_nodes = list(), path=list(), terminal_nodes = list())

    # Iterate over each parent node
    for (hub_node in only_parent_nodes) {
      # Find all directed paths from the current node to all other nodes
      paths <- all_simple_paths(g, from = hub_node, mode = "out")  # Modified to find directed paths

      # Extract the downstream nodes from each path, flatten into a single vector, remove duplicates, and convert indices to GO terms
      downstream_nodes <- unique(unlist(paths))
      downstream_nodes <- get.vertex.attribute(g, "name", index = downstream_nodes)

      chain_of_nodes = downstream_nodes
      # Exclude the hub_node itself from the downstream_nodes
      downstream_nodes <- setdiff(downstream_nodes, hub_node)

      # Exclude parent nodes from downstream_nodes
      parent_nodes <- df_long$from[df_long$to == hub_node]
      downstream_nodes <- setdiff(downstream_nodes, parent_nodes)

      # Get terminal (leaf) nodes for each path
      terminal_nodes <- downstream_nodes[degree(g, downstream_nodes, mode = "out") == 0]

      # Add the current parent node and its downstream nodes to our results tibble
      results <- results %>% add_row(hub_node = hub_node, contained_nodes = list(downstream_nodes), path=list(chain_of_nodes), terminal_nodes=list(terminal_nodes))
    }

    results_joined <- results %>% 
      left_join(df, by = c("hub_node" = "term_id")) %>% 
      rename(hub_node_name = term_name) %>% 
      mutate(path_names = map(path, ~df$term_name[df$term_id %in% .x])) %>%
      mutate(terminal_names = map(terminal_nodes, ~df$term_name[df$term_id %in% .x]))

    # If you wish to remove the original 'contained_nodes' column you can use the select() function:
    # results <- results %>% select(-contained_nodes)

    grouped_gost = results_joined
    grouped_gost
}
# Out:
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     as_data_frame, groups, union
#
#
# The following objects are masked from ‘package:purrr’:
#
#     compose, simplify
#
#
# The following object is masked from ‘package:tidyr’:
#
#     crossing
#
#
# The following object is masked from ‘package:tibble’:
#
#     as_data_frame
#
#
# The following object is masked from ‘package:Seurat’:
#
#     components
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union

# %%
cgsf %>% colnames
# Out:
#  [1] "tag"                   "data_day"              "cluster"
#  [4] "fgf1_day"              "fgf1_comparison"       "bl6_day"
#  [7] "bl6_comparison"        "grouping"              "cells_a"
# [10] "cells_b"               "query"                 "significant"
# [13] "p_value"               "term_size"             "query_size"
# [16] "intersection_size"     "precision"             "recall"
# [19] "term_id"               "source"                "term_name"
# [22] "effective_domain_size" "source_order"          "parents"
# [25] "evidence_codes"        "intersection"          "gene_ids"

# %%
format_grouped_gost = function(grouped_gost){
    grouped_gost = grouped_gost %>%
        distinct(hub_node, .keep_all = TRUE) %>%
        select(tag, cluster, fgf1_day, fgf1_comparison, bl6_day, bl6_comparison, 
               grouping, cells_a, cells_b, 
               hub_node, hub_node_name, terminal_names, term_size, query_size, intersection_size, p_value, gene_ids) %>%
        rowwise %>%
    mutate(gene_ids = str_replace_all(gene_ids, ',', '; ')) %>%
    ungroup %>%
    rowwise %>%
    mutate(terminal_names = terminal_names %>% unlist %>% paste0(collapse = '; ')) %>%
    ungroup %>%
        arrange(p_value)
    grouped_gost
}

# %%
df %>% make_grouped_gost %>% format_grouped_gost
# Out:
#      tag cluster fgf1_day fgf1_comparison bl6_day bl6_comparison grouping
#      cells_a cells_b hub_node hub_node_name terminal_names term_size query_size
#      intersection_size p_value gene_ids

# %%
cgsf = cgsf_all %>%
filter(
       fgf1_comparison == 'obob5v5' &
       bl6_comparison == 'obobBL6d5' &
       fgf1_day == 'Day5' &
       bl6_day == 'Day5' &
       grouping == 'fgf1_grouping' &
       query == 'up' &
       term_size <= 1000 &
       source == 'GO:BP' &
       !(str_detect(cells_b, '(rest|neg|pos)'))
)

df_grouped <- cgsf_all %>%
filter(query == 'up' &
       term_size <= 1000 &
       source == 'GO:BP' &
       !(str_detect(cells_b, '(rest|neg|pos)')) &
       fgf1_day != 'all' &
       bl6_day != 'all'
#        cluster == 'Agrp' 
#        cells_a == 'neg'
       ) %>%
  # Group the data by the `cluster` and `cells_a` columns
#   group_by(tag) %>%
  # Split the data into a list of tibbles, one per group
  group_split(tag) %>%
  # Apply your functions to each tibble
  purrr::map(~ .x %>%
    make_grouped_gost %>%
    format_grouped_gost) %>%
  # Combine all the tibbles into one
  bind_rows()

# %%
df_grouped %>% filter(tag == 'Agrp___Day5.obob5v5__v__Day5.obobBL6d5___restored_grouping.neg_restored_vs_none') %>% head(1)
# Out:
#      tag cluster fgf1_day fgf1_comparison bl6_day bl6_comparison grouping
#      cells_a cells_b hub_node hub_node_name terminal_names term_size query_size
#      intersection_size p_value gene_ids

# %%
df_grouped %>% filter(tag == 'Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_none') %>% filter(str_detect(hub_node_name, 'MAPK'))
# Out:
#      tag cluster fgf1_day fgf1_comparison bl6_day bl6_comparison grouping
#      cells_a cells_b hub_node hub_node_name terminal_names term_size query_size
#      intersection_size p_value gene_ids

# %%
df_grouped %>% pull(fgf1_day) %>% unique
# Out:
# [1] "Day14" "Day5"

# %%
df_grouped %>% filter(fgf1_day != bl6_day) %>% dim
# Out:
# [1]  0 17

# %%
df_grouped %>% pull(fgf1_comparison) %>% unique
# Out:
# [1] "obob14v14" "obob5v5"

# %%
df_grouped %>% pull(bl6_comparison) %>% unique
# Out:
# [1] "obobBL6d14" "obobBL6d5"

# %%
df_grouped %>% 
mutate(fgf1_day = factor(fgf1_day, levels=c('Day5', 'Day14'))) %>%
group_split(fgf1_day)
# Out:
# <list_of<
#   tbl_df<
#     tag              : character
#     cluster          : character
#     fgf1_day         : factor<7c666>
#     fgf1_comparison  : character
#     bl6_day          : character
#     bl6_comparison   : character
#     grouping         : character
#     cells_a          : character
#     cells_b          : character
#     hub_node         : character
#     hub_node_name    : character
#     terminal_names   : character
#     term_size        : integer
#     query_size       : integer
#     intersection_size: integer
#     p_value          : double
#     gene_ids         : character
#   >
# >[2]>
# [[1]]
# # A tibble: 1,668 × 17
#    tag          cluster fgf1_day fgf1_comparison bl6_day bl6_comparison grouping
#    <chr>        <chr>   <fct>    <chr>           <chr>   <chr>          <chr>
#  1 Agrp___Day5… Agrp    Day5     obob5v5         Day5    obobBL6d5      bl6_gro…
#  2 Agrp___Day5… Agrp    Day5     obob5v5         Day5    obobBL6d5      fgf1_gr…
#  3 Agrp___Day5… Agrp    Day5     obob5v5         Day5    obobBL6d5      fgf1_gr…
#  4 Agrp___Day5… Agrp    Day5     obob5v5         Day5    obobBL6d5      fgf1_gr…
#  5 Agrp___Day5… Agrp    Day5     obob5v5         Day5    obobBL6d5      fgf1_gr…
#  6 Agrp___Day5… Agrp    Day5     obob5v5         Day5    obobBL6d5      fgf1_gr…
#  7 Agrp___Day5… Agrp    Day5     obob5v5         Day5    obobBL6d5      fgf1_gr…
#  8 Agrp___Day5… Agrp    Day5     obob5v5         Day5    obobBL6d5      fgf1_gr…
#  9 Agrp___Day5… Agrp    Day5     obob5v5         Day5    obobBL6d5      fgf1_gr…
# 10 Agrp___Day5… Agrp    Day5     obob5v5         Day5    obobBL6d5      fgf1_gr…
# # ℹ 1,658 more rows
# # ℹ 10 more variables: cells_a <chr>, cells_b <chr>, hub_node <chr>,
# #   hub_node_name <chr>, terminal_names <chr>, term_size <int>,
# #   query_size <int>, intersection_size <int>, p_value <dbl>, gene_ids <chr>
#
# [[2]]
# # A tibble: 508 × 17
#    tag          cluster fgf1_day fgf1_comparison bl6_day bl6_comparison grouping
#    <chr>        <chr>   <fct>    <chr>           <chr>   <chr>          <chr>
#  1 Agrp___Day1… Agrp    Day14    obob14v14       Day14   obobBL6d14     bl6_gro…
#  2 Agrp___Day1… Agrp    Day14    obob14v14       Day14   obobBL6d14     bl6_gro…
#  3 Agrp___Day1… Agrp    Day14    obob14v14       Day14   obobBL6d14     bl6_gro…
#  4 Agrp___Day1… Agrp    Day14    obob14v14       Day14   obobBL6d14     bl6_gro…
#  5 Astrocytes_… Astroc… Day14    obob14v14       Day14   obobBL6d14     bl6_gro…
#  6 Astrocytes_… Astroc… Day14    obob14v14       Day14   obobBL6d14     bl6_gro…
#  7 Astrocytes_… Astroc… Day14    obob14v14       Day14   obobBL6d14     bl6_gro…
#  8 Astrocytes_… Astroc… Day14    obob14v14       Day14   obobBL6d14     bl6_gro…
#  9 Astrocytes_… Astroc… Day14    obob14v14       Day14   obobBL6d14     bl6_gro…
# 10 Astrocytes_… Astroc… Day14    obob14v14       Day14   obobBL6d14     bl6_gro…
# # ℹ 498 more rows
# # ℹ 10 more variables: cells_a <chr>, cells_b <chr>, hub_node <chr>,
# #   hub_node_name <chr>, terminal_names <chr>, term_size <int>,
# #   query_size <int>, intersection_size <int>, p_value <dbl>, gene_ids <chr>

# %%
df_grouped %>% write_xlsx('_targets_nhBulkDESeq/grouped_gost_d5_d14_onesheet_nhBulkDESeq.xlsx')
