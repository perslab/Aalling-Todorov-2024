# %%
library(tidyverse)
library(targets)
library(tarchetypes)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.2     ✔ purrr   0.3.4
# ✔ tibble  3.2.1     ✔ dplyr   1.1.2
# ✔ tidyr   1.2.1     ✔ stringr 1.4.1
# ✔ readr   2.1.2     ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
clusters_tibble = qs::qread('clusters_tibble_lvl1.qs')

clusters_tibble$milo_obj = clusters_tibble %>%
    pull(label) %>%
    paste0("milo_", .) %>%
    rlang::syms()
clusters_tibble$milo_index_obj = clusters_tibble %>%
    pull(label) %>%
    paste0("milo_index_tibble_", .) %>%
    rlang::syms()
clusters_tibble$design_df = clusters_tibble %>%
    pull(label) %>%
    paste0("design_df_", .) %>%
    rlang::syms()
clusters_tibble$mm = clusters_tibble %>%
    pull(label) %>%
    paste0("mm_", .) %>%
    rlang::syms()
clusters_tibble
# Out:
#     label                   object              day   cluster
# 1   Astrocytes              exp_labelled_other  all   Astrocytes
# 2   Day14.Astrocytes        exp_labelled_other  Day14 Astrocytes
# 3   Day5.Astrocytes         exp_labelled_other  Day5  Astrocytes
# 4   Endothelial_cells       exp_labelled_other  all   Endothelial_cells
# 5   Day14.Endothelial_cells exp_labelled_other  Day14 Endothelial_cells
# 6   Day5.Endothelial_cells  exp_labelled_other  Day5  Endothelial_cells
# 7   Ependymal_cells         exp_labelled_other  all   Ependymal_cells
# 8   Day14.Ependymal_cells   exp_labelled_other  Day14 Ependymal_cells
# 9   Day5.Ependymal_cells    exp_labelled_other  Day5  Ependymal_cells
# 10  Microglia               exp_labelled_other  all   Microglia
# 11  Day14.Microglia         exp_labelled_other  Day14 Microglia
# 12  Day5.Microglia          exp_labelled_other  Day5  Microglia
# 13  Oligodendrocytes        exp_labelled_other  all   Oligodendrocytes
# 14  Day14.Oligodendrocytes  exp_labelled_other  Day14 Oligodendrocytes
# 15  Day5.Oligodendrocytes   exp_labelled_other  Day5  Oligodendrocytes
# 16  OPC                     exp_labelled_other  all   OPC
# 17  Day14.OPC               exp_labelled_other  Day14 OPC
# 18  Day5.OPC                exp_labelled_other  Day5  OPC
# 19  Pericytes               exp_labelled_other  all   Pericytes
# 20  Day14.Pericytes         exp_labelled_other  Day14 Pericytes
# 21  Day5.Pericytes          exp_labelled_other  Day5  Pericytes
# 22  Tanycytes               exp_labelled_other  all   Tanycytes
# 23  Day14.Tanycytes         exp_labelled_other  Day14 Tanycytes
# 24  Day5.Tanycytes          exp_labelled_other  Day5  Tanycytes
# 25  VLMC                    exp_labelled_other  all   VLMC
# 26  Day14.VLMC              exp_labelled_other  Day14 VLMC
# 27  Day5.VLMC               exp_labelled_other  Day5  VLMC
# 28  Agrp                    exp_labelled_neuron all   Agrp
# 29  Day14.Agrp              exp_labelled_neuron Day14 Agrp
# 30  Day5.Agrp               exp_labelled_neuron Day5  Agrp
# ⋮   ⋮                       ⋮                   ⋮     ⋮
# 130 Sst__Nts                exp_labelled_neuron all   Sst__Nts
# 131 Day14.Sst__Nts          exp_labelled_neuron Day14 Sst__Nts
# 132 Day5.Sst__Nts           exp_labelled_neuron Day5  Sst__Nts
# 133 Sst__Pthlh              exp_labelled_neuron all   Sst__Pthlh
# 134 Day14.Sst__Pthlh        exp_labelled_neuron Day14 Sst__Pthlh
# 135 Day5.Sst__Pthlh         exp_labelled_neuron Day5  Sst__Pthlh
# 136 Sst__Unc13c             exp_labelled_neuron all   Sst__Unc13c
# 137 Day14.Sst__Unc13c       exp_labelled_neuron Day14 Sst__Unc13c
# 138 Day5.Sst__Unc13c        exp_labelled_neuron Day5  Sst__Unc13c
# 139 Tbx19__Pirt             exp_labelled_neuron all   Tbx19__Pirt
# 140 Day14.Tbx19__Pirt       exp_labelled_neuron Day14 Tbx19__Pirt
# 141 Day5.Tbx19__Pirt        exp_labelled_neuron Day5  Tbx19__Pirt
# 142 Th__Nfib                exp_labelled_neuron all   Th__Nfib
# 143 Day14.Th__Nfib          exp_labelled_neuron Day14 Th__Nfib
# 144 Day5.Th__Nfib           exp_labelled_neuron Day5  Th__Nfib
# 145 Th__Slc6a3              exp_labelled_neuron all   Th__Slc6a3
# 146 Day14.Th__Slc6a3        exp_labelled_neuron Day14 Th__Slc6a3
# 147 Day5.Th__Slc6a3         exp_labelled_neuron Day5  Th__Slc6a3
# 148 Tmem215__Dach2          exp_labelled_neuron all   Tmem215__Dach2
# 149 Day14.Tmem215__Dach2    exp_labelled_neuron Day14 Tmem215__Dach2
# 150 Day5.Tmem215__Dach2     exp_labelled_neuron Day5  Tmem215__Dach2
# 151 Tmem215__Greb1          exp_labelled_neuron all   Tmem215__Greb1
# 152 Day14.Tmem215__Greb1    exp_labelled_neuron Day14 Tmem215__Greb1
# 153 Day5.Tmem215__Greb1     exp_labelled_neuron Day5  Tmem215__Greb1
# 154 Trh__Cxcl12             exp_labelled_neuron all   Trh__Cxcl12
# 155 Day14.Trh__Cxcl12       exp_labelled_neuron Day14 Trh__Cxcl12
# 156 Day5.Trh__Cxcl12        exp_labelled_neuron Day5  Trh__Cxcl12
# 157 Trh__Lef1               exp_labelled_neuron all   Trh__Lef1
# 158 Day14.Trh__Lef1         exp_labelled_neuron Day14 Trh__Lef1
# 159 Day5.Trh__Lef1          exp_labelled_neuron Day5  Trh__Lef1
#     milo_obj                     milo_index_obj
# 1   milo_Astrocytes              milo_index_tibble_Astrocytes
# 2   milo_Day14.Astrocytes        milo_index_tibble_Day14.Astrocytes
# 3   milo_Day5.Astrocytes         milo_index_tibble_Day5.Astrocytes
# 4   milo_Endothelial_cells       milo_index_tibble_Endothelial_cells
# 5   milo_Day14.Endothelial_cells milo_index_tibble_Day14.Endothelial_cells
# 6   milo_Day5.Endothelial_cells  milo_index_tibble_Day5.Endothelial_cells
# 7   milo_Ependymal_cells         milo_index_tibble_Ependymal_cells
# 8   milo_Day14.Ependymal_cells   milo_index_tibble_Day14.Ependymal_cells
# 9   milo_Day5.Ependymal_cells    milo_index_tibble_Day5.Ependymal_cells
# 10  milo_Microglia               milo_index_tibble_Microglia
# 11  milo_Day14.Microglia         milo_index_tibble_Day14.Microglia
# 12  milo_Day5.Microglia          milo_index_tibble_Day5.Microglia
# 13  milo_Oligodendrocytes        milo_index_tibble_Oligodendrocytes
# 14  milo_Day14.Oligodendrocytes  milo_index_tibble_Day14.Oligodendrocytes
# 15  milo_Day5.Oligodendrocytes   milo_index_tibble_Day5.Oligodendrocytes
# 16  milo_OPC                     milo_index_tibble_OPC
# 17  milo_Day14.OPC               milo_index_tibble_Day14.OPC
# 18  milo_Day5.OPC                milo_index_tibble_Day5.OPC
# 19  milo_Pericytes               milo_index_tibble_Pericytes
# 20  milo_Day14.Pericytes         milo_index_tibble_Day14.Pericytes
# 21  milo_Day5.Pericytes          milo_index_tibble_Day5.Pericytes
# 22  milo_Tanycytes               milo_index_tibble_Tanycytes
# 23  milo_Day14.Tanycytes         milo_index_tibble_Day14.Tanycytes
# 24  milo_Day5.Tanycytes          milo_index_tibble_Day5.Tanycytes
# 25  milo_VLMC                    milo_index_tibble_VLMC
# 26  milo_Day14.VLMC              milo_index_tibble_Day14.VLMC
# 27  milo_Day5.VLMC               milo_index_tibble_Day5.VLMC
# 28  milo_Agrp                    milo_index_tibble_Agrp
# 29  milo_Day14.Agrp              milo_index_tibble_Day14.Agrp
# 30  milo_Day5.Agrp               milo_index_tibble_Day5.Agrp
# ⋮   ⋮                            ⋮
# 130 milo_Sst__Nts                milo_index_tibble_Sst__Nts
# 131 milo_Day14.Sst__Nts          milo_index_tibble_Day14.Sst__Nts
# 132 milo_Day5.Sst__Nts           milo_index_tibble_Day5.Sst__Nts
# 133 milo_Sst__Pthlh              milo_index_tibble_Sst__Pthlh
# 134 milo_Day14.Sst__Pthlh        milo_index_tibble_Day14.Sst__Pthlh
# 135 milo_Day5.Sst__Pthlh         milo_index_tibble_Day5.Sst__Pthlh
# 136 milo_Sst__Unc13c             milo_index_tibble_Sst__Unc13c
# 137 milo_Day14.Sst__Unc13c       milo_index_tibble_Day14.Sst__Unc13c
# 138 milo_Day5.Sst__Unc13c        milo_index_tibble_Day5.Sst__Unc13c
# 139 milo_Tbx19__Pirt             milo_index_tibble_Tbx19__Pirt
# 140 milo_Day14.Tbx19__Pirt       milo_index_tibble_Day14.Tbx19__Pirt
# 141 milo_Day5.Tbx19__Pirt        milo_index_tibble_Day5.Tbx19__Pirt
# 142 milo_Th__Nfib                milo_index_tibble_Th__Nfib
# 143 milo_Day14.Th__Nfib          milo_index_tibble_Day14.Th__Nfib
# 144 milo_Day5.Th__Nfib           milo_index_tibble_Day5.Th__Nfib
# 145 milo_Th__Slc6a3              milo_index_tibble_Th__Slc6a3
# 146 milo_Day14.Th__Slc6a3        milo_index_tibble_Day14.Th__Slc6a3
# 147 milo_Day5.Th__Slc6a3         milo_index_tibble_Day5.Th__Slc6a3
# 148 milo_Tmem215__Dach2          milo_index_tibble_Tmem215__Dach2
# 149 milo_Day14.Tmem215__Dach2    milo_index_tibble_Day14.Tmem215__Dach2
# 150 milo_Day5.Tmem215__Dach2     milo_index_tibble_Day5.Tmem215__Dach2
# 151 milo_Tmem215__Greb1          milo_index_tibble_Tmem215__Greb1
# 152 milo_Day14.Tmem215__Greb1    milo_index_tibble_Day14.Tmem215__Greb1
# 153 milo_Day5.Tmem215__Greb1     milo_index_tibble_Day5.Tmem215__Greb1
# 154 milo_Trh__Cxcl12             milo_index_tibble_Trh__Cxcl12
# 155 milo_Day14.Trh__Cxcl12       milo_index_tibble_Day14.Trh__Cxcl12
# 156 milo_Day5.Trh__Cxcl12        milo_index_tibble_Day5.Trh__Cxcl12
# 157 milo_Trh__Lef1               milo_index_tibble_Trh__Lef1
# 158 milo_Day14.Trh__Lef1         milo_index_tibble_Day14.Trh__Lef1
# 159 milo_Day5.Trh__Lef1          milo_index_tibble_Day5.Trh__Lef1
#     design_df                         mm
# 1   design_df_Astrocytes              mm_Astrocytes
# 2   design_df_Day14.Astrocytes        mm_Day14.Astrocytes
# 3   design_df_Day5.Astrocytes         mm_Day5.Astrocytes
# 4   design_df_Endothelial_cells       mm_Endothelial_cells
# 5   design_df_Day14.Endothelial_cells mm_Day14.Endothelial_cells
# 6   design_df_Day5.Endothelial_cells  mm_Day5.Endothelial_cells
# 7   design_df_Ependymal_cells         mm_Ependymal_cells
# 8   design_df_Day14.Ependymal_cells   mm_Day14.Ependymal_cells
# 9   design_df_Day5.Ependymal_cells    mm_Day5.Ependymal_cells
# 10  design_df_Microglia               mm_Microglia
# 11  design_df_Day14.Microglia         mm_Day14.Microglia
# 12  design_df_Day5.Microglia          mm_Day5.Microglia
# 13  design_df_Oligodendrocytes        mm_Oligodendrocytes
# 14  design_df_Day14.Oligodendrocytes  mm_Day14.Oligodendrocytes
# 15  design_df_Day5.Oligodendrocytes   mm_Day5.Oligodendrocytes
# 16  design_df_OPC                     mm_OPC
# 17  design_df_Day14.OPC               mm_Day14.OPC
# 18  design_df_Day5.OPC                mm_Day5.OPC
# 19  design_df_Pericytes               mm_Pericytes
# 20  design_df_Day14.Pericytes         mm_Day14.Pericytes
# 21  design_df_Day5.Pericytes          mm_Day5.Pericytes
# 22  design_df_Tanycytes               mm_Tanycytes
# 23  design_df_Day14.Tanycytes         mm_Day14.Tanycytes
# 24  design_df_Day5.Tanycytes          mm_Day5.Tanycytes
# 25  design_df_VLMC                    mm_VLMC
# 26  design_df_Day14.VLMC              mm_Day14.VLMC
# 27  design_df_Day5.VLMC               mm_Day5.VLMC
# 28  design_df_Agrp                    mm_Agrp
# 29  design_df_Day14.Agrp              mm_Day14.Agrp
# 30  design_df_Day5.Agrp               mm_Day5.Agrp
# ⋮   ⋮                                 ⋮
# 130 design_df_Sst__Nts                mm_Sst__Nts
# 131 design_df_Day14.Sst__Nts          mm_Day14.Sst__Nts
# 132 design_df_Day5.Sst__Nts           mm_Day5.Sst__Nts
# 133 design_df_Sst__Pthlh              mm_Sst__Pthlh
# 134 design_df_Day14.Sst__Pthlh        mm_Day14.Sst__Pthlh
# 135 design_df_Day5.Sst__Pthlh         mm_Day5.Sst__Pthlh
# 136 design_df_Sst__Unc13c             mm_Sst__Unc13c
# 137 design_df_Day14.Sst__Unc13c       mm_Day14.Sst__Unc13c
# 138 design_df_Day5.Sst__Unc13c        mm_Day5.Sst__Unc13c
# 139 design_df_Tbx19__Pirt             mm_Tbx19__Pirt
# 140 design_df_Day14.Tbx19__Pirt       mm_Day14.Tbx19__Pirt
# 141 design_df_Day5.Tbx19__Pirt        mm_Day5.Tbx19__Pirt
# 142 design_df_Th__Nfib                mm_Th__Nfib
# 143 design_df_Day14.Th__Nfib          mm_Day14.Th__Nfib
# 144 design_df_Day5.Th__Nfib           mm_Day5.Th__Nfib
# 145 design_df_Th__Slc6a3              mm_Th__Slc6a3
# 146 design_df_Day14.Th__Slc6a3        mm_Day14.Th__Slc6a3
# 147 design_df_Day5.Th__Slc6a3         mm_Day5.Th__Slc6a3
# 148 design_df_Tmem215__Dach2          mm_Tmem215__Dach2
# 149 design_df_Day14.Tmem215__Dach2    mm_Day14.Tmem215__Dach2
# 150 design_df_Day5.Tmem215__Dach2     mm_Day5.Tmem215__Dach2
# 151 design_df_Tmem215__Greb1          mm_Tmem215__Greb1
# 152 design_df_Day14.Tmem215__Greb1    mm_Day14.Tmem215__Greb1
# 153 design_df_Day5.Tmem215__Greb1     mm_Day5.Tmem215__Greb1
# 154 design_df_Trh__Cxcl12             mm_Trh__Cxcl12
# 155 design_df_Day14.Trh__Cxcl12       mm_Day14.Trh__Cxcl12
# 156 design_df_Day5.Trh__Cxcl12        mm_Day5.Trh__Cxcl12
# 157 design_df_Trh__Lef1               mm_Trh__Lef1
# 158 design_df_Day14.Trh__Lef1         mm_Day14.Trh__Lef1
# 159 design_df_Day5.Trh__Lef1          mm_Day5.Trh__Lef1

# %%
contrasts_tibble = tibble(
    contrast_name = c("obob5v5",
                      "obob14v14",
                      "obobBL6",
                      "obobBL6d5",
                      "obobBL6d14",
                      "obob5vBL6",
                      "obob14vBL6",
                      "obobFGF1BL6d5",
                      "obobFGF1BL6d14",
                      "BL6d5d14",
                      "obobVeh_PFd5d14"),
    contrast = c("groupFGF1.Day5.obob - groupVeh_PF.Day5.obob",
                 "groupFGF1.Day14.obob - groupVeh_PF.Day14.obob",
                 "((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)",
                 "groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6",
                 "groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6",
                 "groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)",
                 "groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)",
                 "groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6",
                 "groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6",
                 "groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6",
                 "groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob")
)
contrasts_tibble
# Out:
#    contrast_name
# 1  obob5v5
# 2  obob14v14
# 3  obobBL6
# 4  obobBL6d5
# 5  obobBL6d14
# 6  obob5vBL6
# 7  obob14vBL6
# 8  obobFGF1BL6d5
# 9  obobFGF1BL6d14
# 10 BL6d5d14
# 11 obobVeh_PFd5d14
#    contrast
# 1  groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 2  groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 3  ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 4  groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 5  groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 6  groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 7  groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 8  groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 9  groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 10 groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 11 groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob

# %%
da_recipe = tidyr::crossing(clusters_tibble, contrasts_tibble)
da_recipe$label = paste0(da_recipe$label, '___', da_recipe$contrast_name)
head(da_recipe)
# Out:
#   label             object              day cluster milo_obj
# 1 Agrp___BL6d5d14   exp_labelled_neuron all Agrp    milo_Agrp
# 2 Agrp___obob14v14  exp_labelled_neuron all Agrp    milo_Agrp
# 3 Agrp___obob14vBL6 exp_labelled_neuron all Agrp    milo_Agrp
# 4 Agrp___obob5v5    exp_labelled_neuron all Agrp    milo_Agrp
# 5 Agrp___obob5vBL6  exp_labelled_neuron all Agrp    milo_Agrp
# 6 Agrp___obobBL6    exp_labelled_neuron all Agrp    milo_Agrp
#   milo_index_obj         design_df      mm      contrast_name
# 1 milo_index_tibble_Agrp design_df_Agrp mm_Agrp BL6d5d14
# 2 milo_index_tibble_Agrp design_df_Agrp mm_Agrp obob14v14
# 3 milo_index_tibble_Agrp design_df_Agrp mm_Agrp obob14vBL6
# 4 milo_index_tibble_Agrp design_df_Agrp mm_Agrp obob5v5
# 5 milo_index_tibble_Agrp design_df_Agrp mm_Agrp obob5vBL6
# 6 milo_index_tibble_Agrp design_df_Agrp mm_Agrp obobBL6
#   contrast
# 1 groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 2 groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 3 groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 4 groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 5 groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 6 ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)

# %%
da_recipe = da_recipe %>%
filter(!(str_detect(contrast_name, "obob5v5") & day == 'Day14')) %>%
filter(!(str_detect(contrast_name, "obob14v14") & day == 'Day5')) %>%
# filter(!(contrast_name == 'obobBL6' & day != 'all')) %>% # this one is good to have, as they may be equivalent
filter(!(contrast_name == 'obobBL6d5' & (day == 'Day14'))) %>%
filter(!(contrast_name == 'obobBL6d14' & (day == 'Day5'))) %>%
filter(!(contrast_name == 'obobFGF1BL6d5' & (day == 'Day14'))) %>% 
filter(!(contrast_name == 'obobFGF1BL6d14' & (day == 'Day5'))) %>%
filter(!(contrast_name == "obob5vBL6" & (day != 'all'))) %>% 
filter(!(contrast_name == "obob14vBL6" & (day != 'all'))) %>%
filter(!(contrast_name == 'BL6d5d14' & (day != 'all'))) %>%
filter(!(contrast_name == 'obobVeh_PFd5d14' & (day != 'all')))

# %%
da_recipe
# Out:
#      label                         object              day cluster
# 1    Agrp___BL6d5d14               exp_labelled_neuron all Agrp
# 2    Agrp___obob14v14              exp_labelled_neuron all Agrp
# 3    Agrp___obob14vBL6             exp_labelled_neuron all Agrp
# 4    Agrp___obob5v5                exp_labelled_neuron all Agrp
# 5    Agrp___obob5vBL6              exp_labelled_neuron all Agrp
# 6    Agrp___obobBL6                exp_labelled_neuron all Agrp
# 7    Agrp___obobBL6d14             exp_labelled_neuron all Agrp
# 8    Agrp___obobBL6d5              exp_labelled_neuron all Agrp
# 9    Agrp___obobFGF1BL6d14         exp_labelled_neuron all Agrp
# 10   Agrp___obobFGF1BL6d5          exp_labelled_neuron all Agrp
# 11   Agrp___obobVeh_PFd5d14        exp_labelled_neuron all Agrp
# 12   Arx__Nr5a2___BL6d5d14         exp_labelled_neuron all Arx__Nr5a2
# 13   Arx__Nr5a2___obob14v14        exp_labelled_neuron all Arx__Nr5a2
# 14   Arx__Nr5a2___obob14vBL6       exp_labelled_neuron all Arx__Nr5a2
# 15   Arx__Nr5a2___obob5v5          exp_labelled_neuron all Arx__Nr5a2
# 16   Arx__Nr5a2___obob5vBL6        exp_labelled_neuron all Arx__Nr5a2
# 17   Arx__Nr5a2___obobBL6          exp_labelled_neuron all Arx__Nr5a2
# 18   Arx__Nr5a2___obobBL6d14       exp_labelled_neuron all Arx__Nr5a2
# 19   Arx__Nr5a2___obobBL6d5        exp_labelled_neuron all Arx__Nr5a2
# 20   Arx__Nr5a2___obobFGF1BL6d14   exp_labelled_neuron all Arx__Nr5a2
# 21   Arx__Nr5a2___obobFGF1BL6d5    exp_labelled_neuron all Arx__Nr5a2
# 22   Arx__Nr5a2___obobVeh_PFd5d14  exp_labelled_neuron all Arx__Nr5a2
# 23   Astrocytes___BL6d5d14         exp_labelled_other  all Astrocytes
# 24   Astrocytes___obob14v14        exp_labelled_other  all Astrocytes
# 25   Astrocytes___obob14vBL6       exp_labelled_other  all Astrocytes
# 26   Astrocytes___obob5v5          exp_labelled_other  all Astrocytes
# 27   Astrocytes___obob5vBL6        exp_labelled_other  all Astrocytes
# 28   Astrocytes___obobBL6          exp_labelled_other  all Astrocytes
# 29   Astrocytes___obobBL6d14       exp_labelled_other  all Astrocytes
# 30   Astrocytes___obobBL6d5        exp_labelled_other  all Astrocytes
# ⋮    ⋮                             ⋮                   ⋮   ⋮
# 978  Trh__Cxcl12___obob5v5         exp_labelled_neuron all Trh__Cxcl12
# 979  Trh__Cxcl12___obob5vBL6       exp_labelled_neuron all Trh__Cxcl12
# 980  Trh__Cxcl12___obobBL6         exp_labelled_neuron all Trh__Cxcl12
# 981  Trh__Cxcl12___obobBL6d14      exp_labelled_neuron all Trh__Cxcl12
# 982  Trh__Cxcl12___obobBL6d5       exp_labelled_neuron all Trh__Cxcl12
# 983  Trh__Cxcl12___obobFGF1BL6d14  exp_labelled_neuron all Trh__Cxcl12
# 984  Trh__Cxcl12___obobFGF1BL6d5   exp_labelled_neuron all Trh__Cxcl12
# 985  Trh__Cxcl12___obobVeh_PFd5d14 exp_labelled_neuron all Trh__Cxcl12
# 986  Trh__Lef1___BL6d5d14          exp_labelled_neuron all Trh__Lef1
# 987  Trh__Lef1___obob14v14         exp_labelled_neuron all Trh__Lef1
# 988  Trh__Lef1___obob14vBL6        exp_labelled_neuron all Trh__Lef1
# 989  Trh__Lef1___obob5v5           exp_labelled_neuron all Trh__Lef1
# 990  Trh__Lef1___obob5vBL6         exp_labelled_neuron all Trh__Lef1
# 991  Trh__Lef1___obobBL6           exp_labelled_neuron all Trh__Lef1
# 992  Trh__Lef1___obobBL6d14        exp_labelled_neuron all Trh__Lef1
# 993  Trh__Lef1___obobBL6d5         exp_labelled_neuron all Trh__Lef1
# 994  Trh__Lef1___obobFGF1BL6d14    exp_labelled_neuron all Trh__Lef1
# 995  Trh__Lef1___obobFGF1BL6d5     exp_labelled_neuron all Trh__Lef1
# 996  Trh__Lef1___obobVeh_PFd5d14   exp_labelled_neuron all Trh__Lef1
# 997  VLMC___BL6d5d14               exp_labelled_other  all VLMC
# 998  VLMC___obob14v14              exp_labelled_other  all VLMC
# 999  VLMC___obob14vBL6             exp_labelled_other  all VLMC
# 1000 VLMC___obob5v5                exp_labelled_other  all VLMC
# 1001 VLMC___obob5vBL6              exp_labelled_other  all VLMC
# 1002 VLMC___obobBL6                exp_labelled_other  all VLMC
# 1003 VLMC___obobBL6d14             exp_labelled_other  all VLMC
# 1004 VLMC___obobBL6d5              exp_labelled_other  all VLMC
# 1005 VLMC___obobFGF1BL6d14         exp_labelled_other  all VLMC
# 1006 VLMC___obobFGF1BL6d5          exp_labelled_other  all VLMC
# 1007 VLMC___obobVeh_PFd5d14        exp_labelled_other  all VLMC
#      milo_obj         milo_index_obj                design_df
# 1    milo_Agrp        milo_index_tibble_Agrp        design_df_Agrp
# 2    milo_Agrp        milo_index_tibble_Agrp        design_df_Agrp
# 3    milo_Agrp        milo_index_tibble_Agrp        design_df_Agrp
# 4    milo_Agrp        milo_index_tibble_Agrp        design_df_Agrp
# 5    milo_Agrp        milo_index_tibble_Agrp        design_df_Agrp
# 6    milo_Agrp        milo_index_tibble_Agrp        design_df_Agrp
# 7    milo_Agrp        milo_index_tibble_Agrp        design_df_Agrp
# 8    milo_Agrp        milo_index_tibble_Agrp        design_df_Agrp
# 9    milo_Agrp        milo_index_tibble_Agrp        design_df_Agrp
# 10   milo_Agrp        milo_index_tibble_Agrp        design_df_Agrp
# 11   milo_Agrp        milo_index_tibble_Agrp        design_df_Agrp
# 12   milo_Arx__Nr5a2  milo_index_tibble_Arx__Nr5a2  design_df_Arx__Nr5a2
# 13   milo_Arx__Nr5a2  milo_index_tibble_Arx__Nr5a2  design_df_Arx__Nr5a2
# 14   milo_Arx__Nr5a2  milo_index_tibble_Arx__Nr5a2  design_df_Arx__Nr5a2
# 15   milo_Arx__Nr5a2  milo_index_tibble_Arx__Nr5a2  design_df_Arx__Nr5a2
# 16   milo_Arx__Nr5a2  milo_index_tibble_Arx__Nr5a2  design_df_Arx__Nr5a2
# 17   milo_Arx__Nr5a2  milo_index_tibble_Arx__Nr5a2  design_df_Arx__Nr5a2
# 18   milo_Arx__Nr5a2  milo_index_tibble_Arx__Nr5a2  design_df_Arx__Nr5a2
# 19   milo_Arx__Nr5a2  milo_index_tibble_Arx__Nr5a2  design_df_Arx__Nr5a2
# 20   milo_Arx__Nr5a2  milo_index_tibble_Arx__Nr5a2  design_df_Arx__Nr5a2
# 21   milo_Arx__Nr5a2  milo_index_tibble_Arx__Nr5a2  design_df_Arx__Nr5a2
# 22   milo_Arx__Nr5a2  milo_index_tibble_Arx__Nr5a2  design_df_Arx__Nr5a2
# 23   milo_Astrocytes  milo_index_tibble_Astrocytes  design_df_Astrocytes
# 24   milo_Astrocytes  milo_index_tibble_Astrocytes  design_df_Astrocytes
# 25   milo_Astrocytes  milo_index_tibble_Astrocytes  design_df_Astrocytes
# 26   milo_Astrocytes  milo_index_tibble_Astrocytes  design_df_Astrocytes
# 27   milo_Astrocytes  milo_index_tibble_Astrocytes  design_df_Astrocytes
# 28   milo_Astrocytes  milo_index_tibble_Astrocytes  design_df_Astrocytes
# 29   milo_Astrocytes  milo_index_tibble_Astrocytes  design_df_Astrocytes
# 30   milo_Astrocytes  milo_index_tibble_Astrocytes  design_df_Astrocytes
# ⋮    ⋮                ⋮                             ⋮
# 978  milo_Trh__Cxcl12 milo_index_tibble_Trh__Cxcl12 design_df_Trh__Cxcl12
# 979  milo_Trh__Cxcl12 milo_index_tibble_Trh__Cxcl12 design_df_Trh__Cxcl12
# 980  milo_Trh__Cxcl12 milo_index_tibble_Trh__Cxcl12 design_df_Trh__Cxcl12
# 981  milo_Trh__Cxcl12 milo_index_tibble_Trh__Cxcl12 design_df_Trh__Cxcl12
# 982  milo_Trh__Cxcl12 milo_index_tibble_Trh__Cxcl12 design_df_Trh__Cxcl12
# 983  milo_Trh__Cxcl12 milo_index_tibble_Trh__Cxcl12 design_df_Trh__Cxcl12
# 984  milo_Trh__Cxcl12 milo_index_tibble_Trh__Cxcl12 design_df_Trh__Cxcl12
# 985  milo_Trh__Cxcl12 milo_index_tibble_Trh__Cxcl12 design_df_Trh__Cxcl12
# 986  milo_Trh__Lef1   milo_index_tibble_Trh__Lef1   design_df_Trh__Lef1
# 987  milo_Trh__Lef1   milo_index_tibble_Trh__Lef1   design_df_Trh__Lef1
# 988  milo_Trh__Lef1   milo_index_tibble_Trh__Lef1   design_df_Trh__Lef1
# 989  milo_Trh__Lef1   milo_index_tibble_Trh__Lef1   design_df_Trh__Lef1
# 990  milo_Trh__Lef1   milo_index_tibble_Trh__Lef1   design_df_Trh__Lef1
# 991  milo_Trh__Lef1   milo_index_tibble_Trh__Lef1   design_df_Trh__Lef1
# 992  milo_Trh__Lef1   milo_index_tibble_Trh__Lef1   design_df_Trh__Lef1
# 993  milo_Trh__Lef1   milo_index_tibble_Trh__Lef1   design_df_Trh__Lef1
# 994  milo_Trh__Lef1   milo_index_tibble_Trh__Lef1   design_df_Trh__Lef1
# 995  milo_Trh__Lef1   milo_index_tibble_Trh__Lef1   design_df_Trh__Lef1
# 996  milo_Trh__Lef1   milo_index_tibble_Trh__Lef1   design_df_Trh__Lef1
# 997  milo_VLMC        milo_index_tibble_VLMC        design_df_VLMC
# 998  milo_VLMC        milo_index_tibble_VLMC        design_df_VLMC
# 999  milo_VLMC        milo_index_tibble_VLMC        design_df_VLMC
# 1000 milo_VLMC        milo_index_tibble_VLMC        design_df_VLMC
# 1001 milo_VLMC        milo_index_tibble_VLMC        design_df_VLMC
# 1002 milo_VLMC        milo_index_tibble_VLMC        design_df_VLMC
# 1003 milo_VLMC        milo_index_tibble_VLMC        design_df_VLMC
# 1004 milo_VLMC        milo_index_tibble_VLMC        design_df_VLMC
# 1005 milo_VLMC        milo_index_tibble_VLMC        design_df_VLMC
# 1006 milo_VLMC        milo_index_tibble_VLMC        design_df_VLMC
# 1007 milo_VLMC        milo_index_tibble_VLMC        design_df_VLMC
#      mm             contrast_name
# 1    mm_Agrp        BL6d5d14
# 2    mm_Agrp        obob14v14
# 3    mm_Agrp        obob14vBL6
# 4    mm_Agrp        obob5v5
# 5    mm_Agrp        obob5vBL6
# 6    mm_Agrp        obobBL6
# 7    mm_Agrp        obobBL6d14
# 8    mm_Agrp        obobBL6d5
# 9    mm_Agrp        obobFGF1BL6d14
# 10   mm_Agrp        obobFGF1BL6d5
# 11   mm_Agrp        obobVeh_PFd5d14
# 12   mm_Arx__Nr5a2  BL6d5d14
# 13   mm_Arx__Nr5a2  obob14v14
# 14   mm_Arx__Nr5a2  obob14vBL6
# 15   mm_Arx__Nr5a2  obob5v5
# 16   mm_Arx__Nr5a2  obob5vBL6
# 17   mm_Arx__Nr5a2  obobBL6
# 18   mm_Arx__Nr5a2  obobBL6d14
# 19   mm_Arx__Nr5a2  obobBL6d5
# 20   mm_Arx__Nr5a2  obobFGF1BL6d14
# 21   mm_Arx__Nr5a2  obobFGF1BL6d5
# 22   mm_Arx__Nr5a2  obobVeh_PFd5d14
# 23   mm_Astrocytes  BL6d5d14
# 24   mm_Astrocytes  obob14v14
# 25   mm_Astrocytes  obob14vBL6
# 26   mm_Astrocytes  obob5v5
# 27   mm_Astrocytes  obob5vBL6
# 28   mm_Astrocytes  obobBL6
# 29   mm_Astrocytes  obobBL6d14
# 30   mm_Astrocytes  obobBL6d5
# ⋮    ⋮              ⋮
# 978  mm_Trh__Cxcl12 obob5v5
# 979  mm_Trh__Cxcl12 obob5vBL6
# 980  mm_Trh__Cxcl12 obobBL6
# 981  mm_Trh__Cxcl12 obobBL6d14
# 982  mm_Trh__Cxcl12 obobBL6d5
# 983  mm_Trh__Cxcl12 obobFGF1BL6d14
# 984  mm_Trh__Cxcl12 obobFGF1BL6d5
# 985  mm_Trh__Cxcl12 obobVeh_PFd5d14
# 986  mm_Trh__Lef1   BL6d5d14
# 987  mm_Trh__Lef1   obob14v14
# 988  mm_Trh__Lef1   obob14vBL6
# 989  mm_Trh__Lef1   obob5v5
# 990  mm_Trh__Lef1   obob5vBL6
# 991  mm_Trh__Lef1   obobBL6
# 992  mm_Trh__Lef1   obobBL6d14
# 993  mm_Trh__Lef1   obobBL6d5
# 994  mm_Trh__Lef1   obobFGF1BL6d14
# 995  mm_Trh__Lef1   obobFGF1BL6d5
# 996  mm_Trh__Lef1   obobVeh_PFd5d14
# 997  mm_VLMC        BL6d5d14
# 998  mm_VLMC        obob14v14
# 999  mm_VLMC        obob14vBL6
# 1000 mm_VLMC        obob5v5
# 1001 mm_VLMC        obob5vBL6
# 1002 mm_VLMC        obobBL6
# 1003 mm_VLMC        obobBL6d14
# 1004 mm_VLMC        obobBL6d5
# 1005 mm_VLMC        obobFGF1BL6d14
# 1006 mm_VLMC        obobFGF1BL6d5
# 1007 mm_VLMC        obobVeh_PFd5d14
#      contrast
# 1    groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 2    groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 3    groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 4    groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 5    groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 6    ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 7    groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 8    groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 9    groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 10   groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 11   groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob
# 12   groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 13   groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 14   groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 15   groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 16   groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 17   ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 18   groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 19   groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 20   groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 21   groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 22   groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob
# 23   groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 24   groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 25   groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 26   groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 27   groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 28   ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 29   groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 30   groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# ⋮    ⋮
# 978  groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 979  groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 980  ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 981  groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 982  groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 983  groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 984  groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 985  groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob
# 986  groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 987  groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 988  groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 989  groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 990  groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 991  ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 992  groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 993  groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 994  groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 995  groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 996  groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob
# 997  groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 998  groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 999  groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 1000 groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 1001 groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 1002 ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 1003 groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 1004 groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 1005 groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 1006 groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 1007 groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob

# %%
qs::qsave(da_recipe, 'da_recipe_lvl1.qs')
