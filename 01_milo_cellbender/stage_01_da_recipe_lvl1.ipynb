# %%
library(tidyverse)
library(targets)
library(tarchetypes)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.2     ✔ purrr   0.3.4
# ✔ tibble  3.2.1     ✔ dplyr   1.1.2
# ✔ tidyr   1.2.1     ✔ stringr 1.4.1
# ✔ readr   2.1.2     ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
clusters_tibble = qs::qread('clusters_tibble_lvl1.qs')

clusters_tibble$milo_obj = clusters_tibble %>%
    pull(label) %>%
    paste0("milo_", .) %>%
    rlang::syms()
clusters_tibble$milo_index_obj = clusters_tibble %>%
    pull(label) %>%
    paste0("milo_index_tibble_", .) %>%
    rlang::syms()
clusters_tibble$design_df = clusters_tibble %>%
    pull(label) %>%
    paste0("design_df_", .) %>%
    rlang::syms()
clusters_tibble$mm = clusters_tibble %>%
    pull(label) %>%
    paste0("mm_", .) %>%
    rlang::syms()
clusters_tibble
# Out:
#     label                   object              day   cluster
# 1   Astrocytes              exp_labelled_other  all   Astrocytes
# 2   Day14.Astrocytes        exp_labelled_other  Day14 Astrocytes
# 3   Day5.Astrocytes         exp_labelled_other  Day5  Astrocytes
# 4   Endothelial_cells       exp_labelled_other  all   Endothelial_cells
# 5   Day14.Endothelial_cells exp_labelled_other  Day14 Endothelial_cells
# 6   Day5.Endothelial_cells  exp_labelled_other  Day5  Endothelial_cells
# 7   Ependymal_cells         exp_labelled_other  all   Ependymal_cells
# 8   Day14.Ependymal_cells   exp_labelled_other  Day14 Ependymal_cells
# 9   Day5.Ependymal_cells    exp_labelled_other  Day5  Ependymal_cells
# 10  Microglia               exp_labelled_other  all   Microglia
# 11  Day14.Microglia         exp_labelled_other  Day14 Microglia
# 12  Day5.Microglia          exp_labelled_other  Day5  Microglia
# 13  Oligodendrocytes        exp_labelled_other  all   Oligodendrocytes
# 14  Day14.Oligodendrocytes  exp_labelled_other  Day14 Oligodendrocytes
# 15  Day5.Oligodendrocytes   exp_labelled_other  Day5  Oligodendrocytes
# 16  OPC                     exp_labelled_other  all   OPC
# 17  Day14.OPC               exp_labelled_other  Day14 OPC
# 18  Day5.OPC                exp_labelled_other  Day5  OPC
# 19  Tanycytes               exp_labelled_other  all   Tanycytes
# 20  Day14.Tanycytes         exp_labelled_other  Day14 Tanycytes
# 21  Day5.Tanycytes          exp_labelled_other  Day5  Tanycytes
# 22  Agrp                    exp_labelled_neuron all   Agrp
# 23  Day14.Agrp              exp_labelled_neuron Day14 Agrp
# 24  Day5.Agrp               exp_labelled_neuron Day5  Agrp
# 25  Arx__Nr5a2              exp_labelled_neuron all   Arx__Nr5a2
# 26  Day14.Arx__Nr5a2        exp_labelled_neuron Day14 Arx__Nr5a2
# 27  Day5.Arx__Nr5a2         exp_labelled_neuron Day5  Arx__Nr5a2
# 28  Dlk1                    exp_labelled_neuron all   Dlk1
# 29  Day14.Dlk1              exp_labelled_neuron Day14 Dlk1
# 30  Day5.Dlk1               exp_labelled_neuron Day5  Dlk1
# ⋮   ⋮                       ⋮                   ⋮     ⋮
# 124 Sst__Nts                exp_labelled_neuron all   Sst__Nts
# 125 Day14.Sst__Nts          exp_labelled_neuron Day14 Sst__Nts
# 126 Day5.Sst__Nts           exp_labelled_neuron Day5  Sst__Nts
# 127 Sst__Pthlh              exp_labelled_neuron all   Sst__Pthlh
# 128 Day14.Sst__Pthlh        exp_labelled_neuron Day14 Sst__Pthlh
# 129 Day5.Sst__Pthlh         exp_labelled_neuron Day5  Sst__Pthlh
# 130 Sst__Unc13c             exp_labelled_neuron all   Sst__Unc13c
# 131 Day14.Sst__Unc13c       exp_labelled_neuron Day14 Sst__Unc13c
# 132 Day5.Sst__Unc13c        exp_labelled_neuron Day5  Sst__Unc13c
# 133 Tbx19__Pirt             exp_labelled_neuron all   Tbx19__Pirt
# 134 Day14.Tbx19__Pirt       exp_labelled_neuron Day14 Tbx19__Pirt
# 135 Day5.Tbx19__Pirt        exp_labelled_neuron Day5  Tbx19__Pirt
# 136 Th__Nfib                exp_labelled_neuron all   Th__Nfib
# 137 Day14.Th__Nfib          exp_labelled_neuron Day14 Th__Nfib
# 138 Day5.Th__Nfib           exp_labelled_neuron Day5  Th__Nfib
# 139 Th__Slc6a3              exp_labelled_neuron all   Th__Slc6a3
# 140 Day14.Th__Slc6a3        exp_labelled_neuron Day14 Th__Slc6a3
# 141 Day5.Th__Slc6a3         exp_labelled_neuron Day5  Th__Slc6a3
# 142 Tmem215__Dach2          exp_labelled_neuron all   Tmem215__Dach2
# 143 Day14.Tmem215__Dach2    exp_labelled_neuron Day14 Tmem215__Dach2
# 144 Day5.Tmem215__Dach2     exp_labelled_neuron Day5  Tmem215__Dach2
# 145 Tmem215__Greb1          exp_labelled_neuron all   Tmem215__Greb1
# 146 Day14.Tmem215__Greb1    exp_labelled_neuron Day14 Tmem215__Greb1
# 147 Day5.Tmem215__Greb1     exp_labelled_neuron Day5  Tmem215__Greb1
# 148 Trh__Cxcl12             exp_labelled_neuron all   Trh__Cxcl12
# 149 Day14.Trh__Cxcl12       exp_labelled_neuron Day14 Trh__Cxcl12
# 150 Day5.Trh__Cxcl12        exp_labelled_neuron Day5  Trh__Cxcl12
# 151 Trh__Lef1               exp_labelled_neuron all   Trh__Lef1
# 152 Day14.Trh__Lef1         exp_labelled_neuron Day14 Trh__Lef1
# 153 Day5.Trh__Lef1          exp_labelled_neuron Day5  Trh__Lef1
#     milo_obj                     milo_index_obj
# 1   milo_Astrocytes              milo_index_tibble_Astrocytes
# 2   milo_Day14.Astrocytes        milo_index_tibble_Day14.Astrocytes
# 3   milo_Day5.Astrocytes         milo_index_tibble_Day5.Astrocytes
# 4   milo_Endothelial_cells       milo_index_tibble_Endothelial_cells
# 5   milo_Day14.Endothelial_cells milo_index_tibble_Day14.Endothelial_cells
# 6   milo_Day5.Endothelial_cells  milo_index_tibble_Day5.Endothelial_cells
# 7   milo_Ependymal_cells         milo_index_tibble_Ependymal_cells
# 8   milo_Day14.Ependymal_cells   milo_index_tibble_Day14.Ependymal_cells
# 9   milo_Day5.Ependymal_cells    milo_index_tibble_Day5.Ependymal_cells
# 10  milo_Microglia               milo_index_tibble_Microglia
# 11  milo_Day14.Microglia         milo_index_tibble_Day14.Microglia
# 12  milo_Day5.Microglia          milo_index_tibble_Day5.Microglia
# 13  milo_Oligodendrocytes        milo_index_tibble_Oligodendrocytes
# 14  milo_Day14.Oligodendrocytes  milo_index_tibble_Day14.Oligodendrocytes
# 15  milo_Day5.Oligodendrocytes   milo_index_tibble_Day5.Oligodendrocytes
# 16  milo_OPC                     milo_index_tibble_OPC
# 17  milo_Day14.OPC               milo_index_tibble_Day14.OPC
# 18  milo_Day5.OPC                milo_index_tibble_Day5.OPC
# 19  milo_Tanycytes               milo_index_tibble_Tanycytes
# 20  milo_Day14.Tanycytes         milo_index_tibble_Day14.Tanycytes
# 21  milo_Day5.Tanycytes          milo_index_tibble_Day5.Tanycytes
# 22  milo_Agrp                    milo_index_tibble_Agrp
# 23  milo_Day14.Agrp              milo_index_tibble_Day14.Agrp
# 24  milo_Day5.Agrp               milo_index_tibble_Day5.Agrp
# 25  milo_Arx__Nr5a2              milo_index_tibble_Arx__Nr5a2
# 26  milo_Day14.Arx__Nr5a2        milo_index_tibble_Day14.Arx__Nr5a2
# 27  milo_Day5.Arx__Nr5a2         milo_index_tibble_Day5.Arx__Nr5a2
# 28  milo_Dlk1                    milo_index_tibble_Dlk1
# 29  milo_Day14.Dlk1              milo_index_tibble_Day14.Dlk1
# 30  milo_Day5.Dlk1               milo_index_tibble_Day5.Dlk1
# ⋮   ⋮                            ⋮
# 124 milo_Sst__Nts                milo_index_tibble_Sst__Nts
# 125 milo_Day14.Sst__Nts          milo_index_tibble_Day14.Sst__Nts
# 126 milo_Day5.Sst__Nts           milo_index_tibble_Day5.Sst__Nts
# 127 milo_Sst__Pthlh              milo_index_tibble_Sst__Pthlh
# 128 milo_Day14.Sst__Pthlh        milo_index_tibble_Day14.Sst__Pthlh
# 129 milo_Day5.Sst__Pthlh         milo_index_tibble_Day5.Sst__Pthlh
# 130 milo_Sst__Unc13c             milo_index_tibble_Sst__Unc13c
# 131 milo_Day14.Sst__Unc13c       milo_index_tibble_Day14.Sst__Unc13c
# 132 milo_Day5.Sst__Unc13c        milo_index_tibble_Day5.Sst__Unc13c
# 133 milo_Tbx19__Pirt             milo_index_tibble_Tbx19__Pirt
# 134 milo_Day14.Tbx19__Pirt       milo_index_tibble_Day14.Tbx19__Pirt
# 135 milo_Day5.Tbx19__Pirt        milo_index_tibble_Day5.Tbx19__Pirt
# 136 milo_Th__Nfib                milo_index_tibble_Th__Nfib
# 137 milo_Day14.Th__Nfib          milo_index_tibble_Day14.Th__Nfib
# 138 milo_Day5.Th__Nfib           milo_index_tibble_Day5.Th__Nfib
# 139 milo_Th__Slc6a3              milo_index_tibble_Th__Slc6a3
# 140 milo_Day14.Th__Slc6a3        milo_index_tibble_Day14.Th__Slc6a3
# 141 milo_Day5.Th__Slc6a3         milo_index_tibble_Day5.Th__Slc6a3
# 142 milo_Tmem215__Dach2          milo_index_tibble_Tmem215__Dach2
# 143 milo_Day14.Tmem215__Dach2    milo_index_tibble_Day14.Tmem215__Dach2
# 144 milo_Day5.Tmem215__Dach2     milo_index_tibble_Day5.Tmem215__Dach2
# 145 milo_Tmem215__Greb1          milo_index_tibble_Tmem215__Greb1
# 146 milo_Day14.Tmem215__Greb1    milo_index_tibble_Day14.Tmem215__Greb1
# 147 milo_Day5.Tmem215__Greb1     milo_index_tibble_Day5.Tmem215__Greb1
# 148 milo_Trh__Cxcl12             milo_index_tibble_Trh__Cxcl12
# 149 milo_Day14.Trh__Cxcl12       milo_index_tibble_Day14.Trh__Cxcl12
# 150 milo_Day5.Trh__Cxcl12        milo_index_tibble_Day5.Trh__Cxcl12
# 151 milo_Trh__Lef1               milo_index_tibble_Trh__Lef1
# 152 milo_Day14.Trh__Lef1         milo_index_tibble_Day14.Trh__Lef1
# 153 milo_Day5.Trh__Lef1          milo_index_tibble_Day5.Trh__Lef1
#     design_df                         mm
# 1   design_df_Astrocytes              mm_Astrocytes
# 2   design_df_Day14.Astrocytes        mm_Day14.Astrocytes
# 3   design_df_Day5.Astrocytes         mm_Day5.Astrocytes
# 4   design_df_Endothelial_cells       mm_Endothelial_cells
# 5   design_df_Day14.Endothelial_cells mm_Day14.Endothelial_cells
# 6   design_df_Day5.Endothelial_cells  mm_Day5.Endothelial_cells
# 7   design_df_Ependymal_cells         mm_Ependymal_cells
# 8   design_df_Day14.Ependymal_cells   mm_Day14.Ependymal_cells
# 9   design_df_Day5.Ependymal_cells    mm_Day5.Ependymal_cells
# 10  design_df_Microglia               mm_Microglia
# 11  design_df_Day14.Microglia         mm_Day14.Microglia
# 12  design_df_Day5.Microglia          mm_Day5.Microglia
# 13  design_df_Oligodendrocytes        mm_Oligodendrocytes
# 14  design_df_Day14.Oligodendrocytes  mm_Day14.Oligodendrocytes
# 15  design_df_Day5.Oligodendrocytes   mm_Day5.Oligodendrocytes
# 16  design_df_OPC                     mm_OPC
# 17  design_df_Day14.OPC               mm_Day14.OPC
# 18  design_df_Day5.OPC                mm_Day5.OPC
# 19  design_df_Tanycytes               mm_Tanycytes
# 20  design_df_Day14.Tanycytes         mm_Day14.Tanycytes
# 21  design_df_Day5.Tanycytes          mm_Day5.Tanycytes
# 22  design_df_Agrp                    mm_Agrp
# 23  design_df_Day14.Agrp              mm_Day14.Agrp
# 24  design_df_Day5.Agrp               mm_Day5.Agrp
# 25  design_df_Arx__Nr5a2              mm_Arx__Nr5a2
# 26  design_df_Day14.Arx__Nr5a2        mm_Day14.Arx__Nr5a2
# 27  design_df_Day5.Arx__Nr5a2         mm_Day5.Arx__Nr5a2
# 28  design_df_Dlk1                    mm_Dlk1
# 29  design_df_Day14.Dlk1              mm_Day14.Dlk1
# 30  design_df_Day5.Dlk1               mm_Day5.Dlk1
# ⋮   ⋮                                 ⋮
# 124 design_df_Sst__Nts                mm_Sst__Nts
# 125 design_df_Day14.Sst__Nts          mm_Day14.Sst__Nts
# 126 design_df_Day5.Sst__Nts           mm_Day5.Sst__Nts
# 127 design_df_Sst__Pthlh              mm_Sst__Pthlh
# 128 design_df_Day14.Sst__Pthlh        mm_Day14.Sst__Pthlh
# 129 design_df_Day5.Sst__Pthlh         mm_Day5.Sst__Pthlh
# 130 design_df_Sst__Unc13c             mm_Sst__Unc13c
# 131 design_df_Day14.Sst__Unc13c       mm_Day14.Sst__Unc13c
# 132 design_df_Day5.Sst__Unc13c        mm_Day5.Sst__Unc13c
# 133 design_df_Tbx19__Pirt             mm_Tbx19__Pirt
# 134 design_df_Day14.Tbx19__Pirt       mm_Day14.Tbx19__Pirt
# 135 design_df_Day5.Tbx19__Pirt        mm_Day5.Tbx19__Pirt
# 136 design_df_Th__Nfib                mm_Th__Nfib
# 137 design_df_Day14.Th__Nfib          mm_Day14.Th__Nfib
# 138 design_df_Day5.Th__Nfib           mm_Day5.Th__Nfib
# 139 design_df_Th__Slc6a3              mm_Th__Slc6a3
# 140 design_df_Day14.Th__Slc6a3        mm_Day14.Th__Slc6a3
# 141 design_df_Day5.Th__Slc6a3         mm_Day5.Th__Slc6a3
# 142 design_df_Tmem215__Dach2          mm_Tmem215__Dach2
# 143 design_df_Day14.Tmem215__Dach2    mm_Day14.Tmem215__Dach2
# 144 design_df_Day5.Tmem215__Dach2     mm_Day5.Tmem215__Dach2
# 145 design_df_Tmem215__Greb1          mm_Tmem215__Greb1
# 146 design_df_Day14.Tmem215__Greb1    mm_Day14.Tmem215__Greb1
# 147 design_df_Day5.Tmem215__Greb1     mm_Day5.Tmem215__Greb1
# 148 design_df_Trh__Cxcl12             mm_Trh__Cxcl12
# 149 design_df_Day14.Trh__Cxcl12       mm_Day14.Trh__Cxcl12
# 150 design_df_Day5.Trh__Cxcl12        mm_Day5.Trh__Cxcl12
# 151 design_df_Trh__Lef1               mm_Trh__Lef1
# 152 design_df_Day14.Trh__Lef1         mm_Day14.Trh__Lef1
# 153 design_df_Day5.Trh__Lef1          mm_Day5.Trh__Lef1

# %%
contrasts_tibble = tibble(
    contrast_name = c("obob5v5",
                      "obob14v14",
                      "obobBL6",
                      "obobBL6d5",
                      "obobBL6d14",
                      "obob5vBL6",
                      "obob14vBL6",
                      "obobFGF1BL6d5",
                      "obobFGF1BL6d14",
                      "BL6d5d14",
                      "obobVeh_PFd5d14"),
    contrast = c("groupFGF1.Day5.obob - groupVeh_PF.Day5.obob",
                 "groupFGF1.Day14.obob - groupVeh_PF.Day14.obob",
                 "((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)",
                 "groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6",
                 "groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6",
                 "groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)",
                 "groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)",
                 "groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6",
                 "groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6",
                 "groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6",
                 "groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob")
)
contrasts_tibble
# Out:
#    contrast_name
# 1  obob5v5
# 2  obob14v14
# 3  obobBL6
# 4  obobBL6d5
# 5  obobBL6d14
# 6  obob5vBL6
# 7  obob14vBL6
# 8  obobFGF1BL6d5
# 9  obobFGF1BL6d14
# 10 BL6d5d14
# 11 obobVeh_PFd5d14
#    contrast
# 1  groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 2  groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 3  ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 4  groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 5  groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 6  groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 7  groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 8  groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 9  groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 10 groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 11 groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob

# %%
da_recipe = tidyr::crossing(clusters_tibble, contrasts_tibble)
da_recipe$label = paste0(da_recipe$label, '___', da_recipe$contrast_name)
head(da_recipe)
# Out:
#   label             object              day cluster milo_obj
# 1 Agrp___BL6d5d14   exp_labelled_neuron all Agrp    milo_Agrp
# 2 Agrp___obob14v14  exp_labelled_neuron all Agrp    milo_Agrp
# 3 Agrp___obob14vBL6 exp_labelled_neuron all Agrp    milo_Agrp
# 4 Agrp___obob5v5    exp_labelled_neuron all Agrp    milo_Agrp
# 5 Agrp___obob5vBL6  exp_labelled_neuron all Agrp    milo_Agrp
# 6 Agrp___obobBL6    exp_labelled_neuron all Agrp    milo_Agrp
#   milo_index_obj         design_df      mm      contrast_name
# 1 milo_index_tibble_Agrp design_df_Agrp mm_Agrp BL6d5d14
# 2 milo_index_tibble_Agrp design_df_Agrp mm_Agrp obob14v14
# 3 milo_index_tibble_Agrp design_df_Agrp mm_Agrp obob14vBL6
# 4 milo_index_tibble_Agrp design_df_Agrp mm_Agrp obob5v5
# 5 milo_index_tibble_Agrp design_df_Agrp mm_Agrp obob5vBL6
# 6 milo_index_tibble_Agrp design_df_Agrp mm_Agrp obobBL6
#   contrast
# 1 groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 2 groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 3 groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 4 groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 5 groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 6 ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)

# %%
da_recipe = da_recipe %>%
filter(!(str_detect(contrast_name, "obob5v5") & day == 'Day14')) %>%
filter(!(str_detect(contrast_name, "obob14v14") & day == 'Day5')) %>%
# filter(!(contrast_name == 'obobBL6' & day != 'all')) %>% # this one is good to have, as they may be equivalent
filter(!(contrast_name == 'obobBL6d5' & (day == 'Day14'))) %>%
filter(!(contrast_name == 'obobBL6d14' & (day == 'Day5'))) %>%
filter(!(contrast_name == 'obobFGF1BL6d5' & (day == 'Day14'))) %>% 
filter(!(contrast_name == 'obobFGF1BL6d14' & (day == 'Day5'))) %>%
filter(!(contrast_name == "obob5vBL6" & (day != 'all'))) %>% 
filter(!(contrast_name == "obob14vBL6" & (day != 'all'))) %>%
filter(!(contrast_name == 'BL6d5d14' & (day != 'all'))) %>%
filter(!(contrast_name == 'obobVeh_PFd5d14' & (day != 'all')))

# %%
da_recipe
# Out:
#     label                            object              day cluster
# 1   Agrp___BL6d5d14                  exp_labelled_neuron all Agrp
# 2   Agrp___obob14v14                 exp_labelled_neuron all Agrp
# 3   Agrp___obob14vBL6                exp_labelled_neuron all Agrp
# 4   Agrp___obob5v5                   exp_labelled_neuron all Agrp
# 5   Agrp___obob5vBL6                 exp_labelled_neuron all Agrp
# 6   Agrp___obobBL6                   exp_labelled_neuron all Agrp
# 7   Agrp___obobBL6d14                exp_labelled_neuron all Agrp
# 8   Agrp___obobBL6d5                 exp_labelled_neuron all Agrp
# 9   Agrp___obobFGF1BL6d14            exp_labelled_neuron all Agrp
# 10  Agrp___obobFGF1BL6d5             exp_labelled_neuron all Agrp
# 11  Agrp___obobVeh_PFd5d14           exp_labelled_neuron all Agrp
# 12  Arx__Nr5a2___BL6d5d14            exp_labelled_neuron all Arx__Nr5a2
# 13  Arx__Nr5a2___obob14v14           exp_labelled_neuron all Arx__Nr5a2
# 14  Arx__Nr5a2___obob14vBL6          exp_labelled_neuron all Arx__Nr5a2
# 15  Arx__Nr5a2___obob5v5             exp_labelled_neuron all Arx__Nr5a2
# 16  Arx__Nr5a2___obob5vBL6           exp_labelled_neuron all Arx__Nr5a2
# 17  Arx__Nr5a2___obobBL6             exp_labelled_neuron all Arx__Nr5a2
# 18  Arx__Nr5a2___obobBL6d14          exp_labelled_neuron all Arx__Nr5a2
# 19  Arx__Nr5a2___obobBL6d5           exp_labelled_neuron all Arx__Nr5a2
# 20  Arx__Nr5a2___obobFGF1BL6d14      exp_labelled_neuron all Arx__Nr5a2
# 21  Arx__Nr5a2___obobFGF1BL6d5       exp_labelled_neuron all Arx__Nr5a2
# 22  Arx__Nr5a2___obobVeh_PFd5d14     exp_labelled_neuron all Arx__Nr5a2
# 23  Astrocytes___BL6d5d14            exp_labelled_other  all Astrocytes
# 24  Astrocytes___obob14v14           exp_labelled_other  all Astrocytes
# 25  Astrocytes___obob14vBL6          exp_labelled_other  all Astrocytes
# 26  Astrocytes___obob5v5             exp_labelled_other  all Astrocytes
# 27  Astrocytes___obob5vBL6           exp_labelled_other  all Astrocytes
# 28  Astrocytes___obobBL6             exp_labelled_other  all Astrocytes
# 29  Astrocytes___obobBL6d14          exp_labelled_other  all Astrocytes
# 30  Astrocytes___obobBL6d5           exp_labelled_other  all Astrocytes
# ⋮   ⋮                                ⋮                   ⋮   ⋮
# 940 Tmem215__Greb1___obob5v5         exp_labelled_neuron all Tmem215__Greb1
# 941 Tmem215__Greb1___obob5vBL6       exp_labelled_neuron all Tmem215__Greb1
# 942 Tmem215__Greb1___obobBL6         exp_labelled_neuron all Tmem215__Greb1
# 943 Tmem215__Greb1___obobBL6d14      exp_labelled_neuron all Tmem215__Greb1
# 944 Tmem215__Greb1___obobBL6d5       exp_labelled_neuron all Tmem215__Greb1
# 945 Tmem215__Greb1___obobFGF1BL6d14  exp_labelled_neuron all Tmem215__Greb1
# 946 Tmem215__Greb1___obobFGF1BL6d5   exp_labelled_neuron all Tmem215__Greb1
# 947 Tmem215__Greb1___obobVeh_PFd5d14 exp_labelled_neuron all Tmem215__Greb1
# 948 Trh__Cxcl12___BL6d5d14           exp_labelled_neuron all Trh__Cxcl12
# 949 Trh__Cxcl12___obob14v14          exp_labelled_neuron all Trh__Cxcl12
# 950 Trh__Cxcl12___obob14vBL6         exp_labelled_neuron all Trh__Cxcl12
# 951 Trh__Cxcl12___obob5v5            exp_labelled_neuron all Trh__Cxcl12
# 952 Trh__Cxcl12___obob5vBL6          exp_labelled_neuron all Trh__Cxcl12
# 953 Trh__Cxcl12___obobBL6            exp_labelled_neuron all Trh__Cxcl12
# 954 Trh__Cxcl12___obobBL6d14         exp_labelled_neuron all Trh__Cxcl12
# 955 Trh__Cxcl12___obobBL6d5          exp_labelled_neuron all Trh__Cxcl12
# 956 Trh__Cxcl12___obobFGF1BL6d14     exp_labelled_neuron all Trh__Cxcl12
# 957 Trh__Cxcl12___obobFGF1BL6d5      exp_labelled_neuron all Trh__Cxcl12
# 958 Trh__Cxcl12___obobVeh_PFd5d14    exp_labelled_neuron all Trh__Cxcl12
# 959 Trh__Lef1___BL6d5d14             exp_labelled_neuron all Trh__Lef1
# 960 Trh__Lef1___obob14v14            exp_labelled_neuron all Trh__Lef1
# 961 Trh__Lef1___obob14vBL6           exp_labelled_neuron all Trh__Lef1
# 962 Trh__Lef1___obob5v5              exp_labelled_neuron all Trh__Lef1
# 963 Trh__Lef1___obob5vBL6            exp_labelled_neuron all Trh__Lef1
# 964 Trh__Lef1___obobBL6              exp_labelled_neuron all Trh__Lef1
# 965 Trh__Lef1___obobBL6d14           exp_labelled_neuron all Trh__Lef1
# 966 Trh__Lef1___obobBL6d5            exp_labelled_neuron all Trh__Lef1
# 967 Trh__Lef1___obobFGF1BL6d14       exp_labelled_neuron all Trh__Lef1
# 968 Trh__Lef1___obobFGF1BL6d5        exp_labelled_neuron all Trh__Lef1
# 969 Trh__Lef1___obobVeh_PFd5d14      exp_labelled_neuron all Trh__Lef1
#     milo_obj            milo_index_obj
# 1   milo_Agrp           milo_index_tibble_Agrp
# 2   milo_Agrp           milo_index_tibble_Agrp
# 3   milo_Agrp           milo_index_tibble_Agrp
# 4   milo_Agrp           milo_index_tibble_Agrp
# 5   milo_Agrp           milo_index_tibble_Agrp
# 6   milo_Agrp           milo_index_tibble_Agrp
# 7   milo_Agrp           milo_index_tibble_Agrp
# 8   milo_Agrp           milo_index_tibble_Agrp
# 9   milo_Agrp           milo_index_tibble_Agrp
# 10  milo_Agrp           milo_index_tibble_Agrp
# 11  milo_Agrp           milo_index_tibble_Agrp
# 12  milo_Arx__Nr5a2     milo_index_tibble_Arx__Nr5a2
# 13  milo_Arx__Nr5a2     milo_index_tibble_Arx__Nr5a2
# 14  milo_Arx__Nr5a2     milo_index_tibble_Arx__Nr5a2
# 15  milo_Arx__Nr5a2     milo_index_tibble_Arx__Nr5a2
# 16  milo_Arx__Nr5a2     milo_index_tibble_Arx__Nr5a2
# 17  milo_Arx__Nr5a2     milo_index_tibble_Arx__Nr5a2
# 18  milo_Arx__Nr5a2     milo_index_tibble_Arx__Nr5a2
# 19  milo_Arx__Nr5a2     milo_index_tibble_Arx__Nr5a2
# 20  milo_Arx__Nr5a2     milo_index_tibble_Arx__Nr5a2
# 21  milo_Arx__Nr5a2     milo_index_tibble_Arx__Nr5a2
# 22  milo_Arx__Nr5a2     milo_index_tibble_Arx__Nr5a2
# 23  milo_Astrocytes     milo_index_tibble_Astrocytes
# 24  milo_Astrocytes     milo_index_tibble_Astrocytes
# 25  milo_Astrocytes     milo_index_tibble_Astrocytes
# 26  milo_Astrocytes     milo_index_tibble_Astrocytes
# 27  milo_Astrocytes     milo_index_tibble_Astrocytes
# 28  milo_Astrocytes     milo_index_tibble_Astrocytes
# 29  milo_Astrocytes     milo_index_tibble_Astrocytes
# 30  milo_Astrocytes     milo_index_tibble_Astrocytes
# ⋮   ⋮                   ⋮
# 940 milo_Tmem215__Greb1 milo_index_tibble_Tmem215__Greb1
# 941 milo_Tmem215__Greb1 milo_index_tibble_Tmem215__Greb1
# 942 milo_Tmem215__Greb1 milo_index_tibble_Tmem215__Greb1
# 943 milo_Tmem215__Greb1 milo_index_tibble_Tmem215__Greb1
# 944 milo_Tmem215__Greb1 milo_index_tibble_Tmem215__Greb1
# 945 milo_Tmem215__Greb1 milo_index_tibble_Tmem215__Greb1
# 946 milo_Tmem215__Greb1 milo_index_tibble_Tmem215__Greb1
# 947 milo_Tmem215__Greb1 milo_index_tibble_Tmem215__Greb1
# 948 milo_Trh__Cxcl12    milo_index_tibble_Trh__Cxcl12
# 949 milo_Trh__Cxcl12    milo_index_tibble_Trh__Cxcl12
# 950 milo_Trh__Cxcl12    milo_index_tibble_Trh__Cxcl12
# 951 milo_Trh__Cxcl12    milo_index_tibble_Trh__Cxcl12
# 952 milo_Trh__Cxcl12    milo_index_tibble_Trh__Cxcl12
# 953 milo_Trh__Cxcl12    milo_index_tibble_Trh__Cxcl12
# 954 milo_Trh__Cxcl12    milo_index_tibble_Trh__Cxcl12
# 955 milo_Trh__Cxcl12    milo_index_tibble_Trh__Cxcl12
# 956 milo_Trh__Cxcl12    milo_index_tibble_Trh__Cxcl12
# 957 milo_Trh__Cxcl12    milo_index_tibble_Trh__Cxcl12
# 958 milo_Trh__Cxcl12    milo_index_tibble_Trh__Cxcl12
# 959 milo_Trh__Lef1      milo_index_tibble_Trh__Lef1
# 960 milo_Trh__Lef1      milo_index_tibble_Trh__Lef1
# 961 milo_Trh__Lef1      milo_index_tibble_Trh__Lef1
# 962 milo_Trh__Lef1      milo_index_tibble_Trh__Lef1
# 963 milo_Trh__Lef1      milo_index_tibble_Trh__Lef1
# 964 milo_Trh__Lef1      milo_index_tibble_Trh__Lef1
# 965 milo_Trh__Lef1      milo_index_tibble_Trh__Lef1
# 966 milo_Trh__Lef1      milo_index_tibble_Trh__Lef1
# 967 milo_Trh__Lef1      milo_index_tibble_Trh__Lef1
# 968 milo_Trh__Lef1      milo_index_tibble_Trh__Lef1
# 969 milo_Trh__Lef1      milo_index_tibble_Trh__Lef1
#     design_df                mm                contrast_name
# 1   design_df_Agrp           mm_Agrp           BL6d5d14
# 2   design_df_Agrp           mm_Agrp           obob14v14
# 3   design_df_Agrp           mm_Agrp           obob14vBL6
# 4   design_df_Agrp           mm_Agrp           obob5v5
# 5   design_df_Agrp           mm_Agrp           obob5vBL6
# 6   design_df_Agrp           mm_Agrp           obobBL6
# 7   design_df_Agrp           mm_Agrp           obobBL6d14
# 8   design_df_Agrp           mm_Agrp           obobBL6d5
# 9   design_df_Agrp           mm_Agrp           obobFGF1BL6d14
# 10  design_df_Agrp           mm_Agrp           obobFGF1BL6d5
# 11  design_df_Agrp           mm_Agrp           obobVeh_PFd5d14
# 12  design_df_Arx__Nr5a2     mm_Arx__Nr5a2     BL6d5d14
# 13  design_df_Arx__Nr5a2     mm_Arx__Nr5a2     obob14v14
# 14  design_df_Arx__Nr5a2     mm_Arx__Nr5a2     obob14vBL6
# 15  design_df_Arx__Nr5a2     mm_Arx__Nr5a2     obob5v5
# 16  design_df_Arx__Nr5a2     mm_Arx__Nr5a2     obob5vBL6
# 17  design_df_Arx__Nr5a2     mm_Arx__Nr5a2     obobBL6
# 18  design_df_Arx__Nr5a2     mm_Arx__Nr5a2     obobBL6d14
# 19  design_df_Arx__Nr5a2     mm_Arx__Nr5a2     obobBL6d5
# 20  design_df_Arx__Nr5a2     mm_Arx__Nr5a2     obobFGF1BL6d14
# 21  design_df_Arx__Nr5a2     mm_Arx__Nr5a2     obobFGF1BL6d5
# 22  design_df_Arx__Nr5a2     mm_Arx__Nr5a2     obobVeh_PFd5d14
# 23  design_df_Astrocytes     mm_Astrocytes     BL6d5d14
# 24  design_df_Astrocytes     mm_Astrocytes     obob14v14
# 25  design_df_Astrocytes     mm_Astrocytes     obob14vBL6
# 26  design_df_Astrocytes     mm_Astrocytes     obob5v5
# 27  design_df_Astrocytes     mm_Astrocytes     obob5vBL6
# 28  design_df_Astrocytes     mm_Astrocytes     obobBL6
# 29  design_df_Astrocytes     mm_Astrocytes     obobBL6d14
# 30  design_df_Astrocytes     mm_Astrocytes     obobBL6d5
# ⋮   ⋮                        ⋮                 ⋮
# 940 design_df_Tmem215__Greb1 mm_Tmem215__Greb1 obob5v5
# 941 design_df_Tmem215__Greb1 mm_Tmem215__Greb1 obob5vBL6
# 942 design_df_Tmem215__Greb1 mm_Tmem215__Greb1 obobBL6
# 943 design_df_Tmem215__Greb1 mm_Tmem215__Greb1 obobBL6d14
# 944 design_df_Tmem215__Greb1 mm_Tmem215__Greb1 obobBL6d5
# 945 design_df_Tmem215__Greb1 mm_Tmem215__Greb1 obobFGF1BL6d14
# 946 design_df_Tmem215__Greb1 mm_Tmem215__Greb1 obobFGF1BL6d5
# 947 design_df_Tmem215__Greb1 mm_Tmem215__Greb1 obobVeh_PFd5d14
# 948 design_df_Trh__Cxcl12    mm_Trh__Cxcl12    BL6d5d14
# 949 design_df_Trh__Cxcl12    mm_Trh__Cxcl12    obob14v14
# 950 design_df_Trh__Cxcl12    mm_Trh__Cxcl12    obob14vBL6
# 951 design_df_Trh__Cxcl12    mm_Trh__Cxcl12    obob5v5
# 952 design_df_Trh__Cxcl12    mm_Trh__Cxcl12    obob5vBL6
# 953 design_df_Trh__Cxcl12    mm_Trh__Cxcl12    obobBL6
# 954 design_df_Trh__Cxcl12    mm_Trh__Cxcl12    obobBL6d14
# 955 design_df_Trh__Cxcl12    mm_Trh__Cxcl12    obobBL6d5
# 956 design_df_Trh__Cxcl12    mm_Trh__Cxcl12    obobFGF1BL6d14
# 957 design_df_Trh__Cxcl12    mm_Trh__Cxcl12    obobFGF1BL6d5
# 958 design_df_Trh__Cxcl12    mm_Trh__Cxcl12    obobVeh_PFd5d14
# 959 design_df_Trh__Lef1      mm_Trh__Lef1      BL6d5d14
# 960 design_df_Trh__Lef1      mm_Trh__Lef1      obob14v14
# 961 design_df_Trh__Lef1      mm_Trh__Lef1      obob14vBL6
# 962 design_df_Trh__Lef1      mm_Trh__Lef1      obob5v5
# 963 design_df_Trh__Lef1      mm_Trh__Lef1      obob5vBL6
# 964 design_df_Trh__Lef1      mm_Trh__Lef1      obobBL6
# 965 design_df_Trh__Lef1      mm_Trh__Lef1      obobBL6d14
# 966 design_df_Trh__Lef1      mm_Trh__Lef1      obobBL6d5
# 967 design_df_Trh__Lef1      mm_Trh__Lef1      obobFGF1BL6d14
# 968 design_df_Trh__Lef1      mm_Trh__Lef1      obobFGF1BL6d5
# 969 design_df_Trh__Lef1      mm_Trh__Lef1      obobVeh_PFd5d14
#     contrast
# 1   groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 2   groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 3   groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 4   groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 5   groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 6   ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 7   groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 8   groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 9   groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 10  groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 11  groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob
# 12  groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 13  groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 14  groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 15  groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 16  groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 17  ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 18  groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 19  groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 20  groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 21  groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 22  groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob
# 23  groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 24  groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 25  groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 26  groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 27  groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 28  ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 29  groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 30  groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# ⋮   ⋮
# 940 groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 941 groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 942 ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 943 groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 944 groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 945 groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 946 groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 947 groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob
# 948 groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 949 groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 950 groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 951 groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 952 groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 953 ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 954 groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 955 groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 956 groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 957 groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 958 groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob
# 959 groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 960 groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 961 groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 962 groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 963 groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 964 ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 965 groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 966 groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 967 groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 968 groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 969 groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob

# %%
qs::qsave(da_recipe, 'da_recipe_lvl1.qs')
