# %%
library(targets)
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6      ✔ purrr   0.3.4
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.2      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
library(Seurat)

# %%
targets::tar_visnetwork()
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6      ✔ dplyr   1.0.10
# ✔ tibble  3.1.8      ✔ stringr 1.4.1
# ✔ readr   2.1.2      ✔ forcats 0.5.2
# ✔ purrr   0.3.4
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Loading required package: SummarizedExperiment
# Loading required package: MatrixGenerics
# Loading required package: matrixStats
#
# Attaching package: ‘matrixStats’
#
# The following object is masked from ‘package:dplyr’:
#
#     count
#
#
# Attaching package: ‘MatrixGenerics’
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
# ...

# %%
options()

# %%
gpdfb_neuron = qs::qread('_targets/objects/gpdfb_neuron')
gpdfb_neuron %>% write.csv('gpdf_neuron.csv')

# %%
tar_meta()

# %%
exp = qs::qread('_targets/objects/exp_RElabelled_neuron')
exp
# Out:
# Loading required package: SeuratObject
#
# Attaching sp
#
# Loading required package: Seurat
# An object of class Seurat
# 59227 features across 107464 samples within 3 assays
# Active assay: SCT (26906 features, 3000 variable features)
#  2 other assays present: RNA, integrated
#  2 dimensional reductions calculated: pca, umap

# %%
cell_ids = exp@meta.data %>% filter(strain == 'obob' & time == 'Day5') %>% rownames

# %%
exp_obob5v5 = subset(exp, cells=cell_ids)
exp_obob5v5
# Out:
# An object of class Seurat
# 59227 features across 44641 samples within 3 assays
# Active assay: SCT (26906 features, 3000 variable features)
#  2 other assays present: RNA, integrated
#  2 dimensional reductions calculated: pca, umap

# %%
exp = qs::qread('_targets/objects/exp_labelled_other')
cell_ids = exp@meta.data %>% filter(strain == 'obob' & time == 'Day5') %>% rownames
exp_obob5v5 = subset(exp, cells=cell_ids)
exp_obob5v5
# Out:
# An object of class Seurat
# 56583 features across 13594 samples within 3 assays
# Active assay: SCT (24262 features, 3000 variable features)
#  2 other assays present: RNA, integrated
#  2 dimensional reductions calculated: pca, umap

# %%
exp_obob5v5 %>% return
# Out:
# An object of class Seurat
# 56583 features across 13594 samples within 3 assays
# Active assay: SCT (24262 features, 3000 variable features)
#  2 other assays present: RNA, integrated
#  2 dimensional reductions calculated: pca, umap

# %%
AddMetaData(exp_obob5v5, 'blah', col.name = 'test')@meta.data
# Out:
#                      orig.ident nCount_RNA nFeature_RNA Index.10x nCount_HTO
# GTCCTCAAGCGAGGAG_1_1 SI-TT-A11  41375      6414         SI-TT-A11 2757
# CTTCGGTTCAGCTGAT_1_1 SI-TT-A11  40118      5968         SI-TT-A11 2558
# AATGACCCACAGAAGC_1_1 SI-TT-A11  28771      6022         SI-TT-A11 1698
# TAAGTCGCATGACTCA_1_1 SI-TT-A11  24078      4829         SI-TT-A11 1639
# GGTCTGGCAGCTCCTT_1_1 SI-TT-A11  21647      4381         SI-TT-A11 1902
# CTCGAGGCAGTCTGGC_1_1 SI-TT-A11  21926      4349         SI-TT-A11 1482
# GACCGTGAGCATGAAT_1_1 SI-TT-A11  20985      3796         SI-TT-A11 1667
# CTCTCAGGTATACGGG_1_1 SI-TT-A11  21792      4111         SI-TT-A11 1822
# AGTGATCTCGACTCCT_1_1 SI-TT-A11  20017      4202         SI-TT-A11 1690
# AATTTCCGTAACTAAG_1_1 SI-TT-A11  20107      4937         SI-TT-A11 1222
# GACAGCCCAAGCACCC_1_1 SI-TT-A11  18352      3869         SI-TT-A11 1686
# TAAGCGTAGGCAGTCA_1_1 SI-TT-A11  19346      4828         SI-TT-A11 1794
# ...

# %%
exp_obob5v5@meta.data
# Out:
#                      orig.ident nCount_RNA nFeature_RNA Index.10x nCount_HTO
# GTCCTCAAGCGAGGAG_1_1 SI-TT-A11  41375      6414         SI-TT-A11 2757
# CTTCGGTTCAGCTGAT_1_1 SI-TT-A11  40118      5968         SI-TT-A11 2558
# AATGACCCACAGAAGC_1_1 SI-TT-A11  28771      6022         SI-TT-A11 1698
# TAAGTCGCATGACTCA_1_1 SI-TT-A11  24078      4829         SI-TT-A11 1639
# GGTCTGGCAGCTCCTT_1_1 SI-TT-A11  21647      4381         SI-TT-A11 1902
# CTCGAGGCAGTCTGGC_1_1 SI-TT-A11  21926      4349         SI-TT-A11 1482
# GACCGTGAGCATGAAT_1_1 SI-TT-A11  20985      3796         SI-TT-A11 1667
# CTCTCAGGTATACGGG_1_1 SI-TT-A11  21792      4111         SI-TT-A11 1822
# AGTGATCTCGACTCCT_1_1 SI-TT-A11  20017      4202         SI-TT-A11 1690
# AATTTCCGTAACTAAG_1_1 SI-TT-A11  20107      4937         SI-TT-A11 1222
# GACAGCCCAAGCACCC_1_1 SI-TT-A11  18352      3869         SI-TT-A11 1686
# TAAGCGTAGGCAGTCA_1_1 SI-TT-A11  19346      4828         SI-TT-A11 1794
# ...

# %%
exp_obob5v5@meta.data
# Out:
# reexports                package:Seurat                R Documentation
#
# s
#
# n:
#
#      These objects are imported from other packages. Follow the links
#      below to see their documentation.
#
#      SeuratObject ‘AddMetaData’, ‘Assays’, ‘Cells’,
#           ‘CellsByIdentities’, ‘Command’, ‘CreateAssayObject’,
#           ‘CreateDimReducObject’, ‘CreateSeuratObject’, ‘DefaultAssay’,
#           ‘DefaultAssay<-’, ‘Distances’, ‘Embeddings’, ‘FetchData’,
#           ‘GetAssayData’, ‘GetImage’, ‘GetTissueCoordinates’,
#           ‘HVFInfo’, ‘Idents’, ‘Idents<-’, ‘Images’, ‘Index’,
#           ‘Index<-’, ‘Indices’, ‘IsGlobal’, ‘JS’, ‘JS<-’, ‘Key’,
#           ‘Key<-’, ‘Loadings’, ‘Loadings<-’, ‘LogSeuratCommand’,
#           ‘Misc’, ‘Misc<-’, ‘Neighbors’, ‘Project’, ‘Project<-’,
#           ‘Radius’, ‘Reductions’, ‘RenameCells’, ‘RenameIdents’,
#           ‘ReorderIdent’, ‘RowMergeSparseMatrices’, ‘SVFInfo’,
#           ‘SetAssayData’, ‘SetIdent’, ‘SpatiallyVariableFeatures’,
# ...

# %%
(44641 + 13594)/2
# Out:
# [1] 29117.5

# %%
sce = qs::qread('../genebasisr/_targets/objects/sce_ngo_00_all_40k')
sce
# Out:
# Loading required package: SingleCellExperiment
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘matrixStats’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     count
#
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
# ...

# %%
sce

# %%
.get_only_named_genes_vec = function(vec_of_genes){
    not_a_rik = vec_of_genes %>% stringr::str_ends("Rik") %>% `!`
    not_an_ensmusg = vec_of_genes %>% stringr::str_starts("ENSMUSG") %>% `!`
    not_a_Gm = vec_of_genes %>% stringr::str_starts("Gm\\d") %>% `!`
    not_4_or_more_digits = vec_of_genes %>% stringr::str_ends("\\d{4,}") %>% `!`
    only_named_genes = (not_a_rik & not_an_ensmusg & not_a_Gm & not_4_or_more_digits) %>% which
    vec_of_genes[only_named_genes]
}

# %%
sce_genes = rownames(logcounts(sce))

# %%
get_only_named_genes_vec(sce_genes)
# Out:
#     [1] "Lypla1"          "Tcea1"           "Atp6v1h"         "Oprk1"
#     [5] "Rb1cc1"          "Alkal1"          "St18"            "Pcmtd1"
#     [9] "Rrs1"            "Adhfe1"          "Vxn"             "Sgk3"
#    [13] "Mcmdc2"          "Cspp1"           "Prex2"           "Sulf1"
#    [17] "Xkr9"            "Kcnb2"           "Terf1"           "Rdh10"
#    [21] "Tmem70"          "Ly96"            "Gdap1"           "Pi15"
#    [25] "Crispld1"        "Tfap2d"          "Tfap2b"          "Lincmd1"
#    [29] "Paqr8"           "Efhc1"           "Tmem14a"         "Gsta3"
#    [33] "Khdc1a"          "Khdc1c"          "Khdc1b"          "B3gat2"
#    [37] "Col9a1"          "Lmbrd1"          "Khdrbs2"         "Rab23"
#    [41] "Dst"             "Imp4"            "Ptpn18"          "Cfc1"
#    [45] "Amer3"           "Arhgef4"         "Plekhb2"         "Hs6st1"
#    [49] "Arid5a"          "Fer1l5"          "Cnnm4"           "Cnnm3"
# ...

# %%
library(reticulate)

# %%
pd = import("pandas")

# %%
gpdfb_neuron = qs::qread('_targets/objects/gpdfb_neuron')
write.csv(gpdfb_neuron, 'blah.csv')

# %%
gpdfb_neuron = qs::qread('_targets/objects/gpdfb_neuron')
gpdfb_neuron = gpdfb_neuron %>% rowwise() %>% apply(2,as.character)
write.csv(gpdfb_neuron, 'blah.csv')

# %%
write.csv(gpdfb_neuron, 'blah.csv')

# %%
write.csv(tibble(gpdfb_neuron), 'blah.csv', row.names=FALSE)

# %%
gpdbf_neuron = apply(gpdfb_neuron,2,as.character)

# %%
write.csv(tibble(gpdfb_neuron), 'blah.csv')

# %%
gpdfb_neuron = qs::qread('_targets/objects/gpdfb_neuron')
gpdfb_neuron = gpdfb_neuron %>%
  tibble() %>%
  rowwise() %>% mutate(all_module_genes = paste0(all_module_genes, collapse=" ")) %>%
  rowwise() %>% mutate(intersections = paste0(intersections, collapse=" "))
head(gpdfb_neuron)
#gpdfb_neuron %>% write.csv('gpdf_neuron.csv')

# %%
head(gpdfb_neuron)

# %%
gpdfb_neuron = qs::qread('_targets/objects/gpdfb_neuron')
gpdfb_neuron = gpdfb_neuron %>%
  tibble()
a = gpdfb_neuron$all_module_genes[[1]]

# %%
paste0(a, collapse = '-----')

# %%
gpdfb_neuron = qs::qread('_targets/objects/gpdfb_neuron')
gpdfb_neuron = gpdfb_neuron %>%
  tibble() %>%
  mutate(all_module_genes = paste0(all_module_genes)) %>%
  mutate(intersections = paste0(intersections))
# gpdfb_neuron %>% write.csv('gpdf_neuron.csv')
gpdfb_neuron$all_module_genes[[5]]
gpdfb_neuron %>% write.csv('gpdf_neuron.csv')

# %%
head(gpdfb_neuron)

# %%
gpdfb_df = pd$DataFrame(gpdfb_neuron)
gpdfb_df

# %%
gpdfb_df$to_csv('blah.csv')

# %%
save_df = "import pandas as pd
df = r.gpdfb_neuron
df.to_csv('gp_neuron.csv', index=False)"
py_run_string(save_df)

# %%
gpdfb_other = qs::qread('_targets/objects/gpdfb_other')

# %%
save_df = "import pandas as pd
df = r.gpdfb_other
df.to_csv('gp_other.csv', index=False)"
py_run_string(save_df)

# %%
paste(unlist(gpdfb_neuron$all_module_genes[[5]]), collapse=' ')

# %%
gpdfb_neuron$all_module_genes[[5]]

# %%
dd

# %%
ttb_neuron = qs::qread('_targets/objects//ttb_neuron')
ttb_neuron = ttb_neuron %>% relocate(id, cluster_name, comparison)
save_df = "import pandas as pd
df = r.ttb_neuron
df.to_csv('degs_neuron.csv', index=False)"
py_run_string(save_df)

# %%
ttb_other = qs::qread('_targets/objects//ttb_other')
ttb_other = ttb_other %>% relocate(id, cluster_name, comparison)
save_df = "import pandas as pd
df = r.ttb_other
df.to_csv('degs_other.csv', index=False)"
py_run_string(save_df)

# %%
write_delim(gpdfb_neuron, 'gpdfb_neuron.csv')

# %%
paste(unlist(gpdfb_neuron$all_module_genes[[5]]), collapse=' ')

# %%
ttb_neuron = qs::qread('_targets/objects/ttb_neuron')

# %%
ttb_neuron_summary = ttb_neuron %>% filter(FDR < 0.05) %>% group_by(comparison, cluster_name) %>% summarise(n = n()) %>% arrange(desc(n))
ttb_neuron_summary %>% write.csv('ttb_neuron_summary.csv')
ttb_neuron_summary

# %%
ttb_other = qs::qread('_targets/objects/ttb_other')

# %%
ttb_other_summary = ttb_other %>% filter(FDR < 0.05) %>% group_by(comparison, cluster_name) %>% summarise(n = n()) %>% arrange(desc(n))
ttb_other_summary %>% write.csv('ttb_other_summary.csv')
ttb_other_summary

# %%
edger = qs::qread('_targets/objects/gpdf_neurons_obob_gpdf')
e = edger[[1]]
e$result

# %%
gpdfs = edger %>%
 keep( ~ !is.null(.x$result) ) %>%
 map(~.x$result) %>%
 data.table::rbindlist()

# %%
gpdfs

# %%
g = data.table::rbindlist(gpdfs)
g

# %%
gpdfs[[1]]

# %%
edger[[4]]

# %%
edger = qs::qread('_targets/objects/edger_obob_neuron_labels')
e = edger[[1]]
e$result

# %%
names_vec = edger %>% 
map(~.x$name) %>% 
names %>% 
map(~paste0(.x, '_blah'))
edger = rlang::set_names(edger, names_vec)

# %%
names(edger)

# %%
edger = qs::qread('_targets/objects/qlf_obob_neuron_labels')
e = edger[[1]]
e$result

# %%
edger = qs::qread('_targets/objects/top_tags_obob_neuron_labels')
e = edger[[1]]
e$result

# %%
top_tags_list = edger
top_tags_list_b = top_tags_list %>%
    keep( ~ !is.null(.x$result) ) %>%
    map(~.x$result) %>%
    map(function(item){
        item$table$comparison = item$comparison
        item$table$cluster_name = item$cluster_name
        item$table$id = rownames(item$table)
        item
        }) %>%
    map(~.x$table) %>%
    data.table::rbindlist()
top_tags_list_b

# %%
e$result$table %>%
filter(FDR < 0.05) %>%
rownames %>% list

# %%
list(c(1,2,3)) %>% rlang::set_names('a')

# %%
edger %>% 
map(~paste0(.x$result$cluster_name, '___', .x$result$comparison))

# %%
nulls = edger %>% keep( ~ is.null(.$result) )

# %%
length(nulls)

# %%
names(edger)

# %%
source('build_edger.R')

# %%
lev <- edger_cluster$result$modelmat
    mycontrasts = contrast_str_vec
    con = makeContrasts(contrasts=contrast_str_vec, levels=lev

# %%
q = .fit_qlf(e, c("groupFGF1.Day5-groupVeh_PF.Day5"))

# %%
contrasts_list_obob = c("groupFGF1.Day5-groupVeh_PF.Day5",
                   "groupFGF1.Day14-groupVeh_PF.Day14")
edger_contrasts_list = purrr::cross(list(edger=edger, contrasts_str=contrasts_list_obob))

# %%
edger_contrasts_list[[1]]

# %%
subset_exp_by_strain(obj, 'obob')

# %%
meta = obj@meta.data$hash.mcl.ID  filter(condition_1 == "FGF1") %>%
    select("condition_2", "strain") %>%
    unique()
meta

# %%
meta = 
    obj@meta.data %>%
    filter(condition_1 == "Veh_PF") %>%
    select("condition_2", "strain") %>%
    unique()
meta
