# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6      ✔ purrr   0.3.4
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.2      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
source("../00_preprocessing/splitwrapper.R")
source(paste0("../00_preprocessing/preprocessing.R"))
source(paste0("../01_milo/milo.R"))
source(paste0("../01_milo/milo_plotting.R"))
source(paste0("../00_bmp_preprocessing/bmp_preprocessing.R"))
source('../wgcna/wgcna_functions.R')

# %%
ME = qs::qread('_targets/objects/ME_MOL_bmp_only')
formula_str = '~0+group'
data_subset = 'bmp_only'

# %%
fit_limma_me(ME, formula_str)
# Out:
# Error in eval(ej, envir = levelsenv): object 'Veh_PF.Day5.obob' not found
# Traceback:
#
# 1. fit_limma_me(ME, formula_str)
# 2. limma::makeContrasts(contrasts = contrasts, levels = design)
# 3. eval(ej, envir = levelsenv)
# 4. eval(ej, envir = levelsenv)

# %%
    contrasts= tribble(
            ~"name", ~"expression",
            "Day5.obob.LDNvsVehicle", "LDN.Day5.obob - Vehicle.Day5.obob",
            "Day5.obob.VehiclevsVehPF", "Vehicle.Day5.obob - Veh_PF.Day5.obob",
            "Day5.obob.LDNvsFGF1", "LDN.Day5.obob - FGF1.Day5.obob",
            "Day5.obob.VehiclevsFGF1", "Vehicle.Day5.obob - FGF1.Day5.obob",
            "Day5.obob.FGF1vsVehPF", "FGF1.Day5.obob - Veh_PF.Day5.obob",
            "Day14.obob.FGF1vsVehPF", "FGF1.Day14.obob - Veh_PF.Day14.obob",
            "Day5vsDay14.BL6.VehPF", "Veh_PF.Day5.BL6 - Veh_PF.Day14.BL6",
            "Day5vsDay14.obob.VehPF", "Veh_PF.Day5.obob - Veh_PF.Day14.obob")

# %%
filter_contrasts(ME, contrasts)
# Out:
#   name                   expression
# 1 Day5.obob.LDNvsVehicle LDN.Day5.obob - Vehicle.Day5.obob

# %%
qs::qread('_targets/objects/top_table_Microglia_sct') %>%
filter(comparison == 'Day5.obob.LDNvsVehicle') %>%
filter(significant == TRUE)
# Out:
#   comparison             module            logFC     AveExpr       t
# 1 Day5.obob.LDNvsVehicle Microglia_sct_M04 0.0106516 -7.232087e-19 3.743786
#   P.Value      adj.P.Val   B         significant
# 1 0.0001870561 0.002805841 -1.226759 TRUE

# %%
qs::qread('_targets/objects/hubgenes_summary_Microglia_sct') %>% filter(str_detect(module_name, "M04"))
# Out:
#   label         module_name       module_size
# 1 Microglia_sct Microglia_sct_M04 231
#   genes
# ...

# %%
qs::qread('_targets/objects/gost_tt_summary_Microglia_sct') %>% filter(str_detect(module, "M04"))
# Out:
#     comparison             module            lm_logFC    lm_padj
# 1   Day5.obob.LDNvsVehicle Microglia_sct_M04 0.0106516   0.002805841
# 2   Day5.obob.LDNvsVehicle Microglia_sct_M04 0.0106516   0.002805841
# 3   Day5.obob.LDNvsVehicle Microglia_sct_M04 0.0106516   0.002805841
# 4   Day5.obob.LDNvsVehicle Microglia_sct_M04 0.0106516   0.002805841
# 5   Day5.obob.LDNvsVehicle Microglia_sct_M04 0.0106516   0.002805841
# 6   Day5.obob.LDNvsVehicle Microglia_sct_M04 0.0106516   0.002805841
# 7   Day5.obob.LDNvsVehicle Microglia_sct_M04 0.0106516   0.002805841
# 8   Day5.obob.LDNvsVehicle Microglia_sct_M04 0.0106516   0.002805841
# 9   Day5.obob.LDNvsVehicle Microglia_sct_M04 0.0106516   0.002805841
# 10  Day5.obob.LDNvsVehicle Microglia_sct_M04 0.0106516   0.002805841
# 11  Day5.obob.LDNvsVehicle Microglia_sct_M04 0.0106516   0.002805841
# 12  Day5.obob.LDNvsVehicle Microglia_sct_M04 0.0106516   0.002805841
# 13  Day5.obob.LDNvsVehicle Microglia_sct_M04 0.0106516   0.002805841
# ...
