# %%
from read_roi import read_roi_file
from read_roi import read_roi_zip
import pandas as pd

# %%
rois = read_roi_zip('/data/petar/fgf1/resolve/rois/32810-1377-slide3_D2-1_DAPI_dapi_ROIs.zip')

# %%
rois
# Out:
# OrderedDict([('Cell1_5915_2',
#               {'type': 'freehand',
#                'x': [5903, 5936, 5940, 5933, 5927, 5901, 5896, 5895, 5902],
#                'y': [0, 2, 13, 28, 31, 25, 16, 2, 1],
#                'n': 9,
#                'width': 0,
#                'name': 'Cell1_5915_2',
#                'position': 0}),
#              ('Cell2_9119_3',
#               {'type': 'freehand',
#                'x': [9102,
#                 9152,
#                 9152,
#                 9147,
#                 9141,
#                 9131,
#                 9106,
#                 9096,
#                 9091,
#                 9092,
#                 9101],
#                'y': [0, 2, 12, 23, 28, 30, 25, 18, 9, 2, 1],
#                'n': 11,
#                'width': 0,
#                'name': 'Cell2_9119_3',
#                'position': 0}),
#              ('Cell3_4110_5',
#               {'type': 'freehand',
# ...

# %%
cell_stats = pd.read_csv("/data/petar/fgf1/resolve/baysor_segmentation/32810-1377-slide3_D2-1_results_baysor_results/baysor_cell_stats.csv")
cell_stats.head()
# Out:
#              cell            x           y  n_transcripts  density  \
# 0  Cell1_3694_227  3694.326531  227.346939             49  0.04658
# 1  Cell2_3555_404  3555.257732  404.396907            194  0.02983
# 2  Cell3_3708_282  3708.444444  281.658730            126  0.02454
# 3  Cell4_3839_183  3839.312500  182.687500             48  0.01993
# 4  Cell5_3626_415  3626.315789  415.315789             38  0.03506
#
#    elongation    area  avg_confidence
# 0       1.679  1052.0          0.9835
# 1       2.921  6503.0          0.9781
# 2       2.829  5134.0          0.9747
# 3       3.181  2408.0          0.9449
# 4       2.315  1084.0          0.9822
