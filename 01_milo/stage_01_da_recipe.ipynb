# %%
library(tidyverse)
library(targets)
library(tarchetypes)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6      ✔ purrr   0.3.4
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.2      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
clusters_tibble = qs::qread('clusters_tibble.qs')

clusters_tibble$milo_obj = clusters_tibble %>%
    pull(label) %>%
    paste0("milo_", .) %>%
    rlang::syms()
clusters_tibble$milo_index_obj = clusters_tibble %>%
    pull(label) %>%
    paste0("milo_index_tibble_", .) %>%
    rlang::syms()
clusters_tibble$design_df = clusters_tibble %>%
    pull(label) %>%
    paste0("design_df_", .) %>%
    rlang::syms()
clusters_tibble$mm = clusters_tibble %>%
    pull(label) %>%
    paste0("mm_", .) %>%
    rlang::syms()
clusters_tibble
# Out:
#     label                            object              day
# 1   Astrocytes                       exp_labelled_other  all
# 2   Day14.Astrocytes                 exp_labelled_other  Day14
# 3   Day5.Astrocytes                  exp_labelled_other  Day5
# 4   a1_Tany__Astrocytes              exp_labelled_other  all
# 5   Day14.a1_Tany__Astrocytes        exp_labelled_other  Day14
# 6   Day5.a1_Tany__Astrocytes         exp_labelled_other  Day5
# 7   MOL                              exp_labelled_other  all
# 8   Day14.MOL                        exp_labelled_other  Day14
# 9   Day5.MOL                         exp_labelled_other  Day5
# 10  a2_Tanycytes                     exp_labelled_other  all
# 11  Day14.a2_Tanycytes               exp_labelled_other  Day14
# 12  Day5.a2_Tanycytes                exp_labelled_other  Day5
# 13  NG2_OPC2                         exp_labelled_other  all
# 14  Day14.NG2_OPC2                   exp_labelled_other  Day14
# 15  Day5.NG2_OPC2                    exp_labelled_other  Day5
# 16  a2_Tanycytes__b1_Tanycytes       exp_labelled_other  all
# 17  Day14.a2_Tanycytes__b1_Tanycytes exp_labelled_other  Day14
# 18  Day5.a2_Tanycytes__b1_Tanycytes  exp_labelled_other  Day5
# 19  b1_Tanycytes                     exp_labelled_other  all
# 20  Day14.b1_Tanycytes               exp_labelled_other  Day14
# 21  Day5.b1_Tanycytes                exp_labelled_other  Day5
# 22  b2_Tany                          exp_labelled_other  all
# 23  Day14.b2_Tany                    exp_labelled_other  Day14
# 24  Day5.b2_Tany                     exp_labelled_other  Day5
# 25  Microglia                        exp_labelled_other  all
# 26  Day14.Microglia                  exp_labelled_other  Day14
# 27  Day5.Microglia                   exp_labelled_other  Day5
# 28  Epend                            exp_labelled_other  all
# 29  Day14.Epend                      exp_labelled_other  Day14
# 30  Day5.Epend                       exp_labelled_other  Day5
# ⋮   ⋮                                ⋮                   ⋮
# 118 Th_Nfib__Arx_Nr5a2               exp_labelled_neuron all
# 119 Day14.Th_Nfib__Arx_Nr5a2         exp_labelled_neuron Day14
# 120 Day5.Th_Nfib__Arx_Nr5a2          exp_labelled_neuron Day5
# 121 Th_Slc6a3                        exp_labelled_neuron all
# 122 Day14.Th_Slc6a3                  exp_labelled_neuron Day14
# 123 Day5.Th_Slc6a3                   exp_labelled_neuron Day5
# 124 Tmem215                          exp_labelled_neuron all
# 125 Day14.Tmem215                    exp_labelled_neuron Day14
# 126 Day5.Tmem215                     exp_labelled_neuron Day5
# 127 Trh_Cxcl12                       exp_labelled_neuron all
# 128 Day14.Trh_Cxcl12                 exp_labelled_neuron Day14
# 129 Day5.Trh_Cxcl12                  exp_labelled_neuron Day5
# 130 Trh_Lef1                         exp_labelled_neuron all
# 131 Day14.Trh_Lef1                   exp_labelled_neuron Day14
# 132 Day5.Trh_Lef1                    exp_labelled_neuron Day5
# 133 Unassigned1.sc17.sc28            exp_labelled_neuron all
# 134 Day14.Unassigned1.sc17.sc28      exp_labelled_neuron Day14
# 135 Day5.Unassigned1.sc17.sc28       exp_labelled_neuron Day5
# 136 Unassigned1.sc37                 exp_labelled_neuron all
# 137 Day14.Unassigned1.sc37           exp_labelled_neuron Day14
# 138 Day5.Unassigned1.sc37            exp_labelled_neuron Day5
# 139 Unassigned1.sc39                 exp_labelled_neuron all
# 140 Day14.Unassigned1.sc39           exp_labelled_neuron Day14
# 141 Day5.Unassigned1.sc39            exp_labelled_neuron Day5
# 142 Unassigned2                      exp_labelled_neuron all
# 143 Day14.Unassigned2                exp_labelled_neuron Day14
# 144 Day5.Unassigned2                 exp_labelled_neuron Day5
# 145 Unassigned2__Rgs16_Vip           exp_labelled_neuron all
# 146 Unassigned2__Unassigned1         exp_labelled_neuron all
# 147 Day14.Unassigned2__Unassigned1   exp_labelled_neuron Day14
#     cluster                    milo_obj
# 1   Astrocytes                 milo_Astrocytes
# 2   Astrocytes                 milo_Day14.Astrocytes
# 3   Astrocytes                 milo_Day5.Astrocytes
# 4   a1_Tany__Astrocytes        milo_a1_Tany__Astrocytes
# 5   a1_Tany__Astrocytes        milo_Day14.a1_Tany__Astrocytes
# 6   a1_Tany__Astrocytes        milo_Day5.a1_Tany__Astrocytes
# 7   MOL                        milo_MOL
# 8   MOL                        milo_Day14.MOL
# 9   MOL                        milo_Day5.MOL
# 10  a2_Tanycytes               milo_a2_Tanycytes
# 11  a2_Tanycytes               milo_Day14.a2_Tanycytes
# 12  a2_Tanycytes               milo_Day5.a2_Tanycytes
# 13  NG2_OPC2                   milo_NG2_OPC2
# 14  NG2_OPC2                   milo_Day14.NG2_OPC2
# 15  NG2_OPC2                   milo_Day5.NG2_OPC2
# 16  a2_Tanycytes__b1_Tanycytes milo_a2_Tanycytes__b1_Tanycytes
# 17  a2_Tanycytes__b1_Tanycytes milo_Day14.a2_Tanycytes__b1_Tanycytes
# 18  a2_Tanycytes__b1_Tanycytes milo_Day5.a2_Tanycytes__b1_Tanycytes
# 19  b1_Tanycytes               milo_b1_Tanycytes
# 20  b1_Tanycytes               milo_Day14.b1_Tanycytes
# 21  b1_Tanycytes               milo_Day5.b1_Tanycytes
# 22  b2_Tany                    milo_b2_Tany
# 23  b2_Tany                    milo_Day14.b2_Tany
# 24  b2_Tany                    milo_Day5.b2_Tany
# 25  Microglia                  milo_Microglia
# 26  Microglia                  milo_Day14.Microglia
# 27  Microglia                  milo_Day5.Microglia
# 28  Epend                      milo_Epend
# 29  Epend                      milo_Day14.Epend
# 30  Epend                      milo_Day5.Epend
# ⋮   ⋮                          ⋮
# 118 Th_Nfib__Arx_Nr5a2         milo_Th_Nfib__Arx_Nr5a2
# 119 Th_Nfib__Arx_Nr5a2         milo_Day14.Th_Nfib__Arx_Nr5a2
# 120 Th_Nfib__Arx_Nr5a2         milo_Day5.Th_Nfib__Arx_Nr5a2
# 121 Th_Slc6a3                  milo_Th_Slc6a3
# 122 Th_Slc6a3                  milo_Day14.Th_Slc6a3
# 123 Th_Slc6a3                  milo_Day5.Th_Slc6a3
# 124 Tmem215                    milo_Tmem215
# 125 Tmem215                    milo_Day14.Tmem215
# 126 Tmem215                    milo_Day5.Tmem215
# 127 Trh_Cxcl12                 milo_Trh_Cxcl12
# 128 Trh_Cxcl12                 milo_Day14.Trh_Cxcl12
# 129 Trh_Cxcl12                 milo_Day5.Trh_Cxcl12
# 130 Trh_Lef1                   milo_Trh_Lef1
# 131 Trh_Lef1                   milo_Day14.Trh_Lef1
# 132 Trh_Lef1                   milo_Day5.Trh_Lef1
# 133 Unassigned1.sc17.sc28      milo_Unassigned1.sc17.sc28
# 134 Unassigned1.sc17.sc28      milo_Day14.Unassigned1.sc17.sc28
# 135 Unassigned1.sc17.sc28      milo_Day5.Unassigned1.sc17.sc28
# 136 Unassigned1.sc37           milo_Unassigned1.sc37
# 137 Unassigned1.sc37           milo_Day14.Unassigned1.sc37
# 138 Unassigned1.sc37           milo_Day5.Unassigned1.sc37
# 139 Unassigned1.sc39           milo_Unassigned1.sc39
# 140 Unassigned1.sc39           milo_Day14.Unassigned1.sc39
# 141 Unassigned1.sc39           milo_Day5.Unassigned1.sc39
# 142 Unassigned2                milo_Unassigned2
# 143 Unassigned2                milo_Day14.Unassigned2
# 144 Unassigned2                milo_Day5.Unassigned2
# 145 Unassigned2__Rgs16_Vip     milo_Unassigned2__Rgs16_Vip
# 146 Unassigned2__Unassigned1   milo_Unassigned2__Unassigned1
# 147 Unassigned2__Unassigned1   milo_Day14.Unassigned2__Unassigned1
#     milo_index_obj
# 1   milo_index_tibble_Astrocytes
# 2   milo_index_tibble_Day14.Astrocytes
# 3   milo_index_tibble_Day5.Astrocytes
# 4   milo_index_tibble_a1_Tany__Astrocytes
# 5   milo_index_tibble_Day14.a1_Tany__Astrocytes
# 6   milo_index_tibble_Day5.a1_Tany__Astrocytes
# 7   milo_index_tibble_MOL
# 8   milo_index_tibble_Day14.MOL
# 9   milo_index_tibble_Day5.MOL
# 10  milo_index_tibble_a2_Tanycytes
# 11  milo_index_tibble_Day14.a2_Tanycytes
# 12  milo_index_tibble_Day5.a2_Tanycytes
# 13  milo_index_tibble_NG2_OPC2
# 14  milo_index_tibble_Day14.NG2_OPC2
# 15  milo_index_tibble_Day5.NG2_OPC2
# 16  milo_index_tibble_a2_Tanycytes__b1_Tanycytes
# 17  milo_index_tibble_Day14.a2_Tanycytes__b1_Tanycytes
# 18  milo_index_tibble_Day5.a2_Tanycytes__b1_Tanycytes
# 19  milo_index_tibble_b1_Tanycytes
# 20  milo_index_tibble_Day14.b1_Tanycytes
# 21  milo_index_tibble_Day5.b1_Tanycytes
# 22  milo_index_tibble_b2_Tany
# 23  milo_index_tibble_Day14.b2_Tany
# 24  milo_index_tibble_Day5.b2_Tany
# 25  milo_index_tibble_Microglia
# 26  milo_index_tibble_Day14.Microglia
# 27  milo_index_tibble_Day5.Microglia
# 28  milo_index_tibble_Epend
# 29  milo_index_tibble_Day14.Epend
# 30  milo_index_tibble_Day5.Epend
# ⋮   ⋮
# 118 milo_index_tibble_Th_Nfib__Arx_Nr5a2
# 119 milo_index_tibble_Day14.Th_Nfib__Arx_Nr5a2
# 120 milo_index_tibble_Day5.Th_Nfib__Arx_Nr5a2
# 121 milo_index_tibble_Th_Slc6a3
# 122 milo_index_tibble_Day14.Th_Slc6a3
# 123 milo_index_tibble_Day5.Th_Slc6a3
# 124 milo_index_tibble_Tmem215
# 125 milo_index_tibble_Day14.Tmem215
# 126 milo_index_tibble_Day5.Tmem215
# 127 milo_index_tibble_Trh_Cxcl12
# 128 milo_index_tibble_Day14.Trh_Cxcl12
# 129 milo_index_tibble_Day5.Trh_Cxcl12
# 130 milo_index_tibble_Trh_Lef1
# 131 milo_index_tibble_Day14.Trh_Lef1
# 132 milo_index_tibble_Day5.Trh_Lef1
# 133 milo_index_tibble_Unassigned1.sc17.sc28
# 134 milo_index_tibble_Day14.Unassigned1.sc17.sc28
# 135 milo_index_tibble_Day5.Unassigned1.sc17.sc28
# 136 milo_index_tibble_Unassigned1.sc37
# 137 milo_index_tibble_Day14.Unassigned1.sc37
# 138 milo_index_tibble_Day5.Unassigned1.sc37
# 139 milo_index_tibble_Unassigned1.sc39
# 140 milo_index_tibble_Day14.Unassigned1.sc39
# 141 milo_index_tibble_Day5.Unassigned1.sc39
# 142 milo_index_tibble_Unassigned2
# 143 milo_index_tibble_Day14.Unassigned2
# 144 milo_index_tibble_Day5.Unassigned2
# 145 milo_index_tibble_Unassigned2__Rgs16_Vip
# 146 milo_index_tibble_Unassigned2__Unassigned1
# 147 milo_index_tibble_Day14.Unassigned2__Unassigned1
#     design_df
# 1   design_df_Astrocytes
# 2   design_df_Day14.Astrocytes
# 3   design_df_Day5.Astrocytes
# 4   design_df_a1_Tany__Astrocytes
# 5   design_df_Day14.a1_Tany__Astrocytes
# 6   design_df_Day5.a1_Tany__Astrocytes
# 7   design_df_MOL
# 8   design_df_Day14.MOL
# 9   design_df_Day5.MOL
# 10  design_df_a2_Tanycytes
# 11  design_df_Day14.a2_Tanycytes
# 12  design_df_Day5.a2_Tanycytes
# 13  design_df_NG2_OPC2
# 14  design_df_Day14.NG2_OPC2
# 15  design_df_Day5.NG2_OPC2
# 16  design_df_a2_Tanycytes__b1_Tanycytes
# 17  design_df_Day14.a2_Tanycytes__b1_Tanycytes
# 18  design_df_Day5.a2_Tanycytes__b1_Tanycytes
# 19  design_df_b1_Tanycytes
# 20  design_df_Day14.b1_Tanycytes
# 21  design_df_Day5.b1_Tanycytes
# 22  design_df_b2_Tany
# 23  design_df_Day14.b2_Tany
# 24  design_df_Day5.b2_Tany
# 25  design_df_Microglia
# 26  design_df_Day14.Microglia
# 27  design_df_Day5.Microglia
# 28  design_df_Epend
# 29  design_df_Day14.Epend
# 30  design_df_Day5.Epend
# ⋮   ⋮
# 118 design_df_Th_Nfib__Arx_Nr5a2
# 119 design_df_Day14.Th_Nfib__Arx_Nr5a2
# 120 design_df_Day5.Th_Nfib__Arx_Nr5a2
# 121 design_df_Th_Slc6a3
# 122 design_df_Day14.Th_Slc6a3
# 123 design_df_Day5.Th_Slc6a3
# 124 design_df_Tmem215
# 125 design_df_Day14.Tmem215
# 126 design_df_Day5.Tmem215
# 127 design_df_Trh_Cxcl12
# 128 design_df_Day14.Trh_Cxcl12
# 129 design_df_Day5.Trh_Cxcl12
# 130 design_df_Trh_Lef1
# 131 design_df_Day14.Trh_Lef1
# 132 design_df_Day5.Trh_Lef1
# 133 design_df_Unassigned1.sc17.sc28
# 134 design_df_Day14.Unassigned1.sc17.sc28
# 135 design_df_Day5.Unassigned1.sc17.sc28
# 136 design_df_Unassigned1.sc37
# 137 design_df_Day14.Unassigned1.sc37
# 138 design_df_Day5.Unassigned1.sc37
# 139 design_df_Unassigned1.sc39
# 140 design_df_Day14.Unassigned1.sc39
# 141 design_df_Day5.Unassigned1.sc39
# 142 design_df_Unassigned2
# 143 design_df_Day14.Unassigned2
# 144 design_df_Day5.Unassigned2
# 145 design_df_Unassigned2__Rgs16_Vip
# 146 design_df_Unassigned2__Unassigned1
# 147 design_df_Day14.Unassigned2__Unassigned1
#     mm
# 1   mm_Astrocytes
# 2   mm_Day14.Astrocytes
# 3   mm_Day5.Astrocytes
# 4   mm_a1_Tany__Astrocytes
# 5   mm_Day14.a1_Tany__Astrocytes
# 6   mm_Day5.a1_Tany__Astrocytes
# 7   mm_MOL
# 8   mm_Day14.MOL
# 9   mm_Day5.MOL
# 10  mm_a2_Tanycytes
# 11  mm_Day14.a2_Tanycytes
# 12  mm_Day5.a2_Tanycytes
# 13  mm_NG2_OPC2
# 14  mm_Day14.NG2_OPC2
# 15  mm_Day5.NG2_OPC2
# 16  mm_a2_Tanycytes__b1_Tanycytes
# 17  mm_Day14.a2_Tanycytes__b1_Tanycytes
# 18  mm_Day5.a2_Tanycytes__b1_Tanycytes
# 19  mm_b1_Tanycytes
# 20  mm_Day14.b1_Tanycytes
# 21  mm_Day5.b1_Tanycytes
# 22  mm_b2_Tany
# 23  mm_Day14.b2_Tany
# 24  mm_Day5.b2_Tany
# 25  mm_Microglia
# 26  mm_Day14.Microglia
# 27  mm_Day5.Microglia
# 28  mm_Epend
# 29  mm_Day14.Epend
# 30  mm_Day5.Epend
# ⋮   ⋮
# 118 mm_Th_Nfib__Arx_Nr5a2
# 119 mm_Day14.Th_Nfib__Arx_Nr5a2
# 120 mm_Day5.Th_Nfib__Arx_Nr5a2
# 121 mm_Th_Slc6a3
# 122 mm_Day14.Th_Slc6a3
# 123 mm_Day5.Th_Slc6a3
# 124 mm_Tmem215
# 125 mm_Day14.Tmem215
# 126 mm_Day5.Tmem215
# 127 mm_Trh_Cxcl12
# 128 mm_Day14.Trh_Cxcl12
# 129 mm_Day5.Trh_Cxcl12
# 130 mm_Trh_Lef1
# 131 mm_Day14.Trh_Lef1
# 132 mm_Day5.Trh_Lef1
# 133 mm_Unassigned1.sc17.sc28
# 134 mm_Day14.Unassigned1.sc17.sc28
# 135 mm_Day5.Unassigned1.sc17.sc28
# 136 mm_Unassigned1.sc37
# 137 mm_Day14.Unassigned1.sc37
# 138 mm_Day5.Unassigned1.sc37
# 139 mm_Unassigned1.sc39
# 140 mm_Day14.Unassigned1.sc39
# 141 mm_Day5.Unassigned1.sc39
# 142 mm_Unassigned2
# 143 mm_Day14.Unassigned2
# 144 mm_Day5.Unassigned2
# 145 mm_Unassigned2__Rgs16_Vip
# 146 mm_Unassigned2__Unassigned1
# 147 mm_Day14.Unassigned2__Unassigned1

# %%
contrasts_tibble = tibble(
    contrast_name = c("obob5v5",
                      "obob14v14",
                      "obobBL6",
                      "obobBL6d5",
                      "obobBL6d14",
                      "obob5vBL6",
                      "obob14vBL6",
                      "obobFGF1BL6d5",
                      "obobFGF1BL6d14",
                      "BL6d5d14",
                      "obobVeh_PFd5d14"),
    contrast = c("groupFGF1.Day5.obob - groupVeh_PF.Day5.obob",
                 "groupFGF1.Day14.obob - groupVeh_PF.Day14.obob",
                 "((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)",
                 "groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6",
                 "groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6",
                 "groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)",
                 "groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)",
                 "groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6",
                 "groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6",
                 "groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6",
                 "groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob")
)
contrasts_tibble
# Out:
#    contrast_name
# 1  obob5v5
# 2  obob14v14
# 3  obobBL6
# 4  obobBL6d5
# 5  obobBL6d14
# 6  obob5vBL6
# 7  obob14vBL6
# 8  obobFGF1BL6d5
# 9  obobFGF1BL6d14
# 10 BL6d5d14
# 11 obobVeh_PFd5d14
#    contrast
# 1  groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 2  groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 3  ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 4  groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 5  groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 6  groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 7  groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 8  groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 9  groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 10 groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 11 groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob

# %%
da_recipe = tidyr::crossing(clusters_tibble, contrasts_tibble)
da_recipe$label = paste0(da_recipe$label, '___', da_recipe$contrast_name)
head(da_recipe)
# Out:
#   label                            object             day cluster
# 1 a1_Tany__Astrocytes___BL6d5d14   exp_labelled_other all a1_Tany__Astrocytes
# 2 a1_Tany__Astrocytes___obob14v14  exp_labelled_other all a1_Tany__Astrocytes
# 3 a1_Tany__Astrocytes___obob14vBL6 exp_labelled_other all a1_Tany__Astrocytes
# 4 a1_Tany__Astrocytes___obob5v5    exp_labelled_other all a1_Tany__Astrocytes
# 5 a1_Tany__Astrocytes___obob5vBL6  exp_labelled_other all a1_Tany__Astrocytes
# 6 a1_Tany__Astrocytes___obobBL6    exp_labelled_other all a1_Tany__Astrocytes
#   milo_obj                 milo_index_obj
# 1 milo_a1_Tany__Astrocytes milo_index_tibble_a1_Tany__Astrocytes
# 2 milo_a1_Tany__Astrocytes milo_index_tibble_a1_Tany__Astrocytes
# 3 milo_a1_Tany__Astrocytes milo_index_tibble_a1_Tany__Astrocytes
# 4 milo_a1_Tany__Astrocytes milo_index_tibble_a1_Tany__Astrocytes
# 5 milo_a1_Tany__Astrocytes milo_index_tibble_a1_Tany__Astrocytes
# 6 milo_a1_Tany__Astrocytes milo_index_tibble_a1_Tany__Astrocytes
#   design_df                     mm                     contrast_name
# 1 design_df_a1_Tany__Astrocytes mm_a1_Tany__Astrocytes BL6d5d14
# 2 design_df_a1_Tany__Astrocytes mm_a1_Tany__Astrocytes obob14v14
# 3 design_df_a1_Tany__Astrocytes mm_a1_Tany__Astrocytes obob14vBL6
# 4 design_df_a1_Tany__Astrocytes mm_a1_Tany__Astrocytes obob5v5
# 5 design_df_a1_Tany__Astrocytes mm_a1_Tany__Astrocytes obob5vBL6
# 6 design_df_a1_Tany__Astrocytes mm_a1_Tany__Astrocytes obobBL6
#   contrast
# 1 groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 2 groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 3 groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 4 groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 5 groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 6 ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)

# %%
da_recipe = da_recipe %>%
filter(!(str_detect(contrast_name, "obob5v5") & day == 'Day14')) %>%
filter(!(str_detect(contrast_name, "obob14v14") & day == 'Day5')) %>%
filter(!(contrast_name == 'obobBL6' & day != 'all')) %>%
filter(!(contrast_name == 'obobBL6d5' & (day == 'Day14'))) %>%
filter(!(contrast_name == 'obobBL6d14' & (day == 'Day5'))) %>%
filter(!(contrast_name == 'obobFGF1BL6d5' & (day == 'Day14'))) %>% 
filter(!(contrast_name == 'obobFGF1BL6d14' & (day == 'Day5'))) %>%
filter(!(contrast_name == "obob5vBL6" & (day != 'all'))) %>% 
filter(!(contrast_name == "obob14vBL6" & (day != 'all'))) %>%
filter(!(contrast_name == 'BL6d5d14' & (day != 'all'))) %>%
filter(!(contrast_name == 'obobVeh_PFd5d14' & (day != 'all')))

# %%
da_recipe
# Out:
#     label                                      object              day
# 1   a1_Tany__Astrocytes___BL6d5d14             exp_labelled_other  all
# 2   a1_Tany__Astrocytes___obob14v14            exp_labelled_other  all
# 3   a1_Tany__Astrocytes___obob14vBL6           exp_labelled_other  all
# 4   a1_Tany__Astrocytes___obob5v5              exp_labelled_other  all
# 5   a1_Tany__Astrocytes___obob5vBL6            exp_labelled_other  all
# 6   a1_Tany__Astrocytes___obobBL6              exp_labelled_other  all
# 7   a1_Tany__Astrocytes___obobBL6d14           exp_labelled_other  all
# 8   a1_Tany__Astrocytes___obobBL6d5            exp_labelled_other  all
# 9   a1_Tany__Astrocytes___obobFGF1BL6d14       exp_labelled_other  all
# 10  a1_Tany__Astrocytes___obobFGF1BL6d5        exp_labelled_other  all
# 11  a1_Tany__Astrocytes___obobVeh_PFd5d14      exp_labelled_other  all
# 12  a2_Tanycytes___BL6d5d14                    exp_labelled_other  all
# 13  a2_Tanycytes___obob14v14                   exp_labelled_other  all
# 14  a2_Tanycytes___obob14vBL6                  exp_labelled_other  all
# 15  a2_Tanycytes___obob5v5                     exp_labelled_other  all
# 16  a2_Tanycytes___obob5vBL6                   exp_labelled_other  all
# 17  a2_Tanycytes___obobBL6                     exp_labelled_other  all
# 18  a2_Tanycytes___obobBL6d14                  exp_labelled_other  all
# 19  a2_Tanycytes___obobBL6d5                   exp_labelled_other  all
# 20  a2_Tanycytes___obobFGF1BL6d14              exp_labelled_other  all
# 21  a2_Tanycytes___obobFGF1BL6d5               exp_labelled_other  all
# 22  a2_Tanycytes___obobVeh_PFd5d14             exp_labelled_other  all
# 23  a2_Tanycytes__b1_Tanycytes___BL6d5d14      exp_labelled_other  all
# 24  a2_Tanycytes__b1_Tanycytes___obob14v14     exp_labelled_other  all
# 25  a2_Tanycytes__b1_Tanycytes___obob14vBL6    exp_labelled_other  all
# 26  a2_Tanycytes__b1_Tanycytes___obob5v5       exp_labelled_other  all
# 27  a2_Tanycytes__b1_Tanycytes___obob5vBL6     exp_labelled_other  all
# 28  a2_Tanycytes__b1_Tanycytes___obobBL6       exp_labelled_other  all
# 29  a2_Tanycytes__b1_Tanycytes___obobBL6d14    exp_labelled_other  all
# 30  a2_Tanycytes__b1_Tanycytes___obobBL6d5     exp_labelled_other  all
# ⋮   ⋮                                          ⋮                   ⋮
# 820 Unassigned2___obob5v5                      exp_labelled_neuron all
# 821 Unassigned2___obob5vBL6                    exp_labelled_neuron all
# 822 Unassigned2___obobBL6                      exp_labelled_neuron all
# 823 Unassigned2___obobBL6d14                   exp_labelled_neuron all
# 824 Unassigned2___obobBL6d5                    exp_labelled_neuron all
# 825 Unassigned2___obobFGF1BL6d14               exp_labelled_neuron all
# 826 Unassigned2___obobFGF1BL6d5                exp_labelled_neuron all
# 827 Unassigned2___obobVeh_PFd5d14              exp_labelled_neuron all
# 828 Unassigned2__Rgs16_Vip___BL6d5d14          exp_labelled_neuron all
# 829 Unassigned2__Rgs16_Vip___obob14v14         exp_labelled_neuron all
# 830 Unassigned2__Rgs16_Vip___obob14vBL6        exp_labelled_neuron all
# 831 Unassigned2__Rgs16_Vip___obob5v5           exp_labelled_neuron all
# 832 Unassigned2__Rgs16_Vip___obob5vBL6         exp_labelled_neuron all
# 833 Unassigned2__Rgs16_Vip___obobBL6           exp_labelled_neuron all
# 834 Unassigned2__Rgs16_Vip___obobBL6d14        exp_labelled_neuron all
# 835 Unassigned2__Rgs16_Vip___obobBL6d5         exp_labelled_neuron all
# 836 Unassigned2__Rgs16_Vip___obobFGF1BL6d14    exp_labelled_neuron all
# 837 Unassigned2__Rgs16_Vip___obobFGF1BL6d5     exp_labelled_neuron all
# 838 Unassigned2__Rgs16_Vip___obobVeh_PFd5d14   exp_labelled_neuron all
# 839 Unassigned2__Unassigned1___BL6d5d14        exp_labelled_neuron all
# 840 Unassigned2__Unassigned1___obob14v14       exp_labelled_neuron all
# 841 Unassigned2__Unassigned1___obob14vBL6      exp_labelled_neuron all
# 842 Unassigned2__Unassigned1___obob5v5         exp_labelled_neuron all
# 843 Unassigned2__Unassigned1___obob5vBL6       exp_labelled_neuron all
# 844 Unassigned2__Unassigned1___obobBL6         exp_labelled_neuron all
# 845 Unassigned2__Unassigned1___obobBL6d14      exp_labelled_neuron all
# 846 Unassigned2__Unassigned1___obobBL6d5       exp_labelled_neuron all
# 847 Unassigned2__Unassigned1___obobFGF1BL6d14  exp_labelled_neuron all
# 848 Unassigned2__Unassigned1___obobFGF1BL6d5   exp_labelled_neuron all
# 849 Unassigned2__Unassigned1___obobVeh_PFd5d14 exp_labelled_neuron all
#     cluster                    milo_obj
# 1   a1_Tany__Astrocytes        milo_a1_Tany__Astrocytes
# 2   a1_Tany__Astrocytes        milo_a1_Tany__Astrocytes
# 3   a1_Tany__Astrocytes        milo_a1_Tany__Astrocytes
# 4   a1_Tany__Astrocytes        milo_a1_Tany__Astrocytes
# 5   a1_Tany__Astrocytes        milo_a1_Tany__Astrocytes
# 6   a1_Tany__Astrocytes        milo_a1_Tany__Astrocytes
# 7   a1_Tany__Astrocytes        milo_a1_Tany__Astrocytes
# 8   a1_Tany__Astrocytes        milo_a1_Tany__Astrocytes
# 9   a1_Tany__Astrocytes        milo_a1_Tany__Astrocytes
# 10  a1_Tany__Astrocytes        milo_a1_Tany__Astrocytes
# 11  a1_Tany__Astrocytes        milo_a1_Tany__Astrocytes
# 12  a2_Tanycytes               milo_a2_Tanycytes
# 13  a2_Tanycytes               milo_a2_Tanycytes
# 14  a2_Tanycytes               milo_a2_Tanycytes
# 15  a2_Tanycytes               milo_a2_Tanycytes
# 16  a2_Tanycytes               milo_a2_Tanycytes
# 17  a2_Tanycytes               milo_a2_Tanycytes
# 18  a2_Tanycytes               milo_a2_Tanycytes
# 19  a2_Tanycytes               milo_a2_Tanycytes
# 20  a2_Tanycytes               milo_a2_Tanycytes
# 21  a2_Tanycytes               milo_a2_Tanycytes
# 22  a2_Tanycytes               milo_a2_Tanycytes
# 23  a2_Tanycytes__b1_Tanycytes milo_a2_Tanycytes__b1_Tanycytes
# 24  a2_Tanycytes__b1_Tanycytes milo_a2_Tanycytes__b1_Tanycytes
# 25  a2_Tanycytes__b1_Tanycytes milo_a2_Tanycytes__b1_Tanycytes
# 26  a2_Tanycytes__b1_Tanycytes milo_a2_Tanycytes__b1_Tanycytes
# 27  a2_Tanycytes__b1_Tanycytes milo_a2_Tanycytes__b1_Tanycytes
# 28  a2_Tanycytes__b1_Tanycytes milo_a2_Tanycytes__b1_Tanycytes
# 29  a2_Tanycytes__b1_Tanycytes milo_a2_Tanycytes__b1_Tanycytes
# 30  a2_Tanycytes__b1_Tanycytes milo_a2_Tanycytes__b1_Tanycytes
# ⋮   ⋮                          ⋮
# 820 Unassigned2                milo_Unassigned2
# 821 Unassigned2                milo_Unassigned2
# 822 Unassigned2                milo_Unassigned2
# 823 Unassigned2                milo_Unassigned2
# 824 Unassigned2                milo_Unassigned2
# 825 Unassigned2                milo_Unassigned2
# 826 Unassigned2                milo_Unassigned2
# 827 Unassigned2                milo_Unassigned2
# 828 Unassigned2__Rgs16_Vip     milo_Unassigned2__Rgs16_Vip
# 829 Unassigned2__Rgs16_Vip     milo_Unassigned2__Rgs16_Vip
# 830 Unassigned2__Rgs16_Vip     milo_Unassigned2__Rgs16_Vip
# 831 Unassigned2__Rgs16_Vip     milo_Unassigned2__Rgs16_Vip
# 832 Unassigned2__Rgs16_Vip     milo_Unassigned2__Rgs16_Vip
# 833 Unassigned2__Rgs16_Vip     milo_Unassigned2__Rgs16_Vip
# 834 Unassigned2__Rgs16_Vip     milo_Unassigned2__Rgs16_Vip
# 835 Unassigned2__Rgs16_Vip     milo_Unassigned2__Rgs16_Vip
# 836 Unassigned2__Rgs16_Vip     milo_Unassigned2__Rgs16_Vip
# 837 Unassigned2__Rgs16_Vip     milo_Unassigned2__Rgs16_Vip
# 838 Unassigned2__Rgs16_Vip     milo_Unassigned2__Rgs16_Vip
# 839 Unassigned2__Unassigned1   milo_Unassigned2__Unassigned1
# 840 Unassigned2__Unassigned1   milo_Unassigned2__Unassigned1
# 841 Unassigned2__Unassigned1   milo_Unassigned2__Unassigned1
# 842 Unassigned2__Unassigned1   milo_Unassigned2__Unassigned1
# 843 Unassigned2__Unassigned1   milo_Unassigned2__Unassigned1
# 844 Unassigned2__Unassigned1   milo_Unassigned2__Unassigned1
# 845 Unassigned2__Unassigned1   milo_Unassigned2__Unassigned1
# 846 Unassigned2__Unassigned1   milo_Unassigned2__Unassigned1
# 847 Unassigned2__Unassigned1   milo_Unassigned2__Unassigned1
# 848 Unassigned2__Unassigned1   milo_Unassigned2__Unassigned1
# 849 Unassigned2__Unassigned1   milo_Unassigned2__Unassigned1
#     milo_index_obj
# 1   milo_index_tibble_a1_Tany__Astrocytes
# 2   milo_index_tibble_a1_Tany__Astrocytes
# 3   milo_index_tibble_a1_Tany__Astrocytes
# 4   milo_index_tibble_a1_Tany__Astrocytes
# 5   milo_index_tibble_a1_Tany__Astrocytes
# 6   milo_index_tibble_a1_Tany__Astrocytes
# 7   milo_index_tibble_a1_Tany__Astrocytes
# 8   milo_index_tibble_a1_Tany__Astrocytes
# 9   milo_index_tibble_a1_Tany__Astrocytes
# 10  milo_index_tibble_a1_Tany__Astrocytes
# 11  milo_index_tibble_a1_Tany__Astrocytes
# 12  milo_index_tibble_a2_Tanycytes
# 13  milo_index_tibble_a2_Tanycytes
# 14  milo_index_tibble_a2_Tanycytes
# 15  milo_index_tibble_a2_Tanycytes
# 16  milo_index_tibble_a2_Tanycytes
# 17  milo_index_tibble_a2_Tanycytes
# 18  milo_index_tibble_a2_Tanycytes
# 19  milo_index_tibble_a2_Tanycytes
# 20  milo_index_tibble_a2_Tanycytes
# 21  milo_index_tibble_a2_Tanycytes
# 22  milo_index_tibble_a2_Tanycytes
# 23  milo_index_tibble_a2_Tanycytes__b1_Tanycytes
# 24  milo_index_tibble_a2_Tanycytes__b1_Tanycytes
# 25  milo_index_tibble_a2_Tanycytes__b1_Tanycytes
# 26  milo_index_tibble_a2_Tanycytes__b1_Tanycytes
# 27  milo_index_tibble_a2_Tanycytes__b1_Tanycytes
# 28  milo_index_tibble_a2_Tanycytes__b1_Tanycytes
# 29  milo_index_tibble_a2_Tanycytes__b1_Tanycytes
# 30  milo_index_tibble_a2_Tanycytes__b1_Tanycytes
# ⋮   ⋮
# 820 milo_index_tibble_Unassigned2
# 821 milo_index_tibble_Unassigned2
# 822 milo_index_tibble_Unassigned2
# 823 milo_index_tibble_Unassigned2
# 824 milo_index_tibble_Unassigned2
# 825 milo_index_tibble_Unassigned2
# 826 milo_index_tibble_Unassigned2
# 827 milo_index_tibble_Unassigned2
# 828 milo_index_tibble_Unassigned2__Rgs16_Vip
# 829 milo_index_tibble_Unassigned2__Rgs16_Vip
# 830 milo_index_tibble_Unassigned2__Rgs16_Vip
# 831 milo_index_tibble_Unassigned2__Rgs16_Vip
# 832 milo_index_tibble_Unassigned2__Rgs16_Vip
# 833 milo_index_tibble_Unassigned2__Rgs16_Vip
# 834 milo_index_tibble_Unassigned2__Rgs16_Vip
# 835 milo_index_tibble_Unassigned2__Rgs16_Vip
# 836 milo_index_tibble_Unassigned2__Rgs16_Vip
# 837 milo_index_tibble_Unassigned2__Rgs16_Vip
# 838 milo_index_tibble_Unassigned2__Rgs16_Vip
# 839 milo_index_tibble_Unassigned2__Unassigned1
# 840 milo_index_tibble_Unassigned2__Unassigned1
# 841 milo_index_tibble_Unassigned2__Unassigned1
# 842 milo_index_tibble_Unassigned2__Unassigned1
# 843 milo_index_tibble_Unassigned2__Unassigned1
# 844 milo_index_tibble_Unassigned2__Unassigned1
# 845 milo_index_tibble_Unassigned2__Unassigned1
# 846 milo_index_tibble_Unassigned2__Unassigned1
# 847 milo_index_tibble_Unassigned2__Unassigned1
# 848 milo_index_tibble_Unassigned2__Unassigned1
# 849 milo_index_tibble_Unassigned2__Unassigned1
#     design_df                            mm
# 1   design_df_a1_Tany__Astrocytes        mm_a1_Tany__Astrocytes
# 2   design_df_a1_Tany__Astrocytes        mm_a1_Tany__Astrocytes
# 3   design_df_a1_Tany__Astrocytes        mm_a1_Tany__Astrocytes
# 4   design_df_a1_Tany__Astrocytes        mm_a1_Tany__Astrocytes
# 5   design_df_a1_Tany__Astrocytes        mm_a1_Tany__Astrocytes
# 6   design_df_a1_Tany__Astrocytes        mm_a1_Tany__Astrocytes
# 7   design_df_a1_Tany__Astrocytes        mm_a1_Tany__Astrocytes
# 8   design_df_a1_Tany__Astrocytes        mm_a1_Tany__Astrocytes
# 9   design_df_a1_Tany__Astrocytes        mm_a1_Tany__Astrocytes
# 10  design_df_a1_Tany__Astrocytes        mm_a1_Tany__Astrocytes
# 11  design_df_a1_Tany__Astrocytes        mm_a1_Tany__Astrocytes
# 12  design_df_a2_Tanycytes               mm_a2_Tanycytes
# 13  design_df_a2_Tanycytes               mm_a2_Tanycytes
# 14  design_df_a2_Tanycytes               mm_a2_Tanycytes
# 15  design_df_a2_Tanycytes               mm_a2_Tanycytes
# 16  design_df_a2_Tanycytes               mm_a2_Tanycytes
# 17  design_df_a2_Tanycytes               mm_a2_Tanycytes
# 18  design_df_a2_Tanycytes               mm_a2_Tanycytes
# 19  design_df_a2_Tanycytes               mm_a2_Tanycytes
# 20  design_df_a2_Tanycytes               mm_a2_Tanycytes
# 21  design_df_a2_Tanycytes               mm_a2_Tanycytes
# 22  design_df_a2_Tanycytes               mm_a2_Tanycytes
# 23  design_df_a2_Tanycytes__b1_Tanycytes mm_a2_Tanycytes__b1_Tanycytes
# 24  design_df_a2_Tanycytes__b1_Tanycytes mm_a2_Tanycytes__b1_Tanycytes
# 25  design_df_a2_Tanycytes__b1_Tanycytes mm_a2_Tanycytes__b1_Tanycytes
# 26  design_df_a2_Tanycytes__b1_Tanycytes mm_a2_Tanycytes__b1_Tanycytes
# 27  design_df_a2_Tanycytes__b1_Tanycytes mm_a2_Tanycytes__b1_Tanycytes
# 28  design_df_a2_Tanycytes__b1_Tanycytes mm_a2_Tanycytes__b1_Tanycytes
# 29  design_df_a2_Tanycytes__b1_Tanycytes mm_a2_Tanycytes__b1_Tanycytes
# 30  design_df_a2_Tanycytes__b1_Tanycytes mm_a2_Tanycytes__b1_Tanycytes
# ⋮   ⋮                                    ⋮
# 820 design_df_Unassigned2                mm_Unassigned2
# 821 design_df_Unassigned2                mm_Unassigned2
# 822 design_df_Unassigned2                mm_Unassigned2
# 823 design_df_Unassigned2                mm_Unassigned2
# 824 design_df_Unassigned2                mm_Unassigned2
# 825 design_df_Unassigned2                mm_Unassigned2
# 826 design_df_Unassigned2                mm_Unassigned2
# 827 design_df_Unassigned2                mm_Unassigned2
# 828 design_df_Unassigned2__Rgs16_Vip     mm_Unassigned2__Rgs16_Vip
# 829 design_df_Unassigned2__Rgs16_Vip     mm_Unassigned2__Rgs16_Vip
# 830 design_df_Unassigned2__Rgs16_Vip     mm_Unassigned2__Rgs16_Vip
# 831 design_df_Unassigned2__Rgs16_Vip     mm_Unassigned2__Rgs16_Vip
# 832 design_df_Unassigned2__Rgs16_Vip     mm_Unassigned2__Rgs16_Vip
# 833 design_df_Unassigned2__Rgs16_Vip     mm_Unassigned2__Rgs16_Vip
# 834 design_df_Unassigned2__Rgs16_Vip     mm_Unassigned2__Rgs16_Vip
# 835 design_df_Unassigned2__Rgs16_Vip     mm_Unassigned2__Rgs16_Vip
# 836 design_df_Unassigned2__Rgs16_Vip     mm_Unassigned2__Rgs16_Vip
# 837 design_df_Unassigned2__Rgs16_Vip     mm_Unassigned2__Rgs16_Vip
# 838 design_df_Unassigned2__Rgs16_Vip     mm_Unassigned2__Rgs16_Vip
# 839 design_df_Unassigned2__Unassigned1   mm_Unassigned2__Unassigned1
# 840 design_df_Unassigned2__Unassigned1   mm_Unassigned2__Unassigned1
# 841 design_df_Unassigned2__Unassigned1   mm_Unassigned2__Unassigned1
# 842 design_df_Unassigned2__Unassigned1   mm_Unassigned2__Unassigned1
# 843 design_df_Unassigned2__Unassigned1   mm_Unassigned2__Unassigned1
# 844 design_df_Unassigned2__Unassigned1   mm_Unassigned2__Unassigned1
# 845 design_df_Unassigned2__Unassigned1   mm_Unassigned2__Unassigned1
# 846 design_df_Unassigned2__Unassigned1   mm_Unassigned2__Unassigned1
# 847 design_df_Unassigned2__Unassigned1   mm_Unassigned2__Unassigned1
# 848 design_df_Unassigned2__Unassigned1   mm_Unassigned2__Unassigned1
# 849 design_df_Unassigned2__Unassigned1   mm_Unassigned2__Unassigned1
#     contrast_name
# 1   BL6d5d14
# 2   obob14v14
# 3   obob14vBL6
# 4   obob5v5
# 5   obob5vBL6
# 6   obobBL6
# 7   obobBL6d14
# 8   obobBL6d5
# 9   obobFGF1BL6d14
# 10  obobFGF1BL6d5
# 11  obobVeh_PFd5d14
# 12  BL6d5d14
# 13  obob14v14
# 14  obob14vBL6
# 15  obob5v5
# 16  obob5vBL6
# 17  obobBL6
# 18  obobBL6d14
# 19  obobBL6d5
# 20  obobFGF1BL6d14
# 21  obobFGF1BL6d5
# 22  obobVeh_PFd5d14
# 23  BL6d5d14
# 24  obob14v14
# 25  obob14vBL6
# 26  obob5v5
# 27  obob5vBL6
# 28  obobBL6
# 29  obobBL6d14
# 30  obobBL6d5
# ⋮   ⋮
# 820 obob5v5
# 821 obob5vBL6
# 822 obobBL6
# 823 obobBL6d14
# 824 obobBL6d5
# 825 obobFGF1BL6d14
# 826 obobFGF1BL6d5
# 827 obobVeh_PFd5d14
# 828 BL6d5d14
# 829 obob14v14
# 830 obob14vBL6
# 831 obob5v5
# 832 obob5vBL6
# 833 obobBL6
# 834 obobBL6d14
# 835 obobBL6d5
# 836 obobFGF1BL6d14
# 837 obobFGF1BL6d5
# 838 obobVeh_PFd5d14
# 839 BL6d5d14
# 840 obob14v14
# 841 obob14vBL6
# 842 obob5v5
# 843 obob5vBL6
# 844 obobBL6
# 845 obobBL6d14
# 846 obobBL6d5
# 847 obobFGF1BL6d14
# 848 obobFGF1BL6d5
# 849 obobVeh_PFd5d14
#     contrast
# 1   groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 2   groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 3   groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 4   groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 5   groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 6   ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 7   groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 8   groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 9   groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 10  groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 11  groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob
# 12  groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 13  groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 14  groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 15  groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 16  groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 17  ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 18  groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 19  groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 20  groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 21  groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 22  groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob
# 23  groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 24  groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 25  groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 26  groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 27  groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 28  ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 29  groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 30  groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# ⋮   ⋮
# 820 groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 821 groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 822 ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 823 groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 824 groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 825 groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 826 groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 827 groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob
# 828 groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 829 groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 830 groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 831 groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 832 groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 833 ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 834 groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 835 groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 836 groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 837 groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 838 groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob
# 839 groupVeh_PF.Day5.BL6-groupVeh_PF.Day14.BL6
# 840 groupFGF1.Day14.obob - groupVeh_PF.Day14.obob
# 841 groupVeh_PF.Day14.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 842 groupFGF1.Day5.obob - groupVeh_PF.Day5.obob
# 843 groupVeh_PF.Day5.obob - ((groupVeh_PF.Day5.BL6 + groupVeh_PF.Day14.BL6)/2)
# 844 ((groupVeh_PF.Day5.obob+groupVeh_PF.Day14.obob)/2) - ((groupVeh_PF.Day5.BL6+groupVeh_PF.Day14.BL6)/2)
# 845 groupVeh_PF.Day14.obob - groupVeh_PF.Day14.BL6
# 846 groupVeh_PF.Day5.obob - groupVeh_PF.Day5.BL6
# 847 groupFGF1.Day14.obob - groupVeh_PF.Day14.BL6
# 848 groupFGF1.Day5.obob - groupVeh_PF.Day5.BL6
# 849 groupVeh_PF.Day5.obob-groupVeh_PF.Day14.obob

# %%
qs::qsave(da_recipe, 'da_recipe.qs')
