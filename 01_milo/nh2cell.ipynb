# %%
library(tidyverse)
library(Seurat)

# %%
da_results_nhg = qs::qread('_targets/objects/da_results_nhg_Agrp___all.obob5v5__v__all.obobBL6')
da_results_nhg %>% head

# %%
nhm = qs::qread('_targets/objects/nhm_Agrp___obob5v5')
nhm %>% head

# %%
exp = qs::qread('_targets/objects/obj_Agrp')
exp

# %%
selected_groups = c("none")
selected_nhoods = da_results_nhg %>% filter(restored_grouping %in% selected_groups) %>% pull(Nhood)

# %%
selected_cells = nhm[, selected_nhoods] %>% 
    rowSums %>% 
    enframe(name="cell_id", value="nhood_count") %>% 
    filter(nhood_count > 0) %>%
    distinct(cell_id) %>%
    pull(cell_id)

# %%
dim(nhm)

# %%
get_nhg_cells = function(da_results_nhg, nhm, selected_group){
    selected_nhoods = da_results_nhg %>% filter(restored_grouping == selected_group) %>% pull(Nhood)
    selected_cells = nhm[, selected_nhoods] %>% 
        rowSums %>% 
        enframe(name="cell_id", value="nhood_count") %>% 
        filter(nhood_count > 0) %>%
        distinct(cell_id) %>%
        pull(cell_id)
    selected_cells
}

# %%
get_nhg_cells(da_results_nhg, nhm, 'none') %>% length

# %%
get_cell_nh = function(nhm){
    nhm[1,] %>% colSums %>% enframe %>% filter(value > 0) %>% pull(name)
    }

# %%
get_cell_nh(nhm[1,])

# %%
annotate_nhg = function(da_results_nhg){
    nhg_annotation = da_results_nhg %>%
        select(Nhood, restored_grouping) %>%
        distinct %>%
        mutate(Nhood = as.character(Nhood))
    nhg_annotation
}

# %%
nhg_annotation = annotate_nhg(da_results_nhg)
nhg_annotation %>% head

# %%
summarise_nhg_annotation = function(nhg_annotation){
    grouping_summary = nhg_annotation %>% 
        group_by(restored_grouping) %>% 
        summarise(n = n()) %>%
        ungroup() %>%
        mutate(frac_nhoods = n/sum(n))
    grouping_summary
}

# %%
grouping_summary = summarise_nhg_annotation(nhg_annotation)
grouping_summary

# %%
nhg2cell = function(nhm, da_results_nhg) {
    nhg_annotation = annotate_nhg(da_results_nhg)
    grouping_summary = summarise_nhg_annotation(nhg_annotation)
    nhg_tib = nhm %>% 
        rownames_to_column %>% 
        pivot_longer(cols = !contains("row")) %>%
        rename(Nhood = name) %>%
        filter(value != 0) %>%
        select(-value) %>%
        left_join(nhg_annotation, by = "Nhood") %>%
        left_join(grouping_summary, by="restored_grouping") %>%
        select(-n) %>%
        select(-Nhood) %>%
        mutate(restored_grouping = as.factor(restored_grouping)) %>%
        group_by(rowname, restored_grouping) %>%
        mutate(group_weight = n() * (1-frac_nhoods)) %>%
        ungroup() %>%
        group_by(rowname) %>%
        mutate(total_count = n()) %>%
        ungroup() %>%
        distinct %>%
        mutate(weight = group_weight/total_count) %>%
        arrange(desc(weight)) %>%
        distinct(rowname, .keep_all = TRUE) %>%
        select(-group_weight, -total_count, -weight, -frac_nhoods) %>%
        mutate(fgf1_grouping = case_when( (str_detect(restored_grouping, "pos") & 
                                          !str_detect(restored_grouping, "BL6")) ~ "pos",
                                         (str_detect(restored_grouping, "neg") & 
                                          !str_detect(restored_grouping, "BL6")) ~ "neg",
                                         TRUE ~ "none")
              )
    nhg_tib
}


nhg2cell(nhm, da_results_nhg) %>% head

# %%
nhgc = nhg2cell(nhm, da_results_nhg)
nhgc %>% filter(!(restored_grouping %in% c("pos_restored", "none"))) %>% pull(restored_grouping) %>% as.character %>% unique

# %%
nhgc %>% filter(!(restored_grouping %in% c("pos_restored", "none"))) %>% pull(restored_grouping) %>% as.character %>% unique %>% paste0(collapse='.')
# Out:
# [1] "pos_FGF1.pos_away.neg_restored"

# %%
qs::qread("_targets/objects/obj_D")
# Out:
# Error in qs::qread(""): Failed to open . Check file path.
# Traceback:
#
# 1. qs::qread("")

# %%
get_seurat_nhg_markers = function(seurat_obj, nhgc, grouping_col, group_a, group_b='', tag=''){
    nhgc['grouping'] = nhgc[grouping_col]
    group_a = stringr::str_split(group_a, pattern=fixed('.')) %>% unlist
    cells_a = nhgc %>%
        filter(grouping %in% group_a) %>%
        pull(rowname)
    if (group_b == ''){
        group_b = nhgc %>%
            filter(!(grouping %in% group_a)) %>%
            pull(grouping) %>%
            as.character %>%
            unique %>%
            paste0(collapse='.')
    }
    group_b = stringr::str_split(group_b, pattern=fixed('.')) %>% unlist
    cells_b = nhgc %>%
        filter(grouping %in% group_b) %>%
        pull(rowname)
    markers = Seurat::FindMarkers(seurat_obj, ident.1=cells_a, ident.2=cells_b, slot="data", assay="SCT", verbose=TRUE,
                                  min.cells.group = 10, 
                                  min.cells.feature = 10,
                                  min.pct = 0.01,
                                  logfc.threshold = 0,
                                  only.pos = FALSE) 
    markers['tag'] = tag
    markers
}

# %%
add_gsea_cols_to_seurat_marker_results = function(sm_results){
    sm_results = sm_results %>% 
        rownames_to_column(var = "GeneID")
    converted = gprofiler2::gconvert(query = sm_results$GeneID,
                                     organism = "mmusculus",
                                     target = "ENSG",
                                     mthreshold = 1,
                                     filter_na = FALSE) %>%
                    mutate(ensmusg = target) %>%
                    mutate(GeneID = input) %>%
                    select(GeneID, ensmusg)
    sm_results = sm_results %>%
        left_join(converted) %>%
        distinct(ensmusg, .keep_all=TRUE) %>%
        mutate(gsea_sort_score = -log10(p_val_adj) * avg_log2FC) %>%
        arrange(desc(gsea_sort_score))
    sm_results
}

# %%
markers = get_seurat_nhg_markers(exp_neuron, nhgc, 'fgf1_grouping', c('pos'))

# %%
markers
# Out:
#     GeneID   p_val        avg_log2FC pct.1 pct.2 p_val_adj    tag
# 1   Cntn5    5.169331e-69  1.0138835 0.966 0.858 1.390860e-64
# 2   Tcf4     3.497004e-65 -0.6977552 0.923 0.981 9.409038e-61
# 3   Grik2    1.298251e-64  0.5743450 1.000 1.000 3.493075e-60
# 4   Enox1    1.005230e-50 -0.5525478 0.975 0.992 2.704671e-46
# 5   Fam189a1 4.541651e-43  0.4849314 0.978 0.930 1.221977e-38
# 6   Syt1     3.037669e-42  0.6642320 0.984 0.945 8.173152e-38
# 254 Sema5a   5.213197e-04 -0.3017553 0.385 0.440 1.0000000
# 255 Galnt17  5.911241e-04 -0.3189496 0.891 0.877 1.0000000
# 256 Prr16    7.432631e-04  0.3272373 0.518 0.470 1.0000000
# 257 Stxbp6   7.786370e-04 -0.2540760 0.125 0.172 1.0000000
# 258 Dach2    9.241694e-04  0.2581327 0.275 0.224 1.0000000
# 259 Kcnn2    9.718572e-04  0.3027821 0.387 0.344 1.0000000
# 260 Cntn3    5.946526e-03 -0.3724791 0.296 0.337 1.0000000
# 261 Igf1r    8.291975e-03  0.2823958 0.495 0.469 1.0000000
# 262 Ralyl    9.260364e-03 -0.2770021 0.871 0.884 1.0000000
# 263 Eda      1.269614e-02 -0.3515306 0.725 0.747 1.0000000
# 264 Zfp804b  1.403204e-02 -0.2530958 0.712 0.629 1.0000000
# 265 Kcnq5    1.688665e-02 -0.4157095 0.634 0.652 1.0000000
# 266 Prlr     4.781541e-02 -0.2810493 0.367 0.396 1.0000000
# 267 Epha6    2.956187e-01  0.3672882 0.492 0.508 1.0000000
# 268 Cdh13    2.981062e-01 -0.3334952 0.615 0.624 1.0000000
# 269 Sema6d   3.692897e-01 -0.5700488 0.757 0.709 1.0000000
# 270 Kcnh8    8.100096e-01 -0.3625406 0.431 0.404 1.0000000
# 271 Crb1     9.254594e-01  0.2612481 0.400 0.432 1.0000000

# %%
tibble(a = c(1,2,3), b=c('a', 'b', NULL))
# Out:
# Error:
# ! Tibble columns must have compatible sizes.
# • Size 3: Existing data.
# • Size 2: Column `b`.
# ℹ Only values of size one are recycled.
# Traceback:
#
# 1. tibble(a = c(1, 2, 3), b = c("a", "b", NULL))
# 2. tibble_quos(xs, .rows, .name_repair)
# 3. vectbl_recycle_rows(res, first_size, j, given_col_names[[j]])
# 4. cnd_signal(error_incompatible_size(n, name, size, "Existing data"))
# 5. signal_abort(cnd)

# %%
markers %>% 
    rownames_to_column(var = "GeneID") %>%
    mutate(gsea_sort_score = -log10(p_val_adj) * avg_log2FC) %>%
    arrange(desc(gsea_sort_score))
# Out:
#       GeneID             p_val        avg_log2FC pct.1 pct.2 p_val_adj    tag
# 1     Cntn5              3.145759e-69 1.0131910  0.970 0.854 6.764012e-65
# 2     Grik2              1.126015e-64 0.5741145  1.000 1.000 2.421157e-60
# 3     Nrg1               7.015045e-34 1.1658969  0.914 0.877 1.508375e-29
# 4     Schip1             6.444850e-31 1.1936295  0.927 0.925 1.385772e-26
# 5     Galntl6            3.133208e-37 0.8777898  0.908 0.839 6.737023e-33
# 6     Pde3a              7.189954e-36 0.8524434  0.486 0.283 1.545984e-31
# 7     Syt1               6.761176e-42 0.6641989  0.983 0.943 1.453788e-37
# 8     Thsd7b             3.465978e-26 1.1037375  0.379 0.224 7.452546e-22
# 9     Nell1              8.932171e-28 0.9327506  0.460 0.286 1.920595e-23
# 10    St18               7.775017e-33 0.7244896  0.582 0.388 1.671784e-28
# 11    Slc35f1            1.165568e-29 0.7662531  0.721 0.581 2.506205e-25
# 13005 Tcerg1l            4.607355e-22 -0.6428361 0.134 0.290 9.906735e-18
# 13006 Rmst               2.818240e-29 -0.5122960 0.818 0.930 6.059779e-25
# 13007 Ell2               1.426762e-24 -0.6621795 0.431 0.599 3.067823e-20
# 13008 Vcl                1.667393e-25 -0.6370597 0.565 0.687 3.585228e-21
# 13009 Pid1               4.213063e-24 -0.7837096 0.333 0.520 9.058927e-20
# 13010 ENSMUSG00000021745 2.344607e-25 -0.7505001 0.697 0.778 5.041374e-21
# 13011 Oxr1               4.929842e-33 -0.5711939 0.995 0.994 1.060015e-28
# 13012 Ntng1              1.574407e-26 -0.8825780 0.651 0.769 3.385291e-22
# 13013 Zfpm2              2.844736e-23 -1.2698921 0.176 0.338 6.116752e-19
# 13014 Enox1              1.232224e-50 -0.5513066 0.978 0.992 2.649528e-46
# 13015 Cntnap5c           1.356560e-26 -1.2154458 0.556 0.677 2.916875e-22
# 13016 Grik1              3.371500e-31 -1.0389960 0.346 0.552 7.249399e-27
# 13017 Grm7               6.303494e-25 -1.7079788 0.702 0.777 1.355377e-20
# 13018 Tcf4               4.055740e-65 -0.6965804 0.921 0.981 8.720652e-61
#       gsea_sort_score
# 1     65.016262
# 2     34.226398
# 3     33.602886
# 4     30.865239
# 5     28.239841
# 6     26.264458
# 7     24.467426
# 8     23.319430
# 9     21.188889
# 10    20.124017
# 11    18.850581
# 12    18.180380
# 13    18.070167
# 14    14.229295
# 15    14.100517
# 16    13.875880
# 17    13.555954
# 18    13.536434
# 19    13.271753
# 20    13.143645
# 21    12.451708
# 22    12.278046
# 23    12.052176
# 24    11.897879
# 25    11.387308
# 26    10.284988
# 27    10.252033
# 28    10.168604
# 29     9.917024
# 30     9.391910
# ⋮     ⋮
# 12989  -5.487115
# 12990  -5.956991
# 12991  -6.034824
# 12992  -6.256404
# 12993  -6.484267
# 12994  -6.792023
# 12995  -7.113174
# 12996  -7.790976
# 12997  -8.413841
# 12998  -8.548648
# 12999  -9.019797
# 13000  -9.223467
# 13001  -9.442164
# 13002  -9.560884
# 13003  -9.820281
# 13004 -10.724908
# 13005 -10.930830
# 13006 -12.406552
# 13007 -12.921221
# 13008 -13.024994
# 13009 -14.924121
# 13010 -15.233240
# 13011 -15.978971
# 13012 -18.949306
# 13013 -23.129153
# 13014 -25.126808
# 13015 -26.174725
# 13016 -27.159042
# 13017 -33.934019
# 13018 -41.836236

# %%
Sys.getpid()
# Out:
# [1] 7295

# %%
nhgc
# Out:
#      rowname              restored_grouping fgf1_grouping
# 1    TCATTTGCACTCACTC_1_2 pos_restored      pos
# 2    ATCAGGTGTCGCGTCA_2_1 pos_FGF1          pos
# 3    ATTACCTAGACCTCAT_4_1 pos_FGF1          pos
# 4    GTGTAACTCTTCCCGA_1_2 pos_FGF1          pos
# 5    TGCGGGTAGAATTTGG_1_2 pos_FGF1          pos
# 6    ACAAGCTAGCCGAATG_4_2 pos_FGF1          pos
# 7    TACTTCAAGTGGACTG_2_3 pos_FGF1          pos
# 8    TCCTCGAGTACGAAAT_3_3 pos_FGF1          pos
# 9    TGTTCTAAGGACAGCT_2_1 pos_away          pos
# 10   TCACTCGGTTCATCTT_2_1 pos_away          pos
# 11   CAGTTAGAGCGCTGAA_1_2 pos_away          pos
# 12   TAATCTCGTCGGCACT_3_3 pos_away          pos
# 13   TGACCCTAGTCCCTAA_3_3 pos_away          pos
# 14   GTGCGTGCACGCTATA_1_1 neg_restored      neg
# 15   CAGCAATCATAATGAG_2_1 neg_restored      neg
# 16   CCACCATGTGACTAAA_3_1 neg_restored      neg
# 17   TCCTCTTCAGGTGTGA_4_1 neg_restored      neg
# 18   CTAACTTTCACGGGAA_4_1 neg_restored      neg
# 19   AGAGCAGGTTGTCAGT_5_1 neg_restored      neg
# 20   ATAGAGAGTGAACGGT_5_1 neg_restored      neg
# 21   TTGACCCAGATTAGCA_1_2 neg_restored      neg
# 22   CGAGGCTTCCAACCGG_1_2 neg_restored      neg
# 23   TGATTTCCACGACAGA_2_2 neg_restored      neg
# 24   TAAGCCAGTCACCCTT_2_2 neg_restored      neg
# 25   AAAGGATTCGACCAAT_2_2 neg_restored      neg
# 26   GTAATCGAGTCACTGT_2_2 neg_restored      neg
# 27   TAATCTCAGGGATCGT_2_2 neg_restored      neg
# 28   ACGGTCGAGGTTATAG_2_2 neg_restored      neg
# 29   GTCCTCAGTCGCCTAG_3_2 neg_restored      neg
# 30   TTACGTTAGACCAGAC_3_2 neg_restored      neg
# ⋮    ⋮                    ⋮                 ⋮
# 4698 AACAACCGTGTGGTCC_5_1 neg_restored      neg
# 4699 TCTCCGAAGAGGATGA_1_1 none              none
# 4700 ACAGAAAAGATACAGT_2_1 none              none
# 4701 AGCGTATCAATTTCCT_3_1 none              none
# 4702 CTGTGGGTCCTCTCGA_4_1 none              none
# 4703 TTCAATCCAGACGGAT_5_1 none              none
# 4704 AGGGTGATCGATTTCT_5_1 none              none
# 4705 CTTCCGAGTTACCTGA_1_2 none              none
# 4706 CACTGAATCGGCATTA_1_2 none              none
# 4707 GTCCCATAGAGAACCC_1_2 none              none
# 4708 ATTCTTGGTGCACGCT_1_2 none              none
# 4709 CAGCAATAGTCTCCTC_1_2 none              none
# 4710 TTCTAACAGGAGACCT_1_2 none              none
# 4711 ATGGAGGAGTAATACG_2_2 none              none
# 4712 ACGGGTCGTATGCTAC_4_2 none              none
# 4713 GAGTTACTCTTGCAGA_4_2 none              none
# 4714 GCAACATCAACACAGG_5_2 none              none
# 4715 GACGTTACACCCTAGG_1_3 none              none
# 4716 GGGCTACAGCCTCTCT_2_3 none              none
# 4717 CCTACGTGTATCTTCT_2_3 none              none
# 4718 AGACACTTCATGCCCT_3_3 none              none
# 4719 ACCTGAAAGATCGCTT_4_3 none              none
# 4720 GTGTGGCGTTGGGAAC_4_3 none              none
# 4721 CTCTCGAGTTCGTAAC_5_3 none              none
# 4722 AGGCTGCTCATGGTAC_2_2 pos_restored      pos
# 4723 AATCGTGCATGGAGAC_3_2 none              none
# 4724 AGAAGTATCGCTTTAT_4_1 none              none
# 4725 TATCGCCCAGAGTTGG_2_2 none              none
# 4726 TGTGATGCACGTTGGC_4_2 none              none
# 4727 GCGGAAACATCCGGCA_2_3 none              none

# %%
nhm_long %>% group_by(restored_grouping) %>% summarise(n = n())

# %%
nhm_long %>% group_by(fgf_grouping) %>% summarise(n = n())

# %%
nhm_long %>% group_by(restored_grouping) %>% summarise(n = n())

# %%
none_cells = nhm_long %>% filter(restored_grouping == 'none') %>% pull(rowname)

# %%
exp_neuron = qs::qread('../00_preprocessing/_targets/objects/exp_labelled_neuron')
# exp_other = qs::qread('_targets/objects/obj_Agrp')

# %%
options(repr.plot.width=15, repr.plot.height=10)
DimPlot(exp_neuron, reduction = "umap", cells.highlight = none_cells, label = TRUE,  repel = TRUE)

# %%
neg_restored_cells = nhm_long %>% filter(restored_grouping == 'neg_restored') %>% pull(rowname)

# %%
options(repr.plot.width=15, repr.plot.height=10)
DimPlot(exp_neuron, reduction = "umap", cells.highlight = neg_restored_cells, label = TRUE,  repel = TRUE)

# %%
pos_restored_cells = nhm_long %>% filter(restored_grouping == 'pos_restored') %>% pull(rowname)

# %%
options(repr.plot.width=15, repr.plot.height=10)
DimPlot(exp_neuron, reduction = "umap", cells.highlight = pos_restored_cells, label = TRUE,  repel = TRUE)

# %%
pos_FGF1_cells = nhm_long %>% filter(restored_grouping == 'pos_FGF1') %>% pull(rowname)

# %%
options(repr.plot.width=15, repr.plot.height=10)
DimPlot(exp_neuron, reduction = "umap", cells.highlight = pos_FGF1_cells, label = TRUE,  repel = TRUE)

# %%
pos_away_cells = nhm_long %>% filter(restored_grouping == 'pos_away') %>% pull(rowname)

# %%
options(repr.plot.width=15, repr.plot.height=10)
DimPlot(exp_neuron, reduction = "umap", cells.highlight = pos_away_cells, label = TRUE,  repel = TRUE)

# %%
pos_restored_markers = Seurat::FindMarkers(exp_neuron, ident.1=pos_restored_cells, ident.2=none_cells, slot="data", assay="SCT", verbose=TRUE)
pos_restored_markers

# %%
top10g_markers = pos_restored_markers %>% filter(p_val_adj < 0.05) %>% rownames %>% head(9)
DefaultAssay(exp_neuron) = "RNA"
options(repr.plot.width=15, repr.plot.height=15)
fp = FeaturePlot(exp_neuron,
            features = top10g_markers,
           pt.size=5,
           order=TRUE,
           min.cutoff="q01",
           max.cutoff="q99",
           raster=TRUE,
           raster.dpi=c(1024, 1024),
           ncol=3
           )
fp

# %%
top10g_markers = pos_restored_markers %>% filter(p_val_adj < 0.05) %>% rownames %>% head(9)
DefaultAssay(exp) = "RNA"
options(repr.plot.width=15, repr.plot.height=15)
fp = FeaturePlot(exp,
            features = top10g_markers,
           pt.size=5,
           order=TRUE,
           min.cutoff="q01",
           max.cutoff="q99",
           raster=TRUE,
           raster.dpi=c(1024, 1024),
           ncol=3
           )
fp
