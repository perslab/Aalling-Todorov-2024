# %%
library(tidyverse)
library(targets)
library(tarchetypes)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.2     ✔ purrr   0.3.4
# ✔ tibble  3.2.1     ✔ dplyr   1.1.2
# ✔ tidyr   1.2.1     ✔ stringr 1.4.1
# ✔ readr   2.1.2     ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
all_restored_summary = qs::qread('_targets/objects/all_restored_summary')
all_restored_summary %>% filter(comparison == 'all.obob5v5__v__all.obobBL6') %>% arrange(desc(n_fgf1))
# Out:
#    labels                     n_total n_fgf1 n_fgf1.pos n_fgf1.neg
# 1  Astrocytes                  636    230    54         176
# 2  Htr3b                       238     77    28          49
# 3  MOL                         210     75    35          40
# 4  b1_Tanycytes                224     72    19          53
# 5  a1_Tany__Astrocytes         251     56    17          39
# 6  Trh_Lef1                    208     53    28          25
# 7  NG2_OPC2                    106     48    19          29
# 8  a2_Tanycytes                178     47    22          25
# 9  Agrp                        318     30    12          18
# 10 Sst_Unc13c__Agrp            208     24    10          14
# 11 Sst_Pthlh.sc23              145     20    20          NA
# 12 NFOL                         21     19    17           2
# 13 Microglia                    51     17    10           7
# 14 Pomc_Glipr1__Slc17a6_Trhr   233     13     2          11
# 15 Tmem215                     281     12     3           9
# 16 a2_Tanycytes__b1_Tanycytes  108     11     7           4
# 17 Ghrh                        139      8     4           4
# 18 Kisspeptin                  189      7     2           5
# 19 Rgs16_Dlx1                   95      7     1           6
# 20 Unassigned1.sc17.sc28       275      7     7          NA
# 21 b2_Tany                      80      3     2           1
# 22 Rgs16_Nmu                   292      3     2           1
# 23 Slc17a6_Trhr                177      2    NA           2
# 24 Th_Slc6a3                    48      2     1           1
# 25 Epend                        38      1     1          NA
# 26 Nr5a1_Bdnf                 1416      1    NA           1
# 27 Nr5a1_Nfib                  218      1    NA           1
# 28 Pomc_Lepr                   173      1     1          NA
# 29 Tbx19                       198      1    NA           1
# 30 Fibroblasts2__Fibroblasts3    7      0    NA          NA
# 31 Gm8773_Tac1__Hdc            130      0    NA          NA
# 32 Gpr50                        40      0    NA          NA
# 33 Mural_Cells2                  6      0    NA          NA
# 34 Nfix_Htr2c                  134      0    NA          NA
# 35 NG2_OPC2__Microglia          15      0    NA          NA
# 36 Nr5a1_Bdnf__Nr5a1_Nfib       87      0    NA          NA
# 37 Nr5a1_Bdnf__Unassigned1     147      0    NA          NA
# 38 Oxt__Unassigned1              5      0    NA          NA
# 39 Qrfp                         39      0    NA          NA
# 40 Rgs16_Dlx1__Unassigned2      98      0    NA          NA
# 41 Slc17a6_Fam19a2             322      0    NA          NA
# 42 Sst_Nts                      46      0    NA          NA
# 43 Sst_Pthlh__Ghrh              22      0    NA          NA
# 44 Sst_Pthlh.sc21              159      0    NA          NA
# 45 Th_Nfib__Arx_Nr5a2           98      0    NA          NA
# 46 Trh_Cxcl12                  266      0    NA          NA
# 47 Unassigned1.sc37             68      0    NA          NA
# 48 Unassigned1.sc39             67      0    NA          NA
# 49 Unassigned2                 864      0    NA          NA
# 50 Unassigned2__Rgs16_Vip        5      0    NA          NA
# 51 Unassigned2__Unassigned1     35      0    NA          NA
#    prop_fgf1.pos n_BL6 n_restored n_restored.pos n_restored.neg
# 1  0.2347826     446   157        25             132
# 2  0.3636364     114    17         2              15
# 3  0.4666667     158    62        26              36
# 4  0.2638889      34     7         2               5
# 5  0.3035714     109    29         3              26
# 6  0.5283019      10     1         1               0
# 7  0.3958333      55    24        13              11
# 8  0.4680851      29     5         3               2
# 9  0.4000000     302    22         4              18
# 10 0.4166667     142    15         2              13
# 11 1.0000000       0     0         0               0
# 12 0.8947368       3     3         3               0
# 13 0.5882353       7     2         0               2
# 14 0.1538462      98    10         1               9
# 15 0.2500000     141    10         1               9
# 16 0.6363636       6     2         1               1
# 17 0.5000000     101     6         2               4
# 18 0.2857143     131     7         2               5
# 19 0.1428571      15     2         0               2
# 20 1.0000000      35     1         1               0
# 21 0.6666667       1     0         0               0
# 22 0.6666667       0     0         0               0
# 23        NA       2     0         0               0
# 24 0.5000000      22     0         0               0
# 25 1.0000000       0     0         0               0
# 26        NA       2     0         0               0
# 27        NA       0     0         0               0
# 28 1.0000000      92     1         1               0
# 29        NA      42     1         0               1
# 30        NA       0     0         0               0
# 31        NA       1     0         0               0
# 32        NA      14     0         0               0
# 33        NA       0     0         0               0
# 34        NA       0     0         0               0
# 35        NA       0     0         0               0
# 36        NA       0     0         0               0
# 37        NA      16     0         0               0
# 38        NA       0     0         0               0
# 39        NA       0     0         0               0
# 40        NA       0     0         0               0
# 41        NA      31     0         0               0
# 42        NA       0     0         0               0
# 43        NA       2     0         0               0
# 44        NA       0     0         0               0
# 45        NA      45     0         0               0
# 46        NA     168     0         0               0
# 47        NA      13     0         0               0
# 48        NA       8     0         0               0
# 49        NA       0     0         0               0
# 50        NA       0     0         0               0
# 51        NA       0     0         0               0
#    prop_restored_BL6 prop_restored_FGF1 comparison
# 1  0.35201794        0.68260870         all.obob5v5__v__all.obobBL6
# 2  0.14912281        0.22077922         all.obob5v5__v__all.obobBL6
# 3  0.39240506        0.82666667         all.obob5v5__v__all.obobBL6
# 4  0.20588235        0.09722222         all.obob5v5__v__all.obobBL6
# 5  0.26605505        0.51785714         all.obob5v5__v__all.obobBL6
# 6  0.10000000        0.01886792         all.obob5v5__v__all.obobBL6
# 7  0.43636364        0.50000000         all.obob5v5__v__all.obobBL6
# 8  0.17241379        0.10638298         all.obob5v5__v__all.obobBL6
# 9  0.07284768        0.73333333         all.obob5v5__v__all.obobBL6
# 10 0.10563380        0.62500000         all.obob5v5__v__all.obobBL6
# 11        NaN        0.00000000         all.obob5v5__v__all.obobBL6
# 12 1.00000000        0.15789474         all.obob5v5__v__all.obobBL6
# 13 0.28571429        0.11764706         all.obob5v5__v__all.obobBL6
# 14 0.10204082        0.76923077         all.obob5v5__v__all.obobBL6
# 15 0.07092199        0.83333333         all.obob5v5__v__all.obobBL6
# 16 0.33333333        0.18181818         all.obob5v5__v__all.obobBL6
# 17 0.05940594        0.75000000         all.obob5v5__v__all.obobBL6
# 18 0.05343511        1.00000000         all.obob5v5__v__all.obobBL6
# 19 0.13333333        0.28571429         all.obob5v5__v__all.obobBL6
# 20 0.02857143        0.14285714         all.obob5v5__v__all.obobBL6
# 21 0.00000000        0.00000000         all.obob5v5__v__all.obobBL6
# 22        NaN        0.00000000         all.obob5v5__v__all.obobBL6
# 23 0.00000000        0.00000000         all.obob5v5__v__all.obobBL6
# 24 0.00000000        0.00000000         all.obob5v5__v__all.obobBL6
# 25        NaN        0.00000000         all.obob5v5__v__all.obobBL6
# 26 0.00000000        0.00000000         all.obob5v5__v__all.obobBL6
# 27        NaN        0.00000000         all.obob5v5__v__all.obobBL6
# 28 0.01086957        1.00000000         all.obob5v5__v__all.obobBL6
# 29 0.02380952        1.00000000         all.obob5v5__v__all.obobBL6
# 30        NaN               NaN         all.obob5v5__v__all.obobBL6
# 31 0.00000000               NaN         all.obob5v5__v__all.obobBL6
# 32 0.00000000               NaN         all.obob5v5__v__all.obobBL6
# 33        NaN               NaN         all.obob5v5__v__all.obobBL6
# 34        NaN               NaN         all.obob5v5__v__all.obobBL6
# 35        NaN               NaN         all.obob5v5__v__all.obobBL6
# 36        NaN               NaN         all.obob5v5__v__all.obobBL6
# 37 0.00000000               NaN         all.obob5v5__v__all.obobBL6
# 38        NaN               NaN         all.obob5v5__v__all.obobBL6
# 39        NaN               NaN         all.obob5v5__v__all.obobBL6
# 40        NaN               NaN         all.obob5v5__v__all.obobBL6
# 41 0.00000000               NaN         all.obob5v5__v__all.obobBL6
# 42        NaN               NaN         all.obob5v5__v__all.obobBL6
# 43 0.00000000               NaN         all.obob5v5__v__all.obobBL6
# 44        NaN               NaN         all.obob5v5__v__all.obobBL6
# 45 0.00000000               NaN         all.obob5v5__v__all.obobBL6
# 46 0.00000000               NaN         all.obob5v5__v__all.obobBL6
# 47 0.00000000               NaN         all.obob5v5__v__all.obobBL6
# 48 0.00000000               NaN         all.obob5v5__v__all.obobBL6
# 49        NaN               NaN         all.obob5v5__v__all.obobBL6
# 50        NaN               NaN         all.obob5v5__v__all.obobBL6
# 51        NaN               NaN         all.obob5v5__v__all.obobBL6

# %%
make_tags = function(all_restored_summary){
   all_restored_summary %>%
    rowwise %>%
    mutate(fgf1_tag = str_split(comparison, '__v__', n=2)[[1]][1]) %>% 
    mutate(bl6_tag = str_split(comparison, '__v__', n=2)[[1]][2]) %>%
    mutate(fgf1_day = str_split(fgf1_tag, fixed('.'), n=2)[[1]][1]) %>% 
    mutate(bl6_day = str_split(bl6_tag, fixed('.'), n=2)[[1]][1]) %>%
    mutate(fgf1_tag = str_split(fgf1_tag , fixed('.'), n=2)[[1]][2]) %>% 
    mutate(bl6_tag = str_split(bl6_tag , fixed('.'), n=2)[[1]][2]) %>%
    ungroup
}

# %%
neg_restored = all_restored_summary %>% 
filter(n_restored.neg > 0) %>% #commented out because I want all of these to be considered and output
make_tags %>%
select(labels, comparison, fgf1_tag, bl6_tag, fgf1_day, bl6_day) %>%
mutate(nhood_grouping = "restored_grouping") %>%
mutate(grouping_polarity = "neg_restored") 

neg_restored %>% head(3)
neg_restored %>% dim
# Out:
#   labels       comparison                       fgf1_tag  bl6_tag    fgf1_day
# 1 Microglia    all.obob14v14__v__all.obob14vBL6 obob14v14 obob14vBL6 all
# 2 b1_Tanycytes all.obob14v14__v__all.obob5vBL6  obob14v14 obob5vBL6  all
# 3 b1_Tanycytes all.obob14v14__v__all.obobBL6    obob14v14 obobBL6    all
#   bl6_day nhood_grouping    grouping_polarity
# 1 all     restored_grouping neg_restored
# 2 all     restored_grouping neg_restored
# 3 all     restored_grouping neg_restored
# [1] 96  8

# %%
pos_restored = all_restored_summary %>% 
filter(n_restored.pos > 0) %>%
make_tags %>%
select(labels, comparison, fgf1_tag, bl6_tag, fgf1_day, bl6_day) %>%
mutate(nhood_grouping = "restored_grouping") %>%
mutate(grouping_polarity = "pos_restored") 

pos_restored %>% head(3)
pos_restored %>% dim
# Out:
#   labels comparison                       fgf1_tag  bl6_tag    fgf1_day bl6_day
# 1 MOL    all.obob14v14__v__all.obob14vBL6 obob14v14 obob14vBL6 all      all
# 2 MOL    all.obob14v14__v__all.obob5vBL6  obob14v14 obob5vBL6  all      all
# 3 MOL    all.obob14v14__v__all.obobBL6    obob14v14 obobBL6    all      all
#   nhood_grouping    grouping_polarity
# 1 restored_grouping pos_restored
# 2 restored_grouping pos_restored
# 3 restored_grouping pos_restored
# [1] 87  8

# %%
neg_fgf1 = all_restored_summary %>% 
filter(n_fgf1.neg > 0) %>%
make_tags %>%
select(labels, comparison, fgf1_tag, bl6_tag, fgf1_day, bl6_day) %>%
mutate(nhood_grouping = "fgf1_grouping") %>%
mutate(grouping_polarity = "neg") 

neg_fgf1 %>% head(3)
neg_fgf1 %>% dim
# Out:
#   labels       comparison                       fgf1_tag  bl6_tag    fgf1_day
# 1 b1_Tanycytes all.obob14v14__v__all.obob14vBL6 obob14v14 obob14vBL6 all
# 2 NG2_OPC2     all.obob14v14__v__all.obob14vBL6 obob14v14 obob14vBL6 all
# 3 Microglia    all.obob14v14__v__all.obob14vBL6 obob14v14 obob14vBL6 all
#   bl6_day nhood_grouping grouping_polarity
# 1 all     fgf1_grouping  neg
# 2 all     fgf1_grouping  neg
# 3 all     fgf1_grouping  neg
# [1] 175   8

# %%
pos_fgf1 = all_restored_summary %>% 
filter(n_fgf1.pos > 0) %>%
make_tags %>%
select(labels, comparison, fgf1_tag, bl6_tag, fgf1_day, bl6_day) %>%
mutate(nhood_grouping = "fgf1_grouping") %>%
mutate(grouping_polarity = "pos") 

pos_fgf1 %>% head(3)
pos_fgf1 %>% dim
# Out:
#   labels       comparison                       fgf1_tag  bl6_tag    fgf1_day
# 1 b1_Tanycytes all.obob14v14__v__all.obob14vBL6 obob14v14 obob14vBL6 all
# 2 NG2_OPC2     all.obob14v14__v__all.obob14vBL6 obob14v14 obob14vBL6 all
# 3 b2_Tany      all.obob14v14__v__all.obob14vBL6 obob14v14 obob14vBL6 all
#   bl6_day nhood_grouping grouping_polarity
# 1 all     fgf1_grouping  pos
# 2 all     fgf1_grouping  pos
# 3 all     fgf1_grouping  pos
# [1] 181   8

# %%
d_BL6 = all_restored_summary %>% 
# filter(n_BL6 > 0) %>%
make_tags %>%
select(labels, comparison, fgf1_tag, bl6_tag, fgf1_day, bl6_day) %>%
mutate(nhood_grouping = "BL6") %>%
mutate(grouping_polarity = "pos") 

d_BL6 %>% head(3)
d_BL6 %>% dim
# Out:
#   labels       comparison                       fgf1_tag  bl6_tag    fgf1_day
# 1 b1_Tanycytes all.obob14v14__v__all.obob14vBL6 obob14v14 obob14vBL6 all
# 2 NG2_OPC2     all.obob14v14__v__all.obob14vBL6 obob14v14 obob14vBL6 all
# 3 b2_Tany      all.obob14v14__v__all.obob14vBL6 obob14v14 obob14vBL6 all
#   bl6_day nhood_grouping grouping_polarity
# 1 all     BL6            pos
# 2 all     BL6            pos
# 3 all     BL6            pos
# [1] 605   8

# %%
annotate_nh_grouping_recipe = rbind(pos_restored, neg_restored, pos_fgf1, neg_fgf1, d_BL6) %>%
mutate(milo_obj = paste0("milo_", fgf1_day, '.', labels)) %>%
mutate(milo_obj = str_replace(milo_obj, fixed("_all."), '_')) %>%
mutate(milo_obj = rlang::syms(milo_obj)) %>%
mutate(milo_index_tibble = milo_obj %>% str_replace('milo_', 'milo_index_tibble_') %>% rlang::syms(.)) %>%
mutate(seurat_obj = paste0("obj_", fgf1_day, '.', labels)) %>%
mutate(seurat_obj = str_replace(seurat_obj, fixed("_all."), '_')) %>%
mutate(seurat_obj = rlang::syms(seurat_obj)) %>%
mutate(da_results_obj = paste0("da_results_01_", fgf1_day, '.', labels, '___', fgf1_tag)) %>%
mutate(da_results_obj = str_replace(da_results_obj, fixed("_all."), '_')) %>%
mutate(da_results_obj = rlang::syms(da_results_obj)) %>%
mutate(nhm_obj = paste0("nhm_", fgf1_day, '.', labels, '___', fgf1_tag)) %>%
mutate(nhm_obj = str_replace(nhm_obj, fixed("_all."), '_')) %>%
mutate(nhm_obj = rlang::syms(nhm_obj)) %>%
mutate(restored_df_obj = paste0("restored_df_", comparison)) %>%
mutate(restored_df_obj = rlang::syms(restored_df_obj)) %>%
mutate(da_results_nhg_output_suffix = paste0(labels, '___', comparison)) %>%
relocate("da_results_nhg_output_suffix", "milo_obj", "seurat_obj", "nhm_obj", "da_results_obj", "restored_df_obj", "nhood_grouping", "grouping_polarity")



annotate_nh_grouping_recipe %>% head(3)
annotate_nh_grouping_recipe %>% dim

annotate_nh_grouping_recipe_unique_nhg = annotate_nh_grouping_recipe %>% 
    distinct(da_results_nhg_output_suffix, .keep_all = TRUE)
qs::qsave(annotate_nh_grouping_recipe_unique_nhg, 'annotate_nh_grouping_recipe.qs')
annotate_nh_grouping_recipe_unique_nhg %>% dim
# Out:
# Warning message:
# “There was 1 warning in `mutate()`.
# ℹ In argument: `milo_index_tibble = milo_obj %>% str_replace("milo_",
#   "milo_index_tibble_") %>% rlang::syms(.)`.
# Caused by warning in `stri_replace_first_regex()`:
# ! argument is not an atomic vector; coercing”
#   da_results_nhg_output_suffix           milo_obj seurat_obj
# 1 MOL___all.obob14v14__v__all.obob14vBL6 milo_MOL obj_MOL
# 2 MOL___all.obob14v14__v__all.obob5vBL6  milo_MOL obj_MOL
# 3 MOL___all.obob14v14__v__all.obobBL6    milo_MOL obj_MOL
#   nhm_obj             da_results_obj
# 1 nhm_MOL___obob14v14 da_results_01_MOL___obob14v14
# 2 nhm_MOL___obob14v14 da_results_01_MOL___obob14v14
# 3 nhm_MOL___obob14v14 da_results_01_MOL___obob14v14
#   restored_df_obj                              nhood_grouping
# 1 restored_df_all.obob14v14__v__all.obob14vBL6 restored_grouping
# 2 restored_df_all.obob14v14__v__all.obob5vBL6  restored_grouping
# 3 restored_df_all.obob14v14__v__all.obobBL6    restored_grouping
#   grouping_polarity labels comparison                       fgf1_tag
# 1 pos_restored      MOL    all.obob14v14__v__all.obob14vBL6 obob14v14
# 2 pos_restored      MOL    all.obob14v14__v__all.obob5vBL6  obob14v14
# 3 pos_restored      MOL    all.obob14v14__v__all.obobBL6    obob14v14
#   bl6_tag    fgf1_day bl6_day milo_index_tibble
# 1 obob14vBL6 all      all     milo_index_tibble_MOL
# 2 obob5vBL6  all      all     milo_index_tibble_MOL
# 3 obobBL6    all      all     milo_index_tibble_MOL
# [1] 1144   15
# [1] 605  15

# %%
deg_restored_recipe = annotate_nh_grouping_recipe %>%
mutate(da_results_nhg_obj = rlang::syms(paste0('da_results_nhg_', da_results_nhg_output_suffix))) %>%
mutate(nhgc_obj = rlang::syms(paste0('nhgc_', da_results_nhg_output_suffix))) %>%
rename(group_a = grouping_polarity) %>%
tidyr::crossing(tibble(group_b = c("", "none", "pos", "neg", "pos_restored", "neg_restored"))) %>%
filter(!(group_a == group_b)) %>%
filter(!( (nhood_grouping == 'restored_grouping') & (group_b %in% c("pos", "neg")) )) %>%
filter(!( (nhood_grouping == 'fgf1_grouping') & (group_b %in% c("pos_restored", "neg_restored")) )) %>%
filter(!( (group_a == 'neg_restored') & (group_b  == "pos_restored") )) %>%
filter(!( (group_a == 'neg') & (group_b  == "pos") )) %>%
mutate(group_b_suffix = case_when(group_b == "" ~ "rest",
                                  TRUE ~ group_b)) %>%
mutate(deg_output_suffix = paste0(da_results_nhg_output_suffix, '___', nhood_grouping, '.', group_a, '_vs_', group_b_suffix)) %>%
select(-group_b_suffix) %>%
relocate("deg_output_suffix", "da_results_nhg_obj", "group_a", "group_b", 'nhgc_obj')

deg_restored_recipe %>% head(3)
deg_restored_recipe %>% dim
qs::qsave(deg_restored_recipe, 'deg_restored_recipe.qs')
# Out:
#   deg_output_suffix
# 1 a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6___BL6.pos_vs_rest
# 2 a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6___BL6.pos_vs_neg
# 3 a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6___BL6.pos_vs_neg_restored
#   da_results_nhg_obj                                                    group_a
# 1 da_results_nhg_a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6 pos
# 2 da_results_nhg_a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6 pos
# 3 da_results_nhg_a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6 pos
#   group_b      nhgc_obj
# 1              nhgc_a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6
# 2 neg          nhgc_a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6
# 3 neg_restored nhgc_a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6
#   da_results_nhg_output_suffix
# 1 a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6
# 2 a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6
# 3 a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6
#   milo_obj                 seurat_obj
# 1 milo_a1_Tany__Astrocytes obj_a1_Tany__Astrocytes
# 2 milo_a1_Tany__Astrocytes obj_a1_Tany__Astrocytes
# 3 milo_a1_Tany__Astrocytes obj_a1_Tany__Astrocytes
#   nhm_obj
# 1 nhm_a1_Tany__Astrocytes___obob14v14
# 2 nhm_a1_Tany__Astrocytes___obob14v14
# 3 nhm_a1_Tany__Astrocytes___obob14v14
#   da_results_obj
# 1 da_results_01_a1_Tany__Astrocytes___obob14v14
# 2 da_results_01_a1_Tany__Astrocytes___obob14v14
# 3 da_results_01_a1_Tany__Astrocytes___obob14v14
#   restored_df_obj                              nhood_grouping
# 1 restored_df_all.obob14v14__v__all.obob14vBL6 BL6
# 2 restored_df_all.obob14v14__v__all.obob14vBL6 BL6
# 3 restored_df_all.obob14v14__v__all.obob14vBL6 BL6
#   labels              comparison                       fgf1_tag  bl6_tag
# 1 a1_Tany__Astrocytes all.obob14v14__v__all.obob14vBL6 obob14v14 obob14vBL6
# 2 a1_Tany__Astrocytes all.obob14v14__v__all.obob14vBL6 obob14v14 obob14vBL6
# 3 a1_Tany__Astrocytes all.obob14v14__v__all.obob14vBL6 obob14v14 obob14vBL6
#   fgf1_day bl6_day milo_index_tibble
# 1 all      all     milo_index_tibble_a1_Tany__Astrocytes
# 2 all      all     milo_index_tibble_a1_Tany__Astrocytes
# 3 all      all     milo_index_tibble_a1_Tany__Astrocytes
# [1] 4371   19

# %%
deg_restored_recipe %>%
filter(labels == 'MOL') %>%
filter(comparison == 'Day14.obob14v14__v__Day14.obobBL6d14')
# Out:
#   deg_output_suffix
# 1 MOL___Day14.obob14v14__v__Day14.obobBL6d14___BL6.pos_vs_rest
# 2 MOL___Day14.obob14v14__v__Day14.obobBL6d14___BL6.pos_vs_neg
# 3 MOL___Day14.obob14v14__v__Day14.obobBL6d14___BL6.pos_vs_neg_restored
# 4 MOL___Day14.obob14v14__v__Day14.obobBL6d14___BL6.pos_vs_none
# 5 MOL___Day14.obob14v14__v__Day14.obobBL6d14___BL6.pos_vs_pos_restored
# 6 MOL___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.pos_vs_rest
# 7 MOL___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.pos_vs_neg
# 8 MOL___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.pos_vs_none
#   da_results_nhg_obj                                        group_a
# 1 da_results_nhg_MOL___Day14.obob14v14__v__Day14.obobBL6d14 pos
# 2 da_results_nhg_MOL___Day14.obob14v14__v__Day14.obobBL6d14 pos
# 3 da_results_nhg_MOL___Day14.obob14v14__v__Day14.obobBL6d14 pos
# 4 da_results_nhg_MOL___Day14.obob14v14__v__Day14.obobBL6d14 pos
# 5 da_results_nhg_MOL___Day14.obob14v14__v__Day14.obobBL6d14 pos
# 6 da_results_nhg_MOL___Day14.obob14v14__v__Day14.obobBL6d14 pos
# 7 da_results_nhg_MOL___Day14.obob14v14__v__Day14.obobBL6d14 pos
# 8 da_results_nhg_MOL___Day14.obob14v14__v__Day14.obobBL6d14 pos
#   group_b      nhgc_obj
# 1              nhgc_MOL___Day14.obob14v14__v__Day14.obobBL6d14
# 2 neg          nhgc_MOL___Day14.obob14v14__v__Day14.obobBL6d14
# 3 neg_restored nhgc_MOL___Day14.obob14v14__v__Day14.obobBL6d14
# 4 none         nhgc_MOL___Day14.obob14v14__v__Day14.obobBL6d14
# 5 pos_restored nhgc_MOL___Day14.obob14v14__v__Day14.obobBL6d14
# 6              nhgc_MOL___Day14.obob14v14__v__Day14.obobBL6d14
# 7 neg          nhgc_MOL___Day14.obob14v14__v__Day14.obobBL6d14
# 8 none         nhgc_MOL___Day14.obob14v14__v__Day14.obobBL6d14
#   da_results_nhg_output_suffix               milo_obj       seurat_obj
# 1 MOL___Day14.obob14v14__v__Day14.obobBL6d14 milo_Day14.MOL obj_Day14.MOL
# 2 MOL___Day14.obob14v14__v__Day14.obobBL6d14 milo_Day14.MOL obj_Day14.MOL
# 3 MOL___Day14.obob14v14__v__Day14.obobBL6d14 milo_Day14.MOL obj_Day14.MOL
# 4 MOL___Day14.obob14v14__v__Day14.obobBL6d14 milo_Day14.MOL obj_Day14.MOL
# 5 MOL___Day14.obob14v14__v__Day14.obobBL6d14 milo_Day14.MOL obj_Day14.MOL
# 6 MOL___Day14.obob14v14__v__Day14.obobBL6d14 milo_Day14.MOL obj_Day14.MOL
# 7 MOL___Day14.obob14v14__v__Day14.obobBL6d14 milo_Day14.MOL obj_Day14.MOL
# 8 MOL___Day14.obob14v14__v__Day14.obobBL6d14 milo_Day14.MOL obj_Day14.MOL
#   nhm_obj                   da_results_obj
# 1 nhm_Day14.MOL___obob14v14 da_results_01_Day14.MOL___obob14v14
# 2 nhm_Day14.MOL___obob14v14 da_results_01_Day14.MOL___obob14v14
# 3 nhm_Day14.MOL___obob14v14 da_results_01_Day14.MOL___obob14v14
# 4 nhm_Day14.MOL___obob14v14 da_results_01_Day14.MOL___obob14v14
# 5 nhm_Day14.MOL___obob14v14 da_results_01_Day14.MOL___obob14v14
# 6 nhm_Day14.MOL___obob14v14 da_results_01_Day14.MOL___obob14v14
# 7 nhm_Day14.MOL___obob14v14 da_results_01_Day14.MOL___obob14v14
# 8 nhm_Day14.MOL___obob14v14 da_results_01_Day14.MOL___obob14v14
#   restored_df_obj                                  nhood_grouping labels
# 1 restored_df_Day14.obob14v14__v__Day14.obobBL6d14 BL6            MOL
# 2 restored_df_Day14.obob14v14__v__Day14.obobBL6d14 BL6            MOL
# 3 restored_df_Day14.obob14v14__v__Day14.obobBL6d14 BL6            MOL
# 4 restored_df_Day14.obob14v14__v__Day14.obobBL6d14 BL6            MOL
# 5 restored_df_Day14.obob14v14__v__Day14.obobBL6d14 BL6            MOL
# 6 restored_df_Day14.obob14v14__v__Day14.obobBL6d14 fgf1_grouping  MOL
# 7 restored_df_Day14.obob14v14__v__Day14.obobBL6d14 fgf1_grouping  MOL
# 8 restored_df_Day14.obob14v14__v__Day14.obobBL6d14 fgf1_grouping  MOL
#   comparison                           fgf1_tag  bl6_tag    fgf1_day bl6_day
# 1 Day14.obob14v14__v__Day14.obobBL6d14 obob14v14 obobBL6d14 Day14    Day14
# 2 Day14.obob14v14__v__Day14.obobBL6d14 obob14v14 obobBL6d14 Day14    Day14
# 3 Day14.obob14v14__v__Day14.obobBL6d14 obob14v14 obobBL6d14 Day14    Day14
# 4 Day14.obob14v14__v__Day14.obobBL6d14 obob14v14 obobBL6d14 Day14    Day14
# 5 Day14.obob14v14__v__Day14.obobBL6d14 obob14v14 obobBL6d14 Day14    Day14
# 6 Day14.obob14v14__v__Day14.obobBL6d14 obob14v14 obobBL6d14 Day14    Day14
# 7 Day14.obob14v14__v__Day14.obobBL6d14 obob14v14 obobBL6d14 Day14    Day14
# 8 Day14.obob14v14__v__Day14.obobBL6d14 obob14v14 obobBL6d14 Day14    Day14
#   milo_index_tibble
# 1 milo_index_tibble_Day14.MOL
# 2 milo_index_tibble_Day14.MOL
# 3 milo_index_tibble_Day14.MOL
# 4 milo_index_tibble_Day14.MOL
# 5 milo_index_tibble_Day14.MOL
# 6 milo_index_tibble_Day14.MOL
# 7 milo_index_tibble_Day14.MOL
# 8 milo_index_tibble_Day14.MOL

# %%
clusters_tibble = qs::qread('clusters_tibble.qs') %>%
    dplyr::rename(labels=label, global_seurat_obj=object)

# %%
summary_plot_recipe = deg_restored_recipe %>%
left_join(clusters_tibble, by = 'labels') %>%
mutate(name = str_replace_all(deg_output_suffix, '___', '\n')) %>%
mutate(deg_ensmus_obj = rlang::syms(paste0('deg_ensmus_', deg_output_suffix))) %>%
select(deg_output_suffix, global_seurat_obj, seurat_obj, nhgc_obj, deg_ensmus_obj, nhood_grouping, name, group_a, group_b) %>%
# filter(group_a == 'pos') %>%
# filter(!str_detect(deg_output_suffix, 'd5')) %>%
# filter(!str_detect(deg_output_suffix, 'd14')) %>%
distinct

summary_plot_recipe %>% dim
summary_plot_recipe %>% head
qs::qsave(summary_plot_recipe, "summary_plot_recipe.qs")
# Out:
# [1] 4371    9
#   deg_output_suffix
# 1 a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6___BL6.pos_vs_rest
# 2 a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6___BL6.pos_vs_neg
# 3 a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6___BL6.pos_vs_neg_restored
# 4 a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6___BL6.pos_vs_none
# 5 a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6___BL6.pos_vs_pos_restored
# 6 a1_Tany__Astrocytes___all.obob14v14__v__all.obob5vBL6___BL6.pos_vs_rest
#   global_seurat_obj  seurat_obj
# 1 exp_labelled_other obj_a1_Tany__Astrocytes
# 2 exp_labelled_other obj_a1_Tany__Astrocytes
# 3 exp_labelled_other obj_a1_Tany__Astrocytes
# 4 exp_labelled_other obj_a1_Tany__Astrocytes
# 5 exp_labelled_other obj_a1_Tany__Astrocytes
# 6 exp_labelled_other obj_a1_Tany__Astrocytes
#   nhgc_obj
# 1 nhgc_a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6
# 2 nhgc_a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6
# 3 nhgc_a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6
# 4 nhgc_a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6
# 5 nhgc_a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6
# 6 nhgc_a1_Tany__Astrocytes___all.obob14v14__v__all.obob5vBL6
#   deg_ensmus_obj
# 1 deg_ensmus_a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6___BL6.pos_vs_rest
# 2 deg_ensmus_a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6___BL6.pos_vs_neg
# 3 deg_ensmus_a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6___BL6.pos_vs_neg_restored
# 4 deg_ensmus_a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6___BL6.pos_vs_none
# 5 deg_ensmus_a1_Tany__Astrocytes___all.obob14v14__v__all.obob14vBL6___BL6.pos_vs_pos_restored
# 6 deg_ensmus_a1_Tany__Astrocytes___all.obob14v14__v__all.obob5vBL6___BL6.pos_vs_rest
#   nhood_grouping
# 1 BL6
# 2 BL6
# 3 BL6
# 4 BL6
# 5 BL6
# 6 BL6
#   name
# 1 a1_Tany__Astrocytes\nall.obob14v14__v__all.obob14vBL6\nBL6.pos_vs_rest
# 2 a1_Tany__Astrocytes\nall.obob14v14__v__all.obob14vBL6\nBL6.pos_vs_neg
# 3 a1_Tany__Astrocytes\nall.obob14v14__v__all.obob14vBL6\nBL6.pos_vs_neg_restored
# 4 a1_Tany__Astrocytes\nall.obob14v14__v__all.obob14vBL6\nBL6.pos_vs_none
# 5 a1_Tany__Astrocytes\nall.obob14v14__v__all.obob14vBL6\nBL6.pos_vs_pos_restored
# 6 a1_Tany__Astrocytes\nall.obob14v14__v__all.obob5vBL6\nBL6.pos_vs_rest
#   group_a group_b
# 1 pos
# 2 pos     neg
# 3 pos     neg_restored
# 4 pos     none
# 5 pos     pos_restored
# 6 pos

# %%
tibble(prefix = c('deg_summary_plot_gSCT_', 'deg_summary_plot_reSCT_')) %>%
tidyr::crossing(summary_plot_recipe) %>%
rowwise %>%
mutate(target_name = paste0(prefix, deg_output_suffix, collapse='')) %>% 
ungroup %>%
pull(target_name) %>%
qs::qsave("plot_targets.qs")

# %%
length(qs::qread('plot_targets.qs'))
# Out:
# [1] 8742

# %%
qs::qread('plot_targets.qs') %>% enframe %>% filter(value == 'deg_summary_plot_gSCT_a1_Tany__Astrocytes___all.obob5v5__v__all.obob14vBL6___fgf1_grouping.pos_vs_neg')
# Out:
#   name
# 1 33
#   value
# 1 deg_summary_plot_gSCT_a1_Tany__Astrocytes___all.obob5v5__v__all.obob14vBL6___fgf1_grouping.pos_vs_neg

# %%
summary_plot_recipe %>%
rowwise %>%
mutate(blah = str_split(deg_output_suffix, '___')) %>%
relocate(blah) %>%
mutate(blah = blah[2]) %>%
mutate(blah = str_split(blah, '__')) %>%
mutate(blah = blah[3]) %>%
pull(blah) %>%
unique
# Out:
# [1] "all.obob14vBL6"   "all.obob5vBL6"    "all.obobBL6"      "all.obobBL6d14"
# [5] "all.obobBL6d5"    "Day14.obobBL6d14" "Day5.obobBL6d5"

# %%
summary_plot_recipe %>% distinct(seurat_obj)
# Out:
#     seurat_obj
# 1   obj_a1_Tany__Astrocytes
# 2   obj_Day14.a1_Tany__Astrocytes
# 3   obj_Day5.a1_Tany__Astrocytes
# 4   obj_a2_Tanycytes
# 5   obj_Day14.a2_Tanycytes
# 6   obj_Day5.a2_Tanycytes
# 7   obj_a2_Tanycytes__b1_Tanycytes
# 8   obj_Day14.a2_Tanycytes__b1_Tanycytes
# 9   obj_Day5.a2_Tanycytes__b1_Tanycytes
# 10  obj_Agrp
# 11  obj_Day14.Agrp
# 12  obj_Day5.Agrp
# 13  obj_Astrocytes
# 14  obj_Day14.Astrocytes
# 15  obj_Day5.Astrocytes
# 16  obj_b1_Tanycytes
# 17  obj_Day14.b1_Tanycytes
# 18  obj_Day5.b1_Tanycytes
# 19  obj_b2_Tany
# 20  obj_Day14.b2_Tany
# 21  obj_Day5.b2_Tany
# 22  obj_Epend
# 23  obj_Day14.Epend
# 24  obj_Day5.Epend
# 25  obj_Fibroblasts2__Fibroblasts3
# 26  obj_Day5.Fibroblasts2__Fibroblasts3
# 27  obj_Ghrh
# 28  obj_Day14.Ghrh
# 29  obj_Day5.Ghrh
# 30  obj_Gm8773_Tac1__Hdc
# ⋮   ⋮
# 117 obj_Th_Nfib__Arx_Nr5a2
# 118 obj_Day14.Th_Nfib__Arx_Nr5a2
# 119 obj_Day5.Th_Nfib__Arx_Nr5a2
# 120 obj_Th_Slc6a3
# 121 obj_Day14.Th_Slc6a3
# 122 obj_Day5.Th_Slc6a3
# 123 obj_Tmem215
# 124 obj_Day14.Tmem215
# 125 obj_Day5.Tmem215
# 126 obj_Trh_Cxcl12
# 127 obj_Day14.Trh_Cxcl12
# 128 obj_Day5.Trh_Cxcl12
# 129 obj_Trh_Lef1
# 130 obj_Day14.Trh_Lef1
# 131 obj_Day5.Trh_Lef1
# 132 obj_Unassigned1.sc17.sc28
# 133 obj_Day14.Unassigned1.sc17.sc28
# 134 obj_Day5.Unassigned1.sc17.sc28
# 135 obj_Unassigned1.sc37
# 136 obj_Day14.Unassigned1.sc37
# 137 obj_Day5.Unassigned1.sc37
# 138 obj_Unassigned1.sc39
# 139 obj_Day14.Unassigned1.sc39
# 140 obj_Day5.Unassigned1.sc39
# 141 obj_Unassigned2
# 142 obj_Day14.Unassigned2
# 143 obj_Day5.Unassigned2
# 144 obj_Unassigned2__Rgs16_Vip
# 145 obj_Unassigned2__Unassigned1
# 146 obj_Day14.Unassigned2__Unassigned1
