# %%
library(Seurat)
library(tidyverse)
library(ggplot2)
library(ggrepel)
library(ggbeeswarm)
library(patchwork)
options(ggrepel.max.overlaps = Inf)
# Out:
# Attaching SeuratObject
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.2     ✔ purrr   0.3.4
# ✔ tibble  3.2.1     ✔ dplyr   1.1.2
# ✔ tidyr   1.2.1     ✔ stringr 1.4.1
# ✔ readr   2.1.2     ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
obj_neuron = qs::qread('_targets/objects/exp_labelled_neuron')
obj_neuron
# Out:
# An object of class Seurat
# 59227 features across 107464 samples within 3 assays
# Active assay: SCT (26906 features, 3000 variable features)
#  2 other assays present: RNA, integrated
#  2 dimensional reductions calculated: pca, umap

# %%
DimPlot(obj_neuron)
# Out:
# Rasterizing points since number of points exceeds 100,000.
# To disable this behavior set `raster=FALSE`
# plot without title

# %%
obj_other = qs::qread('_targets/objects/exp_labelled_other')
obj_other
# Out:
# An object of class Seurat
# 56583 features across 37179 samples within 3 assays
# Active assay: SCT (24262 features, 3000 variable features)
#  2 other assays present: RNA, integrated
#  2 dimensional reductions calculated: pca, umap

# %%
DimPlot(obj_other)
# Out:
# plot without title

# %%
obj_other@meta.data$labels
# Out:
#     [1] NG2_OPC2-Microglia        NFOL
#     [3] NG2_OPC2-Microglia        NG2_OPC2-Microglia
#     [5] NG2_OPC2-Microglia        NFOL
#     [7] NG2_OPC2-Microglia        NG2_OPC2-Microglia
#     [9] NG2_OPC2-Microglia        NG2_OPC2-Microglia
#    [11] NG2_OPC2-Microglia        NG2_OPC2-Microglia
#    [13] NG2_OPC2-Microglia        NG2_OPC2-Microglia
#    [15] NG2_OPC2-Microglia        NG2_OPC2-Microglia
#    [17] NG2_OPC2-Microglia        NG2_OPC2-Microglia
#    [19] NG2_OPC2-Microglia        NG2_OPC2-Microglia
#    [21] NG2_OPC2-Microglia        NFOL
#    [23] MOL                       NG2_OPC2
#    [25] Astrocytes                NG2_OPC2-Microglia
#    [27] NG2_OPC2-Microglia        NG2_OPC2
#    [29] NG2_OPC2                  NG2_OPC2
#    [31] NG2_OPC2                  NFOL
#    [33] NFOL                      MOL
#    [35] MOL                       NG2_OPC2
#    [37] NG2_OPC2                  NG2_OPC2
#    [39] NG2_OPC2                  NG2_OPC2-Microglia
#    [41] NG2_OPC2                  NG2_OPC2
#    [43] NFOL                      NG2_OPC2
#    [45] b2_Tany                   NG2_OPC2-Microglia
#    [47] NG2_OPC2-Microglia        NG2_OPC2-Microglia
#    [49] NG2_OPC2                  NG2_OPC2
#    [51] NG2_OPC2                  NG2_OPC2
#    [53] NG2_OPC2                  NG2_OPC2
#    [55] NG2_OPC2                  a2_Tanycytes
#    [57] NG2_OPC2                  NG2_OPC2-Microglia
#    [59] NG2_OPC2                  NFOL
#    [61] NG2_OPC2                  NG2_OPC2
#    [63] NG2_OPC2                  Astrocytes
#    [65] NG2_OPC2                  Astrocytes
#    [67] NG2_OPC2                  MOL-a2_Tanycytes
#    [69] b1_Tanycytes              Astrocytes
#    [71] NG2_OPC2                  NG2_OPC2
#    [73] b2_Tany                   NG2_OPC2
#    [75] NG2_OPC2                  MOL
#    [77] b1_Tanycytes              b2_Tany
#    [79] Astrocytes                Astrocytes
#    [81] NG2_OPC2                  b1_Tanycytes
#    [83] NG2_OPC2-Microglia        Astrocytes
#    [85] Astrocytes                b1_Tanycytes
#    [87] NG2_OPC2                  NG2_OPC2
#    [89] a1_Tany-Astrocytes        Astrocytes
#    [91] NG2_OPC2                  NFOL
#    [93] Astrocytes                NFOL
#    [95] b1_Tanycytes              Astrocytes
#    [97] Astrocytes                a1_Tany-Astrocytes
#    [99] Astrocytes                Astrocytes
#   [101] NG2_OPC2                  NG2_OPC2
#   [103] Astrocytes                NG2_OPC2
#   [105] Astrocytes                Astrocytes
#   [107] a2_Tanycytes              Astrocytes
#   [109] b2_Tany                   NG2_OPC2-Microglia
#   [111] NG2_OPC2-Microglia        NFOL
#   [113] Astrocytes                Astrocytes
#   [115] Astrocytes                NG2_OPC2
#   [117] Astrocytes                Astrocytes
#   [119] Astrocytes                Astrocytes
#   [121] NG2_OPC2-Microglia        Astrocytes
#   [123] b1_Tanycytes              NFOL
#   [125] Astrocytes                Astrocytes
#   [127] NG2_OPC2-Microglia        a2_Tanycytes
#   [129] NFOL                      Astrocytes
#   [131] a2_Tanycytes              b2_Tany
#   [133] b2_Tany                   a2_Tanycytes
#   [135] MOL                       Astrocytes
#   [137] a1_Tany-Astrocytes        NG2_OPC2
#   [139] NG2_OPC2                  a1_Tany-Astrocytes
#   [141] Astrocytes                NG2_OPC2
#   [143] NG2_OPC2                  Astrocytes
#   [145] Astrocytes                Astrocytes
#   [147] a2_Tanycytes              Astrocytes
#   [149] NFOL                      b1_Tanycytes
#   [151] NG2_OPC2                  Astrocytes
#   [153] b2_Tany                   MOL-a2_Tanycytes
#   [155] NG2_OPC2                  a1_Tany-Astrocytes
#   [157] a2_Tanycytes              NG2_OPC2
#   [159] NFOL                      Astrocytes
#   [161] a1_Tany-Astrocytes        Astrocytes
#   [163] NG2_OPC2                  Astrocytes
#   [165] NG2_OPC2-Microglia        Astrocytes
#   [167] b2_Tany                   Astrocytes
#   [169] b1_Tanycytes              Astrocytes
#   [171] Astrocytes                Astrocytes
#   [173] NG2_OPC2                  b1_Tanycytes
#   [175] b2_Tany                   Astrocytes
#   [177] b2_Tany                   NG2_OPC2
#   [179] Astrocytes                NG2_OPC2
#   [181] a2_Tanycytes              a1_Tany-Astrocytes
#   [183] b1_Tanycytes              Astrocytes
#   [185] b1_Tanycytes              Astrocytes
#   [187] b2_Tany                   Astrocytes
#   [189] Astrocytes                Fibroblasts2-Fibroblasts3
#   [191] NG2_OPC2                  b2_Tany
#   [193] Astrocytes                Astrocytes
#   [195] a2_Tanycytes              b1_Tanycytes
#   [197] a2_Tanycytes              NG2_OPC2
#   [199] NG2_OPC2                  NG2_OPC2
#   [201] a2_Tanycytes              b2_Tany
#   [203] b1_Tanycytes              NG2_OPC2-Microglia
#   [205] Astrocytes                Astrocytes
#   [207] Astrocytes                Astrocytes
#   [209] Astrocytes                NFOL
#   [211] Astrocytes                Astrocytes
#   [213] a2_Tanycytes              Astrocytes
#   [215] a2_Tanycytes              Astrocytes
#   [217] Astrocytes                NG2_OPC2
#   [219] b2_Tany                   Astrocytes
#   [221] Astrocytes                Astrocytes
#   [223] b1_Tanycytes              Astrocytes
#   [225] a2_Tanycytes              b1_Tanycytes
#   [227] MOL                       b2_Tany
#   [229] a2_Tanycytes              a1_Tany-Astrocytes
#   [231] a1_Tany-Astrocytes        Astrocytes
#   [233] a2_Tanycytes              NG2_OPC2
#   [235] b1_Tanycytes              Astrocytes
#   [237] Astrocytes                NG2_OPC2
#   [239] a1_Tany-Astrocytes        a2_Tanycytes
#   [241] b1_Tanycytes              a1_Tany-Astrocytes
#   [243] Astrocytes                NG2_OPC2
#   [245] b1_Tanycytes              Astrocytes
#   [247] NG2_OPC2                  Astrocytes
#   [249] b2_Tany                   Astrocytes
#   [251] a1_Tany-Astrocytes        Astrocytes
#   [253] MOL-a2_Tanycytes          a2_Tanycytes
#   [255] Astrocytes                Astrocytes
#   [257] Astrocytes                b2_Tany
#   [259] Astrocytes                Astrocytes
#   [261] Astrocytes                a1_Tany-Astrocytes
#   [263] NG2_OPC2                  NFOL
#   [265] Astrocytes                b2_Tany
#   [267] Astrocytes                b1_Tanycytes
#   [269] b2_Tany                   NG2_OPC2
#   [271] a1_Tany-Astrocytes        NG2_OPC2
#   [273] Astrocytes                Astrocytes
#   [275] b2_Tany                   NG2_OPC2
#   [277] Astrocytes                Astrocytes
#   [279] b2_Tany                   Astrocytes
#   [281] a1_Tany-Astrocytes        Astrocytes
#   [283] b1_Tanycytes              b1_Tanycytes
#   [285] a1_Tany-Astrocytes        b2_Tany
#   [287] a1_Tany-Astrocytes        b2_Tany
#   [289] b1_Tanycytes              b1_Tanycytes
#   [291] Astrocytes                b1_Tanycytes
#   [293] Astrocytes                Astrocytes
#   [295] b1_Tanycytes              NG2_OPC2
#   [297] Astrocytes                a1_Tany-Astrocytes
#   [299] Astrocytes                NFOL
#   [301] a2_Tanycytes              b1_Tanycytes
#   [303] NG2_OPC2                  b2_Tany
#   [305] Astrocytes                Astrocytes
#   [307] NG2_OPC2                  Astrocytes
#   [309] NG2_OPC2-Microglia        Astrocytes
#   [311] a2_Tanycytes              b1_Tanycytes
#   [313] Astrocytes                Astrocytes
#   [315] Microglia                 b1_Tanycytes
#   [317] Astrocytes                Astrocytes
#   [319] NG2_OPC2                  Astrocytes
#   [321] Astrocytes                Astrocytes
#   [323] Astrocytes                Astrocytes
#   [325] b1_Tanycytes              b2_Tany
#   [327] NG2_OPC2                  Astrocytes
#   [329] a2_Tanycytes-b1_Tanycytes Astrocytes
#   [331] b1_Tanycytes              NG2_OPC2
#   [333] MOL                       Astrocytes
#   [335] a1_Tany-Astrocytes        Astrocytes
#   [337] Astrocytes                a2_Tanycytes
#   [339] a1_Tany-Astrocytes        Astrocytes
#   [341] b1_Tanycytes              Astrocytes
#   [343] a1_Tany-Astrocytes        b1_Tanycytes
#   [345] Astrocytes                NG2_OPC2
#   [347] Astrocytes                Astrocytes
#   [349] Astrocytes                a2_Tanycytes
#   [351] b1_Tanycytes              Astrocytes
#   [353] b1_Tanycytes              NG2_OPC2
#   [355] a2_Tanycytes              NG2_OPC2-Microglia
#   [357] Astrocytes                Astrocytes
#   [359] Astrocytes                Astrocytes
#   [361] MOL                       MOL
#   [363] NG2_OPC2                  b1_Tanycytes
#   [365] a2_Tanycytes              Astrocytes
#   [367] Astrocytes                b1_Tanycytes
#   [369] Astrocytes                a2_Tanycytes
#   [371] a2_Tanycytes-b1_Tanycytes a2_Tanycytes
#   [373] b1_Tanycytes              Astrocytes
#   [375] b1_Tanycytes              a1_Tany-Astrocytes
#   [377] Astrocytes                Astrocytes
#   [379] Astrocytes                a1_Tany-Astrocytes
#   [381] MOL                       Astrocytes
#   [383] Astrocytes                a2_Tanycytes-b1_Tanycytes
#   [385] b2_Tany                   Astrocytes
#   [387] a2_Tanycytes              Astrocytes
#   [389] Astrocytes                Astrocytes
#   [391] Epend                     Astrocytes
#   [393] b1_Tanycytes              Astrocytes
#   [395] Astrocytes                Astrocytes
#   [397] b1_Tanycytes              a1_Tany-Astrocytes
#   [399] Astrocytes                a1_Tany-Astrocytes
#   [401] Astrocytes                a2_Tanycytes
#   [403] Astrocytes                Astrocytes
#   [405] NFOL                      Astrocytes
#   [407] Astrocytes                Astrocytes
#   [409] MOL                       b1_Tanycytes
#   [411] a2_Tanycytes              Astrocytes
#   [413] MOL                       b1_Tanycytes
#   [415] Astrocytes                b1_Tanycytes
#   [417] Astrocytes                NG2_OPC2
#   [419] a1_Tany-Astrocytes        NG2_OPC2
#   [421] Astrocytes                b2_Tany
#   [423] NFOL                      b1_Tanycytes
#   [425] Astrocytes                a2_Tanycytes
#   [427] NG2_OPC2                  a1_Tany-Astrocytes
#   [429] NG2_OPC2                  Astrocytes
#   [431] MOL                       Epend
#   [433] NG2_OPC2                  a2_Tanycytes
#   [435] Astrocytes                Astrocytes
#   [437] b1_Tanycytes              Astrocytes
#   [439] NG2_OPC2                  NG2_OPC2
#   [441] Astrocytes                b1_Tanycytes
#   [443] NG2_OPC2                  a2_Tanycytes
#   [445] Astrocytes                a1_Tany-Astrocytes
#   [447] a1_Tany-Astrocytes        a2_Tanycytes
#   [449] a1_Tany-Astrocytes        a2_Tanycytes
#   [451] NG2_OPC2                  b1_Tanycytes
#   [453] Astrocytes                Astrocytes
#   [455] a1_Tany-Astrocytes        b1_Tanycytes
#   [457] Astrocytes                a2_Tanycytes
#   [459] Astrocytes                NG2_OPC2
#   [461] NG2_OPC2                  a1_Tany-Astrocytes
#   [463] b1_Tanycytes              MOL
#   [465] b2_Tany                   Astrocytes
#   [467] a2_Tanycytes-b1_Tanycytes b1_Tanycytes
#   [469] NG2_OPC2-Microglia        b2_Tany
#   [471] NG2_OPC2-Microglia        b1_Tanycytes
#   [473] NG2_OPC2                  b1_Tanycytes
#   [475] MOL                       Astrocytes
#   [477] a2_Tanycytes              Astrocytes
#   [479] Epend                     Astrocytes
#   [481] Astrocytes                b1_Tanycytes
#   [483] b1_Tanycytes              NG2_OPC2
#   [485] a2_Tanycytes              Astrocytes
#   [487] b2_Tany                   NG2_OPC2
#   [489] Astrocytes                Astrocytes
#   [491] Astrocytes                Astrocytes
#   [493] a2_Tanycytes-b1_Tanycytes a2_Tanycytes
#   [495] a2_Tanycytes              Astrocytes
#   [497] a2_Tanycytes              Astrocytes
#   [499] Astrocytes                NG2_OPC2
#   [501] Astrocytes                a2_Tanycytes
#   [503] a1_Tany-Astrocytes        a1_Tany-Astrocytes
#   [505] b1_Tanycytes              MOL
#   [507] NG2_OPC2                  b1_Tanycytes
#   [509] Astrocytes                b1_Tanycytes
#   [511] b1_Tanycytes              a1_Tany-Astrocytes
#   [513] Astrocytes                a2_Tanycytes
#   [515] b1_Tanycytes              b1_Tanycytes
#   [517] NG2_OPC2-Microglia        a2_Tanycytes
#   [519] Astrocytes                a1_Tany-Astrocytes
#   [521] b1_Tanycytes              Astrocytes
#   [523] Astrocytes                a1_Tany-Astrocytes
#   [525] a2_Tanycytes              a2_Tanycytes
#   [527] Astrocytes                Astrocytes
#   [529] Astrocytes                MOL
#   [531] NG2_OPC2                  Astrocytes
#   [533] Astrocytes                b1_Tanycytes
#   [535] a1_Tany-Astrocytes        MOL
#   [537] Astrocytes                b1_Tanycytes
#   [539] b1_Tanycytes              a1_Tany-Astrocytes
#   [541] a1_Tany-Astrocytes        Astrocytes
#   [543] a2_Tanycytes              a2_Tanycytes
#   [545] MOL-a2_Tanycytes          a1_Tany-Astrocytes
#   [547] NG2_OPC2                  Astrocytes
#   [549] b1_Tanycytes              a1_Tany-Astrocytes
#   [551] Astrocytes                a2_Tanycytes-b1_Tanycytes
#   [553] Astrocytes                Astrocytes
#   [555] Epend                     MOL
#   [557] Astrocytes                a1_Tany-Astrocytes
#   [559] Microglia                 Astrocytes
#   [561] b2_Tany                   Astrocytes
#   [563] Astrocytes                Astrocytes
#   [565] Astrocytes                Astrocytes
#   [567] Astrocytes                Astrocytes
#   [569] Astrocytes                NG2_OPC2-Microglia
#   [571] NFOL                      a1_Tany-Astrocytes
#   [573] Astrocytes                Endothelial
#   [575] a1_Tany-Astrocytes        b1_Tanycytes
#   [577] NG2_OPC2                  b1_Tanycytes
#   [579] b2_Tany                   a2_Tanycytes-b1_Tanycytes
#   [581] a2_Tanycytes-b1_Tanycytes Astrocytes
#   [583] Astrocytes                Astrocytes
#   [585] b1_Tanycytes              a1_Tany-Astrocytes
#   [587] b1_Tanycytes              Astrocytes
#   [589] a2_Tanycytes-b1_Tanycytes a1_Tany-Astrocytes
#   [591] Astrocytes                b1_Tanycytes
#   [593] b1_Tanycytes              MOL
#   [595] Astrocytes                a1_Tany-Astrocytes
#   [597] b1_Tanycytes              Astrocytes
#   [599] a1_Tany-Astrocytes        Astrocytes
#   [601] Astrocytes                Astrocytes
#   [603] b1_Tanycytes              b1_Tanycytes
#   [605] MOL                       a2_Tanycytes
#   [607] NG2_OPC2                  Astrocytes
#   [609] Astrocytes                Astrocytes
#   [611] Astrocytes                Astrocytes
#   [613] MOL                       MOL
#   [615] Astrocytes                Astrocytes
#   [617] MOL                       Astrocytes
#   [619] Astrocytes                a2_Tanycytes
#   [621] Microglia                 Astrocytes
#   [623] a1_Tany-Astrocytes        Astrocytes
#   [625] b1_Tanycytes              a1_Tany-Astrocytes
#   [627] a2_Tanycytes              NG2_OPC2
#   [629] NG2_OPC2                  a2_Tanycytes-b1_Tanycytes
#   [631] a2_Tanycytes              Astrocytes
#   [633] a2_Tanycytes              NFOL
#   [635] b2_Tany                   Astrocytes
#   [637] NFOL                      a1_Tany-Astrocytes
#   [639] Astrocytes                Epend
#   [641] Astrocytes                Astrocytes
#   [643] a1_Tany-Astrocytes        b1_Tanycytes
#   [645] a1_Tany-Astrocytes        a1_Tany-Astrocytes
#   [647] b1_Tanycytes              MOL
#   [649] NG2_OPC2                  Microglia
#   [651] Astrocytes                a2_Tanycytes
#   [653] NG2_OPC2                  a2_Tanycytes
#   [655] Astrocytes                b1_Tanycytes
#   [657] a2_Tanycytes-b1_Tanycytes b2_Tany
#   [659] a1_Tany-Astrocytes        a2_Tanycytes
#   [661] NG2_OPC2-Microglia        a1_Tany-Astrocytes
#   [663] a2_Tanycytes              Astrocytes
#   [665] b1_Tanycytes              b2_Tany
#   [667] a1_Tany-Astrocytes        Astrocytes
#   [669] b1_Tanycytes              MOL
#   [671] Astrocytes                a2_Tanycytes
#   [673] a1_Tany-Astrocytes        a1_Tany-Astrocytes
#   [675] NG2_OPC2                  a1_Tany-Astrocytes
#   [677] NG2_OPC2                  a1_Tany-Astrocytes
#   [679] MOL                       NG2_OPC2
#   [681] MOL                       Microglia
#   [683] a1_Tany-Astrocytes        a1_Tany-Astrocytes
#   [685] Astrocytes                a2_Tanycytes
#   [687] Astrocytes                MOL
#   [689] a1_Tany-Astrocytes        Astrocytes
#   [691] Astrocytes                Astrocytes
#   [693] b2_Tany                   Astrocytes
#   [695] Astrocytes                MOL
#   [697] Astrocytes                MOL
#   [699] a2_Tanycytes              Astrocytes
#   [701] a1_Tany-Astrocytes        Astrocytes
#   [703] b1_Tanycytes              a2_Tanycytes
#   [705] a1_Tany-Astrocytes        MOL
#   [707] NG2_OPC2-Microglia        MOL
#   [709] b2_Tany                   Astrocytes
#   [711] Astrocytes                MOL
#   [713] NG2_OPC2-Microglia        a2_Tanycytes
#   [715] MOL                       a1_Tany-Astrocytes
#   [717] Astrocytes                MOL
#   [719] Astrocytes                Astrocytes
#   [721] b1_Tanycytes              a1_Tany-Astrocytes
#   [723] a1_Tany-Astrocytes        Astrocytes
#   [725] b1_Tanycytes              Astrocytes
#   [727] Epend                     a2_Tanycytes
#   [729] MOL                       b1_Tanycytes
#   [731] Epend                     Astrocytes
#   [733] NG2_OPC2                  Astrocytes
#   [735] b1_Tanycytes              a2_Tanycytes
#   [737] Astrocytes                b1_Tanycytes
#   [739] Astrocytes                Epend
#   [741] NG2_OPC2                  Astrocytes
#   [743] Astrocytes                Epend
#   [745] NG2_OPC2                  a1_Tany-Astrocytes
#   [747] a2_Tanycytes              b1_Tanycytes
#   [749] b1_Tanycytes              Epend
#   [751] b2_Tany                   b1_Tanycytes
#   [753] b1_Tanycytes              Astrocytes
#   [755] b1_Tanycytes              b1_Tanycytes
#   [757] NG2_OPC2-Microglia        Astrocytes
#   [759] a2_Tanycytes              a2_Tanycytes
#   [761] MOL                       Astrocytes
#   [763] a2_Tanycytes              b1_Tanycytes
#   [765] a2_Tanycytes-b1_Tanycytes MOL
#   [767] a1_Tany-Astrocytes        a2_Tanycytes
#   [769] MOL                       NG2_OPC2
#   [771] a1_Tany-Astrocytes        Astrocytes
#   [773] a2_Tanycytes              a2_Tanycytes-b1_Tanycytes
#   [775] MOL                       a1_Tany-Astrocytes
#   [777] Astrocytes                b1_Tanycytes
#   [779] Astrocytes                a1_Tany-Astrocytes
#   [781] a1_Tany-Astrocytes        Astrocytes
#   [783] Astrocytes                a2_Tanycytes
#   [785] Astrocytes                Astrocytes
#   [787] MOL-a2_Tanycytes          a2_Tanycytes
#   [789] b1_Tanycytes              Astrocytes
#   [791] a1_Tany-Astrocytes        a2_Tanycytes
#   [793] NG2_OPC2                  NG2_OPC2-Microglia
#   [795] b1_Tanycytes              a1_Tany-Astrocytes
#   [797] a2_Tanycytes-b1_Tanycytes Astrocytes
#   [799] NG2_OPC2                  a2_Tanycytes
#   [801] NG2_OPC2                  a1_Tany-Astrocytes
#   [803] a1_Tany-Astrocytes        a1_Tany-Astrocytes
#   [805] Astrocytes                Astrocytes
#   [807] MOL                       MOL
#   [809] a2_Tanycytes              MOL
#   [811] a2_Tanycytes-b1_Tanycytes b2_Tany
#   [813] a2_Tanycytes              Epend
#   [815] Astrocytes                Astrocytes
#   [817] MOL                       a1_Tany-Astrocytes
#   [819] Astrocytes                b1_Tanycytes
#   [821] b1_Tanycytes              b1_Tanycytes
#   [823] NFOL                      a2_Tanycytes
#   [825] b1_Tanycytes              b2_Tany
#   [827] a2_Tanycytes-b1_Tanycytes Astrocytes
#   [829] a2_Tanycytes              b1_Tanycytes
#   [831] a2_Tanycytes-b1_Tanycytes Astrocytes
#   [833] Astrocytes                MOL
#   [835] Astrocytes                a1_Tany-Astrocytes
#   [837] Astrocytes                a2_Tanycytes
#   [839] a2_Tanycytes-b1_Tanycytes MOL
#   [841] MOL                       a2_Tanycytes
#   [843] NG2_OPC2                  b1_Tanycytes
#   [845] Astrocytes                Astrocytes
#   [847] MOL                       Astrocytes
#   [849] Epend                     a2_Tanycytes
#   [851] Microglia                 Epend
#   [853] NG2_OPC2                  a1_Tany-Astrocytes
#   [855] Astrocytes                Astrocytes
#   [857] a2_Tanycytes              b1_Tanycytes
#   [859] a1_Tany-Astrocytes        Astrocytes
#   [861] a1_Tany-Astrocytes        Astrocytes
#   [863] b1_Tanycytes              Astrocytes
#   [865] Astrocytes                a1_Tany-Astrocytes
#   [867] Astrocytes                NG2_OPC2
#   [869] Astrocytes                b1_Tanycytes
#   [871] a1_Tany-Astrocytes        b1_Tanycytes
#   [873] b1_Tanycytes              MOL
#   [875] Astrocytes                a2_Tanycytes
#   [877] NFOL                      NG2_OPC2
#   [879] MOL                       a2_Tanycytes
#   [881] Astrocytes                Astrocytes
#   [883] MOL                       Astrocytes
#   [885] a2_Tanycytes              a2_Tanycytes
#   [887] MOL                       Astrocytes
#   [889] Astrocytes                a2_Tanycytes
#   [891] Astrocytes                Astrocytes
#   [893] a1_Tany-Astrocytes        Astrocytes
#   [895] NG2_OPC2                  Microglia
#   [897] a2_Tanycytes              Microglia
#   [899] Astrocytes                a2_Tanycytes-b1_Tanycytes
#   [901] a2_Tanycytes              b2_Tany
#   [903] b2_Tany                   NG2_OPC2-Microglia
#   [905] b1_Tanycytes              a2_Tanycytes
#   [907] b1_Tanycytes              Astrocytes
#   [909] a2_Tanycytes              MOL
#   [911] MOL                       Astrocytes
#   [913] Astrocytes                Astrocytes
#   [915] b1_Tanycytes              Microglia
#   [917] Astrocytes                b1_Tanycytes
#   [919] MOL                       a2_Tanycytes
#   [921] Astrocytes                a2_Tanycytes-b1_Tanycytes
#   [923] a2_Tanycytes              Astrocytes
#   [925] Astrocytes                MOL
#   [927] b2_Tany                   Astrocytes
#   [929] Microglia                 Astrocytes
#   [931] b1_Tanycytes              NG2_OPC2
#   [933] b1_Tanycytes              Astrocytes
#   [935] NG2_OPC2                  Astrocytes
#   [937] b1_Tanycytes              Epend
#   [939] MOL                       Astrocytes
#   [941] Epend                     Astrocytes
#   [943] MOL                       Astrocytes
#   [945] Astrocytes                Astrocytes
#   [947] MOL                       a2_Tanycytes
#   [949] Microglia                 NG2_OPC2-Microglia
#   [951] a1_Tany-Astrocytes        NG2_OPC2
#   [953] b1_Tanycytes              b1_Tanycytes
#   [955] Astrocytes                MOL
#   [957] b1_Tanycytes              Astrocytes
#   [959] Astrocytes                NG2_OPC2
#   [961] Epend                     a2_Tanycytes
#   [963] NG2_OPC2                  Astrocytes
#   [965] MOL                       Astrocytes
#   [967] a1_Tany-Astrocytes        Astrocytes
#   [969] Astrocytes                a2_Tanycytes
#   [971] Astrocytes                Astrocytes
#   [973] a1_Tany-Astrocytes        MOL
#   [975] Astrocytes                b1_Tanycytes
#   [977] Astrocytes                Astrocytes
#   [979] NG2_OPC2                  a1_Tany-Astrocytes
#   [981] a2_Tanycytes              b1_Tanycytes
#   [983] b1_Tanycytes              Astrocytes
#   [985] a2_Tanycytes              Astrocytes
#   [987] Astrocytes                b1_Tanycytes
#   [989] Astrocytes                a2_Tanycytes-b1_Tanycytes
#   [991] Microglia                 Astrocytes
#   [993] MOL                       NG2_OPC2
#   [995] b2_Tany                   Astrocytes
#   [997] MOL                       a2_Tanycytes
#   [999] b1_Tanycytes              a1_Tany-Astrocytes
#  [1001] a2_Tanycytes              a2_Tanycytes
#  [1003] Astrocytes                Astrocytes
#  [1005] b2_Tany                   Astrocytes
#  [1007] Astrocytes                NFOL
#  [1009] a2_Tanycytes-b1_Tanycytes Astrocytes
#  [1011] a1_Tany-Astrocytes        MOL
#  [1013] Astrocytes                a2_Tanycytes-b1_Tanycytes
#  [1015] MOL                       NG2_OPC2-Microglia
#  [1017] MOL                       b1_Tanycytes
#  [1019] MOL                       Astrocytes
#  [1021] MOL                       a1_Tany-Astrocytes
#  [1023] a2_Tanycytes              Astrocytes
#  [1025] NG2_OPC2                  a2_Tanycytes
#  [1027] Astrocytes                Astrocytes
#  [1029] MOL                       b2_Tany
#  [1031] Microglia                 MOL
#  [1033] a1_Tany-Astrocytes        MOL
#  [1035] b1_Tanycytes              b1_Tanycytes
#  [1037] a1_Tany-Astrocytes        Microglia
#  [1039] a2_Tanycytes-b1_Tanycytes Astrocytes
#  [1041] MOL                       a2_Tanycytes
#  [1043] a1_Tany-Astrocytes        a2_Tanycytes
#  [1045] Astrocytes                b1_Tanycytes
#  [1047] Astrocytes                NG2_OPC2
#  [1049] b2_Tany                   NG2_OPC2
#  [1051] a1_Tany-Astrocytes        Astrocytes
#  [1053] Astrocytes                MOL
#  [1055] Astrocytes                b2_Tany
#  [1057] a2_Tanycytes              Epend
#  [1059] a2_Tanycytes              Astrocytes
#  [1061] a2_Tanycytes-b1_Tanycytes a2_Tanycytes
#  [1063] Astrocytes                a1_Tany-Astrocytes
#  [1065] MOL                       a2_Tanycytes
#  [1067] a1_Tany-Astrocytes        a1_Tany-Astrocytes
#  [1069] a1_Tany-Astrocytes        Astrocytes
#  [1071] Astrocytes                a2_Tanycytes
#  [1073] b2_Tany                   a2_Tanycytes-b1_Tanycytes
#  [1075] b2_Tany                   MOL
#  [1077] a2_Tanycytes              a1_Tany-Astrocytes
#  [1079] MOL                       NG2_OPC2
#  [1081] a1_Tany-Astrocytes        Epend
#  [1083] Astrocytes                a1_Tany-Astrocytes
#  [1085] b1_Tanycytes              Astrocytes
#  [1087] Astrocytes                Microglia
#  [1089] b1_Tanycytes              b2_Tany
#  [1091] Astrocytes                NG2_OPC2
#  [1093] a2_Tanycytes-b1_Tanycytes a2_Tanycytes
#  [1095] b1_Tanycytes              a1_Tany-Astrocytes
#  [1097] b1_Tanycytes              a2_Tanycytes
#  [1099] a2_Tanycytes-b1_Tanycytes Astrocytes
#  [1101] b1_Tanycytes              MOL
#  [1103] NG2_OPC2                  a1_Tany-Astrocytes
#  [1105] a2_Tanycytes-b1_Tanycytes b2_Tany
#  [1107] a2_Tanycytes-b1_Tanycytes a1_Tany-Astrocytes
#  [1109] a2_Tanycytes              MOL
#  [1111] a1_Tany-Astrocytes        Astrocytes
#  [1113] a2_Tanycytes              a2_Tanycytes
#  [1115] MOL                       a1_Tany-Astrocytes
#  [1117] a2_Tanycytes-b1_Tanycytes Astrocytes
#  [1119] NG2_OPC2                  b1_Tanycytes
#  [1121] a1_Tany-Astrocytes        b1_Tanycytes
#  [1123] a1_Tany-Astrocytes        MOL
#  [1125] Astrocytes                b1_Tanycytes
#  [1127] Astrocytes                a1_Tany-Astrocytes
#  [1129] a1_Tany-Astrocytes        NG2_OPC2
#  [1131] Astrocytes                MOL
#  [1133] MOL                       NG2_OPC2
#  [1135] b1_Tanycytes              a1_Tany-Astrocytes
#  [1137] Astrocytes                Endothelial
#  [1139] Astrocytes                Astrocytes
#  [1141] b1_Tanycytes              a1_Tany-Astrocytes
#  [1143] a1_Tany-Astrocytes        a2_Tanycytes
#  [1145] Astrocytes                a1_Tany-Astrocytes
#  [1147] NG2_OPC2                  Astrocytes
#  [1149] a1_Tany-Astrocytes        a2_Tanycytes
#  [1151] Astrocytes                MOL
#  [1153] Astrocytes                b1_Tanycytes
#  [1155] Astrocytes                Astrocytes
#  [1157] a1_Tany-Astrocytes        b1_Tanycytes
#  [1159] a2_Tanycytes              a1_Tany-Astrocytes
#  [1161] Epend                     Astrocytes
#  [1163] a1_Tany-Astrocytes        Astrocytes
#  [1165] a1_Tany-Astrocytes        a1_Tany-Astrocytes
#  [1167] NG2_OPC2                  Astrocytes
#  [1169] b1_Tanycytes              a1_Tany-Astrocytes
#  [1171] b1_Tanycytes              a1_Tany-Astrocytes
#  [1173] b2_Tany                   Astrocytes
#  [1175] MOL                       a1_Tany-Astrocytes
#  [1177] a1_Tany-Astrocytes        Astrocytes
#  [1179] Astrocytes                Astrocytes
#  [1181] b1_Tanycytes              Astrocytes
#  [1183] Astrocytes                a1_Tany-Astrocytes
#  [1185] a1_Tany-Astrocytes        MOL
#  [1187] Astrocytes                a1_Tany-Astrocytes
#  [1189] b1_Tanycytes              a1_Tany-Astrocytes
#  [1191] a2_Tanycytes              Astrocytes
#  [1193] MOL                       b1_Tanycytes
#  [1195] MOL                       a1_Tany-Astrocytes
#  [1197] Astrocytes                Microglia
#  [1199] Astrocytes                a1_Tany-Astrocytes
#  [1201] a2_Tanycytes-b1_Tanycytes Astrocytes
#  [1203] b1_Tanycytes              a2_Tanycytes
#  [1205] Astrocytes                a2_Tanycytes
#  [1207] MOL                       a1_Tany-Astrocytes
#  [1209] a2_Tanycytes              Astrocytes
#  [1211] MOL                       Astrocytes
#  [1213] NG2_OPC2                  Epend
#  [1215] b1_Tanycytes              MOL-a2_Tanycytes
#  [1217] a2_Tanycytes              MOL
#  [1219] a2_Tanycytes              a2_Tanycytes
#  [1221] MOL                       Astrocytes
#  [1223] a2_Tanycytes-b1_Tanycytes Astrocytes
#  [1225] Astrocytes                Astrocytes
#  [1227] MOL                       MOL
#  [1229] Astrocytes                Astrocytes
#  [1231] a2_Tanycytes              a2_Tanycytes
#  [1233] Astrocytes                a2_Tanycytes-b1_Tanycytes
#  [1235] a2_Tanycytes              MOL
#  [1237] a2_Tanycytes-b1_Tanycytes NG2_OPC2
#  [1239] a2_Tanycytes              a2_Tanycytes-b1_Tanycytes
#  [1241] MOL                       b1_Tanycytes
#  [1243] b2_Tany                   Astrocytes
#  [1245] Astrocytes                Astrocytes
#  [1247] Microglia                 a2_Tanycytes
#  [1249] a1_Tany-Astrocytes        MOL
#  [1251] b1_Tanycytes              a2_Tanycytes-b1_Tanycytes
#  [1253] MOL                       NG2_OPC2-Microglia
#  [1255] NG2_OPC2                  b1_Tanycytes
#  [1257] Astrocytes                Astrocytes
#  [1259] Astrocytes                Epend
#  [1261] MOL                       a1_Tany-Astrocytes
#  [1263] Astrocytes                a2_Tanycytes
#  [1265] Astrocytes                a2_Tanycytes-b1_Tanycytes
#  [1267] a2_Tanycytes              MOL
#  [1269] Astrocytes                Astrocytes
#  [1271] a2_Tanycytes-b1_Tanycytes a2_Tanycytes
#  [1273] Astrocytes                b1_Tanycytes
#  [1275] Astrocytes                b1_Tanycytes
#  [1277] Microglia                 a2_Tanycytes
#  [1279] a1_Tany-Astrocytes        Astrocytes
#  [1281] b2_Tany                   MOL
#  [1283] Astrocytes                MOL
#  [1285] a1_Tany-Astrocytes        b2_Tany
#  [1287] a2_Tanycytes              a2_Tanycytes-b1_Tanycytes
#  [1289] Astrocytes                a1_Tany-Astrocytes
#  [1291] MOL                       Astrocytes
#  [1293] Astrocytes                a2_Tanycytes-b1_Tanycytes
#  [1295] MOL                       b2_Tany
#  [1297] Astrocytes                b1_Tanycytes
#  [1299] a2_Tanycytes              Astrocytes
#  [1301] a1_Tany-Astrocytes        Microglia
#  [1303] a2_Tanycytes              a1_Tany-Astrocytes
#  [1305] Astrocytes                Astrocytes
#  [1307] NG2_OPC2                  Astrocytes
#  [1309] a1_Tany-Astrocytes        Astrocytes
#  [1311] a1_Tany-Astrocytes        a2_Tanycytes
#  [1313] a1_Tany-Astrocytes        Astrocytes
#  [1315] Astrocytes                MOL
#  [1317] a1_Tany-Astrocytes        Astrocytes
#  [1319] b1_Tanycytes              a2_Tanycytes
#  [1321] a2_Tanycytes-b1_Tanycytes NG2_OPC2
#  [1323] a2_Tanycytes              MOL
#  [1325] Astrocytes                Astrocytes
#  [1327] Astrocytes                Astrocytes
#  [1329] Astrocytes                NG2_OPC2
#  [1331] Astrocytes                b2_Tany
#  [1333] Astrocytes                b2_Tany
#  [1335] Astrocytes                Astrocytes
#  [1337] Astrocytes                b1_Tanycytes
#  [1339] Microglia                 Microglia
#  [1341] Astrocytes                MOL
#  [1343] MOL                       a1_Tany-Astrocytes
#  [1345] a1_Tany-Astrocytes        b1_Tanycytes
#  [1347] Astrocytes                Astrocytes
#  [1349] b1_Tanycytes              b1_Tanycytes
#  [1351] Astrocytes                Astrocytes
#  [1353] a1_Tany-Astrocytes        Astrocytes
#  [1355] Astrocytes                MOL
#  [1357] b2_Tany                   MOL
#  [1359] Astrocytes                Astrocytes
#  [1361] b1_Tanycytes              a1_Tany-Astrocytes
#  [1363] Microglia                 Astrocytes
#  [1365] Astrocytes                a2_Tanycytes-b1_Tanycytes
#  [1367] Astrocytes                a1_Tany-Astrocytes
#  [1369] b1_Tanycytes              Astrocytes
#  [1371] Astrocytes                Astrocytes
#  [1373] Astrocytes                b2_Tany
#  [1375] a2_Tanycytes-b1_Tanycytes Astrocytes
#  [1377] Astrocytes                MOL
#  [1379] Astrocytes                Astrocytes
#  [1381] Astrocytes                Astrocytes
#  [1383] NG2_OPC2                  a1_Tany-Astrocytes
#  [1385] a2_Tanycytes-b1_Tanycytes Astrocytes
#  [1387] a1_Tany-Astrocytes        a2_Tanycytes
#  [1389] a2_Tanycytes-b1_Tanycytes a2_Tanycytes
#  [1391] b1_Tanycytes              a2_Tanycytes-b1_Tanycytes
#  [1393] a1_Tany-Astrocytes        Astrocytes
#  [1395] NG2_OPC2                  a1_Tany-Astrocytes
#  [1397] b1_Tanycytes              a2_Tanycytes-b1_Tanycytes
#  [1399] b1_Tanycytes              Astrocytes
#  [1401] b1_Tanycytes              Astrocytes
#  [1403] Astrocytes                b1_Tanycytes
#  [1405] MOL                       Microglia
#  [1407] Mural_Cells2              a1_Tany-Astrocytes
#  [1409] a2_Tanycytes-b1_Tanycytes Astrocytes
#  [1411] a1_Tany-Astrocytes        a2_Tanycytes
#  [1413] b1_Tanycytes              b1_Tanycytes
#  [1415] Astrocytes                Astrocytes
#  [1417] a2_Tanycytes              a1_Tany-Astrocytes
#  [1419] a2_Tanycytes-b1_Tanycytes a1_Tany-Astrocytes
#  [1421] Astrocytes                a1_Tany-Astrocytes
#  [1423] Astrocytes                NG2_OPC2-Microglia
#  [1425] a2_Tanycytes              a2_Tanycytes-b1_Tanycytes
#  [1427] Astrocytes                MOL
#  [1429] MOL                       Astrocytes
#  [1431] b2_Tany                   Astrocytes
#  [1433] Microglia                 b1_Tanycytes
#  [1435] a1_Tany-Astrocytes        Astrocytes
#  [1437] a2_Tanycytes              MOL
#  [1439] b1_Tanycytes              b1_Tanycytes
#  [1441] b1_Tanycytes              MOL
#  [1443] Astrocytes                b1_Tanycytes
#  [1445] a1_Tany-Astrocytes        MOL
#  [1447] b1_Tanycytes              Astrocytes
#  [1449] Astrocytes                Astrocytes
#  [1451] Astrocytes                Astrocytes
#  [1453] Astrocytes                Astrocytes
#  [1455] Astrocytes                b1_Tanycytes
#  [1457] a2_Tanycytes-b1_Tanycytes a2_Tanycytes
#  [1459] a2_Tanycytes              Astrocytes
#  [1461] a1_Tany-Astrocytes        Astrocytes
#  [1463] a1_Tany-Astrocytes        a1_Tany-Astrocytes
#  [1465] b1_Tanycytes              a2_Tanycytes
#  [1467] b1_Tanycytes              Astrocytes
#  [1469] a2_Tanycytes-b1_Tanycytes a2_Tanycytes
#  [1471] a2_Tanycytes              Astrocytes
#  [1473] Astrocytes                MOL
#  [1475] b1_Tanycytes              MOL
#  [1477] b1_Tanycytes              Astrocytes
#  [1479] MOL                       Astrocytes
#  [1481] Astrocytes                b1_Tanycytes
#  [1483] b1_Tanycytes              a2_Tanycytes
#  [1485] Microglia                 b1_Tanycytes
#  [1487] b1_Tanycytes              b1_Tanycytes
#  [1489] MOL                       NG2_OPC2-Microglia
#  [1491] a2_Tanycytes-b1_Tanycytes a2_Tanycytes-b1_Tanycytes
#  [1493] Microglia                 Astrocytes
#  [1495] NG2_OPC2                  a1_Tany-Astrocytes
#  [1497] Epend                     Astrocytes
#  [1499] a1_Tany-Astrocytes        Astrocytes
#  [1501] Astrocytes                Astrocytes
#  [1503] MOL                       a2_Tanycytes
#  [1505] Astrocytes                Mural_Cells2
#  [1507] a2_Tanycytes              Astrocytes
#  [1509] MOL                       MOL
#  [1511] a2_Tanycytes              a1_Tany-Astrocytes
#  [1513] Astrocytes                a1_Tany-Astrocytes
#  [1515] a2_Tanycytes              a2_Tanycytes-b1_Tanycytes
#  [1517] Astrocytes                MOL
#  [1519] b1_Tanycytes              a2_Tanycytes
#  [1521] a1_Tany-Astrocytes        a2_Tanycytes-b1_Tanycytes
#  [1523] Astrocytes                MOL
#  [1525] MOL-a2_Tanycytes          a2_Tanycytes
#  [1527] Microglia                 b1_Tanycytes
#  [1529] a1_Tany-Astrocytes        Astrocytes
#  [1531] Astrocytes                Microglia
#  [1533] b1_Tanycytes              a2_Tanycytes-b1_Tanycytes
#  [1535] b1_Tanycytes              Astrocytes
#  [1537] a2_Tanycytes-b1_Tanycytes a1_Tany-Astrocytes
#  [1539] b1_Tanycytes              Epend
#  [1541] Astrocytes                b1_Tanycytes
#  [1543] Astrocytes                Astrocytes
#  [1545] Astrocytes                Microglia
#  [1547] MOL                       b1_Tanycytes
#  [1549] Astrocytes                MOL
#  [1551] MOL                       a2_Tanycytes
#  [1553] a1_Tany-Astrocytes        MOL
#  [1555] Astrocytes                MOL
#  [1557] Microglia                 a1_Tany-Astrocytes
#  [1559] Epend                     Astrocytes
#  [1561] a1_Tany-Astrocytes        a1_Tany-Astrocytes
#  [1563] Astrocytes                MOL
#  [1565] Astrocytes                MOL
#  [1567] Microglia                 Microglia
#  [1569] MOL                       a2_Tanycytes-b1_Tanycytes
#  [1571] a1_Tany-Astrocytes        Astrocytes
#  [1573] a1_Tany-Astrocytes        a1_Tany-Astrocytes
#  [1575] MOL                       Microglia
#  [1577] NG2_OPC2                  Microglia
#  [1579] MOL                       a2_Tanycytes
#  [1581] Astrocytes                Microglia
#  [1583] a1_Tany-Astrocytes        a1_Tany-Astrocytes
#  [1585] a1_Tany-Astrocytes        MOL
#  [1587] Microglia                 a2_Tanycytes
#  [1589] a2_Tanycytes-b1_Tanycytes MOL
#  [1591] a2_Tanycytes-b1_Tanycytes Astrocytes
#  [1593] Astrocytes                b1_Tanycytes
#  [1595] Astrocytes                b2_Tany
#  [1597] a1_Tany-Astrocytes        Astrocytes
#  [1599] Microglia                 a1_Tany-Astrocytes
# ...
# [36651] MOL                       b1_Tanycytes
# [36653] MOL                       a2_Tanycytes
# [36655] Astrocytes                a1_Tany-Astrocytes
# [36657] a1_Tany-Astrocytes        Astrocytes
# [36659] a2_Tanycytes-b1_Tanycytes MOL
# [36661] Astrocytes                b1_Tanycytes
# [36663] a2_Tanycytes              b2_Tany
# [36665] a1_Tany-Astrocytes        Astrocytes
# [36667] a1_Tany-Astrocytes        Astrocytes
# [36669] Astrocytes                a1_Tany-Astrocytes
# [36671] a2_Tanycytes              a1_Tany-Astrocytes
# [36673] Astrocytes                Astrocytes
# [36675] a2_Tanycytes-b1_Tanycytes Astrocytes
# [36677] MOL                       a2_Tanycytes
# [36679] MOL                       a2_Tanycytes
# [36681] MOL                       MOL
# [36683] MOL                       Astrocytes
# [36685] Astrocytes                a1_Tany-Astrocytes
# [36687] a2_Tanycytes-b1_Tanycytes a2_Tanycytes
# [36689] Astrocytes                b1_Tanycytes
# [36691] Astrocytes                b1_Tanycytes
# [36693] a2_Tanycytes              Astrocytes
# [36695] MOL                       Astrocytes
# [36697] b1_Tanycytes              a2_Tanycytes
# [36699] a2_Tanycytes-b1_Tanycytes Microglia
# [36701] Astrocytes                MOL
# [36703] a2_Tanycytes              a1_Tany-Astrocytes
# [36705] a2_Tanycytes              MOL
# [36707] MOL                       b1_Tanycytes
# [36709] a2_Tanycytes-b1_Tanycytes Astrocytes
# [36711] a1_Tany-Astrocytes        a2_Tanycytes
# [36713] a2_Tanycytes-b1_Tanycytes a2_Tanycytes
# [36715] MOL                       Astrocytes
# [36717] MOL                       b1_Tanycytes
# [36719] a1_Tany-Astrocytes        Astrocytes
# [36721] Astrocytes                b1_Tanycytes
# [36723] Astrocytes                a1_Tany-Astrocytes
# [36725] a1_Tany-Astrocytes        Epend
# [36727] MOL                       Astrocytes
# [36729] b1_Tanycytes              MOL
# [36731] Astrocytes                Astrocytes
# [36733] Astrocytes                MOL
# [36735] Astrocytes                b1_Tanycytes
# [36737] Astrocytes                a2_Tanycytes-b1_Tanycytes
# [36739] Astrocytes                MOL
# [36741] MOL                       Microglia
# [36743] Astrocytes                a2_Tanycytes-b1_Tanycytes
# [36745] Astrocytes                b1_Tanycytes
# [36747] a2_Tanycytes              a2_Tanycytes
# [36749] Astrocytes                a2_Tanycytes
# [36751] MOL                       MOL
# [36753] a1_Tany-Astrocytes        Astrocytes
# [36755] a2_Tanycytes-b1_Tanycytes a2_Tanycytes-b1_Tanycytes
# [36757] b1_Tanycytes              a2_Tanycytes-b1_Tanycytes
# [36759] b1_Tanycytes              a1_Tany-Astrocytes
# [36761] b1_Tanycytes              Astrocytes
# [36763] Astrocytes                a2_Tanycytes-b1_Tanycytes
# [36765] a2_Tanycytes              a1_Tany-Astrocytes
# [36767] a2_Tanycytes              Astrocytes
# [36769] a1_Tany-Astrocytes        Astrocytes
# [36771] NG2_OPC2                  Microglia
# [36773] b1_Tanycytes              Fibroblasts2-Fibroblasts3
# [36775] a2_Tanycytes-b1_Tanycytes Astrocytes
# [36777] Mural_Cells2              Microglia
# [36779] MOL                       MOL
# [36781] Microglia                 MOL
# [36783] Microglia                 a2_Tanycytes-b1_Tanycytes
# [36785] Epend                     MOL
# [36787] Microglia                 MOL
# [36789] a2_Tanycytes              a2_Tanycytes
# [36791] Epend                     Epend
# [36793] b1_Tanycytes              Microglia
# [36795] MOL                       Fibroblasts2-Fibroblasts3
# [36797] Epend                     a2_Tanycytes-b1_Tanycytes
# [36799] Microglia                 a1_Tany-Astrocytes
# [36801] MOL                       Microglia
# [36803] MOL                       a2_Tanycytes-b1_Tanycytes
# [36805] a2_Tanycytes              Microglia
# [36807] a1_Tany-Astrocytes        Mural_Cells2
# [36809] Astrocytes                Fibroblasts2-Fibroblasts3
# [36811] Mural_Cells2              MOL
# [36813] MOL                       MOL
# [36815] MOL                       a2_Tanycytes-b1_Tanycytes
# [36817] Microglia                 Mural_Cells2
# [36819] MOL                       Microglia
# [36821] MOL                       a2_Tanycytes
# [36823] a2_Tanycytes-b1_Tanycytes Astrocytes
# [36825] Fibroblasts2-Fibroblasts3 Fibroblasts2-Fibroblasts3
# [36827] MOL                       MOL
# [36829] a2_Tanycytes              MOL
# [36831] Microglia                 a2_Tanycytes
# [36833] Mural_Cells2              a2_Tanycytes-b1_Tanycytes
# [36835] a2_Tanycytes              MOL
# [36837] MOL                       b1_Tanycytes
# [36839] MOL                       MOL
# [36841] Microglia                 a2_Tanycytes-b1_Tanycytes
# [36843] Epend                     a2_Tanycytes-b1_Tanycytes
# [36845] Microglia                 a2_Tanycytes-b1_Tanycytes
# [36847] MOL                       MOL
# [36849] Microglia                 MOL
# [36851] Microglia                 a2_Tanycytes
# [36853] Microglia                 Fibroblasts2-Fibroblasts3
# [36855] MOL                       a2_Tanycytes
# [36857] Microglia                 Epend
# [36859] MOL                       MOL
# [36861] b1_Tanycytes              MOL
# [36863] Microglia                 a1_Tany-Astrocytes
# [36865] Microglia                 Astrocytes
# [36867] MOL                       NG2_OPC2
# [36869] a1_Tany-Astrocytes        Astrocytes
# [36871] Astrocytes                Mural_Cells2
# [36873] Microglia                 MOL
# [36875] a2_Tanycytes-b1_Tanycytes Parstuber2A-ParsTuber1
# [36877] MOL                       MOL
# [36879] Microglia                 Epend
# [36881] Epend                     a2_Tanycytes-b1_Tanycytes
# [36883] Microglia                 MOL
# [36885] Microglia                 Epend
# [36887] MOL                       Epend
# [36889] a2_Tanycytes-b1_Tanycytes a2_Tanycytes-b1_Tanycytes
# [36891] MOL                       a2_Tanycytes-b1_Tanycytes
# [36893] Microglia                 MOL
# [36895] Microglia                 Microglia
# [36897] Microglia                 Epend
# [36899] Astrocytes                MOL
# [36901] a2_Tanycytes-b1_Tanycytes Microglia
# [36903] MOL                       Astrocytes
# [36905] MOL                       MOL
# [36907] Astrocytes                Microglia
# [36909] MOL                       Microglia
# [36911] Microglia                 Microglia
# [36913] Microglia                 MOL
# [36915] a2_Tanycytes              Microglia
# [36917] MOL                       MOL
# [36919] a2_Tanycytes              MOL
# [36921] Microglia                 MOL
# [36923] Epend                     Microglia
# [36925] Epend                     Microglia
# [36927] b1_Tanycytes              Microglia
# [36929] b1_Tanycytes              Epend
# [36931] MOL                       a2_Tanycytes-b1_Tanycytes
# [36933] MOL                       MOL
# [36935] Mural_Cells2              Astrocytes
# [36937] Astrocytes                MOL
# [36939] Microglia                 a2_Tanycytes
# [36941] Epend                     MOL
# [36943] MOL                       a2_Tanycytes-b1_Tanycytes
# [36945] a1_Tany-Astrocytes        a2_Tanycytes-b1_Tanycytes
# [36947] Astrocytes                a2_Tanycytes
# [36949] a2_Tanycytes-b1_Tanycytes Astrocytes
# [36951] Astrocytes                MOL
# [36953] MOL                       b1_Tanycytes
# [36955] a2_Tanycytes              MOL
# [36957] a2_Tanycytes-b1_Tanycytes MOL
# [36959] a1_Tany-Astrocytes        b1_Tanycytes
# [36961] MOL                       a2_Tanycytes
# [36963] Astrocytes                MOL
# [36965] Fibroblasts2-Fibroblasts3 MOL
# [36967] MOL                       b1_Tanycytes
# [36969] MOL                       MOL
# [36971] a2_Tanycytes-b1_Tanycytes a2_Tanycytes-b1_Tanycytes
# [36973] a2_Tanycytes-b1_Tanycytes a2_Tanycytes-b1_Tanycytes
# [36975] Astrocytes                a2_Tanycytes
# [36977] a1_Tany-Astrocytes        MOL
# [36979] MOL                       Astrocytes
# [36981] a2_Tanycytes              a2_Tanycytes
# [36983] Astrocytes                MOL
# [36985] a2_Tanycytes              Microglia
# [36987] MOL                       a1_Tany-Astrocytes
# [36989] b1_Tanycytes              MOL
# [36991] Microglia                 a2_Tanycytes-b1_Tanycytes
# [36993] MOL                       Microglia
# [36995] MOL                       a2_Tanycytes-b1_Tanycytes
# [36997] MOL                       a1_Tany-Astrocytes
# [36999] Astrocytes                MOL
# [37001] Microglia                 MOL
# [37003] a2_Tanycytes-b1_Tanycytes MOL
# [37005] a2_Tanycytes-b1_Tanycytes a2_Tanycytes-b1_Tanycytes
# [37007] a1_Tany-Astrocytes        MOL
# [37009] a2_Tanycytes-b1_Tanycytes Fibroblasts2-Fibroblasts3
# [37011] b1_Tanycytes              Astrocytes
# [37013] a2_Tanycytes-b1_Tanycytes a2_Tanycytes-b1_Tanycytes
# [37015] a2_Tanycytes              MOL
# [37017] MOL                       a2_Tanycytes-b1_Tanycytes
# [37019] b1_Tanycytes              a2_Tanycytes-b1_Tanycytes
# [37021] a2_Tanycytes              Astrocytes
# [37023] a2_Tanycytes              MOL
# [37025] a1_Tany-Astrocytes        MOL
# [37027] MOL                       a2_Tanycytes-b1_Tanycytes
# [37029] a2_Tanycytes              Astrocytes
# [37031] Microglia                 b1_Tanycytes
# [37033] a2_Tanycytes-b1_Tanycytes Astrocytes
# [37035] a2_Tanycytes              a2_Tanycytes-b1_Tanycytes
# [37037] Epend                     a2_Tanycytes-b1_Tanycytes
# [37039] Astrocytes                MOL
# [37041] b1_Tanycytes              Microglia
# [37043] MOL                       MOL
# [37045] a2_Tanycytes              MOL
# [37047] a2_Tanycytes              MOL
# [37049] a2_Tanycytes-b1_Tanycytes Microglia
# [37051] a2_Tanycytes              MOL
# [37053] MOL                       a2_Tanycytes-b1_Tanycytes
# [37055] MOL                       Epend
# [37057] MOL                       a2_Tanycytes-b1_Tanycytes
# [37059] Astrocytes                b1_Tanycytes
# [37061] MOL                       a2_Tanycytes
# [37063] a2_Tanycytes-b1_Tanycytes MOL
# [37065] a2_Tanycytes-b1_Tanycytes a1_Tany-Astrocytes
# [37067] a1_Tany-Astrocytes        a2_Tanycytes-b1_Tanycytes
# [37069] MOL                       MOL
# [37071] Microglia                 a2_Tanycytes
# [37073] Astrocytes                b1_Tanycytes
# [37075] Epend                     b1_Tanycytes
# [37077] a2_Tanycytes              b1_Tanycytes
# [37079] Microglia                 MOL
# [37081] Astrocytes                MOL
# [37083] a2_Tanycytes              Microglia
# [37085] Epend                     b2_Tany
# [37087] a2_Tanycytes-b1_Tanycytes MOL
# [37089] a2_Tanycytes-b1_Tanycytes a2_Tanycytes
# [37091] MOL                       MOL
# [37093] MOL                       MOL
# [37095] Microglia                 a2_Tanycytes-b1_Tanycytes
# [37097] a2_Tanycytes-b1_Tanycytes b1_Tanycytes
# [37099] MOL                       Microglia
# [37101] MOL                       a2_Tanycytes
# [37103] a1_Tany-Astrocytes        Microglia
# [37105] a2_Tanycytes-b1_Tanycytes MOL
# [37107] MOL                       a2_Tanycytes-b1_Tanycytes
# [37109] a2_Tanycytes-b1_Tanycytes Microglia
# [37111] MOL                       MOL
# [37113] MOL                       MOL
# [37115] b2_Tany                   a2_Tanycytes-b1_Tanycytes
# [37117] MOL                       Fibroblasts2-Fibroblasts3
# [37119] a1_Tany-Astrocytes        MOL
# [37121] MOL                       MOL
# [37123] a1_Tany-Astrocytes        MOL
# [37125] MOL                       Astrocytes
# [37127] b1_Tanycytes              b1_Tanycytes
# [37129] a1_Tany-Astrocytes        MOL
# [37131] Astrocytes                Astrocytes
# [37133] MOL                       MOL
# [37135] Microglia                 a1_Tany-Astrocytes
# [37137] a2_Tanycytes              Microglia
# [37139] a2_Tanycytes              Astrocytes
# [37141] a2_Tanycytes-b1_Tanycytes Microglia
# [37143] b1_Tanycytes              b1_Tanycytes
# [37145] a2_Tanycytes-b1_Tanycytes MOL
# [37147] a2_Tanycytes              MOL
# [37149] a2_Tanycytes              b1_Tanycytes
# [37151] a2_Tanycytes-b1_Tanycytes MOL
# [37153] a2_Tanycytes-b1_Tanycytes MOL
# [37155] MOL                       MOL
# [37157] a2_Tanycytes-b1_Tanycytes a2_Tanycytes
# [37159] a2_Tanycytes-b1_Tanycytes MOL
# [37161] MOL                       a1_Tany-Astrocytes
# [37163] MOL                       MOL
# [37165] a2_Tanycytes              b1_Tanycytes
# [37167] a2_Tanycytes              a1_Tany-Astrocytes
# [37169] Astrocytes                Astrocytes
# [37171] Astrocytes                a1_Tany-Astrocytes
# [37173] Astrocytes                MOL
# [37175] MOL                       a2_Tanycytes
# [37177] a2_Tanycytes-b1_Tanycytes a1_Tany-Astrocytes
# [37179] Microglia
# 17 Levels: Astrocytes a1_Tany-Astrocytes MOL a2_Tanycytes ... MOL-a2_Tanycytes

# %%
labels_classes_tib = (obj_other@meta.data %>% select(labels) %>% mutate(class = 'other') %>% tibble %>% distinct(labels, class)) %>%
bind_rows(obj_neuron@meta.data %>% select(labels) %>% mutate(class = 'neuron') %>% tibble %>% distinct(labels, class)) %>%
mutate(labels = str_replace(labels, fixed('-'), '__'))

labels_classes_tib
# Out:
#    labels                     class
# 1  NG2_OPC2__Microglia        other
# 2  NFOL                       other
# 3  MOL                        other
# 4  NG2_OPC2                   other
# 5  Astrocytes                 other
# 6  b2_Tany                    other
# 7  a2_Tanycytes               other
# 8  MOL__a2_Tanycytes          other
# 9  b1_Tanycytes               other
# 10 a1_Tany__Astrocytes        other
# 11 Fibroblasts2__Fibroblasts3 other
# 12 Microglia                  other
# 13 a2_Tanycytes__b1_Tanycytes other
# 14 Epend                      other
# 15 Endothelial                other
# 16 Mural_Cells2               other
# 17 Parstuber2A__ParsTuber1    other
# 18 Nr5a1_Bdnf                 neuron
# 19 Unassigned1.sc17.sc28      neuron
# 20 Sst_Pthlh__Ghrh            neuron
# 21 Gm8773_Tac1__Hdc           neuron
# 22 Unassigned1.sc37           neuron
# 23 Tbx19                      neuron
# 24 Th_Nfib__Arx_Nr5a2         neuron
# 25 Slc17a6_Fam19a2            neuron
# 26 Nr5a1_Bdnf__Unassigned1    neuron
# 27 Tmem215                    neuron
# 28 Unassigned2                neuron
# 29 Ghrh                       neuron
# 30 Nr5a1_Bdnf__Nr5a1_Nfib     neuron
# 31 Pomc_Glipr1__Slc17a6_Trhr  neuron
# 32 Unassigned1.sc39           neuron
# 33 Oxt__Unassigned1           neuron
# 34 Unassigned2__Unassigned1   neuron
# 35 Nr5a1_Nfib                 neuron
# 36 Sst_Pthlh.sc21             neuron
# 37 Kisspeptin                 neuron
# 38 Sst_Pthlh.sc23             neuron
# 39 Gpr50                      neuron
# 40 Trh_Lef1                   neuron
# 41 Sst_Nts                    neuron
# 42 Pomc_Lepr                  neuron
# 43 Th_Slc6a3                  neuron
# 44 Agrp                       neuron
# 45 Slc17a6_Trhr               neuron
# 46 Qrfp                       neuron
# 47 Unassigned2__Rgs16_Vip     neuron
# 48 Htr3b                      neuron
# 49 Trh_Cxcl12                 neuron
# 50 Nfix_Htr2c                 neuron
# 51 Sst_Unc13c__Agrp           neuron
# 52 Rgs16_Nmu                  neuron
# 53 Rgs16_Dlx1__Unassigned2    neuron
# 54 Rgs16_Dlx1                 neuron

# %%
umap_coords_neuron = obj_neuron %>%
`@`('reductions') %>%
`$`('umap') %>%
`@`('cell.embeddings') %>%
as.data.frame %>%
rownames_to_column('cell_barcode')

umap_coords_neuron %>% head
# Out:
#   cell_barcode         UMAP_1     UMAP_2
# 1 GCAGCCACACAGCCAC_1_1  11.572324  -6.191700
# 2 TGCTTGCAGTTCCGTA_1_1  -8.046150 -10.652480
# 3 TGCGGCACAGCATGCC_1_1  12.231322  -5.405672
# 4 GAGGCAAGTACCTAAC_1_1  -5.908955 -13.647702
# 5 TAGCACATCACTGTTT_1_1 -11.107301   2.068421
# 6 GTAATGCTCTGTCCCA_1_1   1.026788   2.777484

# %%
umap_coords_other = obj_other %>%
`@`('reductions') %>%
`$`('umap') %>%
`@`('cell.embeddings') %>%
as.data.frame %>%
rownames_to_column('cell_barcode')

umap_coords_other %>% head
# Out:
#   cell_barcode         UMAP_1    UMAP_2
# 1 CCTATCGAGCCATTCA_1_1  4.191492 6.290541
# 2 GTCCTCAAGCGAGGAG_1_1 10.034226 8.506844
# 3 AAGGTAATCTGAGGCC_1_1  4.783816 6.037281
# 4 TCCGTGTCACCTGTCT_1_1  4.995845 5.564838
# 5 ATGGTTGGTCGATTCA_1_1  4.080486 6.462632
# 6 CTTCGGTTCAGCTGAT_1_1 11.486538 5.641030

# %%
ambiguous_cells = intersect(umap_coords_neuron %>% pull(cell_barcode), umap_coords_other %>% pull(cell_barcode))
ambiguous_cells %>% length
# Out:
# [1] 356

# %%
umap_coords_neuron = umap_coords_neuron %>% filter(!(cell_barcode %in% ambiguous_cells))
umap_coords_other = umap_coords_other %>% filter(!(cell_barcode %in% ambiguous_cells))
umap_coords = bind_rows(umap_coords_neuron, umap_coords_other)
umap_coords %>% dim
# Out:
# [1] 143931      3

# %%
# da_results_restored = qs::qread('_targets/objects/combined_da_results_nhg_all.obob5v5__v__all.obobBL6')
da_results_restored = qs::qread('_targets/objects/combined_da_results_nhg_Day14.obob14v14__v__Day14.obobBL6d14')
# column_to_rownames('hash.mcl.ID')

dim(da_results_restored)
da_results_restored %>% head
# Out:
# [1] 2572   17
#   logFC      logCPM   F         PValue       FDR        Nhood SpatialFDR
# 1  1.4178493 13.68102 13.700163 0.0004834038 0.04098198 63    0.04115667
# 2 -2.2485752 13.42826 12.505704 0.0008115244 0.04098198 77    0.04115667
# 3  0.8795717 14.02110  7.159536 0.0097059083 0.32676558 45    0.31285519
# 4 -1.0834010 13.73341  5.899467 0.0183063227 0.46223465 44    0.44605430
# 5 -1.1133420 12.79874  4.447746 0.0393314459 0.66277468 86    0.64527736
# 6  0.8031112 13.47498  4.445809 0.0393727535 0.66277468 95    0.64527736
#   polarity labels              labels_fraction
# 1 pos      a1_Tany__Astrocytes 1
# 2 neg      a1_Tany__Astrocytes 1
# 3 none     a1_Tany__Astrocytes 1
# 4 none     a1_Tany__Astrocytes 1
# 5 none     a1_Tany__Astrocytes 1
# 6 none     a1_Tany__Astrocytes 1
#   comparison                           restored exact_grouping
# 1 Day14.obob14v14__v__Day14.obobBL6d14 FALSE    pos_away
# 2 Day14.obob14v14__v__Day14.obobBL6d14 FALSE    neg_away
# 3 Day14.obob14v14__v__Day14.obobBL6d14 FALSE    pos_BL6
# 4 Day14.obob14v14__v__Day14.obobBL6d14 FALSE    neg_BL6
# 5 Day14.obob14v14__v__Day14.obobBL6d14 FALSE    none
# 6 Day14.obob14v14__v__Day14.obobBL6d14 FALSE    pos_BL6
#   restored_grouping fgf1_grouping hash.mcl.ID          n_cells
# 1 pos_away          pos           GTTACCCTCCGATTAG_5_1 163
# 2 neg_away          neg           TATCTTGTCCCTTTGG_3_2 119
# 3 none              none          CGGTCAGCATGGCTGC_1_1 232
# 4 none              none          AGATCGTGTTGCTTGA_1_1 166
# 5 none              none          ATCCCTGCATATGCGT_2_2  74
# 6 none              none          AGCGTATTCGGATTAC_4_1 145

# %%
# da_results_bl6 = qs::qread('_targets/objects/combined_da_results_idx_all.obobBL6') %>%
da_results_bl6 = qs::qread('_targets/objects/combined_da_results_idx_Day14.obobBL6d14') %>%
rename(n_cells = n_cells.x) %>%
select(-n_cells.y) %>%
mutate(polarity = case_when(polarity == 'none' ~ 'none',
                            polarity == 'pos' ~ 'neg',
                            polarity == 'neg' ~ 'pos')) %>%
mutate(logFC = -logFC)


dim(da_results_bl6)
da_results_bl6 %>% head
# Out:
# [1] 4205   12
#   logFC     logCPM   F        PValue       FDR          Nhood SpatialFDR
# 1  3.195449 13.53875 41.52845 2.619369e-08 2.645562e-06 61    2.586281e-06
# 2  2.251205 13.59741 24.57257 6.709624e-06 3.388360e-04 57    3.273074e-04
# 3  1.767861 13.71835 17.73661 9.074024e-05 2.291191e-03  2    2.157144e-03
# 4  1.644810 14.10515 18.35596 7.087806e-05 2.291191e-03 58    2.157144e-03
# 5 -2.533352 13.97691 15.96127 1.867634e-04 3.767747e-03 59    3.483013e-03
# 6 -2.722589 13.56550 15.19557 2.566601e-04 3.767747e-03 14    3.534754e-03
#   polarity labels              labels_fraction n_cells hash.mcl.ID
# 1 pos      a1_Tany__Astrocytes 1               124     ATGCCTCGTAGTCGTT_5_1
# 2 pos      a1_Tany__Astrocytes 1               138     GAGTCTAAGAGAACCC_5_1
# 3 pos      a1_Tany__Astrocytes 1               160     ATTACTCAGTAACCTC_3_2
# 4 pos      a1_Tany__Astrocytes 1               214     CAGATTGCAAAGACGC_4_1
# 5 neg      a1_Tany__Astrocytes 1               227     CAGCAGCCAGCAGTAG_4_2
# 6 neg      a1_Tany__Astrocytes 1               160     AGTAACCCAGCAGTTT_5_2

# %%
da_results_fgf1 = qs::qread('_targets/objects/combined_da_results_idx_Day14.obob14v14') %>%
rename(n_cells = n_cells.x) %>%
select(-n_cells.y)


dim(da_results_fgf1)
da_results_fgf1 %>% head
# Out:
# [1] 4205   12
#   logFC      logCPM   F         PValue       FDR        Nhood SpatialFDR
# 1  1.4178493 13.68102 13.700163 0.0004834038 0.04098198 63    0.04115667
# 2 -2.2485752 13.42826 12.505704 0.0008115244 0.04098198 77    0.04115667
# 3  0.8795717 14.02110  7.159536 0.0097059083 0.32676558 45    0.31285519
# 4 -1.0834010 13.73341  5.899467 0.0183063227 0.46223465 44    0.44605430
# 5 -1.1133420 12.79874  4.447746 0.0393314459 0.66277468 86    0.64527736
# 6  0.8031112 13.47498  4.445809 0.0393727535 0.66277468 95    0.64527736
#   polarity labels              labels_fraction n_cells hash.mcl.ID
# 1 none     a1_Tany__Astrocytes 1               163     GTTACCCTCCGATTAG_5_1
# 2 none     a1_Tany__Astrocytes 1               119     TATCTTGTCCCTTTGG_3_2
# 3 none     a1_Tany__Astrocytes 1               232     CGGTCAGCATGGCTGC_1_1
# 4 none     a1_Tany__Astrocytes 1               166     AGATCGTGTTGCTTGA_1_1
# 5 none     a1_Tany__Astrocytes 1                74     ATCCCTGCATATGCGT_2_2
# 6 none     a1_Tany__Astrocytes 1               145     AGCGTATTCGGATTAC_4_1

# %%
da_results_2 = full_join(da_results_fgf1, da_results_bl6, by=c('Nhood', 'labels'), suffix = c('_fgf1', '_bl6'))
da_results_2 %>% head
# Out:
#   logFC_fgf1 logCPM_fgf1 F_fgf1    PValue_fgf1  FDR_fgf1   Nhood
# 1  1.4178493 13.68102    13.700163 0.0004834038 0.04098198 63
# 2 -2.2485752 13.42826    12.505704 0.0008115244 0.04098198 77
# 3  0.8795717 14.02110     7.159536 0.0097059083 0.32676558 45
# 4 -1.0834010 13.73341     5.899467 0.0183063227 0.46223465 44
# 5 -1.1133420 12.79874     4.447746 0.0393314459 0.66277468 86
# 6  0.8031112 13.47498     4.445809 0.0393727535 0.66277468 95
#   SpatialFDR_fgf1 polarity_fgf1 labels              labels_fraction_fgf1 ⋯
# 1 0.04115667      none          a1_Tany__Astrocytes 1                    ⋯
# 2 0.04115667      none          a1_Tany__Astrocytes 1                    ⋯
# 3 0.31285519      none          a1_Tany__Astrocytes 1                    ⋯
# 4 0.44605430      none          a1_Tany__Astrocytes 1                    ⋯
# 5 0.64527736      none          a1_Tany__Astrocytes 1                    ⋯
# 6 0.64527736      none          a1_Tany__Astrocytes 1                    ⋯
#   logFC_bl6 logCPM_bl6 F_bl6      PValue_bl6   FDR_bl6     SpatialFDR_bl6
# 1 -1.801282 13.68102    6.2647752 0.0151924487 0.073068444 0.070133565
# 2  1.966430 13.42826   13.8067401 0.0004618202 0.005182649 0.004956589
# 3 -2.235722 14.02110   13.0534022 0.0006390258 0.005867418 0.005643035
# 4  1.378966 13.73341    8.7524450 0.0044882897 0.025184292 0.024037415
# 5  0.202485 12.79874    0.1089169 0.7425847920 0.825010022 0.818183401
# 6 -2.828448 13.47498   12.4847330 0.0008190239 0.006893451 0.006622259
#   polarity_bl6 labels_fraction_bl6 n_cells_bl6 hash.mcl.ID_bl6
# 1 neg          1                   163         GTTACCCTCCGATTAG_5_1
# 2 pos          1                   119         TATCTTGTCCCTTTGG_3_2
# 3 neg          1                   232         CGGTCAGCATGGCTGC_1_1
# 4 pos          1                   166         AGATCGTGTTGCTTGA_1_1
# 5 none         1                    74         ATCCCTGCATATGCGT_2_2
# 6 neg          1                   145         AGCGTATTCGGATTAC_4_1

# %%
da_results = da_results_restored %>% full_join(da_results_2, by=c('Nhood', 'labels')) %>%
mutate(exact_grouping = case_when(is.na(exact_grouping) & (polarity_bl6 != 'none') ~ paste0(polarity_bl6, '_BL6'),
                                  is.na(exact_grouping) & (polarity_bl6 == 'none') ~ paste0(polarity_bl6),
                                  TRUE ~ exact_grouping)) %>%
mutate(n_cells = n_cells_fgf1) %>%
left_join(labels_classes_tib, by='labels') %>%
mutate(cell_barcode = hash.mcl.ID_fgf1) %>%
relocate(cell_barcode, .after='hash.mcl.ID') %>%
select(-all_of(c("hash.mcl.ID", "hash.mcl.ID_fgf1", "hash.mcl.ID_bl6"))) %>%
left_join(umap_coords, by='cell_barcode') %>%
mutate(polarity_bl6 = case_when(logFC_bl6 > 0 & SpatialFDR_bl6 < 0.1 ~ 'pos',
                                logFC_bl6 < 0 & SpatialFDR_bl6 < 0.1 ~ 'neg',
                                TRUE ~ 'none')) %>%
mutate(polarity_fgf1 = case_when(logFC_fgf1 > 0 & SpatialFDR_fgf1 < 0.1 ~ 'pos',
                                logFC_fgf1 < 0 & SpatialFDR_fgf1 < 0.1 ~ 'neg',
                                TRUE ~ 'none'))

da_results %>% dim
da_results %>% head
# Out:
# [1] 4205   38
#   logFC      logCPM   F         PValue       FDR        Nhood SpatialFDR
# 1  1.4178493 13.68102 13.700163 0.0004834038 0.04098198 63    0.04115667
# 2 -2.2485752 13.42826 12.505704 0.0008115244 0.04098198 77    0.04115667
# 3  0.8795717 14.02110  7.159536 0.0097059083 0.32676558 45    0.31285519
# 4 -1.0834010 13.73341  5.899467 0.0183063227 0.46223465 44    0.44605430
# 5 -1.1133420 12.79874  4.447746 0.0393314459 0.66277468 86    0.64527736
# 6  0.8031112 13.47498  4.445809 0.0393727535 0.66277468 95    0.64527736
#   polarity labels              labels_fraction ⋯ F_bl6      PValue_bl6
# 1 pos      a1_Tany__Astrocytes 1               ⋯  6.2647752 0.0151924487
# 2 neg      a1_Tany__Astrocytes 1               ⋯ 13.8067401 0.0004618202
# 3 none     a1_Tany__Astrocytes 1               ⋯ 13.0534022 0.0006390258
# 4 none     a1_Tany__Astrocytes 1               ⋯  8.7524450 0.0044882897
# 5 none     a1_Tany__Astrocytes 1               ⋯  0.1089169 0.7425847920
# 6 none     a1_Tany__Astrocytes 1               ⋯ 12.4847330 0.0008190239
#   FDR_bl6     SpatialFDR_bl6 polarity_bl6 labels_fraction_bl6 n_cells_bl6 class
# 1 0.073068444 0.070133565    neg          1                   163         other
# 2 0.005182649 0.004956589    pos          1                   119         other
# 3 0.005867418 0.005643035    neg          1                   232         other
# 4 0.025184292 0.024037415    pos          1                   166         other
# 5 0.825010022 0.818183401    none         1                    74         other
# 6 0.006893451 0.006622259    neg          1                   145         other
#   UMAP_1    UMAP_2
# 1 -3.767336 2.2247326
# 2 -5.014305 0.1738800
# 3 -5.725503 2.2836584
# 4 -4.700331 2.9793917
# 5 -4.655842 0.9839425
# 6 -3.633373 2.1625203

# %%
da_results %>% group_by(class) %>% summarise(n = n())
# Out:
#   class  n
# 1 neuron 3421
# 2 other   784

# %%
da_results %>% filter(restored)
# Out:
#   logFC     logCPM   F         PValue       FDR          Nhood SpatialFDR
# 1 -2.709010 13.43454 24.252780 9.196193e-07 0.0001315056 141   0.0001273364
# 2 -2.387618 13.02594 12.680648 3.787536e-04 0.0237377706 115   0.0233080744
# 3 -1.943500 13.31412 12.166054 4.979952e-04 0.0237377706 142   0.0233080744
# 4 -2.286481 12.99118 11.087312 8.861983e-04 0.0316815888  49   0.0309013095
# 5 -1.963655 13.02591  9.284284 2.343810e-03 0.0478806857  91   0.0458720026
# 6 -1.582072 13.10301  7.229128 7.237062e-03 0.0940818092  22   0.0903345613
# 7 -2.344054 12.68823  7.020741 8.125363e-03 0.0968272483  85   0.0936658902
#   polarity labels labels_fraction ⋯ F_bl6     PValue_bl6   FDR_bl6
# 1 neg      Agrp   1               ⋯ 34.474951 5.102299e-09 2.515961e-08
# 2 neg      Agrp   1               ⋯ 16.950653 4.004394e-05 9.089338e-05
# 3 neg      Agrp   1               ⋯ 24.196044 9.467527e-07 3.384641e-06
# 4 neg      Agrp   1               ⋯ 14.091466 1.794820e-04 3.515879e-04
# 5 neg      Agrp   1               ⋯ 17.002075 3.898351e-05 8.991358e-05
# 6 neg      Agrp   1               ⋯ 11.188963 8.392179e-04 1.363729e-03
# 7 neg      Agrp   1               ⋯  8.324968 3.955460e-03 5.386960e-03
#   SpatialFDR_bl6 polarity_bl6 labels_fraction_bl6 n_cells_bl6 class  UMAP_1
# 1 2.519869e-08   neg          1                   111         neuron -4.642217
# 2 8.761619e-05   neg          1                    74         neuron -4.034168
# 3 3.289476e-06   neg          1                   101         neuron -5.490150
# 4 3.373074e-04   neg          1                    74         neuron -4.363690
# 5 8.665757e-05   neg          1                    78         neuron -4.766002
# 6 1.312010e-03   neg          1                    82         neuron -5.843696
# 7 5.183723e-03   neg          1                    58         neuron -4.199944
#   UMAP_2
# 1 14.70966
# 2 14.78975
# 3 13.64590
# 4 14.55209
# 5 14.47197
# 6 13.77742
# 7 14.49803

# %%
options(repr.plot.width=3.5, repr.plot.height=3.5)
umap_bl6_other = da_results %>%
filter(class == 'other') %>%
mutate(polarity_bl6 = factor(polarity_bl6, levels = c("none", "neg", "pos"))) %>%
arrange(polarity_bl6) %>%
ggplot(aes(x = UMAP_1, y = UMAP_2, color=polarity_bl6, alpha=polarity_bl6)) + 
geom_point(size=0.5, shape = 16) + 
scale_color_manual(values = c('none' =  "#a1a1a1",
                              'neg' = "#1b7837",
                              'pos' = "#762a83")) +
scale_alpha_manual(values = c("none" = 0.25, "neg" = 0.5, "pos"=0.5)) +
theme_minimal() + theme(legend.position=c(0.9,0.125)) + theme(
  axis.ticks = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank()
) + theme(
  axis.text = element_blank(),
  axis.title.x = element_blank(),
  axis.text.x = element_blank(),
  axis.text.y = element_blank(),
  axis.title.y = element_blank()
) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))

umap_bl6_other
# Out:
# Warning message:
# “Removed 6 rows containing missing values (`geom_point()`).”
# plot without title

# %%
options(repr.plot.width=3.5, repr.plot.height=3.5)
label_data <- da_results %>%
  filter(class == 'other') %>%
  mutate(labels = str_replace(labels, fixed('__'), '\n')) %>%
  group_by(labels) %>%
  summarise(UMAP_1 = mean(UMAP_1, na.rm = TRUE),
            UMAP_2 = mean(UMAP_2, na.rm =TRUE),
            label = first(labels))

umap_fgf1_other = da_results %>%
filter(class == 'other') %>%
mutate(polarity_fgf1 = factor(polarity_fgf1, levels = c("none", "neg", "pos"))) %>%
arrange(polarity_fgf1) %>%
ggplot(aes(x = UMAP_1, y = UMAP_2, color=polarity_fgf1, alpha=polarity_fgf1)) + 
geom_point(size=0.5, shape = 16) + 
scale_color_manual(values = c('none' =  "#a1a1a1",
                              'neg' = "#d73027",
                              'pos' = "#4575b4")) +
scale_alpha_manual(values = c("none" = 0.25, "neg" = 0.5, "pos"=0.5)) +
geom_text_repel(data = label_data, aes(x = UMAP_1, y = UMAP_2, label = label), 
              size = 2, 
              box.padding = unit(1, "lines"), 
              point.padding = unit(2, "lines"),
              segment.color = 'grey50',
              inherit.aes = FALSE) +
theme_minimal() + theme(legend.position=c(0.9,0.125)) + theme(
  axis.ticks = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank()
) + theme(
  axis.text = element_blank(),
  axis.title.x = element_blank(),
  axis.text.x = element_blank(),
  axis.text.y = element_blank(),
  axis.title.y = element_blank()
) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))


umap_fgf1_other
# Out:
# Warning message:
# “Removed 6 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 1 rows containing missing values (`geom_text_repel()`).”
# plot without title

# %%
options(repr.plot.width=3.5, repr.plot.height=3.5)
umap_restored_other = da_results %>%
filter(class == 'other') %>%
mutate(polarity = case_when(exact_grouping == 'pos_restored' ~ "pos",
                             exact_grouping == 'neg_restored' ~ "neg",
                             TRUE ~ 'other')) %>%
mutate(polarity = factor(polarity, levels = c("other", "neg", "pos"))) %>%
arrange(polarity) %>%
ggplot(aes(x = UMAP_1, y = UMAP_2, color=polarity, alpha=polarity)) + 
geom_point(size=0.5, shape = 16) + 
scale_color_manual(values = c('other' =  "#a1a1a1",
                              'neg' = "#a50026",
                              'pos' = "#313695")) +
scale_alpha_manual(values = c("other" = 0.25, "neg" = 0.5, "pos"=0.5)) +
theme_minimal() + theme(legend.position=c(0.9,0.125)) + theme(
  axis.ticks = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank()
) + theme(
  axis.text = element_blank(),
  axis.title.x = element_blank(),
  axis.text.x = element_blank(),
  axis.text.y = element_blank(),
  axis.title.y = element_blank()
) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))

umap_restored_other
# Out:
# Warning message:
# “Removed 6 rows containing missing values (`geom_point()`).”
# plot without title

# %%
all_restored_summary = qs::qread('_targets/objects/all_restored_summary') %>%
filter(comparison == 'Day14.obob14v14__v__Day14.obobBL6d14') %>%
mutate(prop_fgf1 = n_fgf1/n_total) %>%
mutate(prop_BL6 = n_BL6/n_total) %>%
mutate(prop_sum = prop_fgf1 + prop_BL6) %>%
arrange(desc(prop_fgf1))

all_restored_summary %>% head

label_order = all_restored_summary %>% pull(labels)
label_order
# Out:
#   labels       n_total n_fgf1 n_fgf1.pos n_fgf1.neg prop_fgf1.pos n_BL6
# 1 Microglia     15      2      1          1         0.5000000       2
# 2 b1_Tanycytes  94      8      4          4         0.5000000      21
# 3 Agrp         143     12      5          7         0.4166667     130
# 4 NG2_OPC2      21      1     NA          1                NA      10
# 5 MOL          103      4      4         NA         1.0000000      51
# 6 b2_Tany       26      1      1         NA         1.0000000       0
#   n_restored n_restored.pos n_restored.neg prop_restored_BL6 prop_restored_FGF1
# 1 0          0              0              0.00000000        0.0000000
# 2 0          0              0              0.00000000        0.0000000
# 3 7          0              7              0.05384615        0.5833333
# 4 0          0              0              0.00000000        0.0000000
# 5 0          0              0              0.00000000        0.0000000
# 6 0          0              0                     NaN        0.0000000
#   comparison                           prop_fgf1  prop_BL6  prop_sum
# 1 Day14.obob14v14__v__Day14.obobBL6d14 0.13333333 0.1333333 0.26666667
# 2 Day14.obob14v14__v__Day14.obobBL6d14 0.08510638 0.2234043 0.30851064
# 3 Day14.obob14v14__v__Day14.obobBL6d14 0.08391608 0.9090909 0.99300699
# 4 Day14.obob14v14__v__Day14.obobBL6d14 0.04761905 0.4761905 0.52380952
# 5 Day14.obob14v14__v__Day14.obobBL6d14 0.03883495 0.4951456 0.53398058
# 6 Day14.obob14v14__v__Day14.obobBL6d14 0.03846154 0.0000000 0.03846154
#  [1] "Microglia"                  "b1_Tanycytes"
#  [3] "Agrp"                       "NG2_OPC2"
#  [5] "MOL"                        "b2_Tany"
#  [7] "a1_Tany__Astrocytes"        "Astrocytes"
#  [9] "a2_Tanycytes"               "a2_Tanycytes__b1_Tanycytes"
# [11] "Epend"                      "Ghrh"
# [13] "Gm8773_Tac1__Hdc"           "Gpr50"
# [15] "Htr3b"                      "Kisspeptin"
# [17] "Nfix_Htr2c"                 "NG2_OPC2__Microglia"
# [19] "Nr5a1_Bdnf"                 "Nr5a1_Bdnf__Nr5a1_Nfib"
# [21] "Nr5a1_Bdnf__Unassigned1"    "Nr5a1_Nfib"
# [23] "Oxt__Unassigned1"           "Pomc_Glipr1__Slc17a6_Trhr"
# [25] "Pomc_Lepr"                  "Qrfp"
# [27] "Rgs16_Dlx1"                 "Rgs16_Dlx1__Unassigned2"
# [29] "Rgs16_Nmu"                  "Slc17a6_Fam19a2"
# [31] "Slc17a6_Trhr"               "Sst_Nts"
# [33] "Sst_Pthlh__Ghrh"            "Sst_Pthlh.sc21"
# [35] "Sst_Pthlh.sc23"             "Sst_Unc13c__Agrp"
# [37] "Tbx19"                      "Th_Nfib__Arx_Nr5a2"
# [39] "Th_Slc6a3"                  "Tmem215"
# [41] "Trh_Cxcl12"                 "Trh_Lef1"
# [43] "Unassigned1.sc17.sc28"      "Unassigned1.sc37"
# [45] "Unassigned1.sc39"           "Unassigned2"
# [47] "Unassigned2__Unassigned1"

# %%
all_restored_summary %>% filter(prop_sum > 0) %>%
left_join(labels_classes_tib, by='labels') %>%
group_by(class) %>% summarise(n=n())
# Out:
#   class  n
# 1 neuron 21
# 2 other   9

# %%
all_restored_summary %>%
left_join(labels_classes_tib, by='labels') %>%
filter(class=='neuron') %>%
arrange(desc(prop_sum)) %>%
head(20)
# Out:
#    labels                    n_total n_fgf1 n_fgf1.pos n_fgf1.neg prop_fgf1.pos
# 1  Agrp                      143     12      5          7         0.4166667
# 2  Sst_Unc13c__Agrp           94      0     NA         NA                NA
# 3  Ghrh                       59      0     NA         NA                NA
# 4  Kisspeptin                 87      0     NA         NA                NA
# 5  Pomc_Glipr1__Slc17a6_Trhr  90      0     NA         NA                NA
# 6  Trh_Cxcl12                109      0     NA         NA                NA
# 7  Pomc_Lepr                  70      0     NA         NA                NA
# 8  Htr3b                     104      0     NA         NA                NA
# 9  Tmem215                   115      0     NA         NA                NA
# 10 Th_Nfib__Arx_Nr5a2         43      0     NA         NA                NA
# 11 Unassigned1.sc37           31      0     NA         NA                NA
# 12 Tbx19                      80      0     NA         NA                NA
# 13 Rgs16_Dlx1                 36      0     NA         NA                NA
# 14 Nr5a1_Bdnf__Unassigned1    81      0     NA         NA                NA
# 15 Th_Slc6a3                  20      0     NA         NA                NA
# 16 Slc17a6_Fam19a2           154      0     NA         NA                NA
# 17 Sst_Pthlh.sc21             74      0     NA         NA                NA
# 18 Rgs16_Dlx1__Unassigned2    48      0     NA         NA                NA
# 19 Rgs16_Nmu                 134      0     NA         NA                NA
# 20 Nr5a1_Nfib                111      0     NA         NA                NA
#    n_BL6 n_restored n_restored.pos n_restored.neg prop_restored_BL6
# 1  130   7          0              7              0.05384615
# 2   57   0          0              0              0.00000000
# 3   32   0          0              0              0.00000000
# 4   46   0          0              0              0.00000000
# 5   47   0          0              0              0.00000000
# 6   54   0          0              0              0.00000000
# 7   32   0          0              0              0.00000000
# 8   44   0          0              0              0.00000000
# 9   40   0          0              0              0.00000000
# 10  11   0          0              0              0.00000000
# 11   6   0          0              0              0.00000000
# 12  14   0          0              0              0.00000000
# 13   5   0          0              0              0.00000000
# 14   5   0          0              0              0.00000000
# 15   1   0          0              0              0.00000000
# 16   5   0          0              0              0.00000000
# 17   2   0          0              0              0.00000000
# 18   1   0          0              0              0.00000000
# 19   2   0          0              0              0.00000000
# 20   1   0          0              0              0.00000000
#    prop_restored_FGF1 comparison                           prop_fgf1
# 1  0.5833333          Day14.obob14v14__v__Day14.obobBL6d14 0.08391608
# 2        NaN          Day14.obob14v14__v__Day14.obobBL6d14 0.00000000
# 3        NaN          Day14.obob14v14__v__Day14.obobBL6d14 0.00000000
# 4        NaN          Day14.obob14v14__v__Day14.obobBL6d14 0.00000000
# 5        NaN          Day14.obob14v14__v__Day14.obobBL6d14 0.00000000
# 6        NaN          Day14.obob14v14__v__Day14.obobBL6d14 0.00000000
# 7        NaN          Day14.obob14v14__v__Day14.obobBL6d14 0.00000000
# 8        NaN          Day14.obob14v14__v__Day14.obobBL6d14 0.00000000
# 9        NaN          Day14.obob14v14__v__Day14.obobBL6d14 0.00000000
# 10       NaN          Day14.obob14v14__v__Day14.obobBL6d14 0.00000000
# 11       NaN          Day14.obob14v14__v__Day14.obobBL6d14 0.00000000
# 12       NaN          Day14.obob14v14__v__Day14.obobBL6d14 0.00000000
# 13       NaN          Day14.obob14v14__v__Day14.obobBL6d14 0.00000000
# 14       NaN          Day14.obob14v14__v__Day14.obobBL6d14 0.00000000
# 15       NaN          Day14.obob14v14__v__Day14.obobBL6d14 0.00000000
# 16       NaN          Day14.obob14v14__v__Day14.obobBL6d14 0.00000000
# 17       NaN          Day14.obob14v14__v__Day14.obobBL6d14 0.00000000
# 18       NaN          Day14.obob14v14__v__Day14.obobBL6d14 0.00000000
# 19       NaN          Day14.obob14v14__v__Day14.obobBL6d14 0.00000000
# 20       NaN          Day14.obob14v14__v__Day14.obobBL6d14 0.00000000
#    prop_BL6    prop_sum    class
# 1  0.909090909 0.993006993 neuron
# 2  0.606382979 0.606382979 neuron
# 3  0.542372881 0.542372881 neuron
# 4  0.528735632 0.528735632 neuron
# 5  0.522222222 0.522222222 neuron
# 6  0.495412844 0.495412844 neuron
# 7  0.457142857 0.457142857 neuron
# 8  0.423076923 0.423076923 neuron
# 9  0.347826087 0.347826087 neuron
# 10 0.255813953 0.255813953 neuron
# 11 0.193548387 0.193548387 neuron
# 12 0.175000000 0.175000000 neuron
# 13 0.138888889 0.138888889 neuron
# 14 0.061728395 0.061728395 neuron
# 15 0.050000000 0.050000000 neuron
# 16 0.032467532 0.032467532 neuron
# 17 0.027027027 0.027027027 neuron
# 18 0.020833333 0.020833333 neuron
# 19 0.014925373 0.014925373 neuron
# 20 0.009009009 0.009009009 neuron

# %%
unchanged_labels = all_restored_summary %>%
filter(!(prop_sum > 0)) %>%
pull(labels)
unchanged_labels
# Out:
#  [1] "Epend"                    "Gm8773_Tac1__Hdc"
#  [3] "Gpr50"                    "Nfix_Htr2c"
#  [5] "NG2_OPC2__Microglia"      "Nr5a1_Bdnf"
#  [7] "Nr5a1_Bdnf__Nr5a1_Nfib"   "Oxt__Unassigned1"
#  [9] "Qrfp"                     "Slc17a6_Trhr"
# [11] "Sst_Nts"                  "Sst_Pthlh__Ghrh"
# [13] "Sst_Pthlh.sc23"           "Trh_Lef1"
# [15] "Unassigned1.sc39"         "Unassigned2"
# [17] "Unassigned2__Unassigned1"

# %%
all_restored_summary %>%
filter(str_detect(labels, 'Ghrh'))
# Out:
#   labels          n_total n_fgf1 n_fgf1.pos n_fgf1.neg prop_fgf1.pos n_BL6
# 1 Ghrh            59      0      NA         NA         NA            32
# 2 Sst_Pthlh__Ghrh 16      0      NA         NA         NA             0
#   n_restored n_restored.pos n_restored.neg prop_restored_BL6 prop_restored_FGF1
# 1 0          0              0                0               NaN
# 2 0          0              0              NaN               NaN
#   comparison                           prop_fgf1 prop_BL6  prop_sum
# 1 Day14.obob14v14__v__Day14.obobBL6d14 0         0.5423729 0.5423729
# 2 Day14.obob14v14__v__Day14.obobBL6d14 0         0.0000000 0.0000000

# %%
beeswarm_tibble = da_results %>%
select(Nhood, labels, class, n_cells, polarity_fgf1, SpatialFDR_fgf1, logFC_fgf1, polarity_bl6, SpatialFDR_bl6, logFC_bl6, exact_grouping) %>%
mutate(restored = case_when(exact_grouping == 'pos_restored' ~ 'yes',
                             exact_grouping == 'neg_restored' ~ 'yes',
                             TRUE ~ 'no')) %>%
mutate(restored = factor(restored, levels=c('no', 'yes')))

# Separate data frames for each type of measurement
polarity_df <- beeswarm_tibble %>%
  select(Nhood, labels, class, n_cells, starts_with("polarity"), exact_grouping, restored) %>%
  pivot_longer(cols = starts_with("polarity"),
               names_to = "comparison",
               values_to = "polarity") %>%
  mutate(comparison = ifelse(str_detect(comparison, "bl6"), "BL6", "FGF1"))

spatial_df <- beeswarm_tibble %>%
  select(Nhood, labels, class, n_cells, starts_with("SpatialFDR"), exact_grouping, restored) %>%
  pivot_longer(cols = starts_with("SpatialFDR"),
               names_to = "comparison",
               values_to = "SpatialFDR") %>%
  mutate(comparison = ifelse(str_detect(comparison, "bl6"), "BL6", "FGF1"))

logfc_df <- beeswarm_tibble %>%
  select(Nhood, labels, class, n_cells, starts_with("logFC"), exact_grouping, restored) %>%
  pivot_longer(cols = starts_with("logFC"),
               names_to = "comparison",
               values_to = "logFC") %>%
  mutate(comparison = ifelse(str_detect(comparison, "bl6"), "BL6", "FGF1"))

# Join all dataframes
beeswarm_tibble <- polarity_df %>%
  inner_join(spatial_df, by = c("Nhood", "labels", "class", "n_cells", "comparison", "exact_grouping", "restored")) %>%
  inner_join(logfc_df, by = c("Nhood", "labels", "class", "n_cells", "comparison", "exact_grouping", "restored"))


beeswarm_tibble = beeswarm_tibble %>%
mutate(labels = factor(labels, levels=rev(label_order))) %>%
rowwise %>%
mutate(label.group = paste0(labels, '.', comparison)) %>% 
ungroup %>%
mutate(polarity = paste0(polarity, '.', comparison)) %>%
mutate(polarity = case_when(str_detect(polarity, 'none') ~ 'none',
                            TRUE ~ polarity)) %>%
mutate(polarity = factor(polarity, levels=rev(c('none', 'neg.BL6', 'pos.BL6', 'neg.FGF1', 'pos.FGF1')))) %>%
arrange(desc(labels))

beeswarm_tibble
# Out:
#      Nhood labels                   class  n_cells exact_grouping restored
# 1    13    Microglia                other  216     pos_FGF1       no
# 2    13    Microglia                other  216     pos_FGF1       no
# 3     9    Microglia                other  164     neg_FGF1       no
# 4     9    Microglia                other  164     neg_FGF1       no
# 5    14    Microglia                other  145     none           no
# 6    14    Microglia                other  145     none           no
# 7     3    Microglia                other  285     none           no
# 8     3    Microglia                other  285     none           no
# 9     7    Microglia                other  215     none           no
# 10    7    Microglia                other  215     none           no
# 11   11    Microglia                other  173     pos_BL6        no
# 12   11    Microglia                other  173     pos_BL6        no
# 13    5    Microglia                other  104     none           no
# 14    5    Microglia                other  104     none           no
# 15    2    Microglia                other  325     none           no
# 16    2    Microglia                other  325     none           no
# 17    6    Microglia                other  226     none           no
# 18    6    Microglia                other  226     none           no
# 19   10    Microglia                other  191     none           no
# 20   10    Microglia                other  191     none           no
# 21    1    Microglia                other  255     pos_BL6        no
# 22    1    Microglia                other  255     pos_BL6        no
# 23   12    Microglia                other  194     none           no
# 24   12    Microglia                other  194     none           no
# 25   15    Microglia                other  168     none           no
# 26   15    Microglia                other  168     none           no
# 27    4    Microglia                other   44     none           no
# 28    4    Microglia                other   44     none           no
# 29    8    Microglia                other   42     none           no
# 30    8    Microglia                other   42     none           no
# ⋮    ⋮     ⋮                        ⋮      ⋮       ⋮              ⋮
# 8381 414   Unassigned2              neuron  68     none           no
# 8382 414   Unassigned2              neuron  68     none           no
# 8383 415   Unassigned2              neuron 127     none           no
# 8384 415   Unassigned2              neuron 127     none           no
# 8385 416   Unassigned2              neuron  74     none           no
# 8386 416   Unassigned2              neuron  74     none           no
# 8387 417   Unassigned2              neuron  57     none           no
# 8388 417   Unassigned2              neuron  57     none           no
# 8389 418   Unassigned2              neuron  53     none           no
# 8390 418   Unassigned2              neuron  53     none           no
# 8391 419   Unassigned2              neuron 104     none           no
# 8392 419   Unassigned2              neuron 104     none           no
# 8393 420   Unassigned2              neuron  68     none           no
# 8394 420   Unassigned2              neuron  68     none           no
# 8395   1   Unassigned2__Unassigned1 neuron 116     none           no
# 8396   1   Unassigned2__Unassigned1 neuron 116     none           no
# 8397   2   Unassigned2__Unassigned1 neuron  63     none           no
# 8398   2   Unassigned2__Unassigned1 neuron  63     none           no
# 8399   3   Unassigned2__Unassigned1 neuron  85     none           no
# 8400   3   Unassigned2__Unassigned1 neuron  85     none           no
# 8401   4   Unassigned2__Unassigned1 neuron 114     none           no
# 8402   4   Unassigned2__Unassigned1 neuron 114     none           no
# 8403   5   Unassigned2__Unassigned1 neuron 116     none           no
# 8404   5   Unassigned2__Unassigned1 neuron 116     none           no
# 8405   6   Unassigned2__Unassigned1 neuron  79     none           no
# 8406   6   Unassigned2__Unassigned1 neuron  79     none           no
# 8407   7   Unassigned2__Unassigned1 neuron  57     none           no
# 8408   7   Unassigned2__Unassigned1 neuron  57     none           no
# 8409   8   Unassigned2__Unassigned1 neuron  57     none           no
# 8410   8   Unassigned2__Unassigned1 neuron  57     none           no
#      comparison polarity SpatialFDR  logFC        label.group
# 1    FGF1       pos.FGF1 0.006057997  0.78728667  Microglia.FGF1
# 2    BL6        none     0.316465781  0.39358123  Microglia.BL6
# 3    FGF1       neg.FGF1 0.064409350 -0.82547521  Microglia.FGF1
# 4    BL6        none     0.338834159 -0.42956058  Microglia.BL6
# 5    FGF1       none     0.107320097  0.61854019  Microglia.FGF1
# 6    BL6        none     0.338834159  0.41453585  Microglia.BL6
# 7    FGF1       none     0.133864369 -0.38119014  Microglia.FGF1
# 8    BL6        none     0.200231830  0.36687699  Microglia.BL6
# 9    FGF1       none     0.133864369  0.43116594  Microglia.FGF1
# 10   BL6        none     0.493812668  0.21318163  Microglia.BL6
# 11   FGF1       none     0.133864369 -0.58134452  Microglia.FGF1
# 12   BL6        neg.BL6  0.079573602 -1.03673512  Microglia.BL6
# 13   FGF1       none     0.215853675  0.52408758  Microglia.FGF1
# 14   BL6        none     0.198542688  0.74899446  Microglia.BL6
# 15   FGF1       none     0.343669501 -0.23647383  Microglia.FGF1
# 16   BL6        none     0.370876195  0.21054645  Microglia.BL6
# 17   FGF1       none     0.521317839 -0.18312743  Microglia.FGF1
# 18   BL6        none     0.200231830 -0.47767932  Microglia.BL6
# 19   FGF1       none     0.521317839 -0.23538775  Microglia.FGF1
# 20   BL6        none     0.810889225 -0.07904196  Microglia.BL6
# 21   FGF1       none     0.672455557  0.10349311  Microglia.FGF1
# 22   BL6        neg.BL6  0.079573602 -0.67572825  Microglia.BL6
# 23   FGF1       none     0.672455557  0.12891326  Microglia.FGF1
# 24   BL6        none     0.200231830 -0.56840066  Microglia.BL6
# 25   FGF1       none     0.708060171  0.13812973  Microglia.FGF1
# 26   BL6        none     0.361020672  0.42142090  Microglia.BL6
# 27   FGF1       none     0.962296373 -0.03631148  Microglia.FGF1
# 28   BL6        none     0.810889225  0.22687911  Microglia.BL6
# 29   FGF1       none     0.962296373 -0.05644472  Microglia.FGF1
# 30   BL6        none     0.810889225  0.31290759  Microglia.BL6
# ⋮    ⋮          ⋮        ⋮           ⋮            ⋮
# 8381 FGF1       none     0.9980504    0.079068352 Unassigned2.FGF1
# 8382 BL6        none     0.9939387   -0.085543066 Unassigned2.BL6
# 8383 FGF1       none     0.9980504    0.117951155 Unassigned2.FGF1
# 8384 BL6        none     0.9856375    0.688671932 Unassigned2.BL6
# 8385 FGF1       none     0.9980504    0.155839058 Unassigned2.FGF1
# 8386 BL6        none     0.9856375   -0.518671201 Unassigned2.BL6
# 8387 FGF1       none     0.9980504    0.136743016 Unassigned2.FGF1
# 8388 BL6        none     0.9856375   -0.453495998 Unassigned2.BL6
# 8389 FGF1       none     0.9980504    0.389499315 Unassigned2.FGF1
# 8390 BL6        none     0.9910473   -0.205044230 Unassigned2.BL6
# 8391 FGF1       none     0.9980504    0.220403429 Unassigned2.FGF1
# 8392 BL6        none     0.9856375    0.782145793 Unassigned2.BL6
# 8393 FGF1       none     0.9980504   -0.237837001 Unassigned2.FGF1
# 8394 BL6        none     0.9856375   -0.568960520 Unassigned2.BL6
# 8395 FGF1       none     0.9794733   -0.008657678 Unassigned2__Unassigned1.FGF1
# 8396 BL6        none     0.8740328    0.156385877 Unassigned2__Unassigned1.BL6
# 8397 FGF1       none     0.9794733   -0.480786669 Unassigned2__Unassigned1.FGF1
# 8398 BL6        none     0.8740328    0.179587815 Unassigned2__Unassigned1.BL6
# 8399 FGF1       none     0.9794733    0.043818607 Unassigned2__Unassigned1.FGF1
# 8400 BL6        none     0.8740328    0.076183953 Unassigned2__Unassigned1.BL6
# 8401 FGF1       none     0.9794733   -0.009219967 Unassigned2__Unassigned1.FGF1
# 8402 BL6        none     0.8740328    0.215337405 Unassigned2__Unassigned1.BL6
# 8403 FGF1       none     0.9794733   -0.070629953 Unassigned2__Unassigned1.FGF1
# 8404 BL6        none     0.8740328    0.076224461 Unassigned2__Unassigned1.BL6
# 8405 FGF1       none     0.9794733   -0.252134734 Unassigned2__Unassigned1.FGF1
# 8406 BL6        none     0.8740328    0.226899685 Unassigned2__Unassigned1.BL6
# 8407 FGF1       none     0.9794733    0.208697507 Unassigned2__Unassigned1.FGF1
# 8408 BL6        none     0.8740328   -0.178488021 Unassigned2__Unassigned1.BL6
# 8409 FGF1       none     0.9794733    0.039335606 Unassigned2__Unassigned1.FGF1
# 8410 BL6        none     0.8740328   -0.429327714 Unassigned2__Unassigned1.BL6

# %%
beeswarm_tibble %>% head %>% print
# Out:
# # A tibble: 6 × 11
#   Nhood labels    class n_cells exact_grouping restored comparison polarity
#   <dbl> <fct>     <chr>   <dbl> <chr>          <fct>    <chr>      <fct>
# 1    13 Microglia other     216 pos_FGF1       no       FGF1       pos.FGF1
# 2    13 Microglia other     216 pos_FGF1       no       BL6        none
# 3     9 Microglia other     164 neg_FGF1       no       FGF1       neg.FGF1
# 4     9 Microglia other     164 neg_FGF1       no       BL6        none
# 5    14 Microglia other     145 none           no       FGF1       none
# 6    14 Microglia other     145 none           no       BL6        none
# # ℹ 3 more variables: SpatialFDR <dbl>, logFC <dbl>, label.group <chr>

# %%
beeswarm_tibble %>% pull(polarity) %>% unique
beeswarm_tibble %>% pull(polarity) %>% levels
# Out:
# [1] pos.FGF1 none     neg.FGF1 neg.BL6  pos.BL6
# Levels: pos.FGF1 neg.FGF1 pos.BL6 neg.BL6 none
# [1] "pos.FGF1" "neg.FGF1" "pos.BL6"  "neg.BL6"  "none"

# %%
beeswarm_tibble %>% filter(restored == 'yes') %>% dim
# Out:
# [1] 14 11

# %%
options(repr.plot.width=3.5, repr.plot.height=10)

# Creating a separate tibble for the labels
label_tibble <- beeswarm_tibble %>%
  filter(class == 'other')  %>%
#   filter(!(labels %in% unchanged_labels)) %>%
  distinct(labels)

beeswarm_other = beeswarm_tibble %>%
  filter(class == 'other') %>%
#   filter(!(labels %in% unchanged_labels)) %>%
  arrange(labels, polarity, restored) %>%
  ggplot(aes(logFC, labels, group=comparison, color=polarity, alpha=polarity, shape=restored)) + 
  geom_quasirandom(size=1, dodge.width = 1, orientation='y') +
  scale_shape_manual(values = c(yes=19, no=1)) +
  scale_color_manual(values = c('none' =  "#a1a1a1",
                                'neg.FGF1' = "#d73027",
                                'pos.FGF1' = "#4575b4",
                                'neg.BL6' = "#00441b",
                                'pos.BL6' = "#40004b")) + 
  scale_alpha_manual(values = c('none' =  0.5,
                                'neg.FGF1' = 0.5,
                                'pos.FGF1' = 0.5,
                                'neg.BL6' = 0.5,
                                'pos.BL6' = 0.5)) +
  geom_text(data = label_tibble, aes(x = 0, y = labels, label = labels), size=3, hjust = 0.5, vjust = 0.5, inherit.aes = FALSE) +
  theme_classic() +
  theme(axis.title.y = element_blank(),
        axis.ticks.y = element_blank(),
        axis.text.y = element_blank())  + 
theme(legend.position=c(0.9,0.08)) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))
beeswarm_other
# Out:
# plot without title

# %%
options(repr.plot.width=7, repr.plot.height=10)
layout <- '
AB
AC
AD
'

ggp = wrap_plots(A = beeswarm_other,
           B = umap_fgf1_other,
           C = umap_bl6_other,
           D = umap_restored_other,
    design = layout) +
plot_layout(guides = 'auto') 

ggp %>% ggsave('beeswarm_umap_other_d14.pdf', plot = ., width = 7, height=9)
ggp
# Out:
# Warning message:
# “Removed 6 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 1 rows containing missing values (`geom_text_repel()`).”
# Warning message:
# “Removed 6 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 6 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 6 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 1 rows containing missing values (`geom_text_repel()`).”
# Warning message:
# “Removed 6 rows containing missing values (`geom_point()`).”
# Warning message:
# “Removed 6 rows containing missing values (`geom_point()`).”
# plot without title

# %%
options(repr.plot.width=3.5, repr.plot.height=3.5)

unchanged_labels_bl6 = da_results %>%
group_by(labels) %>%
summarise(polarities = polarity_bl6 %>% unique) %>%
group_by(labels) %>%
summarise(n=n()) %>%
filter(n == 1) %>%
pull(labels)
unchanged_labels_bl6 %>% length

label_data <- da_results %>%
  filter(class == 'neuron') %>%
  filter(!(labels %in% unchanged_labels_bl6)) %>%
  mutate(labels = str_replace(labels, fixed('__'), '\n')) %>%
  group_by(labels) %>%
  summarise(UMAP_1 = mean(UMAP_1, na.rm = TRUE),
            UMAP_2 = mean(UMAP_2, na.rm =TRUE),
            label = first(labels))

umap_bl6_neuron = da_results %>%
filter(class == 'neuron') %>%
mutate(polarity_bl6 = factor(polarity_bl6, levels = c("none", "neg", "pos"))) %>%
arrange(polarity_bl6) %>%
ggplot(aes(x = UMAP_1, y = UMAP_2, color=polarity_bl6, alpha=polarity_bl6)) + 
geom_point(size=0.5, shape = 16) + 
scale_color_manual(values = c('none' =  "#a1a1a1",
                              'neg' = "#1b7837",
                              'pos' = "#762a83")) +
scale_alpha_manual(values = c("none" = 0.25, "neg" = 0.5, "pos"=0.5)) +
geom_text_repel(data = label_data, aes(x = UMAP_1, y = UMAP_2, label = label), 
              size = 2, 
              box.padding = unit(0, "lines"), 
              point.padding = unit(0, "lines"),
              segment.color = 'grey50',
              inherit.aes = FALSE) +
theme_minimal() + theme(legend.position=c(0.9,0.125)) + theme(
  axis.ticks = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank()
) + theme(
  axis.text = element_blank(),
  axis.title.x = element_blank(),
  axis.text.x = element_blank(),
  axis.text.y = element_blank(),
  axis.title.y = element_blank()
) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))

umap_bl6_neuron
# Out:
# Warning message:
# “Returning more (or less) than 1 row per `summarise()` group was deprecated in
# dplyr 1.1.0.
# ℹ Please use `reframe()` instead.
# ℹ When switching from `summarise()` to `reframe()`, remember that `reframe()`
#   always returns an ungrouped data frame and adjust accordingly.”
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# [1] 18
# plot without title

# %%
options(repr.plot.width=3.5, repr.plot.height=3.5)

unchanged_labels_fgf1 = da_results %>%
group_by(labels) %>%
summarise(polarities = polarity_fgf1 %>% unique) %>%
group_by(labels) %>%
summarise(n=n()) %>%
filter(n == 1) %>%
pull(labels)
unchanged_labels_fgf1 %>% length

label_data <- da_results %>%
  filter(class == 'neuron') %>%
  filter(!(labels %in% unchanged_labels_fgf1)) %>%
  mutate(labels = str_replace(labels, fixed('__'), '\n')) %>%
  group_by(labels) %>%
  summarise(UMAP_1 = mean(UMAP_1, na.rm = TRUE),
            UMAP_2 = mean(UMAP_2, na.rm =TRUE),
            label = first(labels))

umap_fgf1_neuron = da_results %>%
filter(class == 'neuron') %>%
mutate(polarity_fgf1 = factor(polarity_fgf1, levels = c("none", "neg", "pos"))) %>%
arrange(polarity_fgf1) %>%
ggplot(aes(x = UMAP_1, y = UMAP_2, color=polarity_fgf1, alpha=polarity_fgf1)) + 
geom_point(size=0.5, shape = 16) + 
scale_color_manual(values = c('none' =  "#a1a1a1",
                              'neg' = "#d73027",
                              'pos' = "#4575b4")) +
scale_alpha_manual(values = c("none" = 0.25, "neg" = 0.5, "pos"=0.5)) +
geom_text_repel(data = label_data, aes(x = UMAP_1, y = UMAP_2, label = label), 
              size = 2, 
              box.padding = unit(0, "lines"), 
              point.padding = unit(0, "lines"),
              segment.color = 'grey50',
              inherit.aes = FALSE) +
theme_minimal() + theme(legend.position=c(0.9,0.125)) + theme(
  axis.ticks = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank()
) + theme(
  axis.text = element_blank(),
  axis.title.x = element_blank(),
  axis.text.x = element_blank(),
  axis.text.y = element_blank(),
  axis.title.y = element_blank()
) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))


umap_fgf1_neuron
# Out:
# Warning message:
# “Returning more (or less) than 1 row per `summarise()` group was deprecated in
# dplyr 1.1.0.
# ℹ Please use `reframe()` instead.
# ℹ When switching from `summarise()` to `reframe()`, remember that `reframe()`
#   always returns an ungrouped data frame and adjust accordingly.”
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# [1] 39
# plot without title

# %%
options(repr.plot.width=3.5, repr.plot.height=3.5)

label_data <- da_results %>%
  filter(class == 'neuron') %>%
  filter(!(labels %in% unchanged_labels_fgf1)) %>%
  filter(!(labels %in% unchanged_labels_bl6)) %>%
  mutate(labels = str_replace(labels, fixed('__'), '\n')) %>%
  group_by(labels) %>%
  summarise(UMAP_1 = mean(UMAP_1, na.rm = TRUE),
            UMAP_2 = mean(UMAP_2, na.rm =TRUE),
            label = first(labels))

umap_restored_neuron = da_results %>%
filter(class == 'neuron') %>%
mutate(polarity = case_when(exact_grouping == 'pos_restored' ~ "pos",
                             exact_grouping == 'neg_restored' ~ "neg",
                             TRUE ~ 'other')) %>%
mutate(polarity = factor(polarity, levels = c("other", "neg", "pos"))) %>%
arrange(polarity) %>%
ggplot(aes(x = UMAP_1, y = UMAP_2, color=polarity, alpha=polarity)) + 
geom_point(size=0.5, shape = 16) + 
scale_color_manual(values = c('other' =  "#a1a1a1",
                              'neg' = "#a50026",
                              'pos' = "#313695")) +
scale_alpha_manual(values = c("other" = 0.25, "neg" = 0.5, "pos"=0.5)) +
geom_text_repel(data = label_data, aes(x = UMAP_1, y = UMAP_2, label = label), 
              size = 2, 
              box.padding = unit(0, "lines"), 
              point.padding = unit(0, "lines"),
              segment.color = 'grey50',
              inherit.aes = FALSE) +
theme_minimal() + theme(legend.position=c(0.9,0.125)) + theme(
  axis.ticks = element_blank(),
  panel.grid.major = element_blank(),
  panel.grid.minor = element_blank()
) + theme(
  axis.text = element_blank(),
  axis.title.x = element_blank(),
  axis.text.x = element_blank(),
  axis.text.y = element_blank(),
  axis.title.y = element_blank()
) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))

umap_restored_neuron
# Out:
# plot without title

# %%
options(repr.plot.width=3.5, repr.plot.height=10)

# Creating a separate tibble for the labels
label_tibble <- da_results %>%
  filter(class == 'neuron') %>%
  filter((polarity_fgf1 %in% c('pos', 'neg')) | (polarity_bl6 %in% c('pos', 'neg'))) %>%
  distinct(labels)

beeswarm_neuron = beeswarm_tibble %>%
  filter(class == 'neuron') %>%
  filter((labels %in% label_tibble$labels)) %>%
  arrange(labels, polarity, restored) %>%
  ggplot(aes(logFC, labels, group=comparison, color=polarity, alpha=polarity, shape=restored)) + 
  geom_quasirandom(size=1, dodge.width = 1, orientation='y') +
  scale_shape_manual(values = c(yes=19, no=1)) +
  scale_color_manual(values = c('none' =  "#a1a1a1",
                                'neg.FGF1' = "#d73027",
                                'pos.FGF1' = "#4575b4",
                                'neg.BL6' = "#00441b",
                                'pos.BL6' = "#40004b")) + 
  scale_alpha_manual(values = c('none' =  0.25,
                                'neg.FGF1' = 0.25,
                                'pos.FGF1' = 0.25,
                                'neg.BL6' = 0.25,
                                'pos.BL6' = 0.25)) +
  geom_text(data = label_tibble, aes(x = 0, y = labels, label = labels), size=3, hjust = 0.5, vjust = 0.5, inherit.aes = FALSE) +
  theme_classic() +
  theme(axis.title.y = element_blank(),
        axis.ticks.y = element_blank(),
        axis.text.y = element_blank())  + 
theme(legend.position=c(0.85,0.3)) + 
theme(legend.text = element_text(size = 5),
      legend.title = element_text(size = 6),
      legend.key.height = unit(0.2, "cm"))

beeswarm_neuron
# Out:
# plot without title

# %%
options(repr.plot.width=7, repr.plot.height=9.5)
layout <- '
AB
AC
AD
'

ggp = wrap_plots(A = beeswarm_neuron,
           B = umap_fgf1_neuron,
           C = umap_bl6_neuron,
           D = umap_restored_neuron,
    design = layout) +
plot_layout(guides = 'auto') 

ggp %>% ggsave('beeswarm_umap_neurons_d14.pdf', plot = ., width = 7, height=9)
ggp
# Out:
# plot without title

# %%
beeswarm_tibble %>% qs::qsave('beeswarm_tibble_d14.qs')
da_results %>% qs::qsave('beeswarm_da_results_d14.qs')
