# %%
library(tidyverse)
library(writexl)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.2     ✔ purrr   0.3.4
# ✔ tibble  3.2.1     ✔ dplyr   1.1.2
# ✔ tidyr   1.2.1     ✔ stringr 1.4.1
# ✔ readr   2.1.2     ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
split_data_to_excel <- function(input_data, output_dir) {
  # group the data by the "tag" column and create a list of data frames
  grouped_data <- input_data %>% group_split(tag)

  # loop through the groups and write each one to a separate Excel file in a subfolder for each combination of values
  walk2(grouped_data, unique(input_data$tag), function(df, group_val) {
    folder_name <- paste0(output_dir, "/", df$fgf1_day[1], ".", df$fgf1_comparison[1], "__v__", df$bl6_day[1], ".", df$bl6_comparison[1])
    if (!dir.exists(folder_name)) {
      dir.create(folder_name, recursive = TRUE)
    }
    write_xlsx(df, paste0(folder_name, "/", group_val, ".xlsx"))
  })
}

# %%
combined_deg_seurat_formatted = qs::qread('_targets/objects/combined_deg_seurat_formatted')
combined_deg_seurat_formatted %>% write_csv('combined_deg_seurat_formatted.csv')
# split_data_to_excel(combined_deg_seurat_formatted, "outputs/deg_seurat")
combined_deg_seurat_formatted %>% head
# Out:
#   tag
# 1 a1_Tany__Astrocytes___all.obob5v5__v__all.obob14vBL6___fgf1_grouping.neg_vs_none
# 2 a1_Tany__Astrocytes___all.obob5v5__v__all.obob14vBL6___fgf1_grouping.neg_vs_none
# 3 a1_Tany__Astrocytes___all.obob5v5__v__all.obob14vBL6___fgf1_grouping.neg_vs_none
# 4 a1_Tany__Astrocytes___all.obob5v5__v__all.obob14vBL6___fgf1_grouping.neg_vs_none
# 5 a1_Tany__Astrocytes___all.obob5v5__v__all.obob14vBL6___fgf1_grouping.neg_vs_none
# 6 a1_Tany__Astrocytes___all.obob5v5__v__all.obob14vBL6___fgf1_grouping.neg_vs_none
#   data_day cluster             fgf1_day fgf1_comparison bl6_day bl6_comparison
# 1 all      a1_Tany__Astrocytes all      obob5v5         all     obob14vBL6
# 2 all      a1_Tany__Astrocytes all      obob5v5         all     obob14vBL6
# 3 all      a1_Tany__Astrocytes all      obob5v5         all     obob14vBL6
# 4 all      a1_Tany__Astrocytes all      obob5v5         all     obob14vBL6
# 5 all      a1_Tany__Astrocytes all      obob5v5         all     obob14vBL6
# 6 all      a1_Tany__Astrocytes all      obob5v5         all     obob14vBL6
#   grouping      cells_a cells_b GeneID p_val        avg_log2FC pct.1 pct.2
# 1 fgf1_grouping neg     none    Sgcd   1.006914e-19 0.4943435  0.729 0.618
# 2 fgf1_grouping neg     none    Kcnip4 3.665186e-14 0.6583016  0.705 0.649
# 3 fgf1_grouping neg     none    Zfhx3  7.390493e-20 0.3635134  0.918 0.863
# 4 fgf1_grouping neg     none    Cadm1  3.323447e-26 0.2413559  1.000 0.999
# 5 fgf1_grouping neg     none    Lama2  2.002614e-18 0.3048799  0.878 0.763
# 6 fgf1_grouping neg     none    Gria2  4.936700e-16 0.2764835  0.847 0.771
#   p_val_adj    ensmusg            gsea_sort_score
# 1 1.934685e-15 ENSMUSG00000020354 7.273468
# 2 7.042288e-10 ENSMUSG00000029088 6.024965
# 3 1.420009e-15 ENSMUSG00000038872 5.397341
# 4 6.385672e-22 ENSMUSG00000032076 5.115489
# 5 3.847822e-14 ENSMUSG00000019899 4.089898
# 6 9.485375e-12 ENSMUSG00000033981 3.047662

# %%
combined_gsea_seurat_formatted = qs::qread('_targets/objects/combined_gsea_seurat_formatted')
split_data_to_excel(combined_gsea_seurat_formatted, "outputs/gsea_seurat")
combined_gsea_seurat_formatted %>% write_csv('combined_gsea_seurat_formatted')
combined_gsea_seurat_formatted %>% head
# Out:
#   tag
# 1 a1_Tany__Astrocytes___all.obob5v5__v__all.obob14vBL6___fgf1_grouping.neg_vs_none
# 2 a1_Tany__Astrocytes___all.obob5v5__v__all.obob14vBL6___fgf1_grouping.neg_vs_rest
# 3 a1_Tany__Astrocytes___all.obob5v5__v__all.obob14vBL6___fgf1_grouping.neg_vs_rest
# 4 a1_Tany__Astrocytes___all.obob5v5__v__all.obob14vBL6___fgf1_grouping.neg_vs_rest
# 5 a1_Tany__Astrocytes___all.obob5v5__v__all.obob14vBL6___fgf1_grouping.neg_vs_rest
# 6 a1_Tany__Astrocytes___all.obob5v5__v__all.obob14vBL6___fgf1_grouping.neg_vs_rest
#   data_day cluster             fgf1_day fgf1_comparison bl6_day bl6_comparison
# 1 all      a1_Tany__Astrocytes all      obob5v5         all     obob14vBL6
# 2 all      a1_Tany__Astrocytes all      obob5v5         all     obob14vBL6
# 3 all      a1_Tany__Astrocytes all      obob5v5         all     obob14vBL6
# 4 all      a1_Tany__Astrocytes all      obob5v5         all     obob14vBL6
# 5 all      a1_Tany__Astrocytes all      obob5v5         all     obob14vBL6
# 6 all      a1_Tany__Astrocytes all      obob5v5         all     obob14vBL6
#   grouping      cells_a cells_b ⋯ gs_subcat
# 1 fgf1_grouping neg     none    ⋯ GO:MF
# 2 fgf1_grouping neg     rest    ⋯ CGP
# 3 fgf1_grouping neg     rest    ⋯ CGP
# 4 fgf1_grouping neg     rest    ⋯ CGP
# 5 fgf1_grouping neg     rest    ⋯ MIR:MIR_Legacy
# 6 fgf1_grouping neg     rest    ⋯ TFT:GTRD
#   pathway
# 1 GOMF_PROTEIN_CONTAINING_COMPLEX_BINDING
# 2 BENPORATH_PRC2_TARGETS
# 3 BENPORATH_SUZ12_TARGETS
# 4 WONG_ADULT_TISSUE_STEM_MODULE
# 5 ACTGTGA_MIR27A_MIR27B
# 6 MAFG_TARGET_GENES
#   gs_description
# 1 Binding to a macromolecular complex. [GOC:jl]
# 2 Set 'PRC2 targets': Polycomb Repression Complex 2 (PRC) targets; identified by ChIP on chip on human embryonic stem cells as genes that: posess the trimethylated H3K27 mark in their promoters and are bound by SUZ12 [GeneID=23512] and EED [GeneID=8726] Polycomb proteins.
# 3 Set 'Suz12 targets': genes identified by ChIP on chip as targets of the Polycomb protein SUZ12 [GeneID=23512] in human embryonic stem cells.
# 4 The 'adult tissue stem' module: genes coordinately up-regulated in a compendium of adult tissue stem cells.
# 5 Genes having at least one occurence of the motif ACTGTGA in their 3' untranslated region. The motif represents putative target (that is, seed match) of human mature miRNAs hsa-miR-27a and hsa-miR-27b (v7.1 miRBase).
# 6 Genes containing one or more binding sites for UniProt:O15525 (MAFG) in their promoter regions (TSS -1000,+100 bp) as identified by GTRD version 20.06 ChIP-seq harmonization.
#   pval        padj       log2err   ES         NES       size
# 1 0.006235055 0.06235055 0.4070179 -0.8899058 -1.593066 16
# 2 0.010384937 0.09078952 0.3807304  0.7888536  1.504499 16
# 3 0.002856450 0.07426771 0.4317077  0.7565117  1.609581 26
# 4 0.010475714 0.09078952 0.3807304  0.7654812  1.532718 19
# 5 0.006172517 0.01851755 0.4070179  0.7914666  1.517202 17
# 6 0.002768658 0.09136570 0.4317077 -0.8908226 -1.619861 17
#   leadingEdge
# 1 ENSMUSG00000063063, ENSMUSG00000029381, ENSMUSG00000015354
# 2 ENSMUSG00000038872, ENSMUSG00000033981, ENSMUSG00000056258, ENSMUSG00000066687, ENSMUSG00000020709, ENSMUSG00000035131
# 3 ENSMUSG00000029088, ENSMUSG00000038872, ENSMUSG00000033981, ENSMUSG00000056258, ENSMUSG00000066687, ENSMUSG00000020709, ENSMUSG00000031137, ENSMUSG00000020704, ENSMUSG00000035131
# 4 ENSMUSG00000032076, ENSMUSG00000033981, ENSMUSG00000019899, ENSMUSG00000048332, ENSMUSG00000024304
# 5 ENSMUSG00000032076, ENSMUSG00000025932, ENSMUSG00000036019, ENSMUSG00000020122
# 6 ENSMUSG00000063063, ENSMUSG00000015354, ENSMUSG00000021136

# %%
combined_gost_seurat_formatted = qs::qread('_targets/objects/combined_gost_seurat_formatted')
combined_gost_seurat_formatted %>% write_csv('combined_gost_seurat_formatted.csv')
split_data_to_excel(combined_gost_seurat_formatted, "outputs/gprofiler_seurat")
combined_gost_seurat_formatted %>% head
# Out:
#   tag
# 1 a1_Tany__Astrocytes___all.obob5v5__v__all.obob14vBL6___fgf1_grouping.neg_vs_none
# 2 a1_Tany__Astrocytes___all.obob5v5__v__all.obob14vBL6___fgf1_grouping.neg_vs_none
# 3 a1_Tany__Astrocytes___all.obob5v5__v__all.obob14vBL6___fgf1_grouping.neg_vs_none
# 4 a1_Tany__Astrocytes___all.obob5v5__v__all.obob14vBL6___fgf1_grouping.neg_vs_none
# 5 a1_Tany__Astrocytes___all.obob5v5__v__all.obob14vBL6___fgf1_grouping.neg_vs_none
# 6 a1_Tany__Astrocytes___all.obob5v5__v__all.obob14vBL6___fgf1_grouping.neg_vs_none
#   data_day cluster             fgf1_day fgf1_comparison bl6_day bl6_comparison
# 1 all      a1_Tany__Astrocytes all      obob5v5         all     obob14vBL6
# 2 all      a1_Tany__Astrocytes all      obob5v5         all     obob14vBL6
# 3 all      a1_Tany__Astrocytes all      obob5v5         all     obob14vBL6
# 4 all      a1_Tany__Astrocytes all      obob5v5         all     obob14vBL6
# 5 all      a1_Tany__Astrocytes all      obob5v5         all     obob14vBL6
# 6 all      a1_Tany__Astrocytes all      obob5v5         all     obob14vBL6
#   grouping      cells_a cells_b ⋯ recall      term_id    source
# 1 fgf1_grouping neg     none    ⋯ 0.012648221 GO:0007399 GO:BP
# 2 fgf1_grouping neg     none    ⋯ 0.009796718 GO:0048731 GO:BP
# 3 fgf1_grouping neg     none    ⋯ 0.008471074 GO:0007275 GO:BP
# 4 fgf1_grouping neg     none    ⋯ 0.007100210 GO:0048856 GO:BP
# 5 fgf1_grouping neg     none    ⋯ 0.006762717 GO:0032502 GO:BP
# 6 fgf1_grouping neg     none    ⋯ 0.009389671 GO:0009653 GO:BP
#   term_name                          effective_domain_size source_order
# 1 nervous system development         27334                  2985
# 2 system development                 27334                 13811
# 3 multicellular organism development 27334                  2887
# 4 anatomical structure development   27334                 13923
# 5 developmental process              27334                  8073
# 6 anatomical structure morphogenesis 27334                  3664
#   parents
# 1 GO:0048731
# 2 GO:0007275, GO:0048856
# 3 GO:0032501, GO:0048856
# 4 GO:0032502
# 5 GO:0008150
# 6 GO:0032502, GO:0048856
#   evidence_codes
# 1 IEA,IDA IMP IEA,IGI IBA,IMP IGI,IDA,IMP,IMP IBA,IMP ISO IEA,IDA IBA IEA,IMP IEA,IEA,IDA IMP IBA,IDA IMP IGI ISO IBA,IGI,ISO,IBA,IDA IMP IGI ISO IEA,IMP IGI ISO IBA IEA,IMP,IMP,IMP IBA,IGI IEA,IMP,ISO,IMP IGI IBA,IEA,IBA,IDA IMP IGI ISO IBA IEA,ISO,IMP IEA,IEA,IMP ISS ISO IEA
# 2 IMP IBA,IEA,IDA IMP ISO IEA,IGI IBA,IMP IGI,IDA IMP ISS ISO IEA,IMP,IEA,IBA NAS IEA,IEA,IMP ISS ISO IBA IEA,IMP IGI ISO IEA,IEA,IDA IBA IEA,IMP IEA,IEA,IDA IMP IBA,IDA IMP IGI ISO IBA,IGI,ISO,IMP IGI IBA,IDA IMP IGI ISO IEA,IMP IGI ISO IBA IEA,IMP,IMP,IMP IBA,IEA,IGI IEA,IMP IGI,ISO,IMP IGI IBA,IEA,IEA,ISS ISO IBA IEA,IBA,IDA IMP IGI ISO IBA IC IEA,ISO IEA,IMP IEA,IEA,IMP ISS ISO IEA
# 3 IMP IBA,IEA,IDA IMP ISO IEA,IGI IBA IEA,IDA IMP IGI IEA,IDA IMP ISS ISO IEA,IMP,IEA,IBA NAS IEA,IEA,IMP ISS ISO IBA IEA,IMP IGI ISO IEA,IEA,IDA IBA IEA,IMP,IMP IEA,IEA,IDA IMP IBA,IDA IMP IGI ISO IBA,IGI,ISO,IMP IGI IBA,IDA IMP IGI ISO IEA,IMP IGI ISO IBA IEA,IMP,IMP,IMP IBA,IEA,IGI IEA,IMP IGI,ISO,IMP IGI IBA,IEA,IEA,ISS ISO IBA IEA,IBA,IDA IMP IGI ISO IBA IC IEA,ISO IEA,IMP IEA,IEA,IMP ISS ISO IEA
# 4 IMP IBA,IEA,IDA IMP ISO IEA,IGI IBA IC IEA,IDA IMP IGI IBA IEA,IDA IMP ISS ISO IEA,IMP,IEA,IBA NAS IEA,IEA,IMP ISS ISO IBA IEA,IMP IGI ISO IEA,IEA,IDA IBA IEA,IMP IBA IEA,IMP IEA,IBA IEA,IDA IMP IBA,IDA IMP IGI ISO IBA,IGI,
ENSMUSG00000025810,ENSMUSG00000037852,ENSMUSG00000024076,ENSMUSG00000029381,ENSMUSG00000063063
# 6 ENSMUSG00000020354,ENSMUSG00000032076,ENSMUSG00000019899,ENSMUSG00000025932,ENSMUSG00000066687,ENSMUSG00000004328,ENSMUSG00000030223,ENSMUSG00000020122,ENSMUSG00000021340,ENSMUSG00000010461,ENSMUSG00000031137,ENSMUSG00000053166,ENSMUSG00000024304,ENSMUSG00000021466,ENSMUSG00000036053,ENSMUSG00000015222,ENSMUSG00000005360,ENSMUSG00000032186,ENSMUSG00000066392,ENSMUSG00000027684,ENSMUSG00000029765,ENSMUSG00000053702,ENSMUSG00000025810,ENSMUSG00000037852,ENSMUSG00000029381,ENSMUSG00000063063
#   gene_ids
# 1 Zfhx3,Cadm1,Lama2,Eya1,Zbtb16,Asic2,Ptpro,Egfr,Brinp3,Fgf13,Cdh22,Mdga2,Cdh2,Dzip1l,Fnbp1,Mertk,Ptch1,Map2,Slc1a3,Suz12,Cables1,Nrxn3,Mecom,Ntm,Plxna4,Ncam2,Cadm2,Nrp1,Cpe,Vit,Shroom3,Ctnna2
# 2 Sgcd,Zfhx3,Cadm1,Lama2,Eya1,Zbtb16,Asic2,Hif3a,Adap2,Deptor,Ptpro,Egfr,Gpld1,Brinp3,Fgf13,Cdh22,Mdga2,Cdh2,Dzip1l,Fnbp1,Mertk,Ptch1,Map2,Slc1a3,Suz12,Cables1,A2m,Nrxn3,Mecom,Ntm,Plxna4,Ncam2,Smoc1,Nebl,Cadm2,Nrp1,Cpe,Vit,Shroom3,Ctnna2
# 3 Sgcd,Zfhx3,Cadm1,Lama2,Eya1,Zbtb16,Asic2,Hif3a,Adap2,Deptor,Ptpro,Egfr,Gpld1,Brinp3,Eya4,Fgf13,Cdh22,Mdga2,Cdh2,Dzip1l,Fnbp1,Mertk,Ptch1,Map2,Slc1a3,Suz12,Cables1,A2m,Nrxn3,Mecom,Ntm,Plxna4,Ncam2,Smoc1,Nebl,Cadm2,Nrp1,Cpe,Vit,Shroom3,Ctnna2
# 4 Sgcd,Zfhx3,Cadm1,Lama2,Eya1,Zbtb16,Asic2,Hif3a,Adap2,Deptor,Ptpro,Egfr,Gpld1,Brinp3,Eya4,Fgf13,Cdh22,Mdga2,Cdh2,Dzip1l,Fnbp1,Mertk,Ptch1,Fmnl2,Map2,Slc1a3,Suz12,Tmod2,Cables1,Nox3,A2m,Nrxn3,Mecom,Ntm,Plxna4,Ncam2,Smoc1,Nebl,Cadm2,Nrp1,Cpe,Vit,Shroom3,Ctnna2
# 5 Sgcd,Zfhx3,Cadm1,Lama2,Eya1,Zbtb16,Asic2,Hif3a,Adap2,Deptor,Ptpro,Egfr,Gpld1,Brinp3,Lrmda,Eya4,Fgf13,Cdh22,Mdga2,Cdh2,Dzip1l,Zhx3,Fnbp1,Mertk,Ptch1,Fmnl2,Map2,Slc1a3,Suz12,Tmod2,Cables1,Nox3,A2m,Nrxn3,Mecom,Ntm,Plxna4,Ncam2,Smoc1,Nebl,Cadm2,Nrp1,Cpe,Vit,Shroom3,Ctnna2
# 6 Sgcd,Cadm1,Lama2,Eya1,Zbtb16,Hif3a,Ptpro,Egfr,Gpld1,Eya4,Fgf13,Cdh22,Cdh2,Ptch1,Fmnl2,Map2,Slc1a3,Tmod2,Nrxn3,Mecom,Plxna4,Nebl,Nrp1,Cpe,Shroom3,Ctnna2

# %%
input_dir <- "outputs/plots/deg_summary/"
output_dir <- "outputs/plots_seurat/"

# create the output directory if it does not exist
if (!dir.exists(output_dir)) {
  dir.create(output_dir, recursive = TRUE)
}

# define the regular expression to extract the relevant parts of the tag
tag_regex <- "___(\\w+)\\.?(\\w+)?__v__(\\w+)\\.?(\\w+)?___"

# loop through the PDF files in the input directory and copy them to the output directory with the new subfolder structure
pdf_files <- list.files(input_dir, pattern = "*.pdf", full.names = TRUE)
for (pdf_file in pdf_files) {
  file_name <- basename(pdf_file)
  tag_match <- str_match(file_name, tag_regex)
  fgf1_day <- tag_match[[2]]
  fgf1_comparison <- tag_match[[3]]
  bl6_day <- tag_match[[4]]
  bl6_comparison <- tag_match[[5]]
  subfolder_name <- paste0(fgf1_day, ".", fgf1_comparison, "__v__", bl6_day, ".", bl6_comparison)
  subfolder_path <- file.path(output_dir, subfolder_name)
  if (!dir.exists(subfolder_path)) {
    dir.create(subfolder_path, recursive = TRUE)
  }
  new_file_path <- file.path(subfolder_path, file_name)
  file.copy(pdf_file, new_file_path)
}

# %%
all_restored_summary = qs::qread('_targets/objects/all_restored_summary')
# Split the tibble by the 'comparison' column
split_data <- split(all_restored_summary, all_restored_summary$comparison)

dir.create("outputs/restored_summaries", recursive = TRUE)

# Write out a file for each split
walk(split_data, ~ {
  comparison_name <- unique(.x$comparison)
  file_name <- paste0("outputs/restored_summaries/restored_summary_", comparison_name, ".xlsx")
  write_xlsx(.x, file_name)
})
# Out:
# Warning message in dir.create("outputs/restored_summaries", recursive = TRUE):
# “'outputs/restored_summaries' already exists”

# %%
process_combined_da_results = function(da_results_all){
    da_summary = da_results_all %>%
    group_by(labels, polarity) %>%
    summarise(n = n()) %>%
    arrange(desc(labels))

    da_label_groups = da_results_all %>%
    group_by(labels) %>%
    summarise(n_group = n()) %>%
    arrange(desc(labels))

    da_summary = merge(da_summary, da_label_groups)

    da_summary = da_summary %>% mutate(pct_group = n/n_group)

    da_summary_sum = da_summary %>% 
      filter(polarity == 'none') %>%
      mutate(pct_group_changed = (n_group - n)/n_group) %>%
      select(-c(polarity, pct_group, n)) %>%
      arrange(desc(pct_group_changed), desc(n_group))

    da_results_all$labels = da_summary_sum %>% arrange(pct_group_changed, n_group) %>% pull(labels) %>% factor(da_results_all$labels, levels=.)
    da_results_all
}

input_dir <- "_targets/objects"
output_dir <- "outputs/milo_DAbeeswarms/"
dir.create(output_dir, recursive = TRUE)
da_results_files <- list.files(input_dir, pattern = "combined_da_results", full.names = TRUE)
for (da_results_file in da_results_files) {
    file_name = basename(da_results_file)
    da_results = qs::qread(da_results_file) %>% process_combined_da_results
    my_plot = miloR::plotDAbeeswarm(da_results, group.by='labels')
    plot_path = paste0(output_dir, "DAbeeswarm_", file_name, '.pdf')
    ggsave(plot_path, plot = my_plot, width = 10, height = 30)
}
# Out:
# Warning message in dir.create(output_dir, recursive = TRUE):
# “'outputs/milo_DAbeeswarms' already exists”
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.
# `summarise()` has grouped output by 'labels'. You can override using the
# `.groups` argument.

# %%
combined_gost_seurat_formatted %>%
filter(fgf1_day == 'Day5') %>%
filter(cluster == 'Agrp') %>%
filter(cells_b == 'rest')
# Out:
#      tag
# 1    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 2    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 3    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 4    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 5    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 6    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 7    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 8    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 9    Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 10   Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 11   Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 12   Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 13   Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 14   Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 15   Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 16   Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 17   Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 18   Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 19   Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 20   Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 21   Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 22   Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 23   Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 24   Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 25   Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 26   Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 27   Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 28   Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 29   Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# 30   Agrp___Day14.obob14v14__v__Day14.obobBL6d14___fgf1_grouping.neg_vs_rest
# ⋮    ⋮
# 6224 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6225 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6226 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6227 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6228 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6229 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6230 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6231 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6232 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6233 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6234 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6235 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6236 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6237 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6238 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6239 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6240 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6241 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6242 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6243 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6244 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6245 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6246 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6247 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6248 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6249 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6250 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6251 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6252 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
# 6253 Agrp___Day14.obob14v14__v__Day14.obobBL6d14___restored_grouping.neg_restored_vs_rest
#      data_day cluster fgf1_day fgf1_comparison bl6_day bl6_comparison
# 1    all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 2    all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 3    all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 4    all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 5    all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6    all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 7    all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 8    all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 9    all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 10   all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 11   all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 12   all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 13   all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 14   all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 15   all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 16   all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 17   all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 18   all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 19   all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 20   all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 21   all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 22   all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 23   all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 24   all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 25   all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 26   all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 27   all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 28   all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 29   all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 30   all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# ⋮    ⋮        ⋮       ⋮        ⋮               ⋮       ⋮
# 6224 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6225 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6226 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6227 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6228 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6229 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6230 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6231 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6232 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6233 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6234 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6235 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6236 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6237 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6238 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6239 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6240 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6241 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6242 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6243 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6244 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6245 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6246 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6247 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6248 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6249 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6250 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6251 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6252 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
# 6253 all      Agrp    Day14    obob14v14       Day14   obobBL6d14
#      grouping          cells_a      cells_b ⋯ recall     term_id     source
# 1    fgf1_grouping     neg          rest    ⋯ 0.06927593 GO:0007399  GO:BP
# 2    fgf1_grouping     neg          rest    ⋯ 0.05540705 GO:0048731  GO:BP
# 3    fgf1_grouping     neg          rest    ⋯ 0.05007182 GO:0007275  GO:BP
# 4    fgf1_grouping     neg          rest    ⋯ 0.07482630 GO:0022008  GO:BP
# 5    fgf1_grouping     neg          rest    ⋯ 0.07786634 GO:0048699  GO:BP
# 6    fgf1_grouping     neg          rest    ⋯ 0.07845659 GO:0030182  GO:BP
# 7    fgf1_grouping     neg          rest    ⋯ 0.04335260 GO:0048856  GO:BP
# 8    fgf1_grouping     neg          rest    ⋯ 0.08372828 GO:0048666  GO:BP
# 9    fgf1_grouping     neg          rest    ⋯ 0.08828829 GO:0031175  GO:BP
# 10   fgf1_grouping     neg          rest    ⋯ 0.05487053 GO:0065008  GO:BP
# 11   fgf1_grouping     neg          rest    ⋯ 0.12617702 GO:0050808  GO:BP
# 12   fgf1_grouping     neg          rest    ⋯ 0.05669178 GO:0009653  GO:BP
# 13   fgf1_grouping     neg          rest    ⋯ 0.09899749 GO:0034330  GO:BP
# 14   fgf1_grouping     neg          rest    ⋯ 0.04034960 GO:0032502  GO:BP
# 15   fgf1_grouping     neg          rest    ⋯ 0.06919780 GO:0120036  GO:BP
# 16   fgf1_grouping     neg          rest    ⋯ 0.06830437 GO:0030030  GO:BP
# 17   fgf1_grouping     neg          rest    ⋯ 0.03274293 GO:0050794  GO:BP
# 18   fgf1_grouping     neg          rest    ⋯ 0.04980414 GO:0010646  GO:BP
# 19   fgf1_grouping     neg          rest    ⋯ 0.03165971 GO:0050789  GO:BP
# 20   fgf1_grouping     neg          rest    ⋯ 0.04957983 GO:0023051  GO:BP
# 21   fgf1_grouping     neg          rest    ⋯ 0.03114612 GO:0065007  GO:BP
# 22   fgf1_grouping     neg          rest    ⋯ 0.05178366 GO:0035556  GO:BP
# 23   fgf1_grouping     neg          rest    ⋯ 0.08695652 GO:0032989  GO:BP
# 24   fgf1_grouping     neg          rest    ⋯ 0.09187750 GO:0032990  GO:BP
# 25   fgf1_grouping     neg          rest    ⋯ 0.05292376 GO:0050793  GO:BP
# 26   fgf1_grouping     neg          rest    ⋯ 0.07824427 GO:0000902  GO:BP
# 27   fgf1_grouping     neg          rest    ⋯ 0.09442060 GO:0048812  GO:BP
# 28   fgf1_grouping     neg          rest    ⋯ 0.09305556 GO:0048858  GO:BP
# 29   fgf1_grouping     neg          rest    ⋯ 0.09243697 GO:0120039  GO:BP
# 30   fgf1_grouping     neg          rest    ⋯ 0.03674746 GO:0007154  GO:BP
# ⋮    ⋮                 ⋮            ⋮       ⋱ ⋮          ⋮           ⋮
# 6224 restored_grouping neg_restored rest    ⋯ 0.02221482 TF:M09692   TF
# 6225 restored_grouping neg_restored rest    ⋯ 0.02372696 TF:M00939   TF
# 6226 restored_grouping neg_restored rest    ⋯ 0.02365184 TF:M00084   TF
# 6227 restored_grouping neg_restored rest    ⋯ 0.02294264 TF:M01816   TF
# 6228 restored_grouping neg_restored rest    ⋯ 0.02213280 TF:M03944_1 TF
# 6229 restored_grouping neg_restored rest    ⋯ 0.03590664 TF:M02742_1 TF
# 6230 restored_grouping neg_restored rest    ⋯ 0.03087587 TF:M01241_1 TF
# 6231 restored_grouping neg_restored rest    ⋯ 0.02200440 TF:M07041_1 TF
# 6232 restored_grouping neg_restored rest    ⋯ 0.01488079 TF:M00378   TF
# 6233 restored_grouping neg_restored rest    ⋯ 0.02544472 TF:M07387   TF
# 6234 restored_grouping neg_restored rest    ⋯ 0.02768730 TF:M02913_1 TF
# 6235 restored_grouping neg_restored rest    ⋯ 0.02710843 TF:M01588_1 TF
# 6236 restored_grouping neg_restored rest    ⋯ 0.01571258 TF:M00143   TF
# 6237 restored_grouping neg_restored rest    ⋯ 0.04588910 TF:M01253_1 TF
# 6238 restored_grouping neg_restored rest    ⋯ 0.03696498 TF:M10277_1 TF
# 6239 restored_grouping neg_restored rest    ⋯ 0.02753196 TF:M10280   TF
# 6240 restored_grouping neg_restored rest    ⋯ 0.01848163 TF:M01981_1 TF
# 6241 restored_grouping neg_restored rest    ⋯ 0.03739316 TF:M01002   TF
# 6242 restored_grouping neg_restored rest    ⋯ 0.02298468 TF:M00431   TF
# 6243 restored_grouping neg_restored rest    ⋯ 0.02319718 TF:M06457   TF
# 6244 restored_grouping neg_restored rest    ⋯ 0.02030769 TF:M07297   TF
# 6245 restored_grouping neg_restored rest    ⋯ 0.01718582 TF:M00450   TF
# 6246 restored_grouping neg_restored rest    ⋯ 0.02252252 TF:M00235   TF
# 6247 restored_grouping neg_restored rest    ⋯ 0.02104198 TF:M10254   TF
# 6248 restored_grouping neg_restored rest    ⋯ 0.01933475 TF:M10233_1 TF
# 6249 restored_grouping neg_restored rest    ⋯ 0.02262931 TF:M00005_1 TF
# 6250 restored_grouping neg_restored rest    ⋯ 0.03052867 TF:M00325   TF
# 6251 restored_grouping neg_restored rest    ⋯ 0.03330920 TF:M03553   TF
# 6252 restored_grouping neg_restored rest    ⋯ 0.02074529 TF:M02834   TF
# 6253 restored_grouping neg_restored rest    ⋯ 0.02672247 TF:M10254_1 TF
#      term_name
# 1    nervous system development
# 2    system development
# 3    multicellular organism development
# 4    neurogenesis
# 5    generation of neurons
# 6    neuron differentiation
# 7    anatomical structure development
# 8    neuron development
# 9    neuron projection development
# 10   regulation of biological quality
# 11   synapse organization
# 12   anatomical structure morphogenesis
# 13   cell junction organization
# 14   developmental process
# 15   plasma membrane bounded cell projection organization
# 16   cell projection organization
# 17   regulation of cellular process
# 18   regulation of cell communication
# 19   regulation of biological process
# 20   regulation of signaling
# 21   biological regulation
# 22   intracellular signal transduction
# 23   cellular component morphogenesis
# 24   cell part morphogenesis
# 25   regulation of developmental process
# 26   cell morphogenesis
# 27   neuron projection morphogenesis
# 28   cell projection morphogenesis
# 29   plasma membrane bounded cell projection morphogenesis
# 30   cell communication
# ⋮    ⋮
# 6224 Factor: GKLF; motif: WGGGYGKGGCCN
# 6225 Factor: E2F; motif: TTTSGCGSG
# 6226 Factor: MZF-1; motif: KNGNKAGGGGNAA
# 6227 Factor: ZBP89; motif: YCCYCCCCCM
# 6228 Factor: Zfp740; motif: NCCCCCCCAC; match class: 1
# 6229 Factor: E2F-2; motif: NNNANGGCGCGCNNN; match class: 1
# 6230 Factor: BEN; motif: CWGCGAYA; match class: 1
# 6231 Factor: HDAC1; motif: KGCARGGTC; match class: 1
# 6232 Factor: Pax-4; motif: NNNNNYCACCCB
# 6233 Factor: LRF; motif: NGKGGGTSNCN
# 6234 Factor: SP100; motif: NNCGTCGNNTAAWNN; match class: 1
# 6235 Factor: GKLF; motif: GCCMCRCCCNNN; match class: 1
# 6236 Factor: Pax-5; motif: BCNNNRNGCANBGNTGNRTAGCSGCHNB
# 6237 Factor: CNOT3; motif: GGCCGCGSSS; match class: 1
# 6238 Factor: Klf15; motif: RGGGMGGRGNNGGGGGNGG; match class: 1
# 6239 Factor: BTEB2; motif: NGGGSWGGGNGGGGC
# 6240 Factor: ELK-1; motif: ACCGGAWRTN; match class: 1
# 6241 Factor: DEAF1; motif: RNNNRTTCGGGNRTTTCCGGRRNKN
# 6242 Factor: E2F-1; motif: TTTSGCGS
# 6243 Factor: ZN451; motif: CKGGGGGG
# 6244 Factor: MAZ; motif: CCCTCCCYCYN
# 6245 Factor: Zic3; motif: NGGGKGGTC
# 6246 Factor: AhR:Arnt; motif: KNNKNNTYGCGTGCMS
# 6247 Factor: GLI; motif: NSTGGGTGGTCY
# 6248 Factor: Pet-1; motif: GCNGGAAGYG; match class: 1
# 6249 Factor: AP-4; motif: WGARYCAGCTGYGGNCNK; match class: 1
# 6250 Factor: NRSE; motif: TTYAGCWCCDCGGASAGYRCC
# 6251 Factor: KLF3; motif: CCMCACCCNG
# 6252 Factor: Zfp740; motif: NNNCCCCCCCCMNNNN
# 6253 Factor: GLI; motif: NSTGGGTGGTCY; match class: 1
#      effective_domain_size source_order parents
# 1    27205                  2969        GO:0048731
# 2    27205                 13728        GO:0007275, GO:0048856
# 3    27205                  2871        GO:0032501, GO:0048856
# 4    27205                  6923        GO:0007399, GO:0030154
# 5    27205                 13696        GO:0022008
# 6    27205                  7062        GO:0030154, GO:0048699
# 7    27205                 13840        GO:0032502
# 8    27205                 13664        GO:0030182, GO:0048468
# 9    27205                  7471        GO:0048666, GO:0120036
# 10   27205                 16812        GO:0065007
# 11   27205                 14020        GO:0034330
# 12   27205                  3648        GO:0032502, GO:0048856
# 13   27205                  9021        GO:0016043
# 14   27205                  8032        GO:0008150
# 15   27205                 20549        GO:0030030
# 16   27205                  7016        GO:0016043
# 17   27205                 14008        GO:0009987, GO:0050789
# 18   27205                  4388        GO:0007154, GO:0050794
# 19   27205                 14004        GO:0008150, GO:0065007
# 20   27205                  7001        GO:0023052, GO:0050789
# 21   27205                 16811        GO:0008150
# 22   27205                  9589        GO:0007165
# 23   27205                  8397        GO:0009653, GO:0016043, GO:0048869
# 24   27205                  8398        GO:0032989
# 25   27205                 14007        GO:0032502, GO:0050789
# 26   27205                   249        GO:0009653
# 27   27205                 13798        GO:0031175, GO:0120039
# 28   27205                 13842        GO:0000902, GO:0030030, GO:0032990
# 29   27205                 20550        GO:0048858
# 30   27205                  2781        GO:0009987
# ⋮    ⋮                     ⋮            ⋮
# 6224 21866                 1344         TF:M00000
# 6225 21866                  780         TF:M00000
# 6226 21866                 2224         TF:M00000
# 6227 21866                 3776         TF:M00000
# 6228 21866                 4051         TF:M03944
# 6229 21866                  743         TF:M02742
# 6230 21866                  281         TF:M01241
# 6231 21866                 1425         TF:M07041
# 6232 21866                 2614         TF:M00000
# 6233 21866                 1928         TF:M00000
# 6234 21866                 3219         TF:M02913
# 6235 21866                 1343         TF:M01588
# 6236 21866                 2622         TF:M00000
# 6237 21866                  509         TF:M01253
# 6238 21866                 1827         TF:M10277
# 6239 21866                  328         TF:M00000
# 6240 21866                  911         TF:M01981
# 6241 21866                  638         TF:M00000
# 6242 21866                  740         TF:M00000
# 6243 21866                 4150         TF:M00000
# 6244 21866                 2022         TF:M00000
# 6245 21866                 4126         TF:M00000
# 6246 21866                    6         TF:M00000
# 6247 21866                 1356         TF:M00000
# 6248 21866                 2671         TF:M10233
# 6249 21866                  123         TF:M00005
# 6250 21866                 2458         TF:M00000
# 6251 21866                 1836         TF:M00000
# 6252 21866                 4046         TF:M00000
# 6253 21866                 1357         TF:M10254
#      evidence_codes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 1    IEA,IDA IMP IBA,IDA,IMP ISO IEA,ISO,IDA IMP IBA,IDA ISS ISO IEA,IDA IMP IBA,IEA,IMP IEA,ISO IBA,IDA ISS IBA,IEP,ISO IEA,IMP,IMP ISO,IGI,IDA IMP ISO IEA,ISO,IEA,IDA IMP,IEA,ISO IEA,IMP IEA,IDA IMP IGI ISO IEA,IDA,IGI ISO,IGI,IDA IMP ISO,IEA,IDA,IMP IBA,IMP,IDA IBA IEA,IMP,IGI,IDA IMP IGI ISS ISO IBA IEA,IMP,IGI,IMP IGI ISO,IMP ISO IBA IEA,IMP IGI ISO,IMP ISO IEA,ISS ISO IEA,ISS IEA,IMP IGI ISO IBA IEA,IMP,IEA,IDA IMP IBA,IMP,ISO IEA,IGI,ISO IEA,IMP IGI,IMP IBA,IEA,IEA,IMP,IEA,IMP IBA,IMP,IMP,IGI,IMP,IS